# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
import _pickle as cPickle
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "F:/DinoRunTutorial-master (1)/DinoRunTutorial-master/chromedriver.exe"
loss_file_path = "./Object2/loss_df.csv"
actions_file_path = "./Object2/actions_df.csv"
q_value_file_path = "./Object2/q_values.csv"
scores_file_path = "./Object2/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('Object2'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('Object2' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                new_q=np.argmax(q)
                max_Q = epsilon*(sum(q)/len(q))+(1-epsilon)*new_q  # chosing index with maximum q value
                print(new_q)
                
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./Object2/loss_df.csv",index=False)
            scores_df.to_csv("./Object2/scores_df.csv",index=False)
            actions_df.to_csv("./Object2/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 18000 / STATE explore / EPSILON 0.08211889899997268 / ACTION 0 / REWARD 0.1 / Q_MAX  20.652012 / Loss  0.17089301347732544
# 0
# fps: 0.2523085703863422
# TIMESTEP 18001 / STATE explore / EPSILON 0.08211789999997268 / ACTION 0 / REWARD 0.1 / Q_MAX  11.521734 / Loss  0.14950916171073914
# 0
# fps: 6.89727845291148
# TIMESTEP 18002 / STATE explore / EPSILON 0.08211690099997268 / ACTION 0 / REWARD 0.1 / Q_MAX  13.135135 / Loss  0.08257408440113068
# 0
# fps: 5.174939512870402
# TIMESTEP 18003 / STATE explore / EPSILON 0.08211590199997268 / ACTION 0 / REWARD 0.1 / Q_MAX  9.512302 / Loss  0.3345215916633606
# 0
# fps: 7.443334315294819
# TIMESTEP 18004 / STATE explore / EPSILON 0.08211490299997268 / ACTION 0 / REWARD 0.1 / Q_MAX  0.036021717 / Loss  0.5101460814476013
# 0
# fps: 6.80787409754324
# TIMESTEP 18005 / STATE explore / EPSILON 0.08211390399997268 / ACTION 0 / REWARD 0.1 / Q_MAX  3.9480264 / Loss  0.16185492277145386
# 0
# fps: 6.720424025777383
# TIMESTEP 18006 / STATE explore / EPSILON 0.08211290499997267 / ACTION 0 / REWARD 0.1 / Q_MAX  18.220516 / Loss  0.09722428768873215
# 0
# fps: 6.774151556213792
# TIMESTEP 18007 / STATE explore / EPSILON 0.08211190599997267 / ACTION 0 / REWARD 0.1 / Q_MAX  7.237711 / Loss  0.19995516538619995
# 0
# fps: 6.805455002717766
# TIMESTEP 18008 / STATE explore / EPSILON 0.08211090699997267 / ACTION 0 / REWARD 0.1 / Q_MAX  6.243846 / Loss  0.11580391228199005
# 0
# fps: 7.400559324575875
# TIMESTEP 18009 / STATE explore / EPSILON 0.08210990799997267 / ACTION 0 / REWARD 0.1 / Q_MAX  13.392715 / Loss  0.08553806692361832
# 0
# fps: 6.888782314489373
# TIMESTEP 18010 / STATE explore / EPSILON 0.08210890899997267 / ACTION 0 / REWARD 0.1 / Q_MAX  9.180138 / Loss  0.14543737471103668
# ----------Random Action----------
# fps: 6.1835256515156205
# TIMESTEP 18011 / STATE explore / EPSILON 0.08210790999997267 / ACTION 0 / REWARD 0.1 / Q_MAX  6.3616056 / Loss  1.2517573833465576
# 0
# fps: 7.123006458471671
# TIMESTEP 18012 / STATE explore / EPSILON 0.08210691099997267 / ACTION 0 / REWARD 0.1 / Q_MAX  6.780912 / Loss  0.07314038276672363
# 0
# fps: 7.0822214342400756
# TIMESTEP 18013 / STATE explore / EPSILON 0.08210591199997266 / ACTION 0 / REWARD 0.1 / Q_MAX  12.692098 / Loss  0.26535311341285706
# 0
# fps: 7.160741357881366
# TIMESTEP 18014 / STATE explore / EPSILON 0.08210491299997266 / ACTION 0 / REWARD 0.1 / Q_MAX  12.90435 / Loss  0.06973198056221008
# 0
# fps: 7.065483219430186
# TIMESTEP 18015 / STATE explore / EPSILON 0.08210391399997266 / ACTION 0 / REWARD 0.1 / Q_MAX  12.901093 / Loss  0.2188166081905365
# ----------Random Action----------
# fps: 5.343327885079641
# TIMESTEP 18016 / STATE explore / EPSILON 0.08210291499997266 / ACTION 1 / REWARD 0.1 / Q_MAX  18.314917 / Loss  0.6773933172225952
# 0
# fps: 7.014554899045561
# TIMESTEP 18017 / STATE explore / EPSILON 0.08210191599997266 / ACTION 0 / REWARD 0.1 / Q_MAX  12.756353 / Loss  0.24712038040161133
# 0
# fps: 5.953344716825
# TIMESTEP 18018 / STATE explore / EPSILON 0.08210091699997266 / ACTION 0 / REWARD 0.1 / Q_MAX  10.362543 / Loss  0.14982904493808746
# 0
# fps: 7.147952227736271
# TIMESTEP 18019 / STATE explore / EPSILON 0.08209991799997265 / ACTION 0 / REWARD 0.1 / Q_MAX  18.560349 / Loss  0.2174292504787445
# 0
# fps: 6.826744445330594
# TIMESTEP 18020 / STATE explore / EPSILON 0.08209891899997265 / ACTION 0 / REWARD 0.1 / Q_MAX  7.123292 / Loss  0.5374613404273987
# 0
# fps: 7.14051702857532
# TIMESTEP 18021 / STATE explore / EPSILON 0.08209791999997265 / ACTION 0 / REWARD 0.1 / Q_MAX  17.599272 / Loss  0.13357937335968018
# 0
# fps: 6.96871780898391
# TIMESTEP 18022 / STATE explore / EPSILON 0.08209692099997265 / ACTION 0 / REWARD 0.1 / Q_MAX  22.150972 / Loss  0.1380375623703003
# 0
# fps: 6.982035130708074
# TIMESTEP 18023 / STATE explore / EPSILON 0.08209592199997265 / ACTION 0 / REWARD 0.1 / Q_MAX  27.956682 / Loss  0.1464949995279312
# 0
# fps: 6.477239419654232
# TIMESTEP 18024 / STATE explore / EPSILON 0.08209492299997265 / ACTION 0 / REWARD 0.1 / Q_MAX  13.1879015 / Loss  0.19091612100601196
# 0
# fps: 6.9981229571517005
# TIMESTEP 18025 / STATE explore / EPSILON 0.08209392399997265 / ACTION 0 / REWARD 0.1 / Q_MAX  13.214712 / Loss  0.11909348517656326
# 0
# fps: 5.5504219417658165
# TIMESTEP 18026 / STATE explore / EPSILON 0.08209292499997264 / ACTION 0 / REWARD 0.1 / Q_MAX  6.169298 / Loss  0.7461668848991394
# 0
# fps: 7.178978789828976
# TIMESTEP 18027 / STATE explore / EPSILON 0.08209192599997264 / ACTION 0 / REWARD 0.1 / Q_MAX  13.264496 / Loss  0.05046011880040169
# 0
# fps: 6.952119380818911
# TIMESTEP 18028 / STATE explore / EPSILON 0.08209092699997264 / ACTION 0 / REWARD 0.1 / Q_MAX  22.734455 / Loss  3.320859909057617
# 0
# fps: 7.267935892926146
# TIMESTEP 18029 / STATE explore / EPSILON 0.08208992799997264 / ACTION 0 / REWARD 0.1 / Q_MAX  6.0311723 / Loss  0.10084722936153412
# 0
# fps: 6.786405520633611
# TIMESTEP 18030 / STATE explore / EPSILON 0.08208892899997264 / ACTION 0 / REWARD 0.1 / Q_MAX  10.280412 / Loss  0.37654948234558105
# 0
# fps: 6.682083945361912
# TIMESTEP 18031 / STATE explore / EPSILON 0.08208792999997264 / ACTION 0 / REWARD 0.1 / Q_MAX  12.818884 / Loss  0.08421126008033752
# 0
# fps: 6.695438683868578
# TIMESTEP 18032 / STATE explore / EPSILON 0.08208693099997263 / ACTION 0 / REWARD 0.1 / Q_MAX  23.31151 / Loss  0.059984467923641205
# 0
# fps: 6.7313929153774055
# TIMESTEP 18033 / STATE explore / EPSILON 0.08208593199997263 / ACTION 0 / REWARD 0.1 / Q_MAX  12.602443 / Loss  0.06382711231708527
# 0
# fps: 6.021454002526703
# TIMESTEP 18034 / STATE explore / EPSILON 0.08208493299997263 / ACTION 0 / REWARD 0.1 / Q_MAX  11.349193 / Loss  0.2002663016319275
# 0
# fps: 7.334314901534254
# TIMESTEP 18035 / STATE explore / EPSILON 0.08208393399997263 / ACTION 0 / REWARD 0.1 / Q_MAX  8.846117 / Loss  0.05385340005159378
# 0
# fps: 7.276497264138177
# TIMESTEP 18036 / STATE explore / EPSILON 0.08208293499997263 / ACTION 0 / REWARD 0.1 / Q_MAX  19.37139 / Loss  0.5803499221801758
# 0
# fps: 7.142851790607337
# TIMESTEP 18037 / STATE explore / EPSILON 0.08208193599997263 / ACTION 0 / REWARD 0.1 / Q_MAX  12.185861 / Loss  0.11801982671022415
# 0
# fps: 7.0420663289719565
# TIMESTEP 18038 / STATE explore / EPSILON 0.08208093699997263 / ACTION 0 / REWARD 0.1 / Q_MAX  19.34854 / Loss  0.1640487164258957
# 0
# fps: 6.7895034179774445
# TIMESTEP 18039 / STATE explore / EPSILON 0.08207993799997262 / ACTION 0 / REWARD 0.1 / Q_MAX  12.747447 / Loss  0.2838887572288513
# 0
# fps: 6.653506559431463
# TIMESTEP 18040 / STATE explore / EPSILON 0.08207893899997262 / ACTION 0 / REWARD 0.1 / Q_MAX  19.311678 / Loss  0.09105943143367767
# 0
# fps: 5.4325296086375365
# TIMESTEP 18041 / STATE explore / EPSILON 0.08207793999997262 / ACTION 0 / REWARD 0.1 / Q_MAX  13.941512 / Loss  0.5381221175193787
# 0
# fps: 7.120841807890421
# TIMESTEP 18042 / STATE explore / EPSILON 0.08207694099997262 / ACTION 0 / REWARD 0.1 / Q_MAX  22.392853 / Loss  0.1296887844800949
# 0
# fps: 7.091237698169159
# TIMESTEP 18043 / STATE explore / EPSILON 0.08207594199997262 / ACTION 0 / REWARD 0.1 / Q_MAX  10.164488 / Loss  0.02754216268658638
# 0
# fps: 7.159164653973185
# TIMESTEP 18044 / STATE explore / EPSILON 0.08207494299997262 / ACTION 0 / REWARD 0.1 / Q_MAX  8.164051 / Loss  0.049173835664987564
# ----------Random Action----------
# fps: 7.61166965497717
# TIMESTEP 18045 / STATE explore / EPSILON 0.08207394399997262 / ACTION 0 / REWARD 0.1 / Q_MAX  13.07102 / Loss  0.22214540839195251
# 0
# fps: 7.052177962952688
# TIMESTEP 18046 / STATE explore / EPSILON 0.08207294499997261 / ACTION 0 / REWARD 0.1 / Q_MAX  18.915852 / Loss  0.10071273148059845
# 0
# fps: 7.139568967424886
# TIMESTEP 18047 / STATE explore / EPSILON 0.08207194599997261 / ACTION 0 / REWARD 0.1 / Q_MAX  20.971903 / Loss  0.09766502678394318
# 0
# fps: 7.376974041757611
# TIMESTEP 18048 / STATE explore / EPSILON 0.08207094699997261 / ACTION 0 / REWARD 0.1 / Q_MAX  13.38045 / Loss  0.10140255838632584
# 0
# fps: 5.5437093900511245
# TIMESTEP 18049 / STATE explore / EPSILON 0.08206994799997261 / ACTION 0 / REWARD 0.1 / Q_MAX  22.779207 / Loss  0.18333664536476135
# 0
# fps: 6.738671289460704
# TIMESTEP 18050 / STATE explore / EPSILON 0.08206894899997261 / ACTION 0 / REWARD 0.1 / Q_MAX  10.4980545 / Loss  0.4602298140525818
# 0
# fps: 7.363931640138068
# TIMESTEP 18051 / STATE explore / EPSILON 0.0820679499999726 / ACTION 0 / REWARD 0.1 / Q_MAX  8.789552 / Loss  0.052687302231788635
# 0
# fps: 6.831080629899202
# TIMESTEP 18052 / STATE explore / EPSILON 0.0820669509999726 / ACTION 0 / REWARD 0.1 / Q_MAX  10.5789795 / Loss  0.5769277811050415
# ----------Random Action----------
# fps: 7.063472335896478
# TIMESTEP 18053 / STATE explore / EPSILON 0.0820659519999726 / ACTION 0 / REWARD 0.1 / Q_MAX  13.310949 / Loss  6.291820526123047
# 0
# fps: 7.099856286573713
# TIMESTEP 18054 / STATE explore / EPSILON 0.0820649529999726 / ACTION 0 / REWARD 0.1 / Q_MAX  7.592062 / Loss  0.47139772772789
# 0
# fps: 7.006317590028163
# TIMESTEP 18055 / STATE explore / EPSILON 0.0820639539999726 / ACTION 0 / REWARD 0.1 / Q_MAX  13.577353 / Loss  0.07798435539007187
# 0
# fps: 7.1318358810426625
# TIMESTEP 18056 / STATE explore / EPSILON 0.0820629549999726 / ACTION 0 / REWARD 0.1 / Q_MAX  12.962765 / Loss  0.1458704173564911
# 0
# fps: 6.0643403881243545
# TIMESTEP 18057 / STATE explore / EPSILON 0.0820619559999726 / ACTION 0 / REWARD 0.1 / Q_MAX  12.881995 / Loss  0.09836426377296448
# 0
# fps: 6.9440624622317735
# TIMESTEP 18058 / STATE explore / EPSILON 0.0820609569999726 / ACTION 0 / REWARD 0.1 / Q_MAX  18.389498 / Loss  0.26027292013168335
# 0
# fps: 6.934074854145347
# TIMESTEP 18059 / STATE explore / EPSILON 0.0820599579999726 / ACTION 0 / REWARD 0.1 / Q_MAX  16.41248 / Loss  0.10225998610258102
# 0
# fps: 7.047615847080845
# TIMESTEP 18060 / STATE explore / EPSILON 0.08205895899997259 / ACTION 0 / REWARD 0.1 / Q_MAX  18.417875 / Loss  0.05728607624769211
# 0
# fps: 6.744132274460179
# TIMESTEP 18061 / STATE explore / EPSILON 0.08205795999997259 / ACTION 0 / REWARD 0.1 / Q_MAX  11.653849 / Loss  0.04687231779098511
# 0
# fps: 7.2179192422594545
# TIMESTEP 18062 / STATE explore / EPSILON 0.08205696099997259 / ACTION 0 / REWARD 0.1 / Q_MAX  12.386056 / Loss  2.3511157035827637
# ----------Random Action----------
# fps: 5.3070622845032105
# TIMESTEP 18063 / STATE explore / EPSILON 0.08205596199997259 / ACTION 1 / REWARD 0.1 / Q_MAX  10.56008 / Loss  0.05533785745501518
# 0
# fps: 5.517869946101396
# TIMESTEP 18064 / STATE explore / EPSILON 0.08205496299997259 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7004633 / Loss  0.8270308375358582
# 0
# fps: 7.027094404868013
# TIMESTEP 18065 / STATE explore / EPSILON 0.08205396399997258 / ACTION 0 / REWARD 0.1 / Q_MAX  18.60799 / Loss  0.055033110082149506
# 0
# fps: 6.7596859246270675
# TIMESTEP 18066 / STATE explore / EPSILON 0.08205296499997258 / ACTION 0 / REWARD 0.1 / Q_MAX  8.24871 / Loss  0.35983002185821533
# 0
# fps: 6.754580429884839
# TIMESTEP 18067 / STATE explore / EPSILON 0.08205196599997258 / ACTION 0 / REWARD 0.1 / Q_MAX  12.39703 / Loss  1.1079543828964233
# 0
# fps: 7.201733510530527
# TIMESTEP 18068 / STATE explore / EPSILON 0.08205096699997258 / ACTION 0 / REWARD 0.1 / Q_MAX  13.969312 / Loss  0.18664194643497467
# 0
# fps: 7.062639760756527
# TIMESTEP 18069 / STATE explore / EPSILON 0.08204996799997258 / ACTION 0 / REWARD 0.1 / Q_MAX  11.680364 / Loss  0.3120046854019165
# 0
# fps: 7.00543992944961
# TIMESTEP 18070 / STATE explore / EPSILON 0.08204896899997258 / ACTION 0 / REWARD 0.1 / Q_MAX  11.8063345 / Loss  0.7531251907348633
# 0
# fps: 6.281785191697382
# TIMESTEP 18071 / STATE explore / EPSILON 0.08204796999997258 / ACTION 0 / REWARD 0.1 / Q_MAX  9.726869 / Loss  0.3548121154308319
# 0
# fps: 6.415035238841034
# TIMESTEP 18072 / STATE explore / EPSILON 0.08204697099997257 / ACTION 0 / REWARD 0.1 / Q_MAX  22.749065 / Loss  0.2408020943403244
# 0
# fps: 7.244398692855613
# TIMESTEP 18073 / STATE explore / EPSILON 0.08204597199997257 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9982333 / Loss  0.29670271277427673
# 0
# fps: 7.210139533764352
# TIMESTEP 18074 / STATE explore / EPSILON 0.08204497299997257 / ACTION 0 / REWARD 0.1 / Q_MAX  13.027569 / Loss  0.1618177890777588
# 0
# fps: 6.71091861240934
# TIMESTEP 18075 / STATE explore / EPSILON 0.08204397399997257 / ACTION 0 / REWARD 0.1 / Q_MAX  22.545752 / Loss  7.044580936431885
# 0
# fps: 7.1595190462859915
# TIMESTEP 18076 / STATE explore / EPSILON 0.08204297499997257 / ACTION 0 / REWARD 0.1 / Q_MAX  24.781473 / Loss  0.5584421157836914
# 0
# fps: 7.112136046624015
# TIMESTEP 18077 / STATE explore / EPSILON 0.08204197599997257 / ACTION 0 / REWARD 0.1 / Q_MAX  14.336063 / Loss  0.4855789244174957
# 0
# fps: 7.001534082847151
# TIMESTEP 18078 / STATE explore / EPSILON 0.08204097699997256 / ACTION 0 / REWARD 0.1 / Q_MAX  9.291852 / Loss  0.05616236850619316
# 0
# fps: 6.662246669515204
# TIMESTEP 18079 / STATE explore / EPSILON 0.08203997799997256 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9770257 / Loss  0.03761405870318413
# 0
# fps: 6.595284257533945
# TIMESTEP 18080 / STATE explore / EPSILON 0.08203897899997256 / ACTION 0 / REWARD 0.1 / Q_MAX  20.238335 / Loss  0.1555364429950714
# 0
# fps: 6.980408342597709
# TIMESTEP 18081 / STATE explore / EPSILON 0.08203797999997256 / ACTION 0 / REWARD 0.1 / Q_MAX  5.5260363 / Loss  0.2739894390106201
# 0
# fps: 6.825977847287546
# TIMESTEP 18082 / STATE explore / EPSILON 0.08203698099997256 / ACTION 0 / REWARD 0.1 / Q_MAX  13.2689085 / Loss  0.8648328185081482
# 0
# fps: 7.135390776381085
# TIMESTEP 18083 / STATE explore / EPSILON 0.08203598199997256 / ACTION 0 / REWARD 0.1 / Q_MAX  22.634983 / Loss  0.018860340118408203
# 0
# fps: 6.944970808068431
# TIMESTEP 18084 / STATE explore / EPSILON 0.08203498299997256 / ACTION 0 / REWARD 0.1 / Q_MAX  9.790828 / Loss  0.40975630283355713
# 0
# fps: 6.7575295721185915
# TIMESTEP 18085 / STATE explore / EPSILON 0.08203398399997255 / ACTION 0 / REWARD 0.1 / Q_MAX  9.572303 / Loss  0.18559254705905914
# 0
# fps: 7.60095177170527
# TIMESTEP 18086 / STATE explore / EPSILON 0.08203298499997255 / ACTION 0 / REWARD 0.1 / Q_MAX  14.399012 / Loss  0.20136374235153198
# 0
# fps: 5.536304118268215
# TIMESTEP 18087 / STATE explore / EPSILON 0.08203198599997255 / ACTION 0 / REWARD 0.1 / Q_MAX  13.477456 / Loss  0.1706215739250183
# 0
# fps: 7.464236902050114
# TIMESTEP 18088 / STATE explore / EPSILON 0.08203098699997255 / ACTION 0 / REWARD 0.1 / Q_MAX  14.498013 / Loss  0.13359710574150085
# 0
# fps: 7.376416172772199
# TIMESTEP 18089 / STATE explore / EPSILON 0.08202998799997255 / ACTION 0 / REWARD 0.1 / Q_MAX  14.550988 / Loss  0.23068587481975555
# 0
# fps: 7.06095142538728
# TIMESTEP 18090 / STATE explore / EPSILON 0.08202898899997255 / ACTION 0 / REWARD 0.1 / Q_MAX  5.521855 / Loss  0.2143268585205078
# 0
# fps: 6.8772949299612876
# TIMESTEP 18091 / STATE explore / EPSILON 0.08202798999997254 / ACTION 0 / REWARD 0.1 / Q_MAX  22.918589 / Loss  0.33107590675354004
# 0
# fps: 6.9565240466985445
# TIMESTEP 18092 / STATE explore / EPSILON 0.08202699099997254 / ACTION 0 / REWARD 0.1 / Q_MAX  4.299657 / Loss  1.8076050281524658
# 0
# fps: 5.9111586525113555
# TIMESTEP 18093 / STATE explore / EPSILON 0.08202599199997254 / ACTION 0 / REWARD 0.1 / Q_MAX  14.506648 / Loss  2.461111068725586
# 0
# fps: 6.242722189229778
# TIMESTEP 18094 / STATE explore / EPSILON 0.08202499299997254 / ACTION 0 / REWARD 0.1 / Q_MAX  23.580778 / Loss  0.6336944103240967
# 0
# fps: 6.454423745141066
# TIMESTEP 18095 / STATE explore / EPSILON 0.08202399399997254 / ACTION 0 / REWARD 0.1 / Q_MAX  11.18858 / Loss  0.11498720943927765
# 0
# fps: 7.704410152038104
# TIMESTEP 18096 / STATE explore / EPSILON 0.08202299499997254 / ACTION 0 / REWARD 0.1 / Q_MAX  15.539526 / Loss  0.03943480923771858
# 0
# fps: 6.77746824806903
# TIMESTEP 18097 / STATE explore / EPSILON 0.08202199599997254 / ACTION 0 / REWARD 0.1 / Q_MAX  14.446686 / Loss  0.12937529385089874
# 0
# fps: 7.08403960289016
# TIMESTEP 18098 / STATE explore / EPSILON 0.08202099699997253 / ACTION 0 / REWARD 0.1 / Q_MAX  14.933414 / Loss  0.1260056346654892
# 0
# fps: 6.83609076966456
# TIMESTEP 18099 / STATE explore / EPSILON 0.08201999799997253 / ACTION 0 / REWARD 0.1 / Q_MAX  14.294685 / Loss  3.737388849258423
# 0
# fps: 7.461554609141788
# TIMESTEP 18100 / STATE explore / EPSILON 0.08201899899997253 / ACTION 0 / REWARD 0.1 / Q_MAX  10.351947 / Loss  0.12756657600402832
# 0
# fps: 6.8243896486361155
# TIMESTEP 18101 / STATE explore / EPSILON 0.08201799999997253 / ACTION 0 / REWARD 0.1 / Q_MAX  25.385323 / Loss  0.23884496092796326
# 1
# fps: 6.416860708832718
# TIMESTEP 18102 / STATE explore / EPSILON 0.08201700099997253 / ACTION 0 / REWARD 0.1 / Q_MAX  16.12607 / Loss  0.12847286462783813
# 1
# fps: 7.125196633699024
# TIMESTEP 18103 / STATE explore / EPSILON 0.08201600199997253 / ACTION 0 / REWARD 0.1 / Q_MAX  24.673784 / Loss  0.23856565356254578
# 0
# fps: 6.789184709416761
# TIMESTEP 18104 / STATE explore / EPSILON 0.08201500299997252 / ACTION 0 / REWARD 0.1 / Q_MAX  24.716526 / Loss  0.2213757336139679
# 0
# fps: 7.0672570785396065
# TIMESTEP 18105 / STATE explore / EPSILON 0.08201400399997252 / ACTION 0 / REWARD 0.1 / Q_MAX  13.609979 / Loss  0.2640796899795532
# 0
# fps: 7.097933896185433
# TIMESTEP 18106 / STATE explore / EPSILON 0.08201300499997252 / ACTION 0 / REWARD 0.1 / Q_MAX  16.114012 / Loss  0.1300048828125
# 0
# fps: 6.893877483933531
# TIMESTEP 18107 / STATE explore / EPSILON 0.08201200599997252 / ACTION 0 / REWARD 0.1 / Q_MAX  11.040898 / Loss  0.6688874363899231
# 0
# fps: 6.752644755165946
# TIMESTEP 18108 / STATE explore / EPSILON 0.08201100699997252 / ACTION 0 / REWARD 0.1 / Q_MAX  12.930067 / Loss  0.016799315810203552
# 0
# fps: 7.014355475282628
# TIMESTEP 18109 / STATE explore / EPSILON 0.08201000799997252 / ACTION 0 / REWARD 0.1 / Q_MAX  15.114217 / Loss  0.07132730633020401
# 0
# fps: 5.827478026970626
# TIMESTEP 18110 / STATE explore / EPSILON 0.08200900899997252 / ACTION 0 / REWARD 0.1 / Q_MAX  15.230895 / Loss  0.11105681955814362
# ----------Random Action----------
# fps: 5.147667455820284
# TIMESTEP 18111 / STATE explore / EPSILON 0.08200800999997251 / ACTION 1 / REWARD 0.1 / Q_MAX  24.155106 / Loss  0.8699532151222229
# 0
# fps: 6.852318248652181
# TIMESTEP 18112 / STATE explore / EPSILON 0.08200701099997251 / ACTION 0 / REWARD 0.1 / Q_MAX  11.188087 / Loss  0.4143131971359253
# 0
# fps: 6.826733333984381
# TIMESTEP 18113 / STATE explore / EPSILON 0.08200601199997251 / ACTION 0 / REWARD 0.1 / Q_MAX  15.639793 / Loss  0.09048362821340561
# 0
# fps: 6.743319067386502
# TIMESTEP 18114 / STATE explore / EPSILON 0.08200501299997251 / ACTION 0 / REWARD 0.1 / Q_MAX  13.658773 / Loss  1.8827972412109375
# 0
# fps: 6.6909206926531235
# TIMESTEP 18115 / STATE explore / EPSILON 0.08200401399997251 / ACTION 0 / REWARD 0.1 / Q_MAX  12.817795 / Loss  0.2358255684375763
# 0
# fps: 7.180220047351095
# TIMESTEP 18116 / STATE explore / EPSILON 0.0820030149999725 / ACTION 0 / REWARD 0.1 / Q_MAX  24.009874 / Loss  0.15215489268302917
# 0
# fps: 5.595076049634359
# TIMESTEP 18117 / STATE explore / EPSILON 0.0820020159999725 / ACTION 0 / REWARD 0.1 / Q_MAX  17.6093 / Loss  0.2743249237537384
# 0
# fps: 6.649076584074444
# TIMESTEP 18118 / STATE explore / EPSILON 0.0820010169999725 / ACTION 0 / REWARD 0.1 / Q_MAX  16.200928 / Loss  0.3417513370513916
# 0
# fps: 7.179925056190739
# TIMESTEP 18119 / STATE explore / EPSILON 0.0820000179999725 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9740797 / Loss  0.18225090205669403
# 0
# fps: 6.933765353523665
# TIMESTEP 18120 / STATE explore / EPSILON 0.0819990189999725 / ACTION 0 / REWARD 0.1 / Q_MAX  12.039727 / Loss  0.020076794549822807
# 0
# fps: 6.581096644417457
# TIMESTEP 18121 / STATE explore / EPSILON 0.0819980199999725 / ACTION 0 / REWARD 0.1 / Q_MAX  12.895134 / Loss  0.16926248371601105
# 0
# fps: 7.015822091379729
# TIMESTEP 18122 / STATE explore / EPSILON 0.0819970209999725 / ACTION 0 / REWARD 0.1 / Q_MAX  15.603261 / Loss  1.6926332712173462
# 0
# fps: 7.38857865605964
# TIMESTEP 18123 / STATE explore / EPSILON 0.0819960219999725 / ACTION 0 / REWARD 0.1 / Q_MAX  11.653606 / Loss  0.6215004920959473
# 0
# fps: 6.938709202470227
# TIMESTEP 18124 / STATE explore / EPSILON 0.0819950229999725 / ACTION 0 / REWARD 0.1 / Q_MAX  17.277468 / Loss  1.6026661396026611
# 0
# fps: 5.767348229632176
# TIMESTEP 18125 / STATE explore / EPSILON 0.08199402399997249 / ACTION 0 / REWARD 0.1 / Q_MAX  11.430939 / Loss  0.17692166566848755
# 0
# fps: 7.427819542214548
# TIMESTEP 18126 / STATE explore / EPSILON 0.08199302499997249 / ACTION 0 / REWARD 0.1 / Q_MAX  27.452793 / Loss  0.14764317870140076
# ----------Random Action----------
# fps: 5.445083163267956
# TIMESTEP 18127 / STATE explore / EPSILON 0.08199202599997249 / ACTION 1 / REWARD 0.1 / Q_MAX  0.38068658 / Loss  1.294499397277832
# 0
# fps: 7.14076016173654
# TIMESTEP 18128 / STATE explore / EPSILON 0.08199102699997249 / ACTION 0 / REWARD 0.1 / Q_MAX  14.902989 / Loss  0.45169979333877563
# 0
# fps: 6.853068380299755
# TIMESTEP 18129 / STATE explore / EPSILON 0.08199002799997249 / ACTION 0 / REWARD 0.1 / Q_MAX  16.944254 / Loss  0.3736970126628876
# 0
# fps: 6.843809607725079
# TIMESTEP 18130 / STATE explore / EPSILON 0.08198902899997249 / ACTION 0 / REWARD 0.1 / Q_MAX  30.494358 / Loss  0.3595808744430542
# 0
# fps: 6.935760397925707
# TIMESTEP 18131 / STATE explore / EPSILON 0.08198802999997248 / ACTION 0 / REWARD 0.1 / Q_MAX  13.207833 / Loss  0.6058664321899414
# 0
# fps: 5.511909408334024
# TIMESTEP 18132 / STATE explore / EPSILON 0.08198703099997248 / ACTION 0 / REWARD 0.1 / Q_MAX  30.097555 / Loss  0.18950682878494263
# 0
# fps: 6.764231837966943
# TIMESTEP 18133 / STATE explore / EPSILON 0.08198603199997248 / ACTION 0 / REWARD 0.1 / Q_MAX  38.559998 / Loss  0.15023553371429443
# 0
# fps: 7.145699346984253
# TIMESTEP 18134 / STATE explore / EPSILON 0.08198503299997248 / ACTION 0 / REWARD 0.1 / Q_MAX  28.947203 / Loss  9.166681289672852
# 0
# fps: 6.948756223026648
# TIMESTEP 18135 / STATE explore / EPSILON 0.08198403399997248 / ACTION 0 / REWARD 0.1 / Q_MAX  29.990702 / Loss  0.25607889890670776
# 0
# fps: 7.080487866638531
# TIMESTEP 18136 / STATE explore / EPSILON 0.08198303499997248 / ACTION 0 / REWARD 0.1 / Q_MAX  26.28932 / Loss  0.33253681659698486
# 0
# fps: 6.886407145319914
# TIMESTEP 18137 / STATE explore / EPSILON 0.08198203599997247 / ACTION 0 / REWARD 0.1 / Q_MAX  11.688546 / Loss  0.20765598118305206
# ----------Random Action----------
# fps: 5.473556183404347
# TIMESTEP 18138 / STATE explore / EPSILON 0.08198103699997247 / ACTION 1 / REWARD 0.1 / Q_MAX  16.10502 / Loss  0.08307705074548721
# 0
# fps: 6.483827932853806
# TIMESTEP 18139 / STATE explore / EPSILON 0.08198003799997247 / ACTION 0 / REWARD 0.1 / Q_MAX  6.901983 / Loss  2.5222151279449463
# 0
# fps: 5.851387755386751
# TIMESTEP 18140 / STATE explore / EPSILON 0.08197903899997247 / ACTION 0 / REWARD 0.1 / Q_MAX  26.918467 / Loss  0.06000417098402977
# 0
# fps: 7.185189372720529
# TIMESTEP 18141 / STATE explore / EPSILON 0.08197803999997247 / ACTION 0 / REWARD 0.1 / Q_MAX  8.923322 / Loss  4.227588653564453
# ----------Random Action----------
# fps: 5.506496643696148
# TIMESTEP 18142 / STATE explore / EPSILON 0.08197704099997247 / ACTION 1 / REWARD 0.1 / Q_MAX  4.290427 / Loss  0.21287404000759125
# 0
# fps: 6.834197186678681
# TIMESTEP 18143 / STATE explore / EPSILON 0.08197604199997247 / ACTION 0 / REWARD 0.1 / Q_MAX  28.2888 / Loss  0.43474018573760986
# 0
# fps: 6.983267346184456
# TIMESTEP 18144 / STATE explore / EPSILON 0.08197504299997246 / ACTION 0 / REWARD 0.1 / Q_MAX  16.483862 / Loss  0.15406203269958496
# 0
# fps: 6.850673012689323
# TIMESTEP 18145 / STATE explore / EPSILON 0.08197404399997246 / ACTION 0 / REWARD 0.1 / Q_MAX  4.2235208 / Loss  0.3451504409313202
# 0
# fps: 6.8691741538622795
# TIMESTEP 18146 / STATE explore / EPSILON 0.08197304499997246 / ACTION 0 / REWARD 0.1 / Q_MAX  16.612194 / Loss  0.23618118464946747
# 0
# fps: 5.251282051282051
# TIMESTEP 18147 / STATE explore / EPSILON 0.08197204599997246 / ACTION 0 / REWARD 0.1 / Q_MAX  16.766376 / Loss  0.3486853539943695
# 0
# fps: 7.02495234968797
# TIMESTEP 18148 / STATE explore / EPSILON 0.08197104699997246 / ACTION 0 / REWARD 0.1 / Q_MAX  12.751119 / Loss  0.15170545876026154
# 0
# fps: 7.070497562422878
# TIMESTEP 18149 / STATE explore / EPSILON 0.08197004799997246 / ACTION 0 / REWARD 0.1 / Q_MAX  13.8361435 / Loss  0.07464947551488876
# 0
# fps: 6.883175024123829
# TIMESTEP 18150 / STATE explore / EPSILON 0.08196904899997245 / ACTION 0 / REWARD 0.1 / Q_MAX  15.636683 / Loss  0.8730106353759766
# 0
# fps: 6.9499536869035845
# TIMESTEP 18151 / STATE explore / EPSILON 0.08196804999997245 / ACTION 0 / REWARD 0.1 / Q_MAX  12.366376 / Loss  1.2092128992080688
# 0
# fps: 6.896416556777039
# TIMESTEP 18152 / STATE explore / EPSILON 0.08196705099997245 / ACTION 0 / REWARD 0.1 / Q_MAX  26.791397 / Loss  0.07697274535894394
# 0
# fps: 6.985930881938996
# TIMESTEP 18153 / STATE explore / EPSILON 0.08196605199997245 / ACTION 0 / REWARD 0.1 / Q_MAX  16.998863 / Loss  0.4334481954574585
# 0
# fps: 5.704704339831021
# TIMESTEP 18154 / STATE explore / EPSILON 0.08196505299997245 / ACTION 0 / REWARD 0.1 / Q_MAX  26.470287 / Loss  2.2611639499664307
# 0
# fps: 6.787415871433588
# TIMESTEP 18155 / STATE explore / EPSILON 0.08196405399997245 / ACTION 0 / REWARD 0.1 / Q_MAX  15.289536 / Loss  4.660058975219727
# 0
# fps: 7.546739069806775
# TIMESTEP 18156 / STATE explore / EPSILON 0.08196305499997245 / ACTION 0 / REWARD 0.1 / Q_MAX  16.546339 / Loss  0.46428197622299194
# 0
# fps: 7.040364178994245
# TIMESTEP 18157 / STATE explore / EPSILON 0.08196205599997244 / ACTION 0 / REWARD 0.1 / Q_MAX  36.30782 / Loss  0.705180823802948
# 0
# fps: 7.366169009186847
# TIMESTEP 18158 / STATE explore / EPSILON 0.08196105699997244 / ACTION 0 / REWARD 0.1 / Q_MAX  10.2417345 / Loss  0.4532340466976166
# 0
# fps: 6.974268245435212
# TIMESTEP 18159 / STATE explore / EPSILON 0.08196005799997244 / ACTION 0 / REWARD 0.1 / Q_MAX  14.578745 / Loss  6.273584365844727
# 0
# fps: 7.011283436583743
# TIMESTEP 18160 / STATE explore / EPSILON 0.08195905899997244 / ACTION 0 / REWARD 0.1 / Q_MAX  13.944266 / Loss  0.19953016936779022
# 0
# fps: 6.732754386246529
# TIMESTEP 18161 / STATE explore / EPSILON 0.08195805999997244 / ACTION 0 / REWARD 0.1 / Q_MAX  11.633662 / Loss  4.513568878173828
# 0
# fps: 5.548241332328002
# TIMESTEP 18162 / STATE explore / EPSILON 0.08195706099997244 / ACTION 0 / REWARD 0.1 / Q_MAX  14.59433 / Loss  0.8621352910995483
# 0
# fps: 7.5360541895376105
# TIMESTEP 18163 / STATE explore / EPSILON 0.08195606199997243 / ACTION 0 / REWARD 0.1 / Q_MAX  21.23137 / Loss  6.051736831665039
# ----------Random Action----------
# fps: 7.182199573277441
# TIMESTEP 18164 / STATE explore / EPSILON 0.08195506299997243 / ACTION 0 / REWARD 0.1 / Q_MAX  29.755964 / Loss  0.11203821748495102
# 0
# fps: 6.848212230209954
# TIMESTEP 18165 / STATE explore / EPSILON 0.08195406399997243 / ACTION 0 / REWARD 0.1 / Q_MAX  15.141755 / Loss  0.23490914702415466
# 0
# fps: 6.851489935867907
# TIMESTEP 18166 / STATE explore / EPSILON 0.08195306499997243 / ACTION 0 / REWARD 0.1 / Q_MAX  15.469628 / Loss  0.547139585018158
# 0
# fps: 7.185891044157303
# TIMESTEP 18167 / STATE explore / EPSILON 0.08195206599997243 / ACTION 0 / REWARD 0.1 / Q_MAX  14.677685 / Loss  3.9077658653259277
# 0
# fps: 6.450939348031714
# TIMESTEP 18168 / STATE explore / EPSILON 0.08195106699997243 / ACTION 0 / REWARD 0.1 / Q_MAX  18.791706 / Loss  0.23996126651763916
# ----------Random Action----------
# fps: 7.078133965155289
# TIMESTEP 18169 / STATE explore / EPSILON 0.08195006799997243 / ACTION 0 / REWARD 0.1 / Q_MAX  15.087717 / Loss  0.09554481506347656
# 0
# fps: 5.93998136278278
# TIMESTEP 18170 / STATE explore / EPSILON 0.08194906899997242 / ACTION 0 / REWARD 0.1 / Q_MAX  6.387571 / Loss  0.49097809195518494
# 0
# fps: 7.1667612141260735
# TIMESTEP 18171 / STATE explore / EPSILON 0.08194806999997242 / ACTION 0 / REWARD 0.1 / Q_MAX  15.33944 / Loss  0.5949082970619202
# 0
# fps: 6.932138064166386
# TIMESTEP 18172 / STATE explore / EPSILON 0.08194707099997242 / ACTION 0 / REWARD 0.1 / Q_MAX  25.229418 / Loss  0.11014394462108612
# 0
# fps: 6.847720285839764
# TIMESTEP 18173 / STATE explore / EPSILON 0.08194607199997242 / ACTION 0 / REWARD 0.1 / Q_MAX  25.118504 / Loss  0.4122231602668762
# 0
# fps: 6.48692655797135
# TIMESTEP 18174 / STATE explore / EPSILON 0.08194507299997242 / ACTION 0 / REWARD 0.1 / Q_MAX  15.009295 / Loss  0.19078338146209717
# 0
# fps: 6.86058996143038
# TIMESTEP 18175 / STATE explore / EPSILON 0.08194407399997242 / ACTION 0 / REWARD 0.1 / Q_MAX  24.448315 / Loss  0.17988646030426025
# ----------Random Action----------
# fps: 5.33407263936067
# TIMESTEP 18176 / STATE explore / EPSILON 0.08194307499997242 / ACTION 1 / REWARD 0.1 / Q_MAX  18.635437 / Loss  0.2566797435283661
# 0
# fps: 5.3230923478161545
# TIMESTEP 18177 / STATE explore / EPSILON 0.08194207599997241 / ACTION 0 / REWARD 0.1 / Q_MAX  29.786598 / Loss  0.10317721217870712
# 0
# fps: 6.824089861901105
# TIMESTEP 18178 / STATE explore / EPSILON 0.08194107699997241 / ACTION 0 / REWARD 0.1 / Q_MAX  16.315048 / Loss  0.3495331406593323
# 0
# fps: 6.9324015873619285
# TIMESTEP 18179 / STATE explore / EPSILON 0.08194007799997241 / ACTION 0 / REWARD 0.1 / Q_MAX  10.455838 / Loss  2.1139395236968994
# 0
# fps: 6.993303988261972
# TIMESTEP 18180 / STATE explore / EPSILON 0.08193907899997241 / ACTION 0 / REWARD 0.1 / Q_MAX  14.4478445 / Loss  0.43104565143585205
# 0
# fps: 6.938456677491022
# TIMESTEP 18181 / STATE explore / EPSILON 0.08193807999997241 / ACTION 0 / REWARD 0.1 / Q_MAX  11.77428 / Loss  0.19590415060520172
# 0
# fps: 6.984779147765499
# TIMESTEP 18182 / STATE explore / EPSILON 0.0819370809999724 / ACTION 0 / REWARD 0.1 / Q_MAX  15.525776 / Loss  0.2886461913585663
# 0
# fps: 6.439806604852689
# TIMESTEP 18183 / STATE explore / EPSILON 0.0819360819999724 / ACTION 0 / REWARD 0.1 / Q_MAX  22.22079 / Loss  0.20027682185173035
# ----------Random Action----------
# fps: 4.728603043718933
# TIMESTEP 18184 / STATE explore / EPSILON 0.0819350829999724 / ACTION 1 / REWARD 0.1 / Q_MAX  16.492632 / Loss  0.17488670349121094
# 0
# fps: 7.220851840374617
# TIMESTEP 18185 / STATE explore / EPSILON 0.0819340839999724 / ACTION 0 / REWARD 0.1 / Q_MAX  9.377202 / Loss  1.3995598554611206
# 0
# fps: 7.010123328447439
# TIMESTEP 18186 / STATE explore / EPSILON 0.0819330849999724 / ACTION 0 / REWARD 0.1 / Q_MAX  10.356838 / Loss  0.1953451931476593
# 0
# fps: 7.066554571446382
# TIMESTEP 18187 / STATE explore / EPSILON 0.0819320859999724 / ACTION 0 / REWARD 0.1 / Q_MAX  15.490131 / Loss  0.24231332540512085
# 0
# fps: 6.9351755246061835
# TIMESTEP 18188 / STATE explore / EPSILON 0.0819310869999724 / ACTION 0 / REWARD 0.1 / Q_MAX  22.2278 / Loss  2.238165855407715
# ----------Random Action----------
# fps: 7.4936556884408825
# TIMESTEP 18189 / STATE explore / EPSILON 0.0819300879999724 / ACTION 0 / REWARD 0.1 / Q_MAX  14.230108 / Loss  0.4001386761665344
# 0
# fps: 6.74357927231217
# TIMESTEP 18190 / STATE explore / EPSILON 0.0819290889999724 / ACTION 0 / REWARD 0.1 / Q_MAX  21.360434 / Loss  0.2510361075401306
# 0
# fps: 7.046005704935879
# TIMESTEP 18191 / STATE explore / EPSILON 0.08192808999997239 / ACTION 0 / REWARD 0.1 / Q_MAX  14.790247 / Loss  0.22094982862472534
# 0
# fps: 5.604204050928555
# TIMESTEP 18192 / STATE explore / EPSILON 0.08192709099997239 / ACTION 0 / REWARD 0.1 / Q_MAX  13.373705 / Loss  0.537964940071106
# 0
# fps: 7.329201272819091
# TIMESTEP 18193 / STATE explore / EPSILON 0.08192609199997239 / ACTION 0 / REWARD 0.1 / Q_MAX  32.9005 / Loss  0.7638172507286072
# 0
# fps: 7.222107621233593
# TIMESTEP 18194 / STATE explore / EPSILON 0.08192509299997239 / ACTION 0 / REWARD 0.1 / Q_MAX  8.00182 / Loss  0.3075878918170929
# 0
# fps: 7.099976470548405
# TIMESTEP 18195 / STATE explore / EPSILON 0.08192409399997239 / ACTION 0 / REWARD 0.1 / Q_MAX  8.163711 / Loss  0.22237572073936462
# 0
# fps: 7.141939592492823
# TIMESTEP 18196 / STATE explore / EPSILON 0.08192309499997238 / ACTION 0 / REWARD 0.1 / Q_MAX  25.559027 / Loss  0.2916111946105957
# 0
# fps: 6.640486617080361
# TIMESTEP 18197 / STATE explore / EPSILON 0.08192209599997238 / ACTION 0 / REWARD 0.1 / Q_MAX  8.767286 / Loss  0.41140106320381165
# 0
# fps: 6.880690840846753
# TIMESTEP 18198 / STATE explore / EPSILON 0.08192109699997238 / ACTION 0 / REWARD 0.1 / Q_MAX  15.053198 / Loss  0.32098388671875
# 0
# fps: 6.731490145035926
# TIMESTEP 18199 / STATE explore / EPSILON 0.08192009799997238 / ACTION 0 / REWARD 0.1 / Q_MAX  14.025748 / Loss  0.036895547062158585
# 0
# fps: 6.23818192634898
# TIMESTEP 18200 / STATE explore / EPSILON 0.08191909899997238 / ACTION 0 / REWARD 0.1 / Q_MAX  25.188828 / Loss  0.46159592270851135
# 0
# fps: 7.058432313631514
# TIMESTEP 18201 / STATE explore / EPSILON 0.08191809999997238 / ACTION 0 / REWARD 0.1 / Q_MAX  22.91209 / Loss  0.02233874797821045
# 0
# fps: 7.170400053338166
# TIMESTEP 18202 / STATE explore / EPSILON 0.08191710099997238 / ACTION 0 / REWARD 0.1 / Q_MAX  11.44505 / Loss  1.501042127609253
# 0
# fps: 6.773374846988376
# TIMESTEP 18203 / STATE explore / EPSILON 0.08191610199997237 / ACTION 0 / REWARD 0.1 / Q_MAX  13.53551 / Loss  2.285843849182129
# 0
# fps: 6.8756151377154415
# TIMESTEP 18204 / STATE explore / EPSILON 0.08191510299997237 / ACTION 0 / REWARD 0.1 / Q_MAX  11.521404 / Loss  2.2329399585723877
# 0
# fps: 6.901863730158992
# TIMESTEP 18205 / STATE explore / EPSILON 0.08191410399997237 / ACTION 0 / REWARD 0.1 / Q_MAX  21.116793 / Loss  0.19275836646556854
# 0
# fps: 6.657244982826378
# TIMESTEP 18206 / STATE explore / EPSILON 0.08191310499997237 / ACTION 0 / REWARD 0.1 / Q_MAX  10.968491 / Loss  0.15226463973522186
# 0
# fps: 5.528219024974034
# TIMESTEP 18207 / STATE explore / EPSILON 0.08191210599997237 / ACTION 0 / REWARD 0.1 / Q_MAX  13.065361 / Loss  0.10077378898859024
# 0
# fps: 7.106580820060996
# TIMESTEP 18208 / STATE explore / EPSILON 0.08191110699997237 / ACTION 0 / REWARD 0.1 / Q_MAX  15.362045 / Loss  0.4094599783420563
# 0
# fps: 7.223886355181394
# TIMESTEP 18209 / STATE explore / EPSILON 0.08191010799997236 / ACTION 0 / REWARD 0.1 / Q_MAX  13.724922 / Loss  2.1949450969696045
# 0
# fps: 7.014320284030951
# TIMESTEP 18210 / STATE explore / EPSILON 0.08190910899997236 / ACTION 0 / REWARD 0.1 / Q_MAX  17.748644 / Loss  0.16236063838005066
# 0
# fps: 6.941315874833679
# TIMESTEP 18211 / STATE explore / EPSILON 0.08190810999997236 / ACTION 0 / REWARD 0.1 / Q_MAX  15.782829 / Loss  0.5364112854003906
# 0
# fps: 6.740447305703895
# TIMESTEP 18212 / STATE explore / EPSILON 0.08190711099997236 / ACTION 0 / REWARD 0.1 / Q_MAX  14.751427 / Loss  0.3029039800167084
# 0
# fps: 6.665973735360634
# TIMESTEP 18213 / STATE explore / EPSILON 0.08190611199997236 / ACTION 0 / REWARD 0.1 / Q_MAX  24.781258 / Loss  0.146317720413208
# 0
# fps: 6.669121692314053
# TIMESTEP 18214 / STATE explore / EPSILON 0.08190511299997236 / ACTION 0 / REWARD 0.1 / Q_MAX  15.90839 / Loss  0.11872511357069016
# 0
# fps: 6.028542230513941
# TIMESTEP 18215 / STATE explore / EPSILON 0.08190411399997236 / ACTION 0 / REWARD 0.1 / Q_MAX  14.365636 / Loss  0.1945551484823227
# 0
# fps: 7.12093852396394
# TIMESTEP 18216 / STATE explore / EPSILON 0.08190311499997235 / ACTION 0 / REWARD 0.1 / Q_MAX  15.727828 / Loss  0.16068412363529205
# 0
# fps: 6.923167325810946
# TIMESTEP 18217 / STATE explore / EPSILON 0.08190211599997235 / ACTION 0 / REWARD 0.1 / Q_MAX  11.19712 / Loss  0.11033686995506287
# 0
# fps: 7.06782871278453
# TIMESTEP 18218 / STATE explore / EPSILON 0.08190111699997235 / ACTION 0 / REWARD 0.1 / Q_MAX  8.049265 / Loss  0.258979469537735
# 0
# fps: 6.659422383817856
# TIMESTEP 18219 / STATE explore / EPSILON 0.08190011799997235 / ACTION 0 / REWARD 0.1 / Q_MAX  25.998138 / Loss  0.46177369356155396
# 0
# fps: 6.894262758557208
# TIMESTEP 18220 / STATE explore / EPSILON 0.08189911899997235 / ACTION 0 / REWARD 0.1 / Q_MAX  13.532044 / Loss  2.142775535583496
# ----------Random Action----------
# fps: 5.333007832367002
# TIMESTEP 18221 / STATE explore / EPSILON 0.08189811999997235 / ACTION 1 / REWARD 0.1 / Q_MAX  13.821177 / Loss  1.5759764909744263
# 0
# fps: 5.472856261164457
# TIMESTEP 18222 / STATE explore / EPSILON 0.08189712099997234 / ACTION 0 / REWARD 0.1 / Q_MAX  16.06898 / Loss  0.27634936571121216
# 0
# fps: 7.035510482050181
# TIMESTEP 18223 / STATE explore / EPSILON 0.08189612199997234 / ACTION 0 / REWARD 0.1 / Q_MAX  15.562296 / Loss  8.183686256408691
# 0
# fps: 7.03135886165287
# TIMESTEP 18224 / STATE explore / EPSILON 0.08189512299997234 / ACTION 0 / REWARD 0.1 / Q_MAX  25.566418 / Loss  1.3052159547805786
# 0
# fps: 7.1165043766553495
# TIMESTEP 18225 / STATE explore / EPSILON 0.08189412399997234 / ACTION 0 / REWARD 0.1 / Q_MAX  8.707377 / Loss  0.19832387566566467
# 0
# fps: 6.663463860398317
# TIMESTEP 18226 / STATE explore / EPSILON 0.08189312499997234 / ACTION 0 / REWARD 0.1 / Q_MAX  14.946879 / Loss  0.19794361293315887
# 0
# fps: 7.225068516039902
# TIMESTEP 18227 / STATE explore / EPSILON 0.08189212599997234 / ACTION 0 / REWARD 0.1 / Q_MAX  15.013003 / Loss  0.10319255292415619
# 0
# fps: 6.906648443482055
# TIMESTEP 18228 / STATE explore / EPSILON 0.08189112699997234 / ACTION 0 / REWARD 0.1 / Q_MAX  20.44556 / Loss  7.296862602233887
# 0
# fps: 6.810770434889922
# TIMESTEP 18229 / STATE explore / EPSILON 0.08189012799997233 / ACTION 0 / REWARD 0.1 / Q_MAX  14.349118 / Loss  0.21215547621250153
# 0
# fps: 6.248506887905978
# TIMESTEP 18230 / STATE explore / EPSILON 0.08188912899997233 / ACTION 0 / REWARD 0.1 / Q_MAX  18.704865 / Loss  0.17671343684196472
# 0
# fps: 7.137758627144661
# TIMESTEP 18231 / STATE explore / EPSILON 0.08188812999997233 / ACTION 0 / REWARD 0.1 / Q_MAX  27.405973 / Loss  0.638776421546936
# 0
# fps: 6.903601825684343
# TIMESTEP 18232 / STATE explore / EPSILON 0.08188713099997233 / ACTION 0 / REWARD 0.1 / Q_MAX  14.686418 / Loss  0.17780032753944397
# 0
# fps: 6.54761507059953
# TIMESTEP 18233 / STATE explore / EPSILON 0.08188613199997233 / ACTION 0 / REWARD 0.1 / Q_MAX  19.672197 / Loss  0.6763041019439697
# 0
# fps: 7.321985137133251
# TIMESTEP 18234 / STATE explore / EPSILON 0.08188513299997233 / ACTION 0 / REWARD 0.1 / Q_MAX  15.52546 / Loss  2.7346601486206055
# 0
# fps: 7.153865178006444
# TIMESTEP 18235 / STATE explore / EPSILON 0.08188413399997233 / ACTION 0 / REWARD 0.1 / Q_MAX  20.691038 / Loss  0.16420291364192963
# 0
# fps: 7.350651854266451
# TIMESTEP 18236 / STATE explore / EPSILON 0.08188313499997232 / ACTION 0 / REWARD 0.1 / Q_MAX  27.741438 / Loss  0.2518591284751892
# 0
# fps: 5.5970620889913745
# TIMESTEP 18237 / STATE explore / EPSILON 0.08188213599997232 / ACTION 0 / REWARD 0.1 / Q_MAX  15.442866 / Loss  0.49635815620422363
# 0
# fps: 7.287192566698867
# TIMESTEP 18238 / STATE explore / EPSILON 0.08188113699997232 / ACTION 0 / REWARD 0.1 / Q_MAX  13.455623 / Loss  0.5345080494880676
# 0
# fps: 7.198001043411407
# TIMESTEP 18239 / STATE explore / EPSILON 0.08188013799997232 / ACTION 0 / REWARD 0.1 / Q_MAX  32.27639 / Loss  0.19153693318367004
# 0
# fps: 6.805554383699007
# TIMESTEP 18240 / STATE explore / EPSILON 0.08187913899997232 / ACTION 0 / REWARD 0.1 / Q_MAX  19.352757 / Loss  6.4601850509643555
# 0
# fps: 7.022564674405327
# TIMESTEP 18241 / STATE explore / EPSILON 0.08187813999997232 / ACTION 0 / REWARD 0.1 / Q_MAX  10.6947775 / Loss  0.5874325037002563
# 0
# fps: 7.099796196112153
# TIMESTEP 18242 / STATE explore / EPSILON 0.08187714099997231 / ACTION 0 / REWARD 0.1 / Q_MAX  18.931665 / Loss  0.6974008679389954
# 0
# fps: 7.132320982195997
# TIMESTEP 18243 / STATE explore / EPSILON 0.08187614199997231 / ACTION 0 / REWARD 0.1 / Q_MAX  24.863638 / Loss  0.12896515429019928
# 0
# fps: 7.052438833691198
# TIMESTEP 18244 / STATE explore / EPSILON 0.08187514299997231 / ACTION 0 / REWARD 0.1 / Q_MAX  18.252851 / Loss  0.19259831309318542
# 0
# fps: 5.956794357787937
# TIMESTEP 18245 / STATE explore / EPSILON 0.08187414399997231 / ACTION 0 / REWARD 0.1 / Q_MAX  13.079409 / Loss  0.19576136767864227
# 0
# fps: 7.2693592889924155
# TIMESTEP 18246 / STATE explore / EPSILON 0.08187314499997231 / ACTION 0 / REWARD 0.1 / Q_MAX  24.246778 / Loss  0.07485661655664444
# ----------Random Action----------
# fps: 7.153072153133548
# TIMESTEP 18247 / STATE explore / EPSILON 0.0818721459999723 / ACTION 0 / REWARD 0.1 / Q_MAX  25.0756 / Loss  0.6548010110855103
# 0
# fps: 6.969262032903034
# TIMESTEP 18248 / STATE explore / EPSILON 0.0818711469999723 / ACTION 0 / REWARD 0.1 / Q_MAX  13.097246 / Loss  0.4137822985649109
# 0
# fps: 6.9812797419410675
# TIMESTEP 18249 / STATE explore / EPSILON 0.0818701479999723 / ACTION 0 / REWARD 0.1 / Q_MAX  18.21457 / Loss  0.41981518268585205
# 0
# fps: 7.457428707063775
# TIMESTEP 18250 / STATE explore / EPSILON 0.0818691489999723 / ACTION 0 / REWARD 0.1 / Q_MAX  18.183605 / Loss  0.8464908599853516
# 0
# fps: 7.047663215343099
# TIMESTEP 18251 / STATE explore / EPSILON 0.0818681499999723 / ACTION 0 / REWARD 0.1 / Q_MAX  13.170835 / Loss  0.26223474740982056
# 0
# fps: 6.862206283191922
# TIMESTEP 18252 / STATE explore / EPSILON 0.0818671509999723 / ACTION 0 / REWARD 0.1 / Q_MAX  23.816689 / Loss  0.7497426271438599
# 0
# fps: 5.787817485835088
# TIMESTEP 18253 / STATE explore / EPSILON 0.0818661519999723 / ACTION 0 / REWARD 0.1 / Q_MAX  17.955372 / Loss  2.134672164916992
# 0
# fps: 7.276825493761191
# TIMESTEP 18254 / STATE explore / EPSILON 0.0818651529999723 / ACTION 0 / REWARD 0.1 / Q_MAX  14.227017 / Loss  0.40125876665115356
# 0
# fps: 6.469366822296567
# TIMESTEP 18255 / STATE explore / EPSILON 0.0818641539999723 / ACTION 0 / REWARD 0.1 / Q_MAX  18.954462 / Loss  0.1963185966014862
# 0
# fps: 6.980071459834215
# TIMESTEP 18256 / STATE explore / EPSILON 0.08186315499997229 / ACTION 0 / REWARD 0.1 / Q_MAX  3.0115337 / Loss  0.2714325189590454
# 0
# fps: 7.055713216307374
# TIMESTEP 18257 / STATE explore / EPSILON 0.08186215599997229 / ACTION 0 / REWARD 0.1 / Q_MAX  21.357735 / Loss  0.2093026340007782
# 0
# fps: 7.037493666043618
# TIMESTEP 18258 / STATE explore / EPSILON 0.08186115699997229 / ACTION 0 / REWARD 0.1 / Q_MAX  24.337286 / Loss  0.33879077434539795
# ----------Random Action----------
# fps: 6.88863523263472
# TIMESTEP 18259 / STATE explore / EPSILON 0.08186015799997229 / ACTION 0 / REWARD 0.1 / Q_MAX  15.569637 / Loss  0.08114738762378693
# 0
# fps: 5.667649042015126
# TIMESTEP 18260 / STATE explore / EPSILON 0.08185915899997229 / ACTION 0 / REWARD 0.1 / Q_MAX  15.489194 / Loss  0.16192929446697235
# 0
# fps: 7.440218258966108
# TIMESTEP 18261 / STATE explore / EPSILON 0.08185815999997229 / ACTION 0 / REWARD 0.1 / Q_MAX  12.44299 / Loss  0.17751525342464447
# 0
# fps: 6.838029994505844
# TIMESTEP 18262 / STATE explore / EPSILON 0.08185716099997228 / ACTION 0 / REWARD 0.1 / Q_MAX  19.072922 / Loss  1.5753135681152344
# 0
# fps: 6.879866939829312
# TIMESTEP 18263 / STATE explore / EPSILON 0.08185616199997228 / ACTION 0 / REWARD 0.1 / Q_MAX  19.095852 / Loss  0.25736644864082336
# ----------Random Action----------
# fps: 7.077023276218437
# TIMESTEP 18264 / STATE explore / EPSILON 0.08185516299997228 / ACTION 0 / REWARD 0.1 / Q_MAX  19.119055 / Loss  0.11445776373147964
# 0
# fps: 6.935943907924329
# TIMESTEP 18265 / STATE explore / EPSILON 0.08185416399997228 / ACTION 0 / REWARD 0.1 / Q_MAX  24.960066 / Loss  0.5306566953659058
# 0
# fps: 7.091129798507488
# TIMESTEP 18266 / STATE explore / EPSILON 0.08185316499997228 / ACTION 0 / REWARD 0.1 / Q_MAX  14.627805 / Loss  0.5652918815612793
# 0
# fps: 6.960576189053736
# TIMESTEP 18267 / STATE explore / EPSILON 0.08185216599997228 / ACTION 0 / REWARD 0.1 / Q_MAX  10.7674465 / Loss  2.4909064769744873
# 0
# fps: 4.37454396025023
# TIMESTEP 18268 / STATE explore / EPSILON 0.08185116699997227 / ACTION 0 / REWARD 0.1 / Q_MAX  6.323643 / Loss  4.676008701324463
# 0
# fps: 8.365669334684295
# TIMESTEP 18269 / STATE explore / EPSILON 0.08185016799997227 / ACTION 0 / REWARD 0.1 / Q_MAX  8.036284 / Loss  0.36544764041900635
# 0
# fps: 7.301374870746831
# TIMESTEP 18270 / STATE explore / EPSILON 0.08184916899997227 / ACTION 0 / REWARD 0.1 / Q_MAX  22.712341 / Loss  0.36249905824661255
# 0
# fps: 7.445501247927517
# TIMESTEP 18271 / STATE explore / EPSILON 0.08184816999997227 / ACTION 0 / REWARD 0.1 / Q_MAX  16.051716 / Loss  0.09570193290710449
# ----------Random Action----------
# fps: 5.557246487224162
# TIMESTEP 18272 / STATE explore / EPSILON 0.08184717099997227 / ACTION 1 / REWARD 0.1 / Q_MAX  12.426563 / Loss  0.19145789742469788
# 0
# fps: 6.495787491327188
# TIMESTEP 18273 / STATE explore / EPSILON 0.08184617199997227 / ACTION 0 / REWARD 0.1 / Q_MAX  11.702386 / Loss  0.20745548605918884
# ----------Random Action----------
# fps: 5.048196309330663
# TIMESTEP 18274 / STATE explore / EPSILON 0.08184517299997227 / ACTION 1 / REWARD 0.1 / Q_MAX  18.352392 / Loss  0.09142303466796875
# 1
# fps: 5.739685667563
# TIMESTEP 18275 / STATE explore / EPSILON 0.08184417399997226 / ACTION 0 / REWARD 0.1 / Q_MAX  11.001877 / Loss  0.6485902070999146
# 1
# fps: 7.314196429661329
# TIMESTEP 18276 / STATE explore / EPSILON 0.08184317499997226 / ACTION 0 / REWARD 0.1 / Q_MAX  13.209129 / Loss  0.17768719792366028
# 1
# fps: 6.956847121344561
# TIMESTEP 18277 / STATE explore / EPSILON 0.08184217599997226 / ACTION 0 / REWARD 0.1 / Q_MAX  25.09384 / Loss  0.029600530862808228
# 0
# fps: 7.138195940679322
# TIMESTEP 18278 / STATE explore / EPSILON 0.08184117699997226 / ACTION 0 / REWARD 0.1 / Q_MAX  33.392326 / Loss  0.5551985502243042
# 0
# fps: 6.848547687353965
# TIMESTEP 18279 / STATE explore / EPSILON 0.08184017799997226 / ACTION 0 / REWARD 0.1 / Q_MAX  12.909039 / Loss  3.1200203895568848
# ----------Random Action----------
# fps: 6.988910865352411
# TIMESTEP 18280 / STATE explore / EPSILON 0.08183917899997226 / ACTION 0 / REWARD 0.1 / Q_MAX  11.617915 / Loss  0.1351582109928131
# 0
# fps: 6.893152377915901
# TIMESTEP 18281 / STATE explore / EPSILON 0.08183817999997225 / ACTION 0 / REWARD 0.1 / Q_MAX  25.007994 / Loss  0.055590104311704636
# 0
# fps: 6.607981623769365
# TIMESTEP 18282 / STATE explore / EPSILON 0.08183718099997225 / ACTION 0 / REWARD 0.1 / Q_MAX  14.231524 / Loss  1.8771038055419922
# 0
# fps: 5.3998746042760715
# TIMESTEP 18283 / STATE explore / EPSILON 0.08183618199997225 / ACTION 0 / REWARD 0.1 / Q_MAX  12.234075 / Loss  0.2798323333263397
# 1
# fps: 7.124288939128603
# TIMESTEP 18284 / STATE explore / EPSILON 0.08183518299997225 / ACTION 0 / REWARD 0.1 / Q_MAX  17.036076 / Loss  0.18309155106544495
# 1
# fps: 7.027494713843865
# TIMESTEP 18285 / STATE explore / EPSILON 0.08183418399997225 / ACTION 0 / REWARD 0.1 / Q_MAX  9.428069 / Loss  1.9803040027618408
# 1
# fps: 6.9115195177776645
# TIMESTEP 18286 / STATE explore / EPSILON 0.08183318499997225 / ACTION 0 / REWARD 0.1 / Q_MAX  9.187166 / Loss  0.16715534031391144
# 1
# fps: 7.096780961566119
# TIMESTEP 18287 / STATE explore / EPSILON 0.08183218599997225 / ACTION 0 / REWARD 0.1 / Q_MAX  12.615078 / Loss  1.7584757804870605
# 0
# fps: 6.963384284877071
# TIMESTEP 18288 / STATE explore / EPSILON 0.08183118699997224 / ACTION 0 / REWARD 0.1 / Q_MAX  13.523662 / Loss  0.2737964987754822
# 0
# fps: 6.866733790100112
# TIMESTEP 18289 / STATE explore / EPSILON 0.08183018799997224 / ACTION 0 / REWARD 0.1 / Q_MAX  22.212418 / Loss  0.2254624366760254
# 0
# fps: 5.7076232207495305
# TIMESTEP 18290 / STATE explore / EPSILON 0.08182918899997224 / ACTION 0 / REWARD 0.1 / Q_MAX  23.742668 / Loss  0.07314084470272064
# 0
# fps: 6.504370049190192
# TIMESTEP 18291 / STATE explore / EPSILON 0.08182818999997224 / ACTION 0 / REWARD 0.1 / Q_MAX  16.265223 / Loss  1.4900192022323608
# 0
# fps: 6.935829213037223
# TIMESTEP 18292 / STATE explore / EPSILON 0.08182719099997224 / ACTION 0 / REWARD 0.1 / Q_MAX  22.27304 / Loss  0.05940816551446915
# 0
# fps: 6.895101446321071
# TIMESTEP 18293 / STATE explore / EPSILON 0.08182619199997224 / ACTION 0 / REWARD 0.1 / Q_MAX  16.299192 / Loss  2.1705658435821533
# 0
# fps: 6.893480922679946
# TIMESTEP 18294 / STATE explore / EPSILON 0.08182519299997223 / ACTION 0 / REWARD 0.1 / Q_MAX  14.781244 / Loss  0.24545152485370636
# 0
# fps: 6.377811568639377
# TIMESTEP 18295 / STATE explore / EPSILON 0.08182419399997223 / ACTION 0 / REWARD 0.1 / Q_MAX  14.644668 / Loss  0.09631670266389847
# 0
# fps: 7.071737356434241
# TIMESTEP 18296 / STATE explore / EPSILON 0.08182319499997223 / ACTION 0 / REWARD 0.1 / Q_MAX  12.723953 / Loss  0.7318185567855835
# 0
# fps: 7.114621234095462
# TIMESTEP 18297 / STATE explore / EPSILON 0.08182219599997223 / ACTION 0 / REWARD 0.1 / Q_MAX  22.243458 / Loss  0.3263438045978546
# ----------Random Action----------
# fps: 4.43396888623899
# TIMESTEP 18298 / STATE explore / EPSILON 0.08182119699997223 / ACTION 1 / REWARD 0.1 / Q_MAX  14.027335 / Loss  0.12412277609109879
# 0
# fps: 6.901273204137173
# TIMESTEP 18299 / STATE explore / EPSILON 0.08182019799997223 / ACTION 0 / REWARD 0.1 / Q_MAX  15.871127 / Loss  0.04567454755306244
# 0
# fps: 6.8291342249315345
# TIMESTEP 18300 / STATE explore / EPSILON 0.08181919899997223 / ACTION 0 / REWARD 0.1 / Q_MAX  8.863281 / Loss  0.7725667357444763
# 0
# fps: 6.979258428499402
# TIMESTEP 18301 / STATE explore / EPSILON 0.08181819999997222 / ACTION 0 / REWARD 0.1 / Q_MAX  24.459469 / Loss  1.0017026662826538
# 0
# fps: 7.029579412232995
# TIMESTEP 18302 / STATE explore / EPSILON 0.08181720099997222 / ACTION 0 / REWARD 0.1 / Q_MAX  15.492453 / Loss  0.798652708530426
# 0
# ...
# 0
# fps: 7.122135602833025
# TIMESTEP 18668 / STATE explore / EPSILON 0.08145156699997166 / ACTION 0 / REWARD 0.1 / Q_MAX  15.528569 / Loss  0.07119760662317276
# 1
# fps: 6.781796868052355
# TIMESTEP 18669 / STATE explore / EPSILON 0.08145056799997166 / ACTION 0 / REWARD 0.1 / Q_MAX  28.67218 / Loss  0.39117732644081116
# 0
# fps: 7.228629779313554
# TIMESTEP 18670 / STATE explore / EPSILON 0.08144956899997166 / ACTION 0 / REWARD 0.1 / Q_MAX  13.557816 / Loss  0.09527633339166641
# 0
# fps: 5.674949363474863
# TIMESTEP 18671 / STATE explore / EPSILON 0.08144856999997166 / ACTION 0 / REWARD 0.1 / Q_MAX  16.106062 / Loss  0.5109623670578003
# 0
# fps: 6.9135359662425
# TIMESTEP 18672 / STATE explore / EPSILON 0.08144757099997166 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2759337 / Loss  0.876394510269165
# 0
# fps: 6.989539780330388
# TIMESTEP 18673 / STATE explore / EPSILON 0.08144657199997166 / ACTION 0 / REWARD 0.1 / Q_MAX  15.4770155 / Loss  0.568366289138794
# 0
# fps: 7.142377418508894
# TIMESTEP 18674 / STATE explore / EPSILON 0.08144557299997165 / ACTION 0 / REWARD 0.1 / Q_MAX  21.480448 / Loss  0.4184996783733368
# 0
# fps: 6.619254732881771
# TIMESTEP 18675 / STATE explore / EPSILON 0.08144457399997165 / ACTION 0 / REWARD 0.1 / Q_MAX  6.8446198 / Loss  1.3472048044204712
# 0
# fps: 6.874127684960289
# TIMESTEP 18676 / STATE explore / EPSILON 0.08144357499997165 / ACTION 0 / REWARD 0.1 / Q_MAX  13.611556 / Loss  0.029587069526314735
# 0
# fps: 6.693494025125115
# TIMESTEP 18677 / STATE explore / EPSILON 0.08144257599997165 / ACTION 0 / REWARD 0.1 / Q_MAX  10.392826 / Loss  0.9227401614189148
# 0
# fps: 6.983476633522255
# TIMESTEP 18678 / STATE explore / EPSILON 0.08144157699997165 / ACTION 0 / REWARD 0.1 / Q_MAX  11.698458 / Loss  0.43993765115737915
# 0
# fps: 4.996204874818046
# TIMESTEP 18679 / STATE explore / EPSILON 0.08144057799997165 / ACTION 0 / REWARD 0.1 / Q_MAX  14.3011055 / Loss  0.6392515301704407
# 0
# fps: 6.994773478488544
# TIMESTEP 18680 / STATE explore / EPSILON 0.08143957899997165 / ACTION 0 / REWARD 0.1 / Q_MAX  10.944986 / Loss  0.9222440123558044
# ----------Random Action----------
# fps: 5.891190821982072
# TIMESTEP 18681 / STATE explore / EPSILON 0.08143857999997164 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4194486 / Loss  0.2538916766643524
# 0
# fps: 6.889947877396071
# TIMESTEP 18682 / STATE explore / EPSILON 0.08143758099997164 / ACTION 0 / REWARD 0.1 / Q_MAX  33.825165 / Loss  3.4517617225646973
# 1
# fps: 6.92423024285877
# TIMESTEP 18683 / STATE explore / EPSILON 0.08143658199997164 / ACTION 0 / REWARD 0.1 / Q_MAX  15.962173 / Loss  0.27895501255989075
# 1
# fps: 6.821381872117305
# TIMESTEP 18684 / STATE explore / EPSILON 0.08143558299997164 / ACTION 0 / REWARD 0.1 / Q_MAX  6.500634 / Loss  0.043022893369197845
# 0
# fps: 7.229414725288363
# TIMESTEP 18685 / STATE explore / EPSILON 0.08143458399997164 / ACTION 0 / REWARD 0.1 / Q_MAX  13.558735 / Loss  0.09425641596317291
# 1
# fps: 5.897735006440073
# TIMESTEP 18686 / STATE explore / EPSILON 0.08143358499997164 / ACTION 0 / REWARD 0.1 / Q_MAX  16.369196 / Loss  0.2025769054889679
# 0
# fps: 6.939834309814504
# TIMESTEP 18687 / STATE explore / EPSILON 0.08143258599997164 / ACTION 0 / REWARD 0.1 / Q_MAX  4.701557 / Loss  1.1918710470199585
# 0
# fps: 7.146782988004362
# TIMESTEP 18688 / STATE explore / EPSILON 0.08143158699997163 / ACTION 0 / REWARD 0.1 / Q_MAX  16.418455 / Loss  0.4276941120624542
# 0
# fps: 6.937274645883917
# TIMESTEP 18689 / STATE explore / EPSILON 0.08143058799997163 / ACTION 0 / REWARD 0.1 / Q_MAX  11.98504 / Loss  8.416939735412598
# 0
# fps: 6.7148078477831055
# TIMESTEP 18690 / STATE explore / EPSILON 0.08142958899997163 / ACTION 0 / REWARD 0.1 / Q_MAX  16.50313 / Loss  0.9747042655944824
# 1
# fps: 6.681530427911926
# TIMESTEP 18691 / STATE explore / EPSILON 0.08142858999997163 / ACTION 0 / REWARD 0.1 / Q_MAX  14.55441 / Loss  0.3630372881889343
# 1
# fps: 7.069842077850277
# TIMESTEP 18692 / STATE explore / EPSILON 0.08142759099997163 / ACTION 0 / REWARD 0.1 / Q_MAX  15.646325 / Loss  1.1077301502227783
# 1
# fps: 6.565736353290536
# TIMESTEP 18693 / STATE explore / EPSILON 0.08142659199997163 / ACTION 0 / REWARD -1 / Q_MAX  9.779814 / Loss  0.35533207654953003
# 1
# fps: 5.57028018045656
# TIMESTEP 18694 / STATE explore / EPSILON 0.08142559299997162 / ACTION 0 / REWARD 0.1 / Q_MAX  11.730999 / Loss  2.0213372707366943
# 1
# fps: 7.189635607543599
# TIMESTEP 18695 / STATE explore / EPSILON 0.08142459399997162 / ACTION 0 / REWARD 0.1 / Q_MAX  9.901954 / Loss  0.31521686911582947
# 1
# fps: 6.707355647986899
# TIMESTEP 18696 / STATE explore / EPSILON 0.08142359499997162 / ACTION 0 / REWARD 0.1 / Q_MAX  18.885426 / Loss  0.5672957897186279
# 1
# fps: 7.059335184717664
# TIMESTEP 18697 / STATE explore / EPSILON 0.08142259599997162 / ACTION 0 / REWARD 0.1 / Q_MAX  15.456301 / Loss  0.3144584894180298
# 1
# fps: 7.192138262866118
# TIMESTEP 18698 / STATE explore / EPSILON 0.08142159699997162 / ACTION 0 / REWARD 0.1 / Q_MAX  19.728245 / Loss  0.38580214977264404
# 1
# fps: 6.695043249654018
# TIMESTEP 18699 / STATE explore / EPSILON 0.08142059799997162 / ACTION 0 / REWARD 0.1 / Q_MAX  15.897247 / Loss  0.26534634828567505
# 1
# fps: 6.317236642739018
# TIMESTEP 18700 / STATE explore / EPSILON 0.08141959899997162 / ACTION 0 / REWARD 0.1 / Q_MAX  10.081232 / Loss  0.23989802598953247
# 1
# fps: 6.484048449058149
# TIMESTEP 18701 / STATE explore / EPSILON 0.08141859999997161 / ACTION 0 / REWARD 0.1 / Q_MAX  34.776966 / Loss  0.23840878903865814
# 1
# fps: 6.03828867089537
# TIMESTEP 18702 / STATE explore / EPSILON 0.08141760099997161 / ACTION 0 / REWARD 0.1 / Q_MAX  15.676162 / Loss  0.8105756640434265
# 1
# fps: 7.167643017779388
# TIMESTEP 18703 / STATE explore / EPSILON 0.08141660199997161 / ACTION 0 / REWARD 0.1 / Q_MAX  36.049202 / Loss  0.28155049681663513
# 1
# fps: 6.99802954843123
# TIMESTEP 18704 / STATE explore / EPSILON 0.08141560299997161 / ACTION 0 / REWARD 0.1 / Q_MAX  22.92952 / Loss  0.39617156982421875
# 0
# fps: 4.754514137249723
# TIMESTEP 18705 / STATE explore / EPSILON 0.08141460399997161 / ACTION 0 / REWARD 0.1 / Q_MAX  19.222975 / Loss  0.848960280418396
# 0
# fps: 7.105701937916862
# TIMESTEP 18706 / STATE explore / EPSILON 0.0814136049999716 / ACTION 0 / REWARD 0.1 / Q_MAX  23.441236 / Loss  0.3480663597583771
# 0
# fps: 7.332135290292356
# TIMESTEP 18707 / STATE explore / EPSILON 0.0814126059999716 / ACTION 0 / REWARD 0.1 / Q_MAX  21.14121 / Loss  3.016731023788452
# 0
# fps: 7.292158976320456
# TIMESTEP 18708 / STATE explore / EPSILON 0.0814116069999716 / ACTION 0 / REWARD 0.1 / Q_MAX  26.513485 / Loss  0.6697005033493042
# 0
# fps: 5.1638218869113865
# TIMESTEP 18709 / STATE explore / EPSILON 0.0814106079999716 / ACTION 0 / REWARD 0.1 / Q_MAX  23.571405 / Loss  7.362716197967529
# 0
# fps: 7.157600858713329
# TIMESTEP 18710 / STATE explore / EPSILON 0.0814096089999716 / ACTION 0 / REWARD 0.1 / Q_MAX  21.043634 / Loss  1.4390840530395508
# 0
# fps: 6.947961979478991
# TIMESTEP 18711 / STATE explore / EPSILON 0.0814086099999716 / ACTION 0 / REWARD 0.1 / Q_MAX  36.740532 / Loss  1.113891363143921
# 0
# fps: 6.182750874131028
# TIMESTEP 18712 / STATE explore / EPSILON 0.0814076109999716 / ACTION 0 / REWARD 0.1 / Q_MAX  38.24066 / Loss  0.48711928725242615
# 0
# fps: 5.344519397644708
# TIMESTEP 18713 / STATE explore / EPSILON 0.0814066119999716 / ACTION 0 / REWARD 0.1 / Q_MAX  23.836838 / Loss  0.7881535887718201
# 0
# fps: 6.082006887801342
# TIMESTEP 18714 / STATE explore / EPSILON 0.0814056129999716 / ACTION 0 / REWARD 0.1 / Q_MAX  15.690359 / Loss  0.5567775964736938
# ----------Random Action----------
# fps: 7.257711408350781
# TIMESTEP 18715 / STATE explore / EPSILON 0.08140461399997159 / ACTION 0 / REWARD 0.1 / Q_MAX  23.268976 / Loss  0.2346712350845337
# 0
# fps: 5.747346121644712
# TIMESTEP 18716 / STATE explore / EPSILON 0.08140361499997159 / ACTION 0 / REWARD 0.1 / Q_MAX  42.864372 / Loss  0.41436102986335754
# 0
# fps: 6.614724185678283
# TIMESTEP 18717 / STATE explore / EPSILON 0.08140261599997159 / ACTION 0 / REWARD 0.1 / Q_MAX  12.906653 / Loss  0.1678771674633026
# 0
# fps: 7.153181946090679
# TIMESTEP 18718 / STATE explore / EPSILON 0.08140161699997159 / ACTION 0 / REWARD 0.1 / Q_MAX  17.95518 / Loss  4.156017303466797
# 0
# fps: 7.002282171184542
# TIMESTEP 18719 / STATE explore / EPSILON 0.08140061799997159 / ACTION 0 / REWARD 0.1 / Q_MAX  39.809097 / Loss  0.3006196618080139
# 0
# fps: 4.563679055384729
# TIMESTEP 18720 / STATE explore / EPSILON 0.08139961899997158 / ACTION 0 / REWARD 0.1 / Q_MAX  11.018697 / Loss  0.24433282017707825
# ----------Random Action----------
# fps: 5.094880101647274
# TIMESTEP 18721 / STATE explore / EPSILON 0.08139861999997158 / ACTION 1 / REWARD 0.1 / Q_MAX  22.767036 / Loss  0.4968956410884857
# 0
# fps: 6.861948069583029
# TIMESTEP 18722 / STATE explore / EPSILON 0.08139762099997158 / ACTION 0 / REWARD 0.1 / Q_MAX  37.713943 / Loss  0.1663440763950348
# 0
# fps: 6.080525606957449
# TIMESTEP 18723 / STATE explore / EPSILON 0.08139662199997158 / ACTION 0 / REWARD 0.1 / Q_MAX  10.043889 / Loss  0.3140121400356293
# 0
# fps: 6.383052807791812
# TIMESTEP 18724 / STATE explore / EPSILON 0.08139562299997158 / ACTION 0 / REWARD 0.1 / Q_MAX  4.401221 / Loss  18.521575927734375
# 0
# fps: 4.847897547331192
# TIMESTEP 18725 / STATE explore / EPSILON 0.08139462399997158 / ACTION 0 / REWARD 0.1 / Q_MAX  9.734659 / Loss  0.6697072982788086
# 0
# fps: 6.134956331462556
# TIMESTEP 18726 / STATE explore / EPSILON 0.08139362499997158 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.320019 / Loss  2.0204482078552246
# 0
# fps: 6.128161933050958
# TIMESTEP 18727 / STATE explore / EPSILON 0.08139262599997157 / ACTION 0 / REWARD 0.1 / Q_MAX  14.716064 / Loss  0.43708115816116333
# 0
# fps: 7.201535666823484
# TIMESTEP 18728 / STATE explore / EPSILON 0.08139162699997157 / ACTION 0 / REWARD 0.1 / Q_MAX  10.909304 / Loss  0.6020287275314331
# 0
# fps: 7.149463062080251
# TIMESTEP 18729 / STATE explore / EPSILON 0.08139062799997157 / ACTION 0 / REWARD 0.1 / Q_MAX  22.226633 / Loss  0.14692413806915283
# 0
# fps: 6.496602464316969
# TIMESTEP 18730 / STATE explore / EPSILON 0.08138962899997157 / ACTION 0 / REWARD 0.1 / Q_MAX  19.239666 / Loss  0.5751491785049438
# 0
# fps: 7.462669783893616
# TIMESTEP 18731 / STATE explore / EPSILON 0.08138862999997157 / ACTION 0 / REWARD 0.1 / Q_MAX  4.95126 / Loss  2.2638087272644043
# ----------Random Action----------
# fps: 5.776482578157278
# TIMESTEP 18732 / STATE explore / EPSILON 0.08138763099997157 / ACTION 1 / REWARD 0.1 / Q_MAX  7.501159 / Loss  0.23823390901088715
# 0
# fps: 7.2754117924593755
# TIMESTEP 18733 / STATE explore / EPSILON 0.08138663199997156 / ACTION 0 / REWARD 0.1 / Q_MAX  18.554462 / Loss  0.28161051869392395
# 0
# fps: 7.003977650347502
# TIMESTEP 18734 / STATE explore / EPSILON 0.08138563299997156 / ACTION 0 / REWARD 0.1 / Q_MAX  30.813515 / Loss  0.46222639083862305
# 0
# fps: 6.84670307965041
# TIMESTEP 18735 / STATE explore / EPSILON 0.08138463399997156 / ACTION 0 / REWARD 0.1 / Q_MAX  8.531612 / Loss  0.5173661112785339
# 0
# fps: 7.2267615462150125
# TIMESTEP 18736 / STATE explore / EPSILON 0.08138363499997156 / ACTION 0 / REWARD 0.1 / Q_MAX  13.4326725 / Loss  0.2977401316165924
# 0
# fps: 5.958139785954356
# TIMESTEP 18737 / STATE explore / EPSILON 0.08138263599997156 / ACTION 0 / REWARD 0.1 / Q_MAX  19.052216 / Loss  0.5167104601860046
# 0
# fps: 7.94911720781436
# TIMESTEP 18738 / STATE explore / EPSILON 0.08138163699997156 / ACTION 0 / REWARD 0.1 / Q_MAX  7.14755 / Loss  0.435971736907959
# 0
# fps: 6.934659541823184
# TIMESTEP 18739 / STATE explore / EPSILON 0.08138063799997156 / ACTION 0 / REWARD 0.1 / Q_MAX  12.174788 / Loss  0.2148403823375702
# 0
# fps: 7.072715192925774
# TIMESTEP 18740 / STATE explore / EPSILON 0.08137963899997155 / ACTION 0 / REWARD 0.1 / Q_MAX  18.042965 / Loss  0.9460672736167908
# ----------Random Action----------
# fps: 7.288965507653381
# TIMESTEP 18741 / STATE explore / EPSILON 0.08137863999997155 / ACTION 0 / REWARD 0.1 / Q_MAX  16.141024 / Loss  1.1932703256607056
# 0
# fps: 6.921545006584397
# TIMESTEP 18742 / STATE explore / EPSILON 0.08137764099997155 / ACTION 0 / REWARD 0.1 / Q_MAX  30.774805 / Loss  0.32147446274757385
# 0
# fps: 7.089799305946447
# TIMESTEP 18743 / STATE explore / EPSILON 0.08137664199997155 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9412084 / Loss  1.7989633083343506
# 0
# fps: 6.3659342477313325
# TIMESTEP 18744 / STATE explore / EPSILON 0.08137564299997155 / ACTION 0 / REWARD 0.1 / Q_MAX  8.822218 / Loss  0.12045394629240036
# ----------Random Action----------
# fps: 5.677230730081728
# TIMESTEP 18745 / STATE explore / EPSILON 0.08137464399997155 / ACTION 0 / REWARD 0.1 / Q_MAX  17.471954 / Loss  0.04607778415083885
# 0
# fps: 6.979932069581251
# TIMESTEP 18746 / STATE explore / EPSILON 0.08137364499997154 / ACTION 0 / REWARD 0.1 / Q_MAX  0.28050062 / Loss  0.30884361267089844
# 0
# fps: 7.349557025905574
# TIMESTEP 18747 / STATE explore / EPSILON 0.08137264599997154 / ACTION 0 / REWARD 0.1 / Q_MAX  17.95462 / Loss  2.008615732192993
# 0
# fps: 6.754460777366949
# TIMESTEP 18748 / STATE explore / EPSILON 0.08137164699997154 / ACTION 0 / REWARD 0.1 / Q_MAX  18.631075 / Loss  0.2672906517982483
# 0
# fps: 6.4213404533499086
# TIMESTEP 18749 / STATE explore / EPSILON 0.08137064799997154 / ACTION 0 / REWARD 0.1 / Q_MAX  8.899236 / Loss  0.26798689365386963
# 0
# fps: 7.0336581594750465
# TIMESTEP 18750 / STATE explore / EPSILON 0.08136964899997154 / ACTION 0 / REWARD 0.1 / Q_MAX  23.641748 / Loss  1.0059449672698975
# 0
# fps: 6.982860434490899
# TIMESTEP 18751 / STATE explore / EPSILON 0.08136864999997154 / ACTION 0 / REWARD 0.1 / Q_MAX  6.832303 / Loss  11.588976860046387
# 0
# fps: 7.077715923031621
# TIMESTEP 18752 / STATE explore / EPSILON 0.08136765099997154 / ACTION 0 / REWARD 0.1 / Q_MAX  9.483391 / Loss  0.14006854593753815
# 0
# fps: 6.2212768860865015
# TIMESTEP 18753 / STATE explore / EPSILON 0.08136665199997153 / ACTION 0 / REWARD 0.1 / Q_MAX  22.552998 / Loss  0.0762556791305542
# ----------Random Action----------
# fps: 7.3393200859516625
# TIMESTEP 18754 / STATE explore / EPSILON 0.08136565299997153 / ACTION 0 / REWARD 0.1 / Q_MAX  31.604048 / Loss  0.3117804527282715
# 0
# fps: 6.9245388928144544
# TIMESTEP 18755 / STATE explore / EPSILON 0.08136465399997153 / ACTION 0 / REWARD 0.1 / Q_MAX  11.738261 / Loss  0.28396111726760864
# 0
# fps: 3.6715681554377113
# TIMESTEP 18756 / STATE explore / EPSILON 0.08136365499997153 / ACTION 0 / REWARD 0.1 / Q_MAX  16.703262 / Loss  0.11162698268890381
# 0
# fps: 4.209327088378423
# TIMESTEP 18757 / STATE explore / EPSILON 0.08136265599997153 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7757115 / Loss  0.1618276834487915
# 0
# fps: 4.717381401997712
# TIMESTEP 18758 / STATE explore / EPSILON 0.08136165699997153 / ACTION 0 / REWARD 0.1 / Q_MAX  6.915493 / Loss  0.38719168305397034
# 0
# fps: 6.136607904443232
# TIMESTEP 18759 / STATE explore / EPSILON 0.08136065799997153 / ACTION 0 / REWARD 0.1 / Q_MAX  21.347286 / Loss  0.29844915866851807
# 0
# fps: 7.212892153237914
# TIMESTEP 18760 / STATE explore / EPSILON 0.08135965899997152 / ACTION 0 / REWARD 0.1 / Q_MAX  14.407013 / Loss  0.2675968110561371
# 0
# fps: 7.1084476607716365
# TIMESTEP 18761 / STATE explore / EPSILON 0.08135865999997152 / ACTION 0 / REWARD 0.1 / Q_MAX  7.0672784 / Loss  0.852466344833374
# 0
# fps: 6.963615504792327
# TIMESTEP 18762 / STATE explore / EPSILON 0.08135766099997152 / ACTION 0 / REWARD 0.1 / Q_MAX  7.467455 / Loss  0.2232501059770584
# 0
# fps: 7.199483679606717
# TIMESTEP 18763 / STATE explore / EPSILON 0.08135666199997152 / ACTION 0 / REWARD 0.1 / Q_MAX  11.756517 / Loss  0.21987032890319824
# 0
# fps: 6.9810357281954145
# TIMESTEP 18764 / STATE explore / EPSILON 0.08135566299997152 / ACTION 0 / REWARD 0.1 / Q_MAX  30.637001 / Loss  0.6489352583885193
# 0
# fps: 7.202537362386384
# TIMESTEP 18765 / STATE explore / EPSILON 0.08135466399997152 / ACTION 0 / REWARD 0.1 / Q_MAX  17.022768 / Loss  0.4078698456287384
# 0
# fps: 5.8134723069246546
# TIMESTEP 18766 / STATE explore / EPSILON 0.08135366499997151 / ACTION 0 / REWARD 0.1 / Q_MAX  12.239908 / Loss  0.05215946584939957
# 0
# fps: 7.205556500421754
# TIMESTEP 18767 / STATE explore / EPSILON 0.08135266599997151 / ACTION 0 / REWARD 0.1 / Q_MAX  16.846838 / Loss  0.1998295783996582
# 0
# fps: 6.8701755420477015
# TIMESTEP 18768 / STATE explore / EPSILON 0.08135166699997151 / ACTION 0 / REWARD 0.1 / Q_MAX  21.929834 / Loss  0.28144994378089905
# 0
