# %%
from keras import backend as K
# !pip install selenium
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
# Out:
# Using TensorFlow backend.
# Error processing line 3 of /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/googleapis_common_protos-1.6.0-py3.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/divyanshumarwah/anaconda3/lib/python3.7/site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 580, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3 in /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages (from selenium) (1.24.2)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# []

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('./objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('./objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: use options instead of chrome_options
# Now we build the model
# We finish building the model
# fps: 2.4715177342409445
# TIMESTEP 1001 / STATE explore / EPSILON 0.09910089999999863 / ACTION 1 / REWARD 0.1 / Q_MAX  10.012491 / Loss  41.61846923828125
# fps: 0.9387333971046852
# TIMESTEP 1002 / STATE explore / EPSILON 0.09909990099999863 / ACTION 1 / REWARD 0.1 / Q_MAX  10.113318 / Loss  18.1099853515625
# fps: 11.703183682580429
# TIMESTEP 1003 / STATE explore / EPSILON 0.09909890199999863 / ACTION 1 / REWARD 0.1 / Q_MAX  10.345312 / Loss  17.58559226989746
# ----------Random Action----------
# fps: 11.454119934568235
# TIMESTEP 1004 / STATE explore / EPSILON 0.09909790299999863 / ACTION 1 / REWARD 0.1 / Q_MAX  10.7374735 / Loss  13.773286819458008
# fps: 11.884372361344871
# TIMESTEP 1005 / STATE explore / EPSILON 0.09909690399999863 / ACTION 1 / REWARD 0.1 / Q_MAX  11.307553 / Loss  5.942440986633301
# fps: 11.774674774152617
# TIMESTEP 1006 / STATE explore / EPSILON 0.09909590499999862 / ACTION 1 / REWARD 0.1 / Q_MAX  11.880706 / Loss  8.927412033081055
# ----------Random Action----------
# fps: 11.130168957199455
# TIMESTEP 1007 / STATE explore / EPSILON 0.09909490599999862 / ACTION 1 / REWARD 0.1 / Q_MAX  12.41362 / Loss  1.9207894802093506
# fps: 11.640238893452633
# TIMESTEP 1008 / STATE explore / EPSILON 0.09909390699999862 / ACTION 1 / REWARD 0.1 / Q_MAX  12.857759 / Loss  1.641106367111206
# fps: 11.63126514811179
# TIMESTEP 1009 / STATE explore / EPSILON 0.09909290799999862 / ACTION 1 / REWARD 0.1 / Q_MAX  13.239563 / Loss  0.6649473905563354
# fps: 11.829135808040071
# TIMESTEP 1010 / STATE explore / EPSILON 0.09909190899999862 / ACTION 1 / REWARD 0.1 / Q_MAX  13.587121 / Loss  0.03500988334417343
# fps: 11.79563587480771
# TIMESTEP 1011 / STATE explore / EPSILON 0.09909090999999862 / ACTION 1 / REWARD 0.1 / Q_MAX  14.601776 / Loss  0.11342810839414597
# fps: 11.308907073621203
# TIMESTEP 1012 / STATE explore / EPSILON 0.09908991099999861 / ACTION 1 / REWARD 0.1 / Q_MAX  15.895645 / Loss  0.5222311019897461
# fps: 8.906597921944446
# TIMESTEP 1013 / STATE explore / EPSILON 0.09908891199999861 / ACTION 1 / REWARD 0.1 / Q_MAX  17.112293 / Loss  0.6551849842071533
# fps: 7.139641886267654
# TIMESTEP 1014 / STATE explore / EPSILON 0.09908791299999861 / ACTION 1 / REWARD 0.1 / Q_MAX  18.241093 / Loss  0.6006482243537903
# ----------Random Action----------
# fps: 9.945024173145638
# TIMESTEP 1015 / STATE explore / EPSILON 0.09908691399999861 / ACTION 1 / REWARD 0.1 / Q_MAX  19.318642 / Loss  0.2116214632987976
# fps: 11.123468446009738
# TIMESTEP 1016 / STATE explore / EPSILON 0.09908591499999861 / ACTION 1 / REWARD 0.1 / Q_MAX  20.3151 / Loss  0.16668403148651123
# fps: 11.301106587523341
# TIMESTEP 1017 / STATE explore / EPSILON 0.09908491599999861 / ACTION 1 / REWARD 0.1 / Q_MAX  21.249876 / Loss  0.019555119797587395
# fps: 11.881005931574444
# TIMESTEP 1018 / STATE explore / EPSILON 0.0990839169999986 / ACTION 1 / REWARD 0.1 / Q_MAX  22.273558 / Loss  0.006067842710763216
# ----------Random Action----------
# fps: 14.342491938489736
# TIMESTEP 1019 / STATE explore / EPSILON 0.0990829179999986 / ACTION 0 / REWARD 0.1 / Q_MAX  23.4903 / Loss  0.03790222108364105
# fps: 9.962741004135403
# TIMESTEP 1020 / STATE explore / EPSILON 0.0990819189999986 / ACTION 1 / REWARD 0.1 / Q_MAX  24.478231 / Loss  0.12256041169166565
# fps: 10.494155324259408
# TIMESTEP 1021 / STATE explore / EPSILON 0.0990809199999986 / ACTION 1 / REWARD 0.1 / Q_MAX  25.354483 / Loss  0.15831275284290314
# fps: 10.341139168725375
# TIMESTEP 1022 / STATE explore / EPSILON 0.0990799209999986 / ACTION 1 / REWARD 0.1 / Q_MAX  26.146536 / Loss  0.15021632611751556
# fps: 11.608730549727932
# TIMESTEP 1023 / STATE explore / EPSILON 0.0990789219999986 / ACTION 1 / REWARD 0.1 / Q_MAX  26.856451 / Loss  0.1755789816379547
# fps: 10.303440618259891
# TIMESTEP 1024 / STATE explore / EPSILON 0.0990779229999986 / ACTION 1 / REWARD 0.1 / Q_MAX  27.551086 / Loss  0.041999250650405884
# fps: 10.247380315412713
# TIMESTEP 1025 / STATE explore / EPSILON 0.0990769239999986 / ACTION 1 / REWARD 0.1 / Q_MAX  28.101612 / Loss  0.01143440417945385
# fps: 11.859975342992547
# TIMESTEP 1026 / STATE explore / EPSILON 0.0990759249999986 / ACTION 1 / REWARD 0.1 / Q_MAX  28.615349 / Loss  0.012794111855328083
# fps: 13.543731392442668
# TIMESTEP 1027 / STATE explore / EPSILON 0.09907492599999859 / ACTION 0 / REWARD 0.1 / Q_MAX  29.316784 / Loss  0.019721388816833496
# fps: 13.24059903528045
# TIMESTEP 1028 / STATE explore / EPSILON 0.09907392699999859 / ACTION 0 / REWARD 0.1 / Q_MAX  29.97631 / Loss  0.0576847568154335
# fps: 12.060811529691199
# TIMESTEP 1029 / STATE explore / EPSILON 0.09907292799999859 / ACTION 0 / REWARD 0.1 / Q_MAX  30.59633 / Loss  0.056401725858449936
# fps: 13.089365739180367
# TIMESTEP 1030 / STATE explore / EPSILON 0.09907192899999859 / ACTION 0 / REWARD 0.1 / Q_MAX  31.179564 / Loss  0.022298848256468773
# fps: 11.67786572819886
# TIMESTEP 1031 / STATE explore / EPSILON 0.09907092999999859 / ACTION 1 / REWARD 0.1 / Q_MAX  31.646086 / Loss  0.009919035248458385
# fps: 11.35781287233812
# TIMESTEP 1032 / STATE explore / EPSILON 0.09906993099999858 / ACTION 1 / REWARD 0.1 / Q_MAX  32.043655 / Loss  0.02018922194838524
# fps: 11.141433352813047
# TIMESTEP 1033 / STATE explore / EPSILON 0.09906893199999858 / ACTION 1 / REWARD 0.1 / Q_MAX  21.628183 / Loss  0.023421388119459152
# fps: 11.56312529119375
# TIMESTEP 1034 / STATE explore / EPSILON 0.09906793299999858 / ACTION 1 / REWARD 0.1 / Q_MAX  32.83016 / Loss  0.020800655707716942
# fps: 11.27598072952512
# TIMESTEP 1035 / STATE explore / EPSILON 0.09906693399999858 / ACTION 1 / REWARD 0.1 / Q_MAX  33.071224 / Loss  0.01705343648791313
# fps: 11.683590953533654
# TIMESTEP 1036 / STATE explore / EPSILON 0.09906593499999858 / ACTION 1 / REWARD 0.1 / Q_MAX  33.17176 / Loss  0.014228945598006248
# fps: 10.9525580229376
# TIMESTEP 1037 / STATE explore / EPSILON 0.09906493599999858 / ACTION 1 / REWARD 0.1 / Q_MAX  33.15478 / Loss  0.0228195171803236
# ----------Random Action----------
# fps: 14.180389611267758
# TIMESTEP 1038 / STATE explore / EPSILON 0.09906393699999858 / ACTION 0 / REWARD 0.1 / Q_MAX  33.166325 / Loss  0.008187521249055862
# fps: 13.514275311653204
# TIMESTEP 1039 / STATE explore / EPSILON 0.09906293799999857 / ACTION 0 / REWARD 0.1 / Q_MAX  33.169685 / Loss  0.017012663185596466
# fps: 13.723424652603956
# TIMESTEP 1040 / STATE explore / EPSILON 0.09906193899999857 / ACTION 0 / REWARD 0.1 / Q_MAX  33.14265 / Loss  0.027834147214889526
# ----------Random Action----------
# fps: 13.684783388908103
# TIMESTEP 1041 / STATE explore / EPSILON 0.09906093999999857 / ACTION 0 / REWARD 0.1 / Q_MAX  33.103226 / Loss  0.02773645892739296
# fps: 11.780925496804999
# TIMESTEP 1042 / STATE explore / EPSILON 0.09905994099999857 / ACTION 0 / REWARD 0.1 / Q_MAX  33.053295 / Loss  0.016690969467163086
# fps: 13.169177441333275
# TIMESTEP 1043 / STATE explore / EPSILON 0.09905894199999857 / ACTION 0 / REWARD 0.1 / Q_MAX  32.93972 / Loss  0.01779978908598423
# fps: 10.225894457108724
# TIMESTEP 1044 / STATE explore / EPSILON 0.09905794299999857 / ACTION 1 / REWARD 0.1 / Q_MAX  32.832745 / Loss  0.01992896944284439
# fps: 11.68059752202137
# TIMESTEP 1045 / STATE explore / EPSILON 0.09905694399999856 / ACTION 1 / REWARD 0.1 / Q_MAX  32.67334 / Loss  0.013482242822647095
# fps: 11.035086611521542
# TIMESTEP 1046 / STATE explore / EPSILON 0.09905594499999856 / ACTION 1 / REWARD 0.1 / Q_MAX  32.426357 / Loss  0.01640477403998375
# fps: 11.692613056641225
# TIMESTEP 1047 / STATE explore / EPSILON 0.09905494599999856 / ACTION 1 / REWARD 0.1 / Q_MAX  32.085648 / Loss  0.01718815229833126
# fps: 10.995656060673586
# TIMESTEP 1048 / STATE explore / EPSILON 0.09905394699999856 / ACTION 1 / REWARD 0.1 / Q_MAX  31.70968 / Loss  0.018890636041760445
# fps: 11.226513421857728
# TIMESTEP 1049 / STATE explore / EPSILON 0.09905294799999856 / ACTION 1 / REWARD 0.1 / Q_MAX  31.36363 / Loss  0.0114799365401268
# fps: 11.919937022732634
# TIMESTEP 1050 / STATE explore / EPSILON 0.09905194899999856 / ACTION 1 / REWARD 0.1 / Q_MAX  30.993092 / Loss  0.009846102446317673
# fps: 10.649928650141938
# TIMESTEP 1051 / STATE explore / EPSILON 0.09905094999999856 / ACTION 1 / REWARD 0.1 / Q_MAX  30.61115 / Loss  0.010968911461532116
# fps: 13.494361670296861
# TIMESTEP 1052 / STATE explore / EPSILON 0.09904995099999855 / ACTION 0 / REWARD 0.1 / Q_MAX  30.226658 / Loss  0.013507276773452759
# fps: 11.238335110687165
# TIMESTEP 1053 / STATE explore / EPSILON 0.09904895199999855 / ACTION 1 / REWARD 0.1 / Q_MAX  29.809444 / Loss  0.013381855562329292
# fps: 13.173148072538144
# TIMESTEP 1054 / STATE explore / EPSILON 0.09904795299999855 / ACTION 0 / REWARD 0.1 / Q_MAX  22.0172 / Loss  0.01589271053671837
# fps: 11.402243855495053
# TIMESTEP 1055 / STATE explore / EPSILON 0.09904695399999855 / ACTION 1 / REWARD 0.1 / Q_MAX  28.979877 / Loss  0.013914958573877811
# fps: 14.044165263133223
# TIMESTEP 1056 / STATE explore / EPSILON 0.09904595499999855 / ACTION 0 / REWARD 0.1 / Q_MAX  28.525747 / Loss  0.012259887531399727
# fps: 14.249715468008413
# TIMESTEP 1057 / STATE explore / EPSILON 0.09904495599999855 / ACTION 0 / REWARD 0.1 / Q_MAX  28.001331 / Loss  0.01495196670293808
# fps: 14.187968500527697
# TIMESTEP 1058 / STATE explore / EPSILON 0.09904395699999854 / ACTION 0 / REWARD 0.1 / Q_MAX  27.530388 / Loss  0.006417817436158657
# fps: 14.198102317772069
# TIMESTEP 1059 / STATE explore / EPSILON 0.09904295799999854 / ACTION 0 / REWARD 0.1 / Q_MAX  27.090137 / Loss  0.008850191719830036
# fps: 13.787029823713683
# TIMESTEP 1060 / STATE explore / EPSILON 0.09904195899999854 / ACTION 0 / REWARD 0.1 / Q_MAX  26.650055 / Loss  0.009665902704000473
# fps: 14.650287291080877
# TIMESTEP 1061 / STATE explore / EPSILON 0.09904095999999854 / ACTION 0 / REWARD 0.1 / Q_MAX  26.229559 / Loss  0.007602403871715069
# fps: 14.22193287625713
# TIMESTEP 1062 / STATE explore / EPSILON 0.09903996099999854 / ACTION 0 / REWARD 0.1 / Q_MAX  25.826035 / Loss  0.004381438251584768
# fps: 10.909058752233541
# TIMESTEP 1063 / STATE explore / EPSILON 0.09903896199999854 / ACTION 1 / REWARD 0.1 / Q_MAX  25.438324 / Loss  0.006359610706567764
# fps: 11.736947999070962
# TIMESTEP 1064 / STATE explore / EPSILON 0.09903796299999854 / ACTION 1 / REWARD 0.1 / Q_MAX  19.022606 / Loss  0.009919697418808937
# fps: 11.104444103210366
# TIMESTEP 1065 / STATE explore / EPSILON 0.09903696399999853 / ACTION 1 / REWARD 0.1 / Q_MAX  24.723583 / Loss  0.006667303387075663
# fps: 11.686064945739242
# TIMESTEP 1066 / STATE explore / EPSILON 0.09903596499999853 / ACTION 1 / REWARD 0.1 / Q_MAX  24.36824 / Loss  0.006997254677116871
# fps: 11.709881765009701
# TIMESTEP 1067 / STATE explore / EPSILON 0.09903496599999853 / ACTION 1 / REWARD 0.1 / Q_MAX  23.972536 / Loss  0.007399458438158035
# fps: 11.647285551637
# TIMESTEP 1068 / STATE explore / EPSILON 0.09903396699999853 / ACTION 1 / REWARD 0.1 / Q_MAX  23.570251 / Loss  0.008081629872322083
# fps: 14.213017149944257
# TIMESTEP 1069 / STATE explore / EPSILON 0.09903296799999853 / ACTION 0 / REWARD 0.1 / Q_MAX  23.198198 / Loss  0.004063949920237064
# fps: 13.38386968106323
# TIMESTEP 1070 / STATE explore / EPSILON 0.09903196899999853 / ACTION 0 / REWARD 0.1 / Q_MAX  17.27346 / Loss  0.00510620791465044
# fps: 14.044729589906208
# TIMESTEP 1071 / STATE explore / EPSILON 0.09903096999999852 / ACTION 0 / REWARD 0.1 / Q_MAX  22.474787 / Loss  0.0024149264208972454
# fps: 14.21224658527577
# TIMESTEP 1072 / STATE explore / EPSILON 0.09902997099999852 / ACTION 0 / REWARD 0.1 / Q_MAX  22.141035 / Loss  0.002840506611391902
# fps: 14.437975249995697
# TIMESTEP 1073 / STATE explore / EPSILON 0.09902897199999852 / ACTION 0 / REWARD 0.1 / Q_MAX  21.820183 / Loss  0.0018018204718828201
# fps: 13.114617955781238
# TIMESTEP 1074 / STATE explore / EPSILON 0.09902797299999852 / ACTION 0 / REWARD 0.1 / Q_MAX  21.516026 / Loss  0.0037309438921511173
# fps: 11.097657066504386
# TIMESTEP 1075 / STATE explore / EPSILON 0.09902697399999852 / ACTION 1 / REWARD 0.1 / Q_MAX  21.210884 / Loss  0.0038519485387951136
# ----------Random Action----------
# fps: 10.103056230007322
# TIMESTEP 1076 / STATE explore / EPSILON 0.09902597499999852 / ACTION 1 / REWARD 0.1 / Q_MAX  20.910152 / Loss  0.0044173882342875
# fps: 10.858111798862492
# TIMESTEP 1077 / STATE explore / EPSILON 0.09902497599999852 / ACTION 1 / REWARD 0.1 / Q_MAX  20.61513 / Loss  0.004954915028065443
# fps: 11.857226051213624
# TIMESTEP 1078 / STATE explore / EPSILON 0.09902397699999851 / ACTION 1 / REWARD 0.1 / Q_MAX  20.304241 / Loss  0.004440515302121639
# fps: 10.855020665488247
# TIMESTEP 1079 / STATE explore / EPSILON 0.09902297799999851 / ACTION 1 / REWARD 0.1 / Q_MAX  19.9997 / Loss  0.003993642516434193
# fps: 10.906420644248671
# TIMESTEP 1080 / STATE explore / EPSILON 0.09902197899999851 / ACTION 1 / REWARD 0.1 / Q_MAX  19.70113 / Loss  0.0036514028906822205
# fps: 10.5978320741845
# TIMESTEP 1081 / STATE explore / EPSILON 0.09902097999999851 / ACTION 1 / REWARD 0.1 / Q_MAX  19.401705 / Loss  0.0031439363956451416
# fps: 11.999736791662018
# TIMESTEP 1082 / STATE explore / EPSILON 0.09901998099999851 / ACTION 1 / REWARD 0.1 / Q_MAX  19.108143 / Loss  0.0023012948222458363
# fps: 11.629394672049331
# TIMESTEP 1083 / STATE explore / EPSILON 0.0990189819999985 / ACTION 1 / REWARD 0.1 / Q_MAX  14.600428 / Loss  0.0021632062271237373
# fps: 11.726775314606522
# TIMESTEP 1084 / STATE explore / EPSILON 0.0990179829999985 / ACTION 1 / REWARD 0.1 / Q_MAX  18.54478 / Loss  0.0012579770991578698
# fps: 14.204545531514263
# TIMESTEP 1085 / STATE explore / EPSILON 0.0990169839999985 / ACTION 0 / REWARD 0.1 / Q_MAX  18.27919 / Loss  0.0015566898509860039
# fps: 13.84930642919172
# TIMESTEP 1086 / STATE explore / EPSILON 0.0990159849999985 / ACTION 0 / REWARD 0.1 / Q_MAX  18.022758 / Loss  0.0014080542605370283
# fps: 14.517985213081161
# TIMESTEP 1087 / STATE explore / EPSILON 0.0990149859999985 / ACTION 0 / REWARD 0.1 / Q_MAX  17.774366 / Loss  0.0012142558116465807
# fps: 14.024817513366749
# TIMESTEP 1088 / STATE explore / EPSILON 0.0990139869999985 / ACTION 0 / REWARD 0.1 / Q_MAX  17.541376 / Loss  0.001288220169954002
# fps: 10.766137126106631
# TIMESTEP 1089 / STATE explore / EPSILON 0.0990129879999985 / ACTION 0 / REWARD 0.1 / Q_MAX  17.315123 / Loss  0.0014355736784636974
# fps: 9.2054034479353
# TIMESTEP 1090 / STATE explore / EPSILON 0.0990119889999985 / ACTION 1 / REWARD 0.1 / Q_MAX  17.094395 / Loss  0.001727322698570788
# fps: 9.277216948162827
# TIMESTEP 1091 / STATE explore / EPSILON 0.0990109899999985 / ACTION 1 / REWARD 0.1 / Q_MAX  16.879845 / Loss  0.0016545264516025782
# ----------Random Action----------
# fps: 7.951483164514007
# TIMESTEP 1092 / STATE explore / EPSILON 0.09900999099999849 / ACTION 1 / REWARD 0.1 / Q_MAX  16.666996 / Loss  0.0017221206799149513
# fps: 6.905511331363138
# TIMESTEP 1093 / STATE explore / EPSILON 0.09900899199999849 / ACTION 1 / REWARD 0.1 / Q_MAX  16.458172 / Loss  0.0016724837478250265
# fps: 10.671144457080633
# TIMESTEP 1094 / STATE explore / EPSILON 0.09900799299999849 / ACTION 1 / REWARD 0.1 / Q_MAX  16.25084 / Loss  0.0019803778268396854
# fps: 11.678841222151991
# TIMESTEP 1095 / STATE explore / EPSILON 0.09900699399999849 / ACTION 1 / REWARD 0.1 / Q_MAX  16.04512 / Loss  0.001262702513486147
# fps: 10.268654962456269
# TIMESTEP 1096 / STATE explore / EPSILON 0.09900599499999849 / ACTION 1 / REWARD 0.1 / Q_MAX  15.845636 / Loss  0.0011610976653173566
# fps: 10.184650799123903
# TIMESTEP 1097 / STATE explore / EPSILON 0.09900499599999849 / ACTION 1 / REWARD 0.1 / Q_MAX  15.651826 / Loss  0.0008859946392476559
# fps: 7.968311444545978
# TIMESTEP 1098 / STATE explore / EPSILON 0.09900399699999848 / ACTION 1 / REWARD 0.1 / Q_MAX  15.465758 / Loss  0.0007090065628290176
# fps: 10.128526857727936
# TIMESTEP 1099 / STATE explore / EPSILON 0.09900299799999848 / ACTION 1 / REWARD 0.1 / Q_MAX  15.285912 / Loss  0.00027467432664707303
# fps: 9.73671454969218
# TIMESTEP 1100 / STATE explore / EPSILON 0.09900199899999848 / ACTION 1 / REWARD 0.1 / Q_MAX  15.1183815 / Loss  0.0006724210106767714
# fps: 10.988770992166417
# TIMESTEP 1101 / STATE explore / EPSILON 0.09900099999999848 / ACTION 1 / REWARD 0.1 / Q_MAX  14.955775 / Loss  0.0005937610985711217
# fps: 11.386704529104033
# TIMESTEP 1102 / STATE explore / EPSILON 0.09900000099999848 / ACTION 1 / REWARD 0.1 / Q_MAX  12.085174 / Loss  0.0006154975853860378
# ----------Random Action----------
# fps: 11.933366905942636
# TIMESTEP 1103 / STATE explore / EPSILON 0.09899900199999848 / ACTION 1 / REWARD 0.1 / Q_MAX  14.654482 / Loss  0.0004646003362722695
# ----------Random Action----------
# fps: 11.85367397693873
# TIMESTEP 1104 / STATE explore / EPSILON 0.09899800299999847 / ACTION 1 / REWARD 0.1 / Q_MAX  14.506108 / Loss  0.0004000685876235366
# fps: 13.308110886540238
# TIMESTEP 1105 / STATE explore / EPSILON 0.09899700399999847 / ACTION 0 / REWARD 0.1 / Q_MAX  14.363231 / Loss  0.0006680903024971485
# fps: 14.458181517344078
# TIMESTEP 1106 / STATE explore / EPSILON 0.09899600499999847 / ACTION 0 / REWARD 0.1 / Q_MAX  14.218328 / Loss  0.0005103984149172902
# fps: 14.18859244074138
# TIMESTEP 1107 / STATE explore / EPSILON 0.09899500599999847 / ACTION 0 / REWARD 0.1 / Q_MAX  14.080311 / Loss  0.0005530306953005493
# fps: 13.731152134983747
# TIMESTEP 1108 / STATE explore / EPSILON 0.09899400699999847 / ACTION 0 / REWARD 0.1 / Q_MAX  13.938929 / Loss  0.0004214256186969578
# fps: 10.665283382536547
# TIMESTEP 1109 / STATE explore / EPSILON 0.09899300799999847 / ACTION 0 / REWARD 0.1 / Q_MAX  13.800686 / Loss  0.002069871872663498
# fps: 11.148392584224865
# TIMESTEP 1110 / STATE explore / EPSILON 0.09899200899999847 / ACTION 0 / REWARD 0.1 / Q_MAX  13.66619 / Loss  0.00043966775410808623
# fps: 9.48937556561086
# TIMESTEP 1111 / STATE explore / EPSILON 0.09899100999999846 / ACTION 1 / REWARD 0.1 / Q_MAX  11.48743 / Loss  0.0004235817468725145
# fps: 11.078984209497547
# TIMESTEP 1112 / STATE explore / EPSILON 0.09899001099999846 / ACTION 1 / REWARD 0.1 / Q_MAX  13.409612 / Loss  0.0003020644944626838
# fps: 9.512942697406471
# TIMESTEP 1113 / STATE explore / EPSILON 0.09898901199999846 / ACTION 1 / REWARD 0.1 / Q_MAX  13.288034 / Loss  0.00029003541567362845
# fps: 10.22851290055114
# TIMESTEP 1114 / STATE explore / EPSILON 0.09898801299999846 / ACTION 1 / REWARD 0.1 / Q_MAX  13.168344 / Loss  0.0007519868668168783
# ----------Random Action----------
# fps: 11.841592767948143
# TIMESTEP 1115 / STATE explore / EPSILON 0.09898701399999846 / ACTION 1 / REWARD 0.1 / Q_MAX  13.057778 / Loss  0.0007582445978187025
# fps: 9.929414884046855
# TIMESTEP 1116 / STATE explore / EPSILON 0.09898601499999846 / ACTION 1 / REWARD 0.1 / Q_MAX  12.957716 / Loss  0.00018297095084562898
# ----------Random Action----------
# fps: 14.531868010033676
# TIMESTEP 1117 / STATE explore / EPSILON 0.09898501599999845 / ACTION 0 / REWARD 0.1 / Q_MAX  12.861183 / Loss  0.00017938759992830455
# fps: 10.707102578044628
# TIMESTEP 1118 / STATE explore / EPSILON 0.09898401699999845 / ACTION 1 / REWARD 0.1 / Q_MAX  12.766728 / Loss  0.0002072690549539402
# fps: 8.848387933817
# TIMESTEP 1119 / STATE explore / EPSILON 0.09898301799999845 / ACTION 1 / REWARD 0.1 / Q_MAX  12.672882 / Loss  0.0004294624668546021
# fps: 9.163030702885031
# TIMESTEP 1120 / STATE explore / EPSILON 0.09898201899999845 / ACTION 1 / REWARD 0.1 / Q_MAX  12.58363 / Loss  0.00027550029335543513
# fps: 9.221939325180621
# TIMESTEP 1121 / STATE explore / EPSILON 0.09898101999999845 / ACTION 1 / REWARD 0.1 / Q_MAX  12.494018 / Loss  0.00025339785497635603
# fps: 10.232805058942931
# TIMESTEP 1122 / STATE explore / EPSILON 0.09898002099999845 / ACTION 1 / REWARD 0.1 / Q_MAX  12.402369 / Loss  0.000143821511301212
# fps: 12.270576739668478
# TIMESTEP 1123 / STATE explore / EPSILON 0.09897902199999845 / ACTION 0 / REWARD 0.1 / Q_MAX  12.314596 / Loss  0.0001189601025544107
# fps: 14.404654213760015
# TIMESTEP 1124 / STATE explore / EPSILON 0.09897802299999844 / ACTION 0 / REWARD 0.1 / Q_MAX  12.229532 / Loss  0.00011707319208653644
# fps: 13.74271466110969
# TIMESTEP 1125 / STATE explore / EPSILON 0.09897702399999844 / ACTION 0 / REWARD 0.1 / Q_MAX  12.148244 / Loss  0.00012030885409330949
# fps: 12.743105580249313
# TIMESTEP 1126 / STATE explore / EPSILON 0.09897602499999844 / ACTION 0 / REWARD 0.1 / Q_MAX  12.070533 / Loss  0.0001072195591405034
# ----------Random Action----------
# fps: 10.753274588577332
# TIMESTEP 1127 / STATE explore / EPSILON 0.09897502599999844 / ACTION 1 / REWARD 0.1 / Q_MAX  11.994946 / Loss  0.000102415811852552
# ----------Random Action----------
# fps: 9.213269309340445
# TIMESTEP 1128 / STATE explore / EPSILON 0.09897402699999844 / ACTION 1 / REWARD 0.1 / Q_MAX  11.919875 / Loss  0.00013415500870905817
# ----------Random Action----------
# fps: 13.111625173496055
# TIMESTEP 1129 / STATE explore / EPSILON 0.09897302799999844 / ACTION 0 / REWARD 0.1 / Q_MAX  11.846663 / Loss  0.0001578920055180788
# fps: 10.385513827777379
# TIMESTEP 1130 / STATE explore / EPSILON 0.09897202899999843 / ACTION 1 / REWARD 0.1 / Q_MAX  11.775911 / Loss  0.0001356459251837805
# fps: 9.039214503073197
# TIMESTEP 1131 / STATE explore / EPSILON 0.09897102999999843 / ACTION 1 / REWARD 0.1 / Q_MAX  11.707125 / Loss  8.584371244069189e-05
# fps: 8.370577775471634
# TIMESTEP 1132 / STATE explore / EPSILON 0.09897003099999843 / ACTION 1 / REWARD 0.1 / Q_MAX  11.639765 / Loss  6.441294681280851e-05
# fps: 8.961058328116755
# TIMESTEP 1133 / STATE explore / EPSILON 0.09896903199999843 / ACTION 1 / REWARD 0.1 / Q_MAX  11.573995 / Loss  5.015228089177981e-05
# fps: 11.719894154169426
# TIMESTEP 1134 / STATE explore / EPSILON 0.09896803299999843 / ACTION 0 / REWARD 0.1 / Q_MAX  11.511633 / Loss  8.75722907949239e-05
# fps: 13.193037198271252
# TIMESTEP 1135 / STATE explore / EPSILON 0.09896703399999843 / ACTION 0 / REWARD 0.1 / Q_MAX  11.4491415 / Loss  5.798527126898989e-05
# fps: 13.774442609006925
# TIMESTEP 1136 / STATE explore / EPSILON 0.09896603499999843 / ACTION 0 / REWARD 0.1 / Q_MAX  11.387858 / Loss  5.773139127995819e-05
# fps: 14.06271772330574
# TIMESTEP 1137 / STATE explore / EPSILON 0.09896503599999842 / ACTION 0 / REWARD 0.1 / Q_MAX  11.329731 / Loss  6.08656628173776e-05
# fps: 10.24465211253157
# TIMESTEP 1138 / STATE explore / EPSILON 0.09896403699999842 / ACTION 1 / REWARD 0.1 / Q_MAX  11.27034 / Loss  3.7804733437951654e-05
# fps: 8.971523786504333
# TIMESTEP 1139 / STATE explore / EPSILON 0.09896303799999842 / ACTION 1 / REWARD 0.1 / Q_MAX  11.020226 / Loss  2.4420160116278566e-05
# fps: 9.40070690702402
# TIMESTEP 1140 / STATE explore / EPSILON 0.09896203899999842 / ACTION 1 / REWARD 0.1 / Q_MAX  11.161544 / Loss  2.9884577088523656e-05
# fps: 10.004708598798281
# TIMESTEP 1141 / STATE explore / EPSILON 0.09896103999999842 / ACTION 1 / REWARD 0.1 / Q_MAX  11.110651 / Loss  3.724871203303337e-05
# fps: 10.018736593685357
# TIMESTEP 1142 / STATE explore / EPSILON 0.09896004099999842 / ACTION 1 / REWARD 0.1 / Q_MAX  11.061391 / Loss  3.2201758585870266e-05
# ----------Random Action----------
# fps: 11.28732972007083
# TIMESTEP 1143 / STATE explore / EPSILON 0.09895904199999841 / ACTION 1 / REWARD 0.1 / Q_MAX  11.013526 / Loss  3.205963002983481e-05
# fps: 10.752805935405803
# TIMESTEP 1144 / STATE explore / EPSILON 0.09895804299999841 / ACTION 1 / REWARD 0.1 / Q_MAX  10.776561 / Loss  3.414919774513692e-05
# fps: 10.405197756371296
# TIMESTEP 1145 / STATE explore / EPSILON 0.09895704399999841 / ACTION 1 / REWARD 0.1 / Q_MAX  10.91968 / Loss  3.778588506975211e-05
# fps: 13.278240333293233
# TIMESTEP 1146 / STATE explore / EPSILON 0.09895604499999841 / ACTION 0 / REWARD 0.1 / Q_MAX  10.874946 / Loss  3.1398994906339794e-05
# fps: 14.319233631714429
# TIMESTEP 1147 / STATE explore / EPSILON 0.09895504599999841 / ACTION 0 / REWARD 0.1 / Q_MAX  10.628385 / Loss  1.4296084373199847e-05
# fps: 14.440162362589126
# TIMESTEP 1148 / STATE explore / EPSILON 0.09895404699999841 / ACTION 0 / REWARD 0.1 / Q_MAX  10.788973 / Loss  1.3441504052025266e-05
# fps: 14.120286425106299
# TIMESTEP 1149 / STATE explore / EPSILON 0.0989530479999984 / ACTION 0 / REWARD 0.1 / Q_MAX  10.530865 / Loss  1.9196959328837693e-05
# ----------Random Action----------
# fps: 14.719696783589816
# TIMESTEP 1150 / STATE explore / EPSILON 0.0989520489999984 / ACTION 0 / REWARD 0.1 / Q_MAX  10.708314 / Loss  1.0431853297632188e-05
# fps: 11.01697078901955
# TIMESTEP 1151 / STATE explore / EPSILON 0.0989510499999984 / ACTION 1 / REWARD 0.1 / Q_MAX  10.667851 / Loss  1.6553916793782264e-05
# fps: 10.2007510165963
# TIMESTEP 1152 / STATE explore / EPSILON 0.0989500509999984 / ACTION 1 / REWARD 0.1 / Q_MAX  10.410963 / Loss  5.026213329983875e-05
# fps: 8.071479567781852
# TIMESTEP 1153 / STATE explore / EPSILON 0.0989490519999984 / ACTION 1 / REWARD 0.1 / Q_MAX  10.584915 / Loss  1.2674967365455814e-05
# fps: 9.52480265966627
# TIMESTEP 1154 / STATE explore / EPSILON 0.0989480529999984 / ACTION 1 / REWARD 0.1 / Q_MAX  10.544716 / Loss  7.812396688677836e-06
# fps: 9.515748397708581
# TIMESTEP 1155 / STATE explore / EPSILON 0.0989470539999984 / ACTION 0 / REWARD 0.1 / Q_MAX  10.50481 / Loss  7.056342383293668e-06
# fps: 11.45355692638742
# TIMESTEP 1156 / STATE explore / EPSILON 0.0989460549999984 / ACTION 0 / REWARD 0.1 / Q_MAX  10.466727 / Loss  2.2475294827017933e-05
# fps: 11.694373501366197
# TIMESTEP 1157 / STATE explore / EPSILON 0.0989450559999984 / ACTION 0 / REWARD 0.1 / Q_MAX  10.430303 / Loss  1.048443573381519e-05
# fps: 12.005094782999453
# TIMESTEP 1158 / STATE explore / EPSILON 0.09894405699999839 / ACTION 0 / REWARD 0.1 / Q_MAX  10.398149 / Loss  1.2493337635532953e-05
# fps: 10.98479943849063
# TIMESTEP 1159 / STATE explore / EPSILON 0.09894305799999839 / ACTION 1 / REWARD 0.1 / Q_MAX  10.366323 / Loss  5.058157512394246e-06
# ----------Random Action----------
# fps: 11.359750829440044
# TIMESTEP 1160 / STATE explore / EPSILON 0.09894205899999839 / ACTION 1 / REWARD 0.1 / Q_MAX  10.338456 / Loss  4.788297246705042e-06
# ----------Random Action----------
# fps: 10.99519486613521
# TIMESTEP 1161 / STATE explore / EPSILON 0.09894105999999839 / ACTION 1 / REWARD 0.1 / Q_MAX  10.312727 / Loss  3.6632325191021664e-06
# fps: 9.149219187972943
# TIMESTEP 1162 / STATE explore / EPSILON 0.09894006099999839 / ACTION 1 / REWARD 0.1 / Q_MAX  10.290601 / Loss  1.5849571354920045e-05
# ----------Random Action----------
# fps: 11.963865697228316
# TIMESTEP 1163 / STATE explore / EPSILON 0.09893906199999838 / ACTION 0 / REWARD 0.1 / Q_MAX  10.271515 / Loss  2.7720384423446376e-06
# fps: 9.910130093518006
# TIMESTEP 1164 / STATE explore / EPSILON 0.09893806299999838 / ACTION 1 / REWARD 0.1 / Q_MAX  10.253974 / Loss  2.980061708512949e-06
# fps: 11.614838445264125
# TIMESTEP 1165 / STATE explore / EPSILON 0.09893706399999838 / ACTION 0 / REWARD 0.1 / Q_MAX  10.235342 / Loss  2.687301957848831e-06
# fps: 12.172680494649807
# TIMESTEP 1166 / STATE explore / EPSILON 0.09893606499999838 / ACTION 0 / REWARD 0.1 / Q_MAX  10.300871 / Loss  1.1477935913717374e-05
# ----------Random Action----------
# fps: 11.876497904632462
# TIMESTEP 1167 / STATE explore / EPSILON 0.09893506599999838 / ACTION 0 / REWARD 0.1 / Q_MAX  10.205081 / Loss  5.930786301178159e-06
# fps: 8.175680575102042
# TIMESTEP 1168 / STATE explore / EPSILON 0.09893406699999838 / ACTION 1 / REWARD 0.1 / Q_MAX  10.191115 / Loss  1.8363065237281262e-06
# fps: 5.944594835918965
# TIMESTEP 1169 / STATE explore / EPSILON 0.09893306799999838 / ACTION 1 / REWARD 0.1 / Q_MAX  10.179017 / Loss  2.384442723268876e-06
# fps: 7.351489296067922
# TIMESTEP 1170 / STATE explore / EPSILON 0.09893206899999837 / ACTION 1 / REWARD 0.1 / Q_MAX  10.167096 / Loss  5.371009137888905e-06
# fps: 9.747440146131286
# TIMESTEP 1171 / STATE explore / EPSILON 0.09893106999999837 / ACTION 1 / REWARD 0.1 / Q_MAX  10.154666 / Loss  1.2446796517906478e-06
# fps: 9.826177814220452
# TIMESTEP 1172 / STATE explore / EPSILON 0.09893007099999837 / ACTION 1 / REWARD 0.1 / Q_MAX  10.143468 / Loss  1.4480566505881143e-06
# fps: 10.005901956901878
# TIMESTEP 1173 / STATE explore / EPSILON 0.09892907199999837 / ACTION 1 / REWARD 0.1 / Q_MAX  10.133671 / Loss  2.7771420718636364e-06
# fps: 8.487452876196182
# TIMESTEP 1174 / STATE explore / EPSILON 0.09892807299999837 / ACTION 0 / REWARD 0.1 / Q_MAX  10.124033 / Loss  2.0677584871009458e-06
# fps: 8.678828008607846
# TIMESTEP 1175 / STATE explore / EPSILON 0.09892707399999837 / ACTION 0 / REWARD 0.1 / Q_MAX  10.11442 / Loss  3.8464801832560624e-07
# fps: 12.179997676849808
# TIMESTEP 1176 / STATE explore / EPSILON 0.09892607499999836 / ACTION 0 / REWARD 0.1 / Q_MAX  10.107081 / Loss  9.010716894408688e-06
# fps: 13.41739336280638
# TIMESTEP 1177 / STATE explore / EPSILON 0.09892507599999836 / ACTION 0 / REWARD 0.1 / Q_MAX  10.101789 / Loss  1.0657689927029423e-05
# ----------Random Action----------
# fps: 10.823312044384233
# TIMESTEP 1178 / STATE explore / EPSILON 0.09892407699999836 / ACTION 0 / REWARD 0.1 / Q_MAX  10.098485 / Loss  3.5778484743786976e-06
# fps: 9.05140627596372
# TIMESTEP 1179 / STATE explore / EPSILON 0.09892307799999836 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0947275 / Loss  1.0702649433369515e-06
# fps: 9.185867841718425
# TIMESTEP 1180 / STATE explore / EPSILON 0.09892207899999836 / ACTION 1 / REWARD 0.1 / Q_MAX  10.092988 / Loss  2.257513642689446e-06
# fps: 9.062397234375844
# TIMESTEP 1181 / STATE explore / EPSILON 0.09892107999999836 / ACTION 1 / REWARD 0.1 / Q_MAX  10.091781 / Loss  7.765923328406643e-06
# fps: 9.65428472781678
# TIMESTEP 1182 / STATE explore / EPSILON 0.09892008099999836 / ACTION 1 / REWARD 0.1 / Q_MAX  10.09114 / Loss  1.8730179363046773e-06
# fps: 9.375071805520475
# TIMESTEP 1183 / STATE explore / EPSILON 0.09891908199999835 / ACTION 1 / REWARD 0.1 / Q_MAX  10.090745 / Loss  1.8599007489683572e-07
# fps: 7.5559430733201225
# TIMESTEP 1184 / STATE explore / EPSILON 0.09891808299999835 / ACTION 1 / REWARD 0.1 / Q_MAX  10.092925 / Loss  3.089985739279655e-06
# fps: 6.852027197014993
# TIMESTEP 1185 / STATE explore / EPSILON 0.09891708399999835 / ACTION 1 / REWARD 0.1 / Q_MAX  10.093252 / Loss  1.0965802175633144e-05
# fps: 7.835646431340314
# TIMESTEP 1186 / STATE explore / EPSILON 0.09891608499999835 / ACTION 1 / REWARD 0.1 / Q_MAX  10.092995 / Loss  2.0790394046343863e-06
# fps: 10.10344561782163
# TIMESTEP 1187 / STATE explore / EPSILON 0.09891508599999835 / ACTION 0 / REWARD 0.1 / Q_MAX  10.094251 / Loss  2.613333435874665e-06
# fps: 14.077396575218328
# TIMESTEP 1188 / STATE explore / EPSILON 0.09891408699999835 / ACTION 0 / REWARD 0.1 / Q_MAX  10.096521 / Loss  2.925837179645896e-05
# fps: 13.942114832949404
# TIMESTEP 1189 / STATE explore / EPSILON 0.09891308799999834 / ACTION 0 / REWARD 0.1 / Q_MAX  10.433551 / Loss  2.55608620136627e-06
# fps: 10.983102331317903
# TIMESTEP 1190 / STATE explore / EPSILON 0.09891208899999834 / ACTION 1 / REWARD 0.1 / Q_MAX  10.43521 / Loss  2.1896400994592113e-06
# fps: 11.268891623365807
# TIMESTEP 1191 / STATE explore / EPSILON 0.09891108999999834 / ACTION 1 / REWARD 0.1 / Q_MAX  10.443988 / Loss  8.364016139239538e-06
# fps: 11.269769703874273
# TIMESTEP 1192 / STATE explore / EPSILON 0.09891009099999834 / ACTION 1 / REWARD 0.1 / Q_MAX  10.110938 / Loss  4.817755780095467e-06
# fps: 11.154826493053339
# TIMESTEP 1193 / STATE explore / EPSILON 0.09890909199999834 / ACTION 1 / REWARD 0.1 / Q_MAX  10.115427 / Loss  4.4375224206305575e-06
# fps: 11.225612024505068
# TIMESTEP 1194 / STATE explore / EPSILON 0.09890809299999834 / ACTION 1 / REWARD 0.1 / Q_MAX  10.120356 / Loss  5.145247996551916e-06
# fps: 10.828397570112278
# TIMESTEP 1195 / STATE explore / EPSILON 0.09890709399999834 / ACTION 0 / REWARD 0.1 / Q_MAX  10.125069 / Loss  4.998937583877705e-06
# fps: 11.405096300002448
# TIMESTEP 1196 / STATE explore / EPSILON 0.09890609499999833 / ACTION 0 / REWARD 0.1 / Q_MAX  10.128957 / Loss  1.7939748886419693e-06
# fps: 10.431412341699744
# TIMESTEP 1197 / STATE explore / EPSILON 0.09890509599999833 / ACTION 0 / REWARD 0.1 / Q_MAX  10.462541 / Loss  6.165263584989589e-06
# ----------Random Action----------
# fps: 10.57141488913925
# TIMESTEP 1198 / STATE explore / EPSILON 0.09890409699999833 / ACTION 1 / REWARD 0.1 / Q_MAX  10.460299 / Loss  8.95473021955695e-06
# fps: 11.2827752431781
# TIMESTEP 1199 / STATE explore / EPSILON 0.09890309799999833 / ACTION 1 / REWARD 0.1 / Q_MAX  10.146336 / Loss  3.058123411392444e-06
# fps: 9.961747193266214
# TIMESTEP 1200 / STATE explore / EPSILON 0.09890209899999833 / ACTION 1 / REWARD 0.1 / Q_MAX  10.149259 / Loss  2.191030716858222e-06
# fps: 9.601640905428173
# TIMESTEP 1201 / STATE explore / EPSILON 0.09890109999999833 / ACTION 1 / REWARD 0.1 / Q_MAX  10.154946 / Loss  4.448521394806448e-06
# fps: 12.95922188509952
# TIMESTEP 1202 / STATE explore / EPSILON 0.09890010099999832 / ACTION 0 / REWARD 0.1 / Q_MAX  10.159341 / Loss  1.3685405065189116e-05
# fps: 14.33322853588857
# TIMESTEP 1203 / STATE explore / EPSILON 0.09889910199999832 / ACTION 0 / REWARD 0.1 / Q_MAX  10.16397 / Loss  1.5409355000883806e-06
# ----------Random Action----------
# fps: 13.170169874713475
# TIMESTEP 1204 / STATE explore / EPSILON 0.09889810299999832 / ACTION 0 / REWARD 0.1 / Q_MAX  10.170462 / Loss  2.6921770768240094e-06
# fps: 8.93208994478009
# TIMESTEP 1205 / STATE explore / EPSILON 0.09889710399999832 / ACTION 1 / REWARD 0.1 / Q_MAX  10.176362 / Loss  8.687413355801255e-06
# fps: 10.114019223442375
# TIMESTEP 1206 / STATE explore / EPSILON 0.09889610499999832 / ACTION 0 / REWARD 0.1 / Q_MAX  10.181587 / Loss  2.9569393973361002e-06
# fps: 7.842341837001802
# TIMESTEP 1207 / STATE explore / EPSILON 0.09889510599999832 / ACTION 0 / REWARD 0.1 / Q_MAX  10.400903 / Loss  1.1477930002001813e-06
# ----------Random Action----------
# fps: 8.654634144328366
# TIMESTEP 1208 / STATE explore / EPSILON 0.09889410699999832 / ACTION 1 / REWARD 0.1 / Q_MAX  10.191078 / Loss  5.685641554009635e-06
# fps: 10.376444160766328
# TIMESTEP 1209 / STATE explore / EPSILON 0.09889310799999831 / ACTION 0 / REWARD 0.1 / Q_MAX  10.386117 / Loss  4.8647898438503034e-06
# fps: 9.632335109314717
# TIMESTEP 1210 / STATE explore / EPSILON 0.09889210899999831 / ACTION 1 / REWARD 0.1 / Q_MAX  10.382306 / Loss  1.8391237972537056e-06
# fps: 11.343283905008912
# TIMESTEP 1211 / STATE explore / EPSILON 0.09889110999999831 / ACTION 1 / REWARD 0.1 / Q_MAX  10.377601 / Loss  3.1651672998123104e-06
# fps: 11.052679566673605
# TIMESTEP 1212 / STATE explore / EPSILON 0.09889011099999831 / ACTION 1 / REWARD 0.1 / Q_MAX  10.366989 / Loss  1.945922349477769e-06
# fps: 12.323936792247707
# TIMESTEP 1213 / STATE explore / EPSILON 0.09888911199999831 / ACTION 0 / REWARD 0.1 / Q_MAX  10.207098 / Loss  1.870986352514592e-06
# fps: 13.719474419319702
# TIMESTEP 1214 / STATE explore / EPSILON 0.0988881129999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.205663 / Loss  2.751868350969744e-06
# fps: 12.928264735889824
# TIMESTEP 1215 / STATE explore / EPSILON 0.0988871139999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.204228 / Loss  2.9693765100091696e-06
# fps: 11.482875493475987
# TIMESTEP 1216 / STATE explore / EPSILON 0.0988861149999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.201472 / Loss  1.5990407291610609e-06
# fps: 12.026747106793444
# TIMESTEP 1217 / STATE explore / EPSILON 0.0988851159999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.197658 / Loss  1.8627368945089984e-06
# fps: 10.722238980719775
# TIMESTEP 1218 / STATE explore / EPSILON 0.0988841169999983 / ACTION 1 / REWARD 0.1 / Q_MAX  10.193001 / Loss  2.9734394502156647e-06
# fps: 10.469689027343028
# TIMESTEP 1219 / STATE explore / EPSILON 0.0988831179999983 / ACTION 1 / REWARD 0.1 / Q_MAX  10.187596 / Loss  4.3848203858942725e-06
# fps: 8.998315887934679
# TIMESTEP 1220 / STATE explore / EPSILON 0.0988821189999983 / ACTION 1 / REWARD 0.1 / Q_MAX  10.255654 / Loss  1.806554791983217e-06
# fps: 8.86306562926586
# TIMESTEP 1221 / STATE explore / EPSILON 0.0988811199999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.175604 / Loss  1.3839110124536091e-06
# ----------Random Action----------
# fps: 9.918684036900316
# TIMESTEP 1222 / STATE explore / EPSILON 0.0988801209999983 / ACTION 0 / REWARD 0.1 / Q_MAX  10.167763 / Loss  4.1069608869293006e-07
# fps: 14.005008581369413
# TIMESTEP 1223 / STATE explore / EPSILON 0.09887912199999829 / ACTION 0 / REWARD 0.1 / Q_MAX  10.159842 / Loss  3.188810751453275e-06
# ----------Random Action----------
# fps: 14.409652461899984
# TIMESTEP 1224 / STATE explore / EPSILON 0.09887812299999829 / ACTION 0 / REWARD 0.1 / Q_MAX  10.152091 / Loss  9.039325732373982e-07
# ----------Random Action----------
# fps: 11.36193566912454
# TIMESTEP 1225 / STATE explore / EPSILON 0.09887712399999829 / ACTION 0 / REWARD 0.1 / Q_MAX  10.143472 / Loss  4.8161409722524695e-06
# fps: 12.509070954157608
# TIMESTEP 1226 / STATE explore / EPSILON 0.09887612499999829 / ACTION 0 / REWARD 0.1 / Q_MAX  10.135392 / Loss  1.0404028216726147e-06
# fps: 9.038474302338111
# TIMESTEP 1227 / STATE explore / EPSILON 0.09887512599999829 / ACTION 1 / REWARD 0.1 / Q_MAX  10.1272545 / Loss  8.609937367509701e-07
# fps: 9.735313368954168
# TIMESTEP 1228 / STATE explore / EPSILON 0.09887412699999829 / ACTION 1 / REWARD 0.1 / Q_MAX  10.197578 / Loss  2.323813532711938e-06
# ----------Random Action----------
# fps: 12.968638206165995
# TIMESTEP 1229 / STATE explore / EPSILON 0.09887312799999828 / ACTION 0 / REWARD 0.1 / Q_MAX  10.195942 / Loss  2.4748344458203064e-06
# fps: 9.523721293533693
# TIMESTEP 1230 / STATE explore / EPSILON 0.09887212899999828 / ACTION 1 / REWARD 0.1 / Q_MAX  10.102934 / Loss  2.6980735583492788e-06
# fps: 12.173599078193886
# TIMESTEP 1231 / STATE explore / EPSILON 0.09887112999999828 / ACTION 0 / REWARD 0.1 / Q_MAX  10.197685 / Loss  1.1920358247152762e-06
# fps: 13.739653421561242
# TIMESTEP 1232 / STATE explore / EPSILON 0.09887013099999828 / ACTION 0 / REWARD 0.1 / Q_MAX  10.08985 / Loss  3.5695661608770024e-06
# ----------Random Action----------
# fps: 11.153728942014919
# TIMESTEP 1233 / STATE explore / EPSILON 0.09886913199999828 / ACTION 1 / REWARD 0.1 / Q_MAX  10.084805 / Loss  4.4706066546496e-06
# fps: 13.72082083424657
# TIMESTEP 1234 / STATE explore / EPSILON 0.09886813299999828 / ACTION 0 / REWARD 0.1 / Q_MAX  10.080273 / Loss  6.843595201644348e-07
# fps: 14.362825100590703
# TIMESTEP 1235 / STATE explore / EPSILON 0.09886713399999827 / ACTION 0 / REWARD 0.1 / Q_MAX  10.0756645 / Loss  6.55152803119563e-07
# fps: 11.55748564374442
# TIMESTEP 1236 / STATE explore / EPSILON 0.09886613499999827 / ACTION 1 / REWARD 0.1 / Q_MAX  10.070693 / Loss  4.2856763116105867e-07
# fps: 10.680464874665146
# TIMESTEP 1237 / STATE explore / EPSILON 0.09886513599999827 / ACTION 1 / REWARD 0.1 / Q_MAX  10.066196 / Loss  1.2050550139974803e-06
# ----------Random Action----------
# fps: 11.636944760425047
# TIMESTEP 1238 / STATE explore / EPSILON 0.09886413699999827 / ACTION 1 / REWARD 0.1 / Q_MAX  10.062761 / Loss  2.031524672929663e-06
# fps: 11.958237585033045
# TIMESTEP 1239 / STATE explore / EPSILON 0.09886313799999827 / ACTION 1 / REWARD 0.1 / Q_MAX  10.059916 / Loss  9.943410077539738e-07
# fps: 11.00497470666023
# TIMESTEP 1240 / STATE explore / EPSILON 0.09886213899999827 / ACTION 0 / REWARD 0.1 / Q_MAX  10.057128 / Loss  4.807355935554369e-07
# ----------Random Action----------
# fps: 11.206835834693784
# TIMESTEP 1241 / STATE explore / EPSILON 0.09886113999999827 / ACTION 0 / REWARD 0.1 / Q_MAX  10.054609 / Loss  1.4431151384997065e-06
# fps: 9.806213892766046
# TIMESTEP 1242 / STATE explore / EPSILON 0.09886014099999826 / ACTION 0 / REWARD 0.1 / Q_MAX  10.054278 / Loss  9.707073331810534e-07
# fps: 9.036604861401369
# TIMESTEP 1243 / STATE explore / EPSILON 0.09885914199999826 / ACTION 1 / REWARD 0.1 / Q_MAX  10.053383 / Loss  2.5989847927121446e-06
# fps: 7.939787681916617
# TIMESTEP 1244 / STATE explore / EPSILON 0.09885814299999826 / ACTION 1 / REWARD 0.1 / Q_MAX  10.251012 / Loss  1.4422282674786402e-06
# fps: 13.446471278444246
# TIMESTEP 1245 / STATE explore / EPSILON 0.09885714399999826 / ACTION 0 / REWARD 0.1 / Q_MAX  10.246836 / Loss  5.361123953662172e-07
# fps: 14.004447442053035
# TIMESTEP 1246 / STATE explore / EPSILON 0.09885614499999826 / ACTION 0 / REWARD 0.1 / Q_MAX  10.053411 / Loss  3.779810413107043e-06
# fps: 13.87482467515283
# TIMESTEP 1247 / STATE explore / EPSILON 0.09885514599999826 / ACTION 0 / REWARD 0.1 / Q_MAX  10.05493 / Loss  1.0426812195873936e-06
# fps: 10.782605118923977
# TIMESTEP 1248 / STATE explore / EPSILON 0.09885414699999825 / ACTION 1 / REWARD 0.1 / Q_MAX  10.233441 / Loss  5.611603910438134e-07
# fps: 10.696889863684472
# TIMESTEP 1249 / STATE explore / EPSILON 0.09885314799999825 / ACTION 1 / REWARD 0.1 / Q_MAX  10.059483 / Loss  1.0058181487693219e-06
# fps: 13.522815275740331
# TIMESTEP 1250 / STATE explore / EPSILON 0.09885214899999825 / ACTION 0 / REWARD 0.1 / Q_MAX  10.061228 / Loss  1.1169221352247405e-06
# ----------Random Action----------
# fps: 14.118717895204561
# TIMESTEP 1251 / STATE explore / EPSILON 0.09885114999999825 / ACTION 0 / REWARD 0.1 / Q_MAX  10.205213 / Loss  4.997319820176926e-07
# fps: 13.405857366134924
# TIMESTEP 1252 / STATE explore / EPSILON 0.09885015099999825 / ACTION 0 / REWARD 0.1 / Q_MAX  10.06305 / Loss  2.180223361847311e-07
# fps: 14.098358672013392
# TIMESTEP 1253 / STATE explore / EPSILON 0.09884915199999825 / ACTION 0 / REWARD 0.1 / Q_MAX  10.064341 / Loss  7.619440225425933e-07
# fps: 13.853057261098321
# TIMESTEP 1254 / STATE explore / EPSILON 0.09884815299999825 / ACTION 0 / REWARD 0.1 / Q_MAX  10.065219 / Loss  9.536510106045171e-07
# fps: 11.406523057509839
# TIMESTEP 1255 / STATE explore / EPSILON 0.09884715399999824 / ACTION 1 / REWARD 0.1 / Q_MAX  10.154025 / Loss  4.006022322755598e-07
# fps: 11.439000509999536
# TIMESTEP 1256 / STATE explore / EPSILON 0.09884615499999824 / ACTION 1 / REWARD 0.1 / Q_MAX  10.067346 / Loss  2.2562926460523158e-07
# fps: 11.74190947571163
# TIMESTEP 1257 / STATE explore / EPSILON 0.09884515599999824 / ACTION 1 / REWARD 0.1 / Q_MAX  10.068413 / Loss  3.9781050986675837e-07
# fps: 14.56532564721407
# TIMESTEP 1258 / STATE explore / EPSILON 0.09884415699999824 / ACTION 0 / REWARD 0.1 / Q_MAX  10.069049 / Loss  1.0351249102313886e-07
# ----------Random Action----------
# fps: 14.635462428249909
# TIMESTEP 1259 / STATE explore / EPSILON 0.09884315799999824 / ACTION 0 / REWARD 0.1 / Q_MAX  10.069617 / Loss  2.8418781994332676e-07
# fps: 14.632705249460122
# TIMESTEP 1260 / STATE explore / EPSILON 0.09884215899999824 / ACTION 0 / REWARD 0.1 / Q_MAX  10.070348 / Loss  2.9647495125573187e-07
# fps: 11.663187985061969
# TIMESTEP 1261 / STATE explore / EPSILON 0.09884115999999823 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0707245 / Loss  2.105366263549513e-07
# fps: 10.102642538339808
# TIMESTEP 1262 / STATE explore / EPSILON 0.09884016099999823 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0721855 / Loss  1.7343302260997007e-07
# fps: 11.371115015073633
# TIMESTEP 1263 / STATE explore / EPSILON 0.09883916199999823 / ACTION 1 / REWARD 0.1 / Q_MAX  10.070489 / Loss  2.2391191123460885e-07
# fps: 11.682354350205694
# TIMESTEP 1264 / STATE explore / EPSILON 0.09883816299999823 / ACTION 1 / REWARD 0.1 / Q_MAX  10.069813 / Loss  1.4504394130199216e-07
# fps: 13.730028413926751
# TIMESTEP 1265 / STATE explore / EPSILON 0.09883716399999823 / ACTION 0 / REWARD 0.1 / Q_MAX  10.068607 / Loss  1.799527353796293e-07
# fps: 14.480993778526594
# TIMESTEP 1266 / STATE explore / EPSILON 0.09883616499999823 / ACTION 0 / REWARD 0.1 / Q_MAX  10.066852 / Loss  2.827323726251052e-07
# fps: 13.996409383655354
# TIMESTEP 1267 / STATE explore / EPSILON 0.09883516599999823 / ACTION 0 / REWARD 0.1 / Q_MAX  10.064891 / Loss  1.13389546640974e-07
# fps: 11.062211860025952
# TIMESTEP 1268 / STATE explore / EPSILON 0.09883416699999822 / ACTION 1 / REWARD 0.1 / Q_MAX  10.01972 / Loss  1.2470209753701056e-07
# fps: 11.909444805683409
# TIMESTEP 1269 / STATE explore / EPSILON 0.09883316799999822 / ACTION 1 / REWARD 0.1 / Q_MAX  10.060123 / Loss  7.710386284998094e-08
# fps: 11.691961174575033
# TIMESTEP 1270 / STATE explore / EPSILON 0.09883216899999822 / ACTION 1 / REWARD 0.1 / Q_MAX  10.057609 / Loss  3.6748284060195147e-07
# fps: 11.901233166678962
# TIMESTEP 1271 / STATE explore / EPSILON 0.09883116999999822 / ACTION 1 / REWARD 0.1 / Q_MAX  10.055067 / Loss  3.8125131140986923e-07
# fps: 14.584926524282109
# TIMESTEP 1272 / STATE explore / EPSILON 0.09883017099999822 / ACTION 0 / REWARD 0.1 / Q_MAX  10.000825 / Loss  1.1289486678833782e-07
# fps: 14.608140818679233
# TIMESTEP 1273 / STATE explore / EPSILON 0.09882917199999822 / ACTION 0 / REWARD 0.1 / Q_MAX  10.000851 / Loss  4.4749322114512324e-07
# fps: 14.082170256341385
# TIMESTEP 1274 / STATE explore / EPSILON 0.09882817299999822 / ACTION 0 / REWARD 0.1 / Q_MAX  10.04768 / Loss  1.0967294201691402e-06
# fps: 14.20315060885584
# TIMESTEP 1275 / STATE explore / EPSILON 0.09882717399999821 / ACTION 0 / REWARD 0.1 / Q_MAX  10.045904 / Loss  1.5161407418418094e-07
# fps: 11.79480661181195
# TIMESTEP 1276 / STATE explore / EPSILON 0.09882617499999821 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0437975 / Loss  2.450159399813856e-07
# fps: 11.882116642539653
# TIMESTEP 1277 / STATE explore / EPSILON 0.09882517599999821 / ACTION 1 / REWARD 0.1 / Q_MAX  10.042056 / Loss  8.746189905650681e-08
# fps: 11.355506642516982
# TIMESTEP 1278 / STATE explore / EPSILON 0.09882417699999821 / ACTION 1 / REWARD 0.1 / Q_MAX  10.040289 / Loss  4.582128099173133e-08
# fps: 14.478694319405706
# TIMESTEP 1279 / STATE explore / EPSILON 0.09882317799999821 / ACTION 0 / REWARD 0.1 / Q_MAX  10.038906 / Loss  8.131917184073245e-08
# ----------Random Action----------
# fps: 10.191604806278779
# TIMESTEP 1280 / STATE explore / EPSILON 0.0988221789999982 / ACTION 0 / REWARD 0.1 / Q_MAX  10.037411 / Loss  8.553982411285688e-08
# fps: 9.831982334656983
# TIMESTEP 1281 / STATE explore / EPSILON 0.0988211799999982 / ACTION 0 / REWARD 0.1 / Q_MAX  10.035782 / Loss  2.1860017795916065e-08
# fps: 8.293875355687339
# TIMESTEP 1282 / STATE explore / EPSILON 0.0988201809999982 / ACTION 1 / REWARD 0.1 / Q_MAX  10.034408 / Loss  2.8293982268223772e-08
# fps: 8.159997509766384
# TIMESTEP 1283 / STATE explore / EPSILON 0.0988191819999982 / ACTION 1 / REWARD 0.1 / Q_MAX  10.034214 / Loss  5.2759560276172124e-08
# ----------Random Action----------
# fps: 10.537313807804685
# TIMESTEP 1284 / STATE explore / EPSILON 0.0988181829999982 / ACTION 1 / REWARD 0.1 / Q_MAX  10.035583 / Loss  4.4791079290007474e-08
# fps: 14.169132178219494
# TIMESTEP 1285 / STATE explore / EPSILON 0.0988171839999982 / ACTION 0 / REWARD 0.1 / Q_MAX  10.029797 / Loss  5.156900328984193e-08
# fps: 14.045717270894588
# TIMESTEP 1286 / STATE explore / EPSILON 0.0988161849999982 / ACTION 0 / REWARD 0.1 / Q_MAX  10.036816 / Loss  5.151568416295049e-08
# fps: 14.752105909207616
# TIMESTEP 1287 / STATE explore / EPSILON 0.0988151859999982 / ACTION 0 / REWARD 0.1 / Q_MAX  10.026882 / Loss  2.5328745323349722e-08
# ----------Random Action----------
# fps: 11.641078872723437
# TIMESTEP 1288 / STATE explore / EPSILON 0.0988141869999982 / ACTION 1 / REWARD 0.1 / Q_MAX  10.025499 / Loss  1.5635748695785878e-08
# fps: 10.0981427890426
# TIMESTEP 1289 / STATE explore / EPSILON 0.09881318799999819 / ACTION 1 / REWARD 0.1 / Q_MAX  10.03742 / Loss  5.40705968887778e-08
# fps: 11.212917713735765
# TIMESTEP 1290 / STATE explore / EPSILON 0.09881218899999819 / ACTION 1 / REWARD 0.1 / Q_MAX  10.022938 / Loss  2.8897005677208654e-08
# fps: 14.102624969318759
# TIMESTEP 1291 / STATE explore / EPSILON 0.09881118999999819 / ACTION 0 / REWARD 0.1 / Q_MAX  10.02161 / Loss  2.7009093628294067e-08
# fps: 13.47619506615516
# TIMESTEP 1292 / STATE explore / EPSILON 0.09881019099999819 / ACTION 0 / REWARD 0.1 / Q_MAX  10.020438 / Loss  1.745365807437338e-08
# fps: 13.787573674677606
# TIMESTEP 1293 / STATE explore / EPSILON 0.09880919199999819 / ACTION 0 / REWARD 0.1 / Q_MAX  10.036275 / Loss  1.686706241343927e-08
# fps: 9.10457344670173
# TIMESTEP 1294 / STATE explore / EPSILON 0.09880819299999818 / ACTION 1 / REWARD 0.1 / Q_MAX  10.017992 / Loss  1.690841600066051e-08
# fps: 8.3235511244116
# TIMESTEP 1295 / STATE explore / EPSILON 0.09880719399999818 / ACTION 1 / REWARD 0.1 / Q_MAX  10.016718 / Loss  1.7172681054944405e-08
# fps: 7.892961584349207
# TIMESTEP 1296 / STATE explore / EPSILON 0.09880619499999818 / ACTION 1 / REWARD 0.1 / Q_MAX  10.015374 / Loss  1.6211686215683585e-08
# fps: 10.959884608148505
# TIMESTEP 1297 / STATE explore / EPSILON 0.09880519599999818 / ACTION 1 / REWARD 0.1 / Q_MAX  10.032888 / Loss  1.6580287365286495e-08
# fps: 11.176316666000506
# TIMESTEP 1298 / STATE explore / EPSILON 0.09880419699999818 / ACTION 1 / REWARD 0.1 / Q_MAX  10.012955 / Loss  4.0753178609520546e-08
# ...
# fps: 12.396053883756258
# TIMESTEP 1914 / STATE explore / EPSILON 0.09818881299999724 / ACTION 1 / REWARD 0.1 / Q_MAX  10.127036 / Loss  1.8491746232029982e-06
# ----------Random Action----------
# fps: 15.108946556966037
# TIMESTEP 1915 / STATE explore / EPSILON 0.09818781399999724 / ACTION 0 / REWARD 0.1 / Q_MAX  10.154134 / Loss  1.3465022448144737e-06
# fps: 12.087958453176245
# TIMESTEP 1916 / STATE explore / EPSILON 0.09818681499999724 / ACTION 1 / REWARD 0.1 / Q_MAX  10.103498 / Loss  1.6659917037031846e-06
# fps: 14.098974755453964
# TIMESTEP 1917 / STATE explore / EPSILON 0.09818581599999723 / ACTION 0 / REWARD 0.1 / Q_MAX  10.101427 / Loss  1.557410314489971e-06
# fps: 10.753164313567643
# TIMESTEP 1918 / STATE explore / EPSILON 0.09818481699999723 / ACTION 1 / REWARD 0.1 / Q_MAX  10.095515 / Loss  1.2877189874416217e-06
# fps: 12.08123856844531
# TIMESTEP 1919 / STATE explore / EPSILON 0.09818381799999723 / ACTION 1 / REWARD 0.1 / Q_MAX  10.00082 / Loss  1.6746596429584315e-06
# fps: 14.417131563117643
# TIMESTEP 1920 / STATE explore / EPSILON 0.09818281899999723 / ACTION 0 / REWARD 0.1 / Q_MAX  10.087725 / Loss  7.647951179023948e-07
# fps: 13.936740952906268
# TIMESTEP 1921 / STATE explore / EPSILON 0.09818181999999723 / ACTION 0 / REWARD 0.1 / Q_MAX  9.969965 / Loss  1.5515779523411766e-06
# ----------Random Action----------
# fps: 12.385438567480097
# TIMESTEP 1922 / STATE explore / EPSILON 0.09818082099999723 / ACTION 0 / REWARD 0.1 / Q_MAX  9.963714 / Loss  6.279817625909345e-07
# fps: 11.07161448022089
# TIMESTEP 1923 / STATE explore / EPSILON 0.09817982199999722 / ACTION 1 / REWARD 0.1 / Q_MAX  10.083912 / Loss  5.966745675323182e-07
# fps: 13.447721523451653
# TIMESTEP 1924 / STATE explore / EPSILON 0.09817882299999722 / ACTION 0 / REWARD 0.1 / Q_MAX  10.08414 / Loss  3.399084675947961e-07
# fps: 13.548675110555507
# TIMESTEP 1925 / STATE explore / EPSILON 0.09817782399999722 / ACTION 0 / REWARD 0.1 / Q_MAX  9.96865 / Loss  1.8515090687287739e-06
# fps: 10.571947804475991
# TIMESTEP 1926 / STATE explore / EPSILON 0.09817682499999722 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0862055 / Loss  1.4337435914058005e-06
# fps: 13.81982807192116
# TIMESTEP 1927 / STATE explore / EPSILON 0.09817582599999722 / ACTION 0 / REWARD 0.1 / Q_MAX  10.090524 / Loss  9.856300948740682e-07
# fps: 13.455832202470894
# TIMESTEP 1928 / STATE explore / EPSILON 0.09817482699999722 / ACTION 0 / REWARD 0.1 / Q_MAX  10.093903 / Loss  2.4653907075844472e-06
# fps: 11.474048480769914
# TIMESTEP 1929 / STATE explore / EPSILON 0.09817382799999722 / ACTION 1 / REWARD 0.1 / Q_MAX  10.098243 / Loss  2.235268311778782e-06
# ----------Random Action----------
# fps: 14.486445413821567
# TIMESTEP 1930 / STATE explore / EPSILON 0.09817282899999721 / ACTION 0 / REWARD 0.1 / Q_MAX  10.058886 / Loss  4.51113834287753e-07
# fps: 15.367522432245277
# TIMESTEP 1931 / STATE explore / EPSILON 0.09817182999999721 / ACTION 0 / REWARD 0.1 / Q_MAX  10.08528 / Loss  1.8671215684662457e-06
# fps: 11.749408930472296
# TIMESTEP 1932 / STATE explore / EPSILON 0.09817083099999721 / ACTION 1 / REWARD 0.1 / Q_MAX  10.115513 / Loss  5.494931428984273e-06
# fps: 14.852666841363485
# TIMESTEP 1933 / STATE explore / EPSILON 0.09816983199999721 / ACTION 0 / REWARD 0.1 / Q_MAX  10.146672 / Loss  1.498686287959572e-06
# fps: 14.652027345674053
# TIMESTEP 1934 / STATE explore / EPSILON 0.09816883299999721 / ACTION 0 / REWARD 0.1 / Q_MAX  10.17486 / Loss  9.58302507569897e-07
# fps: 11.929938733367845
# TIMESTEP 1935 / STATE explore / EPSILON 0.0981678339999972 / ACTION 1 / REWARD 0.1 / Q_MAX  10.19642 / Loss  3.3198493838426657e-06
# ----------Random Action----------
# fps: 12.552910543800317
# TIMESTEP 1936 / STATE explore / EPSILON 0.0981668349999972 / ACTION 1 / REWARD 0.1 / Q_MAX  10.2204 / Loss  1.5220874729493516e-06
# fps: 15.035826695440825
# TIMESTEP 1937 / STATE explore / EPSILON 0.0981658359999972 / ACTION 0 / REWARD 0.1 / Q_MAX  10.134115 / Loss  1.6664650956954574e-06
# fps: 14.974148795264599
# TIMESTEP 1938 / STATE explore / EPSILON 0.0981648369999972 / ACTION 0 / REWARD 0.1 / Q_MAX  10.13567 / Loss  1.8495317135602818e-06
# fps: 14.954608174165417
# TIMESTEP 1939 / STATE explore / EPSILON 0.0981638379999972 / ACTION 0 / REWARD 0.1 / Q_MAX  10.246102 / Loss  1.5566138245048933e-06
# fps: 15.02317068365874
# TIMESTEP 1940 / STATE explore / EPSILON 0.0981628389999972 / ACTION 0 / REWARD 0.1 / Q_MAX  10.135624 / Loss  1.4040672340343008e-06
# fps: 14.450012574802852
# TIMESTEP 1941 / STATE explore / EPSILON 0.0981618399999972 / ACTION 0 / REWARD 0.1 / Q_MAX  10.135319 / Loss  1.2392647477099672e-06
# fps: 12.064488849642032
# TIMESTEP 1942 / STATE explore / EPSILON 0.0981608409999972 / ACTION 1 / REWARD 0.1 / Q_MAX  10.13505 / Loss  2.7211544875171967e-06
# fps: 8.57183964423517
# TIMESTEP 1943 / STATE explore / EPSILON 0.0981598419999972 / ACTION 1 / REWARD 0.1 / Q_MAX  10.206985 / Loss  9.668035545473685e-07
# fps: 12.168689799234071
# TIMESTEP 1944 / STATE explore / EPSILON 0.09815884299999719 / ACTION 0 / REWARD 0.1 / Q_MAX  10.133725 / Loss  4.2902865970972925e-06
# fps: 11.279164638590018
# TIMESTEP 1945 / STATE explore / EPSILON 0.09815784399999719 / ACTION 1 / REWARD 0.1 / Q_MAX  10.184886 / Loss  7.465143312401779e-07
# fps: 11.849052765991107
# TIMESTEP 1946 / STATE explore / EPSILON 0.09815684499999719 / ACTION 1 / REWARD 0.1 / Q_MAX  10.179289 / Loss  9.309726920037065e-06
# fps: 11.811846474022298
# TIMESTEP 1947 / STATE explore / EPSILON 0.09815584599999719 / ACTION 0 / REWARD 0.1 / Q_MAX  10.130834 / Loss  1.749222519720206e-06
# fps: 13.076714908369862
# TIMESTEP 1948 / STATE explore / EPSILON 0.09815484699999719 / ACTION 0 / REWARD 0.1 / Q_MAX  10.180231 / Loss  4.863438334723469e-06
# fps: 10.891354023848104
# TIMESTEP 1949 / STATE explore / EPSILON 0.09815384799999718 / ACTION 1 / REWARD 0.1 / Q_MAX  10.131699 / Loss  1.0552370440564118e-05
# fps: 14.787889899200017
# TIMESTEP 1950 / STATE explore / EPSILON 0.09815284899999718 / ACTION 0 / REWARD 0.1 / Q_MAX  10.227917 / Loss  1.3438332189252833e-06
# fps: 14.733812949640289
# TIMESTEP 1951 / STATE explore / EPSILON 0.09815184999999718 / ACTION 0 / REWARD 0.1 / Q_MAX  10.261159 / Loss  3.1212257454171777e-06
# fps: 12.212554084823639
# TIMESTEP 1952 / STATE explore / EPSILON 0.09815085099999718 / ACTION 1 / REWARD 0.1 / Q_MAX  10.292112 / Loss  4.715204795502359e-06
# fps: 12.320570100842755
# TIMESTEP 1953 / STATE explore / EPSILON 0.09814985199999718 / ACTION 1 / REWARD 0.1 / Q_MAX  10.315769 / Loss  3.5724108329304727e-06
# fps: 13.64666992028632
# TIMESTEP 1954 / STATE explore / EPSILON 0.09814885299999718 / ACTION 0 / REWARD 0.1 / Q_MAX  10.140227 / Loss  3.0127375794108957e-06
# fps: 14.730811646120886
# TIMESTEP 1955 / STATE explore / EPSILON 0.09814785399999718 / ACTION 0 / REWARD 0.1 / Q_MAX  10.352656 / Loss  2.539002707635518e-06
# fps: 11.984102357502664
# TIMESTEP 1956 / STATE explore / EPSILON 0.09814685499999717 / ACTION 1 / REWARD 0.1 / Q_MAX  10.139791 / Loss  2.354918251512572e-06
# fps: 11.63778426432559
# TIMESTEP 1957 / STATE explore / EPSILON 0.09814585599999717 / ACTION 1 / REWARD 0.1 / Q_MAX  10.137035 / Loss  2.151151875295909e-06
# fps: 14.223910308365861
# TIMESTEP 1958 / STATE explore / EPSILON 0.09814485699999717 / ACTION 0 / REWARD 0.1 / Q_MAX  10.337805 / Loss  1.208345747727435e-05
# fps: 11.746875148785769
# TIMESTEP 1959 / STATE explore / EPSILON 0.09814385799999717 / ACTION 1 / REWARD 0.1 / Q_MAX  10.134789 / Loss  2.0925931494275574e-06
# fps: 12.097162535547621
# TIMESTEP 1960 / STATE explore / EPSILON 0.09814285899999717 / ACTION 1 / REWARD 0.1 / Q_MAX  10.13641 / Loss  1.6031242921599187e-05
# fps: 14.83286475628689
# TIMESTEP 1961 / STATE explore / EPSILON 0.09814185999999717 / ACTION 0 / REWARD 0.1 / Q_MAX  10.13712 / Loss  3.312412081868388e-05
# fps: 11.486208785190053
# TIMESTEP 1962 / STATE explore / EPSILON 0.09814086099999716 / ACTION 1 / REWARD 0.1 / Q_MAX  10.143934 / Loss  5.630985469906591e-06
# fps: 11.101622508668378
# TIMESTEP 1963 / STATE explore / EPSILON 0.09813986199999716 / ACTION 1 / REWARD 0.1 / Q_MAX  10.147983 / Loss  3.340748662594706e-06
# fps: 14.504128916245937
# TIMESTEP 1964 / STATE explore / EPSILON 0.09813886299999716 / ACTION 0 / REWARD 0.1 / Q_MAX  10.150853 / Loss  7.449159966199659e-06
# fps: 12.283513638573412
# TIMESTEP 1965 / STATE explore / EPSILON 0.09813786399999716 / ACTION 1 / REWARD 0.1 / Q_MAX  10.152615 / Loss  7.675253073102795e-06
# fps: 14.3651370993705
# TIMESTEP 1966 / STATE explore / EPSILON 0.09813686499999716 / ACTION 0 / REWARD 0.1 / Q_MAX  10.589676 / Loss  9.495168342255056e-06
# fps: 12.047301042932274
# TIMESTEP 1967 / STATE explore / EPSILON 0.09813586599999716 / ACTION 1 / REWARD 0.1 / Q_MAX  10.560427 / Loss  5.395596872403985e-06
# fps: 14.399263953640066
# TIMESTEP 1968 / STATE explore / EPSILON 0.09813486699999716 / ACTION 0 / REWARD 0.1 / Q_MAX  10.515892 / Loss  4.585865553963231e-06
# fps: 14.48624528125939
# TIMESTEP 1969 / STATE explore / EPSILON 0.09813386799999715 / ACTION 0 / REWARD 0.1 / Q_MAX  10.135487 / Loss  4.778742550115567e-06
# ----------Random Action----------
# fps: 11.74868488131719
# TIMESTEP 1970 / STATE explore / EPSILON 0.09813286899999715 / ACTION 1 / REWARD 0.1 / Q_MAX  10.394119 / Loss  4.650747086998308e-06
# fps: 14.223090330762918
# TIMESTEP 1971 / STATE explore / EPSILON 0.09813186999999715 / ACTION 0 / REWARD 0.1 / Q_MAX  10.327701 / Loss  3.0723540476174094e-06
# fps: 12.589420730517677
# TIMESTEP 1972 / STATE explore / EPSILON 0.09813087099999715 / ACTION 0 / REWARD 0.1 / Q_MAX  10.267767 / Loss  1.0873524161070236e-06
# fps: 11.298914639304119
# TIMESTEP 1973 / STATE explore / EPSILON 0.09812987199999715 / ACTION 1 / REWARD 0.1 / Q_MAX  10.098383 / Loss  5.113721272209659e-06
# fps: 13.826661699890225
# TIMESTEP 1974 / STATE explore / EPSILON 0.09812887299999715 / ACTION 0 / REWARD 0.1 / Q_MAX  10.09065 / Loss  1.1245641644563875e-06
# fps: 13.89178178831307
# TIMESTEP 1975 / STATE explore / EPSILON 0.09812787399999714 / ACTION 0 / REWARD 0.1 / Q_MAX  10.131703 / Loss  1.850925059443398e-06
# fps: 11.324418092916137
# TIMESTEP 1976 / STATE explore / EPSILON 0.09812687499999714 / ACTION 1 / REWARD 0.1 / Q_MAX  10.097984 / Loss  2.0488191694312263e-06
# fps: 11.306346352390632
# TIMESTEP 1977 / STATE explore / EPSILON 0.09812587599999714 / ACTION 1 / REWARD 0.1 / Q_MAX  10.070417 / Loss  2.231271025721071e-07
# fps: 13.945081506651196
# TIMESTEP 1978 / STATE explore / EPSILON 0.09812487699999714 / ACTION 0 / REWARD 0.1 / Q_MAX  10.064729 / Loss  1.0557033647273784e-06
# fps: 14.311855731663623
# TIMESTEP 1979 / STATE explore / EPSILON 0.09812387799999714 / ACTION 0 / REWARD 0.1 / Q_MAX  10.059641 / Loss  6.758953531971201e-06
# fps: 11.227865789346883
# TIMESTEP 1980 / STATE explore / EPSILON 0.09812287899999714 / ACTION 1 / REWARD 0.1 / Q_MAX  10.057904 / Loss  1.517767032055417e-05
# fps: 10.471518734521052
# TIMESTEP 1981 / STATE explore / EPSILON 0.09812187999999714 / ACTION 1 / REWARD 0.1 / Q_MAX  10.050719 / Loss  2.511557067919057e-05
# fps: 12.715175252981513
# TIMESTEP 1982 / STATE explore / EPSILON 0.09812088099999713 / ACTION 0 / REWARD 0.1 / Q_MAX  10.060078 / Loss  7.757756975479424e-06
# fps: 13.798868272141071
# TIMESTEP 1983 / STATE explore / EPSILON 0.09811988199999713 / ACTION 0 / REWARD 0.1 / Q_MAX  10.064726 / Loss  4.733951936941594e-05
# fps: 11.025977781399677
# TIMESTEP 1984 / STATE explore / EPSILON 0.09811888299999713 / ACTION 1 / REWARD 0.1 / Q_MAX  10.079365 / Loss  0.00027512997621670365
# fps: 12.295865030854698
# TIMESTEP 1985 / STATE explore / EPSILON 0.09811788399999713 / ACTION 0 / REWARD 0.1 / Q_MAX  10.100596 / Loss  0.00021113082766532898
# fps: 11.263172310823839
# TIMESTEP 1986 / STATE explore / EPSILON 0.09811688499999713 / ACTION 0 / REWARD 0.1 / Q_MAX  10.139596 / Loss  3.341336196172051e-05
# fps: 11.570589549706618
# TIMESTEP 1987 / STATE explore / EPSILON 0.09811588599999713 / ACTION 1 / REWARD 0.1 / Q_MAX  10.94778 / Loss  4.2195842979708686e-05
# fps: 13.851913499517828
# TIMESTEP 1988 / STATE explore / EPSILON 0.09811488699999713 / ACTION 0 / REWARD 0.1 / Q_MAX  10.20486 / Loss  1.8242515579913743e-05
# fps: 11.669872820404382
# TIMESTEP 1989 / STATE explore / EPSILON 0.09811388799999712 / ACTION 0 / REWARD 0.1 / Q_MAX  10.24125 / Loss  5.5549186072312295e-05
# fps: 10.053172008475308
# TIMESTEP 1990 / STATE explore / EPSILON 0.09811288899999712 / ACTION 1 / REWARD 0.1 / Q_MAX  11.410809 / Loss  5.8841433201450855e-05
# fps: 12.435821107935341
# TIMESTEP 1991 / STATE explore / EPSILON 0.09811188999999712 / ACTION 0 / REWARD 0.1 / Q_MAX  10.296621 / Loss  2.125715218426194e-05
# fps: 12.276107520839187
# TIMESTEP 1992 / STATE explore / EPSILON 0.09811089099999712 / ACTION 0 / REWARD 0.1 / Q_MAX  10.318065 / Loss  0.00020067246805410832
# fps: 10.6187599686068
# TIMESTEP 1993 / STATE explore / EPSILON 0.09810989199999712 / ACTION 1 / REWARD 0.1 / Q_MAX  10.36326 / Loss  0.00033893121872097254
# fps: 9.709126936360521
# TIMESTEP 1994 / STATE explore / EPSILON 0.09810889299999712 / ACTION 1 / REWARD 0.1 / Q_MAX  10.409224 / Loss  0.00013852166011929512
# fps: 11.155360514907311
# TIMESTEP 1995 / STATE explore / EPSILON 0.09810789399999711 / ACTION 0 / REWARD 0.1 / Q_MAX  10.46925 / Loss  0.0001712178491288796
# fps: 10.395217654231642
# TIMESTEP 1996 / STATE explore / EPSILON 0.09810689499999711 / ACTION 0 / REWARD 0.1 / Q_MAX  11.985629 / Loss  0.00023722188780084252
# fps: 10.793982160595814
# TIMESTEP 1997 / STATE explore / EPSILON 0.09810589599999711 / ACTION 1 / REWARD 0.1 / Q_MAX  10.594186 / Loss  0.00028886727523058653
# ----------Random Action----------
# fps: 12.445415054478126
# TIMESTEP 1998 / STATE explore / EPSILON 0.09810489699999711 / ACTION 0 / REWARD 0.1 / Q_MAX  10.665638 / Loss  0.00011686739162541926
# fps: 10.955905285566889
# TIMESTEP 1999 / STATE explore / EPSILON 0.09810389799999711 / ACTION 0 / REWARD 0.1 / Q_MAX  10.7207155 / Loss  0.0006910832016728818
# fps: 9.309710785075355
# Now we save model
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-4829a0a02061> in <module>
# ----> 1 playGame(observe=False);
#
# <ipython-input-19-12216cee503d> in playGame(observe)
#       6     model = buildmodel()
#       7     try:
# ----> 8         trainNetwork(model,game_state,observe=observe)
#       9     except StopIteration:
#      10         game.end()
#
# <ipython-input-18-d8111a223a7c> in trainNetwork(model, game_state, observe)
#     120             save_obj(t,"time") #caching time steps
#     121             save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
# --> 122             loss_df.to_csv("./objects/loss_df.csv",index=False)
#     123             scores_df.to_csv("./objects/scores_df.csv",index=False)
#     124             actions_df.to_csv("./objects/actions_df.csv",index=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './objects/loss_df.csv'
