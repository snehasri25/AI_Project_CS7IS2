# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
import _pickle as cPickle
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects_sarsa/loss_df.csv"
actions_file_path = "./objects_sarsa/actions_df.csv"
q_value_file_path = "./objects_sarsa/q_values.csv"
scores_file_path = "./objects_sarsa/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('objects_sarsa/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects_sarsa/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model_sarsa.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    max_Q1 = 0
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model_sarsa.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model_sarsa.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                #new_q=np.argmax(q)
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1 # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                #print(Q_sa.shape)
                new_q=np.argmax(Q_sa)
                #max_Q1 = (1-epsilon)*(np.mean(Q_sa))+epsilon*np.max(Q_sa)
                max_Q1 = np.mean(Q_sa)

                #print(max_Q1)
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * max_Q1
                    #targets[i, action_t] = (targets[i, action_t]* (1-LEARNING_RATE)) + (LEARNING_RATE * (reward_t + GAMMA * max_Q1))
                    
                                                                                                         
            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = max_Q1
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model_sarsa.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects_sarsa/loss_df.csv",index=False)
            scores_df.to_csv("./objects_sarsa/scores_df.csv",index=False)
            actions_df.to_csv("./objects_sarsa/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model_sarsa.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX " , max_Q1, "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 300000 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.119135946 / Loss  0.11727751791477203
# fps: 0.17994786437874005
# TIMESTEP 300001 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8665842 / Loss  0.04455725848674774
# fps: 9.089006869352287
# TIMESTEP 300002 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8569287 / Loss  0.024190392345190048
# fps: 8.432982353142235
# TIMESTEP 300003 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.44173634 / Loss  0.042537886649370193
# fps: 8.86979434311393
# TIMESTEP 300004 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8387265 / Loss  0.004928814712911844
# fps: 7.403772932115818
# TIMESTEP 300005 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8799603 / Loss  0.011493423953652382
# fps: 7.579209101619816
# TIMESTEP 300006 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7954073 / Loss  0.07201085984706879
# fps: 8.494603664525956
# TIMESTEP 300007 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.503662 / Loss  0.05360764265060425
# fps: 7.145516743216169
# TIMESTEP 300008 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8195708 / Loss  0.022551279515028
# fps: 8.557184535346323
# TIMESTEP 300009 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8152646 / Loss  0.030473608523607254
# fps: 9.419115781152804
# TIMESTEP 300010 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7037864 / Loss  0.02603844925761223
# fps: 9.641812179893888
# TIMESTEP 300011 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.75526047 / Loss  0.2085668444633484
# fps: 9.077283331818398
# TIMESTEP 300012 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7383766 / Loss  0.09433601051568985
# fps: 8.509424813502102
# TIMESTEP 300013 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7863269 / Loss  0.015507952310144901
# fps: 8.904631388992092
# TIMESTEP 300014 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.5847921 / Loss  0.03576909378170967
# fps: 8.889344792141321
# TIMESTEP 300015 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8275733 / Loss  0.098238006234169
# fps: 9.517562192102856
# TIMESTEP 300016 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8639843 / Loss  0.01938481256365776
# fps: 8.25409919944583
# TIMESTEP 300017 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.77547 / Loss  0.004860208369791508
# fps: 6.99325734789017
# TIMESTEP 300018 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6603619 / Loss  0.03370813652873039
# fps: 8.601177500753625
# TIMESTEP 300019 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5628487 / Loss  0.11477179825305939
# fps: 8.807214925404475
# TIMESTEP 300020 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.3959585 / Loss  0.053683266043663025
# fps: 9.123565981179931
# TIMESTEP 300021 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8409312 / Loss  0.0352986678481102
# fps: 8.02980422788135
# TIMESTEP 300022 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6846192 / Loss  0.006777239963412285
# fps: 9.087588995151037
# TIMESTEP 300023 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.8992956 / Loss  0.011484967544674873
# fps: 8.901777679678082
# TIMESTEP 300024 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8263242 / Loss  0.015588401816785336
# fps: 9.272212790039616
# TIMESTEP 300025 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.6834965 / Loss  0.007769042160362005
# fps: 9.537624725989394
# TIMESTEP 300026 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7982281 / Loss  0.031234320253133774
# fps: 8.371496660825272
# TIMESTEP 300027 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4337497 / Loss  0.016279343515634537
# fps: 9.49640118368114
# TIMESTEP 300028 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6881179 / Loss  0.03611508011817932
# fps: 9.787038830307287
# TIMESTEP 300029 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5971715 / Loss  0.07175922393798828
# fps: 9.379663215331977
# TIMESTEP 300030 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8810756 / Loss  0.021224014461040497
# fps: 9.590575667221541
# TIMESTEP 300031 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.6383059 / Loss  0.07350378483533859
# fps: 9.259848638719875
# TIMESTEP 300032 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4279888 / Loss  0.022006450220942497
# fps: 8.26889099615763
# TIMESTEP 300033 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8431284 / Loss  0.007845211774110794
# fps: 9.75378705077462
# TIMESTEP 300034 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.88729215 / Loss  0.09792426973581314
# fps: 9.621022497889676
# TIMESTEP 300035 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8072156 / Loss  0.03194313496351242
# fps: 9.204393385781845
# TIMESTEP 300036 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.61053044 / Loss  0.15750478208065033
# fps: 9.251637778532638
# TIMESTEP 300037 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6204405 / Loss  0.08484450727701187
# fps: 9.79931778888837
# TIMESTEP 300038 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5933666 / Loss  0.22138002514839172
# fps: 7.710712959456429
# TIMESTEP 300039 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.3818199 / Loss  0.12286906689405441
# fps: 5.555524060934145
# TIMESTEP 300040 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0943959 / Loss  0.023404397070407867
# fps: 9.489826439717724
# TIMESTEP 300041 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6966523 / Loss  0.017555760219693184
# fps: 9.717990185402291
# TIMESTEP 300042 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7862382 / Loss  0.009255550801753998
# fps: 8.10150680195241
# TIMESTEP 300043 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8172356 / Loss  0.020260732620954514
# fps: 8.29965232636601
# TIMESTEP 300044 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.854013 / Loss  0.010900646448135376
# fps: 9.457344694552612
# TIMESTEP 300045 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.21449302 / Loss  0.019854089245200157
# fps: 8.398837784421426
# TIMESTEP 300046 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0209458 / Loss  0.017819110304117203
# fps: 9.566448240234104
# TIMESTEP 300047 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8187718 / Loss  0.015924707055091858
# fps: 9.88239063950502
# TIMESTEP 300048 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9694936 / Loss  0.1598970890045166
# fps: 9.87050664457691
# TIMESTEP 300049 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9158201 / Loss  0.05996149405837059
# fps: 8.084859816687066
# TIMESTEP 300050 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6125847 / Loss  0.13622824847698212
# fps: 8.093362148811362
# TIMESTEP 300051 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8029423 / Loss  0.16586488485336304
# fps: 10.191679099581574
# TIMESTEP 300052 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8188562 / Loss  0.010721574537456036
# fps: 8.286927400792278
# TIMESTEP 300053 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.4109863 / Loss  0.0515400692820549
# fps: 10.031292302246714
# TIMESTEP 300054 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7995806 / Loss  0.01273270882666111
# fps: 8.551828192889488
# TIMESTEP 300055 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.9097517 / Loss  0.09385675936937332
# fps: 8.496978463321199
# TIMESTEP 300056 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5630397 / Loss  0.047312404960393906
# fps: 9.234182050350604
# TIMESTEP 300057 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.788629 / Loss  0.049556244164705276
# fps: 9.774881726444336
# TIMESTEP 300058 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8643448 / Loss  0.15948142111301422
# fps: 9.90336770376107
# TIMESTEP 300059 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8769857 / Loss  0.015737783163785934
# fps: 9.37603583827175
# TIMESTEP 300060 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4683473 / Loss  0.08472168445587158
# fps: 9.649509392290614
# TIMESTEP 300061 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9121433 / Loss  0.029394663870334625
# fps: 9.465113182723922
# TIMESTEP 300062 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.431686 / Loss  0.04058954492211342
# fps: 9.815967460343463
# TIMESTEP 300063 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0628529 / Loss  0.04531308263540268
# fps: 8.045823725978416
# TIMESTEP 300064 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.2104762 / Loss  0.04192829504609108
# fps: 9.383587295266263
# TIMESTEP 300065 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4597394 / Loss  0.033038198947906494
# fps: 8.457161753171206
# TIMESTEP 300066 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7928343 / Loss  0.04990840330719948
# fps: 9.507594870713788
# TIMESTEP 300067 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4207367 / Loss  0.055762965232133865
# fps: 8.264866419960354
# TIMESTEP 300068 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0798247 / Loss  0.02023363672196865
# fps: 9.433160756937166
# TIMESTEP 300069 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.48417607 / Loss  0.0591612234711647
# fps: 9.57962342064152
# TIMESTEP 300070 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7287974 / Loss  0.016268085688352585
# fps: 9.41264758091844
# TIMESTEP 300071 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6468104 / Loss  0.12077866494655609
# fps: 7.418465581981899
# TIMESTEP 300072 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7772028 / Loss  0.01647442951798439
# fps: 9.51829654357017
# TIMESTEP 300073 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.65932786 / Loss  0.04865538701415062
# fps: 9.562871206991288
# TIMESTEP 300074 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4407332 / Loss  0.1448683887720108
# fps: 9.247517417761708
# TIMESTEP 300075 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.760706 / Loss  0.03107297047972679
# fps: 6.207355642083235
# TIMESTEP 300076 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.4215941 / Loss  0.025336725637316704
# fps: 8.059784895820323
# TIMESTEP 300077 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9236854 / Loss  0.08000541478395462
# fps: 9.939580074885066
# TIMESTEP 300078 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7252992 / Loss  0.03954799473285675
# fps: 9.504104777766448
# TIMESTEP 300079 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7608447 / Loss  0.039206285029649734
# fps: 9.38127861541111
# TIMESTEP 300080 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.686276 / Loss  0.024247510358691216
# fps: 9.463255268264067
# TIMESTEP 300081 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6656556 / Loss  0.10166186094284058
# fps: 9.92328348392256
# TIMESTEP 300082 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.711915 / Loss  0.17036767303943634
# fps: 8.458082691225728
# TIMESTEP 300083 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.4403676 / Loss  0.013206493109464645
# fps: 8.465901682359947
# TIMESTEP 300084 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7350824 / Loss  0.018004056066274643
# fps: 9.957986704653372
# TIMESTEP 300085 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5554038 / Loss  0.022108223289251328
# fps: 7.977875079411574
# TIMESTEP 300086 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.59824973 / Loss  0.04378964751958847
# fps: 9.529520286819134
# TIMESTEP 300087 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.38743067 / Loss  0.13729336857795715
# fps: 9.562958419877837
# TIMESTEP 300088 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0642266 / Loss  0.05052819103002548
# fps: 9.711577333885947
# TIMESTEP 300089 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7630205 / Loss  0.03087768889963627
# fps: 9.363121707295294
# TIMESTEP 300090 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6665219 / Loss  0.03901945427060127
# fps: 9.624356070775423
# TIMESTEP 300091 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.7556896 / Loss  0.026714347302913666
# fps: 8.196786795413727
# TIMESTEP 300092 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.779553 / Loss  0.013453586958348751
# fps: 9.555463921283629
# TIMESTEP 300093 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6949785 / Loss  0.10314074903726578
# fps: 9.807841963483988
# TIMESTEP 300094 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7598827 / Loss  0.007948270067572594
# fps: 7.857739143467346
# TIMESTEP 300095 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7248278 / Loss  0.03836650401353836
# fps: 8.288433986835111
# TIMESTEP 300096 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7119157 / Loss  0.1269105076789856
# fps: 8.390604963981428
# TIMESTEP 300097 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.75862235 / Loss  0.029790261760354042
# fps: 9.373311909321902
# TIMESTEP 300098 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7106661 / Loss  0.013828221708536148
# fps: 8.25190691012684
# TIMESTEP 300099 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7043612 / Loss  0.01028519682586193
# fps: 8.220643805760698
# TIMESTEP 300100 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7353778 / Loss  0.01726182922720909
# fps: 9.649931208385675
# TIMESTEP 300101 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7453262 / Loss  0.019966943189501762
# fps: 8.2634335092026
# TIMESTEP 300102 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.83455324 / Loss  0.025241026654839516
# fps: 7.943938119805753
# TIMESTEP 300103 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.1615447 / Loss  0.11149685084819794
# fps: 9.661823819253602
# TIMESTEP 300104 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0909286 / Loss  0.04574093967676163
# fps: 9.0580524223243
# TIMESTEP 300105 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7733054 / Loss  0.13545791804790497
# fps: 8.128968738492548
# TIMESTEP 300106 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6121297 / Loss  0.03980996087193489
# fps: 9.425974160229947
# TIMESTEP 300107 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8262388 / Loss  0.02646053582429886
# fps: 8.901777679678082
# TIMESTEP 300108 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4465122 / Loss  0.01722688041627407
# fps: 9.522705033227155
# TIMESTEP 300109 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8220223 / Loss  0.00907752476632595
# fps: 9.773811160538475
# TIMESTEP 300110 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5832461 / Loss  0.11921278387308121
# fps: 8.580168849739279
# TIMESTEP 300111 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7764589 / Loss  0.020002540200948715
# fps: 6.078692639575885
# TIMESTEP 300112 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.52949595 / Loss  0.03552260994911194
# fps: 9.656729750886402
# TIMESTEP 300113 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.242233 / Loss  0.019002418965101242
# fps: 8.18344893519467
# TIMESTEP 300114 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.686669 / Loss  0.08582713454961777
# fps: 9.570748581833781
# TIMESTEP 300115 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6202445 / Loss  0.13686232268810272
# fps: 8.213898381427047
# TIMESTEP 300116 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7387026 / Loss  0.13353917002677917
# fps: 9.713084155435135
# TIMESTEP 300117 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8719845 / Loss  0.12339477241039276
# fps: 9.367073794417236
# TIMESTEP 300118 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7389313 / Loss  0.029191281646490097
# fps: 9.342994932338364
# TIMESTEP 300119 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7543192 / Loss  0.17905715107917786
# fps: 9.60826149803794
# TIMESTEP 300120 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8171072 / Loss  0.024735404178500175
# fps: 9.351202035087876
# TIMESTEP 300121 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.43968445 / Loss  0.0500355027616024
# fps: 8.373819834172851
# TIMESTEP 300122 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5803564 / Loss  0.04498947784304619
# fps: 10.044625173924185
# TIMESTEP 300123 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8061612 / Loss  0.027368340641260147
# fps: 9.5495463497376
# TIMESTEP 300124 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.7998143 / Loss  0.09415266662836075
# fps: 8.230193240506727
# TIMESTEP 300125 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.78264165 / Loss  0.049322377890348434
# fps: 8.311988093751795
# TIMESTEP 300126 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4811904 / Loss  0.1649419218301773
# fps: 8.479028358414128
# TIMESTEP 300127 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7900265 / Loss  0.01982029341161251
# fps: 9.347346651334028
# TIMESTEP 300128 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7374877 / Loss  0.06025043874979019
# fps: 8.41891609795263
# TIMESTEP 300129 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6807826 / Loss  0.006232048384845257
# fps: 9.673589601068308
# TIMESTEP 300130 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8046355 / Loss  0.0830635279417038
# fps: 8.116038947971331
# TIMESTEP 300131 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.531066 / Loss  0.020507624372839928
# fps: 8.498924033960812
# TIMESTEP 300132 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5046372 / Loss  0.05981007590889931
# fps: 9.948963665431636
# TIMESTEP 300133 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6716166 / Loss  0.12613631784915924
# fps: 9.70131191828729
# TIMESTEP 300134 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.4096972 / Loss  0.027899067848920822
# fps: 8.00890577710734
# TIMESTEP 300135 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6160426 / Loss  0.008286144584417343
# fps: 9.444567290479332
# TIMESTEP 300136 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4814134 / Loss  0.011812299489974976
# fps: 9.766391982545644
# TIMESTEP 300137 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6815941 / Loss  0.022764526307582855
# fps: 9.307500271837421
# TIMESTEP 300138 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7382926 / Loss  0.15181873738765717
# fps: 9.445247880377872
# TIMESTEP 300139 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7281777 / Loss  0.03414124622941017
# fps: 9.333597402626303
# TIMESTEP 300140 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6529356 / Loss  0.12296216189861298
# fps: 8.621349963617828
# TIMESTEP 300141 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5405853 / Loss  0.00893448293209076
# fps: 7.01690191269492
# TIMESTEP 300142 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.1776068 / Loss  0.1086159273982048
# fps: 8.524436369105324
# TIMESTEP 300143 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5114998 / Loss  0.007512561045587063
# fps: 8.37248259851526
# TIMESTEP 300144 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7143191 / Loss  0.025365427136421204
# fps: 7.818236382920423
# TIMESTEP 300145 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6242037 / Loss  0.06953322142362595
# fps: 7.782289801560427
# TIMESTEP 300146 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.1733683 / Loss  0.006383644416928291
# fps: 8.58132745191511
# TIMESTEP 300147 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7285926 / Loss  0.01777639612555504
# fps: 5.5419733756152345
# TIMESTEP 300148 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6960557 / Loss  0.08959966897964478
# fps: 7.853531211498204
# TIMESTEP 300149 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.037889346 / Loss  0.08442310988903046
# fps: 8.217873460974788
# TIMESTEP 300150 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4429023 / Loss  0.0412089079618454
# fps: 7.744312202039151
# TIMESTEP 300151 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6735067 / Loss  0.030259408056735992
# fps: 8.484087925513732
# TIMESTEP 300152 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.6273586 / Loss  0.02349335514008999
# fps: 7.616037187681581
# TIMESTEP 300153 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6599369 / Loss  0.008981069549918175
# fps: 7.465698367775582
# TIMESTEP 300154 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7654962 / Loss  0.04383983463048935
# fps: 7.555847791506863
# TIMESTEP 300155 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.6619246 / Loss  0.04450391232967377
# fps: 8.552926830263013
# TIMESTEP 300156 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.27899793 / Loss  0.013989947736263275
# fps: 8.898472688081705
# TIMESTEP 300157 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7015122 / Loss  0.029610181227326393
# fps: 8.645286557904175
# TIMESTEP 300158 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7772745 / Loss  0.09002640843391418
# fps: 6.619568133682227
# TIMESTEP 300159 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6493237 / Loss  0.013282627798616886
# fps: 7.365237684666349
# TIMESTEP 300160 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.77113163 / Loss  0.008753687143325806
# fps: 7.368809041509355
# TIMESTEP 300161 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.631299 / Loss  0.017240654677152634
# fps: 6.509700209214112
# TIMESTEP 300162 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5902867 / Loss  0.025818679481744766
# fps: 7.079197209033846
# TIMESTEP 300163 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.879375 / Loss  0.030236057937145233
# fps: 7.646778704335048
# TIMESTEP 300164 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.4701841 / Loss  0.008389003574848175
# fps: 7.515461663889337
# TIMESTEP 300165 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5885049 / Loss  0.03644724190235138
# fps: 7.241346924118118
# TIMESTEP 300166 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7767316 / Loss  0.04684311896562576
# fps: 8.678361121111676
# TIMESTEP 300167 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7526988 / Loss  0.015070891007781029
# fps: 7.532454191666772
# TIMESTEP 300168 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5567093 / Loss  0.022173810750246048
# fps: 7.6190393149537785
# TIMESTEP 300169 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6970053 / Loss  0.013811723329126835
# fps: 7.319046464026021
# TIMESTEP 300170 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.850307 / Loss  0.055870987474918365
# fps: 6.667944835260919
# TIMESTEP 300171 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.3601484 / Loss  0.058829378336668015
# fps: 7.126915835763174
# TIMESTEP 300172 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6925837 / Loss  0.013604522682726383
# fps: 8.34605978720483
# TIMESTEP 300173 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.09018847 / Loss  0.01805828884243965
# fps: 6.443783827797212
# TIMESTEP 300174 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4111366 / Loss  0.034732889384031296
# fps: 8.260487833699324
# TIMESTEP 300175 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5626326 / Loss  0.031209297478199005
# fps: 6.96331492189666
# TIMESTEP 300176 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.11995864 / Loss  0.021536607295274734
# fps: 6.656727266956046
# TIMESTEP 300177 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7988336 / Loss  0.018587704747915268
# fps: 8.517373654915005
# TIMESTEP 300178 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7958714 / Loss  0.009934606030583382
# fps: 7.157161164379237
# TIMESTEP 300179 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9269361 / Loss  0.05352130904793739
# fps: 7.3133674622327
# TIMESTEP 300180 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.5072973 / Loss  0.05236368253827095
# fps: 7.206720286460973
# TIMESTEP 300181 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.43196303 / Loss  0.10859144479036331
# fps: 7.1981863395396175
# TIMESTEP 300182 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.51967096 / Loss  0.012326139956712723
# fps: 6.912954835009255
# TIMESTEP 300183 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8678596 / Loss  0.007873122580349445
# fps: 4.806999327252243
# TIMESTEP 300184 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8630259 / Loss  0.029833711683750153
# fps: 7.493213898421966
# TIMESTEP 300185 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.3304852 / Loss  0.01461845263838768
# fps: 7.090782144155263
# TIMESTEP 300186 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9277458 / Loss  0.015975534915924072
# fps: 8.386092172348295
# TIMESTEP 300187 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7655013 / Loss  0.019388912245631218
# fps: 7.140614279852976
# TIMESTEP 300188 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6684942 / Loss  0.012891578488051891
# fps: 7.247640885896809
# TIMESTEP 300189 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.74797386 / Loss  0.044571612030267715
# fps: 7.331750787485535
# TIMESTEP 300190 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8718385 / Loss  0.016875918954610825
# fps: 7.220938860606728
# TIMESTEP 300191 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8748122 / Loss  0.047498393803834915
# fps: 7.143715552891003
# TIMESTEP 300192 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7305453 / Loss  0.039845895022153854
# fps: 8.790123249804573
# TIMESTEP 300193 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8051872 / Loss  0.029373344033956528
# fps: 7.5334553494612555
# TIMESTEP 300194 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8993113 / Loss  0.006196674890816212
# fps: 7.0900270124987745
# TIMESTEP 300195 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9024818 / Loss  0.029082827270030975
# fps: 8.944699998933709
# TIMESTEP 300196 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7584105 / Loss  0.0456484779715538
# fps: 8.481754629339406
# TIMESTEP 300197 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8917754 / Loss  0.05391303449869156
# fps: 6.892268861165521
# TIMESTEP 300198 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  0.6651437 / Loss  0.08342994749546051
# fps: 7.141270795272869
# TIMESTEP 300199 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.6031748 / Loss  0.06921852380037308
# fps: 7.39404922662511
# TIMESTEP 300200 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7692686 / Loss  0.08290773630142212
# fps: 7.024846457767722
# TIMESTEP 300201 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.5562167 / Loss  0.02882428653538227
# fps: 7.65157745338057
# TIMESTEP 300202 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9215184 / Loss  0.04239584505558014
# fps: 7.283484844538217
# TIMESTEP 300203 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.14587876 / Loss  0.010866032913327217
# fps: 7.284711897847744
# TIMESTEP 300204 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8329804 / Loss  0.034421056509017944
# fps: 7.482506404447077
# TIMESTEP 300205 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7945912 / Loss  0.014881311915814877
# fps: 8.156411283579072
# TIMESTEP 300206 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8243947 / Loss  0.034796372056007385
# fps: 7.112268706929296
# TIMESTEP 300207 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9026527 / Loss  0.020349502563476562
# fps: 7.400559324575875
# TIMESTEP 300208 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7501015 / Loss  0.01680813543498516
# fps: 8.645286557904175
# TIMESTEP 300209 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9607749 / Loss  0.006849915720522404
# fps: 6.989632962546349
# TIMESTEP 300210 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.74092716 / Loss  0.2263304442167282
# fps: 8.765085972699383
# TIMESTEP 300211 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7934823 / Loss  0.11998729407787323
# fps: 8.338957844990924
# TIMESTEP 300212 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.63805497 / Loss  0.027837438508868217
# fps: 8.426239585991036
# TIMESTEP 300213 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6163785 / Loss  0.12524327635765076
# fps: 8.089818638409001
# TIMESTEP 300214 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.57689357 / Loss  0.020708050578832626
# fps: 7.277166378943899
# TIMESTEP 300215 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8054802 / Loss  0.023072414100170135
# fps: 7.484015095416953
# TIMESTEP 300216 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.77697617 / Loss  0.06106545031070709
# fps: 7.177357199082788
# TIMESTEP 300217 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8205485 / Loss  0.06875016540288925
# fps: 7.730139276176715
# TIMESTEP 300218 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5692984 / Loss  0.016525795683264732
# fps: 7.591514192785869
# TIMESTEP 300219 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7878273 / Loss  0.016666052863001823
# fps: 5.619641864235327
# TIMESTEP 300220 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9580532 / Loss  0.024343568831682205
# fps: 7.225217869145871
# TIMESTEP 300221 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8047035 / Loss  0.07131975144147873
# fps: 8.360300024118335
# TIMESTEP 300222 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8901082 / Loss  0.1248156875371933
# fps: 8.884938430610779
# TIMESTEP 300223 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.0593207 / Loss  0.1801079511642456
# fps: 8.461597742123558
# TIMESTEP 300224 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7979455 / Loss  0.022134099155664444
# fps: 8.566552427013933
# TIMESTEP 300225 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.785607 / Loss  0.01667684316635132
# fps: 7.533874832502883
# TIMESTEP 300226 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6814065 / Loss  0.020304113626480103
# fps: 8.67663766389051
# TIMESTEP 300227 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7473176 / Loss  0.026200225576758385
# fps: 7.275373933013823
# TIMESTEP 300228 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.707807 / Loss  0.051964133977890015
# fps: 7.418570551789154
# TIMESTEP 300229 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6998491 / Loss  0.18469607830047607
# fps: 8.245126311919968
# TIMESTEP 300230 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6550238 / Loss  0.022354617714881897
# fps: 7.160191266019212
# TIMESTEP 300231 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6878052 / Loss  0.021507583558559418
# fps: 7.471736295684022
# TIMESTEP 300232 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5419122 / Loss  0.01811131276190281
# fps: 7.144238778106897
# TIMESTEP 300233 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8090079 / Loss  0.021892637014389038
# fps: 7.282409931417658
# TIMESTEP 300234 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7064292 / Loss  0.03292447701096535
# fps: 8.75189934167284
# TIMESTEP 300235 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7785301 / Loss  0.033754121512174606
# fps: 7.47630447066289
# TIMESTEP 300236 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7120618 / Loss  0.022015603259205818
# fps: 7.3634403769583505
# TIMESTEP 300237 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.3568904 / Loss  0.2004496157169342
# fps: 8.945997308290337
# TIMESTEP 300238 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7167085 / Loss  0.15468065440654755
# fps: 8.347189246956601
# TIMESTEP 300239 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7029963 / Loss  0.049073394387960434
# fps: 7.568022460637948
# TIMESTEP 300240 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7508559 / Loss  0.01619384065270424
# fps: 7.374846808069193
# TIMESTEP 300241 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  0.5910206 / Loss  0.019034072756767273
# fps: 8.671740321496873
# TIMESTEP 300242 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7542968 / Loss  0.0211208313703537
# fps: 7.277810360324406
# TIMESTEP 300243 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6752245 / Loss  0.02409534901380539
# fps: 9.069549798901527
# TIMESTEP 300244 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.579747 / Loss  0.05247564613819122
# fps: 8.394803364883284
# TIMESTEP 300245 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.9305929 / Loss  0.009707443416118622
# fps: 8.745457654118658
# TIMESTEP 300246 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5523881 / Loss  0.005415379535406828
# fps: 8.910211798695643
# TIMESTEP 300247 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4892375 / Loss  0.029923174530267715
# fps: 8.349615296565041
# TIMESTEP 300248 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7717445 / Loss  0.012541827745735645
# fps: 8.293448966557717
# TIMESTEP 300249 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.73145 / Loss  0.05627620220184326
# fps: 8.892906968361865
# TIMESTEP 300250 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8673809 / Loss  0.06934640556573868
# fps: 8.892548736921333
# TIMESTEP 300251 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.5146979 / Loss  0.05403735488653183
# fps: 8.714821186659021
# TIMESTEP 300252 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8020781 / Loss  0.022197211161255836
# fps: 8.514831867605382
# TIMESTEP 300253 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8429966 / Loss  0.025051720440387726
# fps: 8.983918366647533
# TIMESTEP 300254 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8173776 / Loss  0.18898771703243256
# fps: 8.332977045245938
# TIMESTEP 300255 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6956097 / Loss  0.03506368771195412
# fps: 5.4731204964859215
# TIMESTEP 300256 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.60353214 / Loss  0.04143423214554787
# fps: 8.797018375081535
# TIMESTEP 300257 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7902107 / Loss  0.02402963489294052
# fps: 7.750193556016682
# TIMESTEP 300258 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8082594 / Loss  0.01740824244916439
# fps: 7.6880005132294045
# TIMESTEP 300259 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.65891135 / Loss  0.0586603619158268
# fps: 8.822702614014753
# TIMESTEP 300260 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6828936 / Loss  0.24884480237960815
# fps: 7.4468496108175675
# TIMESTEP 300261 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7371823 / Loss  0.01091754250228405
# fps: 9.40538673878286
# TIMESTEP 300262 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8310623 / Loss  0.04333541542291641
# fps: 7.955238431220815
# TIMESTEP 300263 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8672203 / Loss  0.03066800720989704
# fps: 7.865460491771307
# TIMESTEP 300264 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.47174618 / Loss  0.24298757314682007
# fps: 7.436761962850801
# TIMESTEP 300265 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7797525 / Loss  0.008198963478207588
# fps: 9.426482585644647
# TIMESTEP 300266 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.732775 / Loss  0.07349801063537598
# fps: 8.901248716055042
# TIMESTEP 300267 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.3833903 / Loss  0.03664350137114525
# fps: 8.350895356569731
# TIMESTEP 300268 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8215632 / Loss  0.28883522748947144
# fps: 8.103478988317075
# TIMESTEP 300269 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.84912 / Loss  0.06519289314746857
# fps: 7.8576213777754464
# TIMESTEP 300270 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6222582 / Loss  0.2655869722366333
# fps: 8.098347045205736
# TIMESTEP 300271 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7905564 / Loss  0.03110908344388008
# fps: 8.062511653656221
# TIMESTEP 300272 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5238113 / Loss  0.0405513271689415
# fps: 8.780554386714146
# TIMESTEP 300273 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.68326354 / Loss  0.009191058576107025
# fps: 8.112350032009934
# TIMESTEP 300274 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8127561 / Loss  0.022281866520643234
# fps: 9.307355695404798
# TIMESTEP 300275 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8163345 / Loss  0.01601678878068924
# fps: 8.812359099666567
# TIMESTEP 300276 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.24593115 / Loss  0.018113017082214355
# fps: 8.0350343485274
# TIMESTEP 300277 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.666903 / Loss  0.008089026436209679
# fps: 7.905756043864907
# TIMESTEP 300278 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.42359662 / Loss  0.017354924231767654
# fps: 7.7077373164169884
# TIMESTEP 300279 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.2033095 / Loss  0.0478566475212574
# fps: 8.138274671116458
# TIMESTEP 300280 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7220841 / Loss  0.02460477128624916
# fps: 8.08793107437889
# TIMESTEP 300281 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.86083996 / Loss  0.0799069032073021
# fps: 8.080809949041027
# TIMESTEP 300282 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8616853 / Loss  0.011670170351862907
# fps: 8.129378382150001
# TIMESTEP 300283 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.88957 / Loss  0.009126713499426842
# fps: 9.143255757174124
# TIMESTEP 300284 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7867692 / Loss  0.01879318431019783
# fps: 8.963796920814847
# TIMESTEP 300285 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.756763 / Loss  0.009587897919118404
# fps: 8.11484556985536
# TIMESTEP 300286 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9248645 / Loss  0.014089424163103104
# fps: 8.186595567769714
# TIMESTEP 300287 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7308052 / Loss  0.005917631089687347
# fps: 9.001792072386847
# TIMESTEP 300288 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.60911214 / Loss  0.028653327375650406
# fps: 7.972006865236472
# TIMESTEP 300289 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.685498 / Loss  0.020044289529323578
# fps: 9.538448943205541
# TIMESTEP 300290 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8026476 / Loss  0.005795499309897423
# fps: 9.061340004623238
# TIMESTEP 300291 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9649721 / Loss  0.1696474403142929
# fps: 6.213875761122387
# TIMESTEP 300292 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6106724 / Loss  0.08250721544027328
# fps: 9.487572497534405
# TIMESTEP 300293 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.67766416 / Loss  0.01176670752465725
# fps: 9.42692750287687
# TIMESTEP 300294 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5856826 / Loss  0.03184519708156586
# fps: 7.938780802186508
# TIMESTEP 300295 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7059022 / Loss  0.012807963415980339
# fps: 9.337628538925115
# TIMESTEP 300296 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8240921 / Loss  0.019817164167761803
# fps: 9.448120199130493
# TIMESTEP 300297 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9427975 / Loss  0.05514761060476303
# fps: 9.611123714198639
# TIMESTEP 300298 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9598352 / Loss  0.024434905499219894
# fps: 9.102913632762904
# TIMESTEP 300299 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5211691 / Loss  0.23342826962471008
# fps: 7.9074551679411185
# TIMESTEP 300300 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.48913452 / Loss  0.01897415891289711
# fps: 9.770487067971478
# TIMESTEP 300301 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9414537 / Loss  0.02651766873896122
# fps: 9.53545641380063
# TIMESTEP 300302 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8001888 / Loss  0.11067797988653183
# fps: 9.218108732393128
# TIMESTEP 300303 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6390048 / Loss  0.011105515994131565
# fps: 9.66667819024506
# TIMESTEP 300304 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.873825 / Loss  0.1815006583929062
# fps: 7.712144920447838
# TIMESTEP 300305 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8223348 / Loss  0.241173654794693
# fps: 9.50643122162613
# TIMESTEP 300306 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7542546 / Loss  0.0301455520093441
# fps: 8.088305397212302
# ...
# TIMESTEP 300930 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7340126 / Loss  0.023410409688949585
# fps: 4.478682418868472
# TIMESTEP 300931 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.708111 / Loss  0.00824681669473648
# fps: 4.395351786045508
# TIMESTEP 300932 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5953115 / Loss  0.04535868018865585
# fps: 6.048398098223826
# TIMESTEP 300933 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.778137 / Loss  0.09080904722213745
# fps: 5.242486813488989
# TIMESTEP 300934 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7896922 / Loss  0.010029243305325508
# fps: 5.498044232846402
# TIMESTEP 300935 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6756924 / Loss  0.03256458789110184
# fps: 6.8895065013567764
# TIMESTEP 300936 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4901929 / Loss  0.019810229539871216
# fps: 6.658809185124975
# TIMESTEP 300937 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.750689 / Loss  0.008317114785313606
# fps: 6.496632652429013
# TIMESTEP 300938 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7408996 / Loss  0.014193441718816757
# fps: 6.165682247826585
# TIMESTEP 300939 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6204857 / Loss  0.10927064716815948
# fps: 5.0283154925389955
# TIMESTEP 300940 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6895509 / Loss  0.0059046074748039246
# fps: 6.638163985901651
# TIMESTEP 300941 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7188847 / Loss  0.02400655299425125
# fps: 6.525844766477575
# TIMESTEP 300942 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7412624 / Loss  0.009950997307896614
# fps: 6.471852414193222
# TIMESTEP 300943 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8929374 / Loss  0.17503927648067474
# fps: 7.9928347924186
# TIMESTEP 300944 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7802246 / Loss  0.16919691860675812
# fps: 7.222891151308086
# TIMESTEP 300945 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.667815 / Loss  0.0348607674241066
# fps: 7.45533433702281
# TIMESTEP 300946 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8122846 / Loss  0.010057619772851467
# fps: 6.5111756213421925
# TIMESTEP 300947 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.9661884 / Loss  0.018312422558665276
# fps: 6.911997890625644
# TIMESTEP 300948 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7043874 / Loss  0.10779296606779099
# fps: 7.109483879388229
# TIMESTEP 300949 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.3032448 / Loss  0.04218200594186783
# fps: 8.323699789045026
# TIMESTEP 300950 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.9695594 / Loss  0.005475664045661688
# fps: 7.023117341522469
# TIMESTEP 300951 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9242301 / Loss  0.03011825680732727
# fps: 7.234789328338
# TIMESTEP 300952 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7950996 / Loss  0.0030604051426053047
# fps: 6.8160831001342315
# TIMESTEP 300953 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7417979 / Loss  0.01776745729148388
# fps: 7.342686381126778
# TIMESTEP 300954 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6646848 / Loss  0.015797220170497894
# fps: 6.497991407904542
# TIMESTEP 300955 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.710768 / Loss  0.03201751038432121
# fps: 7.210226295993234
# TIMESTEP 300956 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.2089998 / Loss  0.05855618417263031
# fps: 7.286774784791654
# TIMESTEP 300957 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.41187575 / Loss  0.032723523676395416
# fps: 6.850203090370724
# TIMESTEP 300958 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7231021 / Loss  0.0109181497246027
# fps: 8.428847317091796
# TIMESTEP 300959 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.058564 / Loss  0.04314074665307999
# fps: 7.141890948471092
# TIMESTEP 300960 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.663185 / Loss  0.02052983082830906
# fps: 8.312004565920477
# TIMESTEP 300961 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.2339392 / Loss  0.04315033182501793
# fps: 7.305393476829613
# TIMESTEP 300962 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.81297433 / Loss  0.01661047711968422
# fps: 7.89141715365135
# TIMESTEP 300963 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7618272 / Loss  0.008673327974975109
# fps: 7.397478972329367
# TIMESTEP 300964 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7123168 / Loss  0.007146757561713457
# fps: 6.922196127878057
# TIMESTEP 300965 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.3176012 / Loss  0.013727603480219841
# fps: 7.133133674488056
# TIMESTEP 300966 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6851189 / Loss  0.03346047177910805
# fps: 7.240071946668324
# TIMESTEP 300967 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7359711 / Loss  0.02990134432911873
# fps: 7.0407541823480235
# TIMESTEP 300968 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8646188 / Loss  0.016439102590084076
# fps: 6.666747200137331
# TIMESTEP 300969 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4674592 / Loss  0.08208108693361282
# fps: 7.5346733325309385
# TIMESTEP 300970 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7701962 / Loss  0.012021214701235294
# fps: 6.839892239551737
# TIMESTEP 300971 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4622304 / Loss  0.03928431123495102
# fps: 6.6053279747018845
# TIMESTEP 300972 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.829217 / Loss  0.0047723171301186085
# fps: 7.433993966742643
# TIMESTEP 300973 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.72864693 / Loss  0.030242592096328735
# fps: 7.16590411300601
# TIMESTEP 300974 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6948519 / Loss  0.010877920314669609
# fps: 6.473630434044445
# TIMESTEP 300975 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.39744848 / Loss  0.005110743455588818
# fps: 4.114975502267291
# TIMESTEP 300976 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7670299 / Loss  0.030248813331127167
# fps: 6.494982780406828
# TIMESTEP 300977 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.60590565 / Loss  0.1759994775056839
# fps: 6.774239083912752
# TIMESTEP 300978 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8040962 / Loss  0.03666171059012413
# fps: 5.863969678455738
# TIMESTEP 300979 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.6334059 / Loss  0.08783406019210815
# fps: 6.945511329106274
# TIMESTEP 300980 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7932036 / Loss  0.143962100148201
# fps: 6.136356520759542
# TIMESTEP 300981 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8450108 / Loss  0.006110784597694874
# fps: 8.337648293629337
# TIMESTEP 300982 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8458498 / Loss  0.011713927611708641
# fps: 7.235001483464545
# TIMESTEP 300983 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9539568 / Loss  0.01895194500684738
# fps: 6.153317107593089
# TIMESTEP 300984 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7905805 / Loss  0.010288255289196968
# fps: 7.879113034722692
# TIMESTEP 300985 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.056281 / Loss  0.04844877868890762
# fps: 6.61892047140215
# TIMESTEP 300986 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  0.7893009 / Loss  0.03144539147615433
# fps: 7.87902422896731
# TIMESTEP 300987 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7321612 / Loss  0.051533907651901245
# fps: 7.000342147383741
# TIMESTEP 300988 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6374424 / Loss  0.02783113718032837
# fps: 6.829523417184597
# TIMESTEP 300989 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9586644 / Loss  0.010154413059353828
# fps: 6.721231719863214
# TIMESTEP 300990 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7126465 / Loss  0.012141995131969452
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4829a0a02061> in <module>
# ----> 1 playGame(observe=False);
#
# <ipython-input-13-12216cee503d> in playGame(observe)
#       6     model = buildmodel()
#       7     try:
# ----> 8         trainNetwork(model,game_state,observe=observe)
#       9     except StopIteration:
#      10         game.end()
#
# <ipython-input-12-4119cec8c736> in trainNetwork(model, game_state, observe)
#      68
#      69         #run the selected action and observed next state and reward
# ---> 70         x_t1, r_t, terminal = game_state.get_state(a_t)
#      71         print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
#      72         last_time = time.time()
#
# <ipython-input-5-35ecfd7f7a27> in get_state(self, actions)
#      12         if actions[1] == 1:
#      13             self._agent.jump()
# ---> 14         image = grab_screen(self._game._driver)
#      15         self._display.send(image) #display the image on screen
#      16         if self._agent.is_crashed():
#
# <ipython-input-6-bda1e8471266> in grab_screen(_driver)
#       7
#       8 def grab_screen(_driver):
# ----> 9     image_b64 = _driver.execute_script(getbase64Script)
#      10     screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
#      11     image = process_img(screen)#processing image as required
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
