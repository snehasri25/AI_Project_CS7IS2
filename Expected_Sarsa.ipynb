# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
import _pickle as cPickle
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects_sarsa/loss_df.csv"
actions_file_path = "./objects_sarsa/actions_df.csv"
q_value_file_path = "./objects_sarsa/q_values.csv"
scores_file_path = "./objects_sarsa/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('objects_sarsa/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects_sarsa/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model_sarsa.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    max_Q1 = 0
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model_sarsa.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model_sarsa.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                #new_q=np.argmax(q)
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1 # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                #print(Q_sa.shape)
                new_q=np.argmax(Q_sa)
                max_Q1 = (1-epsilon)*(np.mean(Q_sa))+epsilon*np.max(Q_sa)
                #print(max_Q1)
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * max_Q1
                    #targets[i, action_t] = (targets[i, action_t]* (1-LEARNING_RATE)) + (LEARNING_RATE * (reward_t + GAMMA * max_Q1))
                    
                                                                                                         
            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = max_Q1
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model_sarsa.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects_sarsa/loss_df.csv",index=False)
            scores_df.to_csv("./objects_sarsa/scores_df.csv",index=False)
            actions_df.to_csv("./objects_sarsa/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model_sarsa.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX " , max_Q1, "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 92000 / STATE explore / EPSILON 0.008192898999872633 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3350081124221527 / Loss  0.039076924324035645
# fps: 0.15286006733446197
# TIMESTEP 92001 / STATE explore / EPSILON 0.008191899999872633 / ACTION 0 / REWARD 0.1 / Q_MAX  9.893148391663454 / Loss  0.012504711747169495
# fps: 8.09950429373927
# TIMESTEP 92002 / STATE explore / EPSILON 0.008190900999872634 / ACTION 0 / REWARD 0.1 / Q_MAX  2.666292346873819 / Loss  0.19898907840251923
# fps: 7.655809250190286
# TIMESTEP 92003 / STATE explore / EPSILON 0.008189901999872634 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3428909726146223 / Loss  0.05599108338356018
# fps: 7.349853241393813
# TIMESTEP 92004 / STATE explore / EPSILON 0.008188902999872634 / ACTION 0 / REWARD 0.1 / Q_MAX  0.9780839925166811 / Loss  0.05401793494820595
# fps: 7.650586520694668
# TIMESTEP 92005 / STATE explore / EPSILON 0.008187903999872634 / ACTION 0 / REWARD 0.1 / Q_MAX  8.577630249964836 / Loss  0.037346675992012024
# fps: 7.20057133439543
# TIMESTEP 92006 / STATE explore / EPSILON 0.008186904999872634 / ACTION 0 / REWARD 0.1 / Q_MAX  2.712849476490983 / Loss  0.08186394721269608
# fps: 8.176413711362715
# TIMESTEP 92007 / STATE explore / EPSILON 0.008185905999872635 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3986743765717415 / Loss  0.7465826272964478
# fps: 7.890110799676442
# TIMESTEP 92008 / STATE explore / EPSILON 0.008184906999872635 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.1041138451512724 / Loss  0.06094716489315033
# fps: 7.828699417649694
# TIMESTEP 92009 / STATE explore / EPSILON 0.008183907999872635 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2803745304399388 / Loss  1.3691340684890747
# fps: 8.281625955901662
# TIMESTEP 92010 / STATE explore / EPSILON 0.008182908999872635 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.42470538747451786 / Loss  0.012882099486887455
# fps: 8.259349185250825
# TIMESTEP 92011 / STATE explore / EPSILON 0.008181909999872635 / ACTION 0 / REWARD 0.1 / Q_MAX  10.775126277736788 / Loss  0.048662688583135605
# fps: 7.595844863306434
# TIMESTEP 92012 / STATE explore / EPSILON 0.008180910999872636 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2318218259803912 / Loss  0.03223826736211777
# fps: 8.088632958115335
# TIMESTEP 92013 / STATE explore / EPSILON 0.008179911999872636 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.7930696499705945 / Loss  1.5473483800888062
# fps: 8.06907272027703
# TIMESTEP 92014 / STATE explore / EPSILON 0.008178912999872636 / ACTION 0 / REWARD 0.1 / Q_MAX  2.60646216115004 / Loss  0.03637856990098953
# fps: 7.938705672148027
# TIMESTEP 92015 / STATE explore / EPSILON 0.008177913999872636 / ACTION 0 / REWARD 0.1 / Q_MAX  2.268392548951541 / Loss  0.2818378508090973
# fps: 8.699655482107262
# TIMESTEP 92016 / STATE explore / EPSILON 0.008176914999872636 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5975609169112346 / Loss  0.518267810344696
# fps: 7.999481234813722
# TIMESTEP 92017 / STATE explore / EPSILON 0.008175915999872637 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7027212870640214 / Loss  0.11152259260416031
# fps: 8.072986519051176
# TIMESTEP 92018 / STATE explore / EPSILON 0.008174916999872637 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.416690150000513 / Loss  0.043160028755664825
# fps: 8.342009534738947
# TIMESTEP 92019 / STATE explore / EPSILON 0.008173917999872637 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4477803776247273 / Loss  0.19362755119800568
# fps: 8.140091021125052
# TIMESTEP 92020 / STATE explore / EPSILON 0.008172918999872637 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8436052096173587 / Loss  0.04314931482076645
# fps: 8.073126367799144
# TIMESTEP 92021 / STATE explore / EPSILON 0.008171919999872638 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.013778644105046743 / Loss  0.06742246448993683
# fps: 8.15414375059538
# TIMESTEP 92022 / STATE explore / EPSILON 0.008170920999872638 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6486334658148665 / Loss  0.10474764555692673
# fps: 9.171044863581303
# TIMESTEP 92023 / STATE explore / EPSILON 0.008169921999872638 / ACTION 0 / REWARD 0.1 / Q_MAX  11.485053872520513 / Loss  0.06242702156305313
# fps: 8.022969201606008
# TIMESTEP 92024 / STATE explore / EPSILON 0.008168922999872638 / ACTION 0 / REWARD 0.1 / Q_MAX  2.824796332364835 / Loss  0.09283021092414856
# fps: 8.605765896635706
# TIMESTEP 92025 / STATE explore / EPSILON 0.008167923999872638 / ACTION 0 / REWARD 0.1 / Q_MAX  11.599590188703456 / Loss  0.039730194956064224
# ----------Random Action----------
# fps: 8.738060516162365
# TIMESTEP 92026 / STATE explore / EPSILON 0.008166924999872639 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.2132907459005855 / Loss  0.12126857042312622
# fps: 8.40710362798156
# TIMESTEP 92027 / STATE explore / EPSILON 0.008165925999872639 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8403649709726486 / Loss  0.03261677175760269
# fps: 8.855673955775512
# TIMESTEP 92028 / STATE explore / EPSILON 0.008164926999872639 / ACTION 0 / REWARD 0.1 / Q_MAX  2.085941457860935 / Loss  0.07993791997432709
# fps: 8.662141091383715
# TIMESTEP 92029 / STATE explore / EPSILON 0.00816392799987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2867430000847087 / Loss  0.09473800659179688
# fps: 8.023306839593316
# TIMESTEP 92030 / STATE explore / EPSILON 0.00816292899987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.416419887147997 / Loss  0.05597618967294693
# fps: 7.637894614163134
# TIMESTEP 92031 / STATE explore / EPSILON 0.00816192999987264 / ACTION 0 / REWARD 0.1 / Q_MAX  1.915886179493512 / Loss  0.04725430905818939
# fps: 7.394922662190776
# TIMESTEP 92032 / STATE explore / EPSILON 0.00816093099987264 / ACTION 0 / REWARD 0.1 / Q_MAX  12.470981171094651 / Loss  0.6078149080276489
# fps: 7.591747785448214
# TIMESTEP 92033 / STATE explore / EPSILON 0.00815993199987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.182474931062588 / Loss  0.05929657816886902
# fps: 8.410998076880656
# TIMESTEP 92034 / STATE explore / EPSILON 0.00815893299987264 / ACTION 0 / REWARD 0.1 / Q_MAX  11.38434498258272 / Loss  0.027936570346355438
# fps: 7.4811050685539895
# TIMESTEP 92035 / STATE explore / EPSILON 0.00815793399987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9964012374408666 / Loss  0.005858968012034893
# fps: 7.614751285826587
# TIMESTEP 92036 / STATE explore / EPSILON 0.00815693499987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7656240846607796 / Loss  0.0905357301235199
# fps: 8.373602504312272
# TIMESTEP 92037 / STATE explore / EPSILON 0.00815593599987264 / ACTION 0 / REWARD 0.1 / Q_MAX  2.302030708459881 / Loss  0.04704613611102104
# fps: 8.123269524259586
# TIMESTEP 92038 / STATE explore / EPSILON 0.008154936999872641 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6869431994015704 / Loss  0.06803909689188004
# fps: 7.87986796447741
# TIMESTEP 92039 / STATE explore / EPSILON 0.008153937999872641 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4127884997465716 / Loss  0.08842162042856216
# fps: 8.302215149157863
# TIMESTEP 92040 / STATE explore / EPSILON 0.008152938999872641 / ACTION 0 / REWARD 0.1 / Q_MAX  3.674872524259158 / Loss  0.10543610155582428
# fps: 8.262212670565686
# TIMESTEP 92041 / STATE explore / EPSILON 0.008151939999872642 / ACTION 0 / REWARD 0.1 / Q_MAX  2.778635768109363 / Loss  0.3848671019077301
# fps: 7.927272452362322
# TIMESTEP 92042 / STATE explore / EPSILON 0.008150940999872642 / ACTION 0 / REWARD 0.1 / Q_MAX  3.019505947810487 / Loss  0.01619415543973446
# fps: 7.007956478297627
# TIMESTEP 92043 / STATE explore / EPSILON 0.008149941999872642 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8748522305775968 / Loss  0.016545549035072327
# fps: 8.241448692152918
# TIMESTEP 92044 / STATE explore / EPSILON 0.008148942999872642 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8227311257259022 / Loss  0.07992324978113174
# fps: 7.569401908996902
# TIMESTEP 92045 / STATE explore / EPSILON 0.008147943999872643 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9955745813764265 / Loss  0.13386684656143188
# fps: 8.08771273539246
# TIMESTEP 92046 / STATE explore / EPSILON 0.008146944999872643 / ACTION 0 / REWARD 0.1 / Q_MAX  11.85174618099427 / Loss  0.03769359737634659
# fps: 8.724610187542643
# TIMESTEP 92047 / STATE explore / EPSILON 0.008145945999872643 / ACTION 0 / REWARD 0.1 / Q_MAX  2.550588280250993 / Loss  0.06060321629047394
# fps: 8.363217272361112
# TIMESTEP 92048 / STATE explore / EPSILON 0.008144946999872643 / ACTION 0 / REWARD 0.1 / Q_MAX  3.015094276043853 / Loss  0.03041013702750206
# fps: 8.3972235513637
# TIMESTEP 92049 / STATE explore / EPSILON 0.008143947999872643 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5572270599248785 / Loss  0.060451265424489975
# fps: 8.030572936211927
# TIMESTEP 92050 / STATE explore / EPSILON 0.008142948999872644 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5517730367025266 / Loss  0.020089691504836082
# fps: 7.991875325110847
# TIMESTEP 92051 / STATE explore / EPSILON 0.008141949999872644 / ACTION 0 / REWARD 0.1 / Q_MAX  11.417859713235615 / Loss  0.12697723507881165
# fps: 8.503921171079842
# TIMESTEP 92052 / STATE explore / EPSILON 0.008140950999872644 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.078378555396231 / Loss  0.02498229593038559
# fps: 8.907959876733305
# TIMESTEP 92053 / STATE explore / EPSILON 0.008139951999872644 / ACTION 0 / REWARD 0.1 / Q_MAX  2.950475571537115 / Loss  0.031042534857988358
# fps: 6.434501400637574
# TIMESTEP 92054 / STATE explore / EPSILON 0.008138952999872644 / ACTION 0 / REWARD 0.1 / Q_MAX  9.045706753749236 / Loss  0.028415240347385406
# fps: 7.753703724244004
# TIMESTEP 92055 / STATE explore / EPSILON 0.008137953999872645 / ACTION 0 / REWARD 0.1 / Q_MAX  0.735705286783318 / Loss  0.04955071210861206
# fps: 8.357567992475945
# TIMESTEP 92056 / STATE explore / EPSILON 0.008136954999872645 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8129956518585968 / Loss  0.03533913567662239
# fps: 8.013389070177986
# TIMESTEP 92057 / STATE explore / EPSILON 0.008135955999872645 / ACTION 0 / REWARD 0.1 / Q_MAX  11.660787421416439 / Loss  0.019822433590888977
# fps: 8.785041796090374
# TIMESTEP 92058 / STATE explore / EPSILON 0.008134956999872645 / ACTION 0 / REWARD 0.1 / Q_MAX  11.048282221119916 / Loss  0.024334821850061417
# fps: 8.062434163482166
# TIMESTEP 92059 / STATE explore / EPSILON 0.008133957999872645 / ACTION 0 / REWARD 0.1 / Q_MAX  1.773924805430779 / Loss  0.21876102685928345
# fps: 8.083566533299413
# TIMESTEP 92060 / STATE explore / EPSILON 0.008132958999872646 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7741959317908047 / Loss  0.04991493746638298
# fps: 8.354138823215413
# TIMESTEP 92061 / STATE explore / EPSILON 0.008131959999872646 / ACTION 0 / REWARD 0.1 / Q_MAX  10.483295638456987 / Loss  0.035190969705581665
# fps: 8.427509383313375
# TIMESTEP 92062 / STATE explore / EPSILON 0.008130960999872646 / ACTION 0 / REWARD 0.1 / Q_MAX  8.962160455388464 / Loss  0.03593754395842552
# fps: 8.04725935277403
# TIMESTEP 92063 / STATE explore / EPSILON 0.008129961999872646 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5101798093398573 / Loss  0.01393936388194561
# fps: 8.609404795382376
# TIMESTEP 92064 / STATE explore / EPSILON 0.008128962999872646 / ACTION 0 / REWARD 0.1 / Q_MAX  2.789087494516565 / Loss  0.0462816096842289
# fps: 8.258926338630818
# TIMESTEP 92065 / STATE explore / EPSILON 0.008127963999872647 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6707733247194505 / Loss  0.08306603133678436
# fps: 7.995074445636862
# TIMESTEP 92066 / STATE explore / EPSILON 0.008126964999872647 / ACTION 0 / REWARD 0.1 / Q_MAX  10.745477735697225 / Loss  0.020816868171095848
# fps: 8.137911498380879
# TIMESTEP 92067 / STATE explore / EPSILON 0.008125965999872647 / ACTION 0 / REWARD 0.1 / Q_MAX  2.755939256843888 / Loss  0.04797898232936859
# fps: 7.9763882549825045
# TIMESTEP 92068 / STATE explore / EPSILON 0.008124966999872647 / ACTION 0 / REWARD 0.1 / Q_MAX  10.697537860748504 / Loss  0.037627119570970535
# fps: 7.982551566895176
# TIMESTEP 92069 / STATE explore / EPSILON 0.008123967999872648 / ACTION 0 / REWARD 0.1 / Q_MAX  10.155005892246638 / Loss  0.029137399047613144
# fps: 8.075069212612675
# TIMESTEP 92070 / STATE explore / EPSILON 0.008122968999872648 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.7120063780390423 / Loss  0.03476109355688095
# fps: 8.576835225866875
# TIMESTEP 92071 / STATE explore / EPSILON 0.008121969999872648 / ACTION 0 / REWARD 0.1 / Q_MAX  2.954502677237439 / Loss  0.04358549416065216
# fps: 7.744841301349248
# TIMESTEP 92072 / STATE explore / EPSILON 0.008120970999872648 / ACTION 0 / REWARD 0.1 / Q_MAX  10.652572511089788 / Loss  0.020690947771072388
# fps: 8.554775968410404
# TIMESTEP 92073 / STATE explore / EPSILON 0.008119971999872648 / ACTION 0 / REWARD 0.1 / Q_MAX  2.829401929283103 / Loss  0.054104987531900406
# fps: 8.240347664814655
# TIMESTEP 92074 / STATE explore / EPSILON 0.008118972999872649 / ACTION 0 / REWARD 0.1 / Q_MAX  3.02659746622806 / Loss  0.014213167130947113
# fps: 8.149485788008262
# TIMESTEP 92075 / STATE explore / EPSILON 0.008117973999872649 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7011342456359237 / Loss  0.04151288419961929
# fps: 8.319819730468486
# TIMESTEP 92076 / STATE explore / EPSILON 0.008116974999872649 / ACTION 0 / REWARD 0.1 / Q_MAX  11.253861491851685 / Loss  0.027194859459996223
# fps: 8.929598814582677
# TIMESTEP 92077 / STATE explore / EPSILON 0.00811597599987265 / ACTION 0 / REWARD 0.1 / Q_MAX  10.445957671793066 / Loss  0.046481903642416
# fps: 8.093877543143956
# TIMESTEP 92078 / STATE explore / EPSILON 0.00811497699987265 / ACTION 0 / REWARD 0.1 / Q_MAX  10.882252381898455 / Loss  0.037461940199136734
# fps: 7.320489952072942
# TIMESTEP 92079 / STATE explore / EPSILON 0.00811397799987265 / ACTION 0 / REWARD 0.1 / Q_MAX  10.47404764510319 / Loss  0.036369238048791885
# fps: 8.607408319481213
# TIMESTEP 92080 / STATE explore / EPSILON 0.00811297899987265 / ACTION 0 / REWARD 0.1 / Q_MAX  3.159804274574373 / Loss  0.020878810435533524
# ----------Random Action----------
# fps: 6.994575177895142
# TIMESTEP 92081 / STATE explore / EPSILON 0.00811197999987265 / ACTION 1 / REWARD 0.1 / Q_MAX  11.202349047627768 / Loss  0.048425815999507904
# ----------Random Action----------
# fps: 8.634288031652645
# TIMESTEP 92082 / STATE explore / EPSILON 0.00811098099987265 / ACTION 0 / REWARD 0.1 / Q_MAX  10.57190280105085 / Loss  0.026670042425394058
# fps: 8.457929187621748
# TIMESTEP 92083 / STATE explore / EPSILON 0.00810998199987265 / ACTION 0 / REWARD 0.1 / Q_MAX  3.352106745472616 / Loss  0.016955338418483734
# fps: 8.366804108493266
# TIMESTEP 92084 / STATE explore / EPSILON 0.00810898299987265 / ACTION 0 / REWARD 0.1 / Q_MAX  10.636703059924558 / Loss  0.029102951288223267
# fps: 8.521734536936014
# TIMESTEP 92085 / STATE explore / EPSILON 0.00810798399987265 / ACTION 0 / REWARD 0.1 / Q_MAX  3.4091424108658654 / Loss  0.07885561138391495
# fps: 8.275661768187772
# TIMESTEP 92086 / STATE explore / EPSILON 0.008106984999872651 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4121074927609754 / Loss  0.09865330904722214
# fps: 8.172940447472106
# TIMESTEP 92087 / STATE explore / EPSILON 0.008105985999872651 / ACTION 0 / REWARD 0.1 / Q_MAX  3.6353237864737706 / Loss  0.04167570546269417
# fps: 8.42722152904609
# TIMESTEP 92088 / STATE explore / EPSILON 0.008104986999872651 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2407696827138754 / Loss  0.14672361314296722
# fps: 8.174135044697234
# TIMESTEP 92089 / STATE explore / EPSILON 0.008103987999872652 / ACTION 0 / REWARD 0.1 / Q_MAX  12.020138376304965 / Loss  2.511263132095337
# fps: 8.920862330060745
# TIMESTEP 92090 / STATE explore / EPSILON 0.008102988999872652 / ACTION 0 / REWARD 0.1 / Q_MAX  3.383644037455049 / Loss  0.011270003393292427
# fps: 8.512809896388305
# TIMESTEP 92091 / STATE explore / EPSILON 0.008101989999872652 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2887766520104056 / Loss  0.16390487551689148
# fps: 8.663321938675397
# TIMESTEP 92092 / STATE explore / EPSILON 0.008100990999872652 / ACTION 0 / REWARD 0.1 / Q_MAX  3.4016031677462353 / Loss  0.07411755621433258
# fps: 8.511496993593504
# TIMESTEP 92093 / STATE explore / EPSILON 0.008099991999872653 / ACTION 0 / REWARD 0.1 / Q_MAX  2.507506243229735 / Loss  0.02041240967810154
# fps: 8.800654650748022
# TIMESTEP 92094 / STATE explore / EPSILON 0.008098992999872653 / ACTION 0 / REWARD 0.1 / Q_MAX  2.556436626711131 / Loss  0.1561737209558487
# fps: 8.187250754933174
# TIMESTEP 92095 / STATE explore / EPSILON 0.008097993999872653 / ACTION 0 / REWARD 0.1 / Q_MAX  10.625723469831913 / Loss  0.07054276019334793
# fps: 8.083286116796367
# TIMESTEP 92096 / STATE explore / EPSILON 0.008096994999872653 / ACTION 0 / REWARD 0.1 / Q_MAX  3.703091668962278 / Loss  0.0544169619679451
# fps: 8.350812223874742
# TIMESTEP 92097 / STATE explore / EPSILON 0.008095995999872653 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1655672564144304 / Loss  0.13346761465072632
# fps: 8.385974803911571
# TIMESTEP 92098 / STATE explore / EPSILON 0.008094996999872654 / ACTION 0 / REWARD 0.1 / Q_MAX  3.9614840823266673 / Loss  0.021875424310564995
# fps: 8.011414578800895
# TIMESTEP 92099 / STATE explore / EPSILON 0.008093997999872654 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.4964898276531581 / Loss  0.004532688297331333
# fps: 8.344532181019853
# TIMESTEP 92100 / STATE explore / EPSILON 0.008092998999872654 / ACTION 0 / REWARD 0.1 / Q_MAX  9.803997427420747 / Loss  0.019934777170419693
# fps: 8.969662753148992
# TIMESTEP 92101 / STATE explore / EPSILON 0.008091999999872654 / ACTION 0 / REWARD 0.1 / Q_MAX  3.382674871292104 / Loss  0.05838796868920326
# fps: 8.664306224049247
# TIMESTEP 92102 / STATE explore / EPSILON 0.008091000999872654 / ACTION 0 / REWARD 0.1 / Q_MAX  3.432405311473956 / Loss  0.05513547733426094
# fps: 8.597774661976565
# TIMESTEP 92103 / STATE explore / EPSILON 0.008090001999872655 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3998801499826463 / Loss  0.009688207879662514
# fps: 8.57243530262959
# TIMESTEP 92104 / STATE explore / EPSILON 0.008089002999872655 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1169915081904502 / Loss  0.024777714163064957
# fps: 8.453428892749605
# TIMESTEP 92105 / STATE explore / EPSILON 0.008088003999872655 / ACTION 0 / REWARD 0.1 / Q_MAX  3.17038970555374 / Loss  0.1476018726825714
# fps: 8.617453084101397
# TIMESTEP 92106 / STATE explore / EPSILON 0.008087004999872655 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8508184394950873 / Loss  0.08272463828325272
# fps: 9.043404765446953
# TIMESTEP 92107 / STATE explore / EPSILON 0.008086005999872655 / ACTION 0 / REWARD 0.1 / Q_MAX  9.483271117657399 / Loss  0.08505819737911224
# fps: 7.9948153739411545
# TIMESTEP 92108 / STATE explore / EPSILON 0.008085006999872656 / ACTION 0 / REWARD 0.1 / Q_MAX  3.334453858913742 / Loss  0.10321865975856781
# fps: 8.4699876412572
# TIMESTEP 92109 / STATE explore / EPSILON 0.008084007999872656 / ACTION 0 / REWARD 0.1 / Q_MAX  3.375549437207257 / Loss  2.172374963760376
# fps: 8.388758997661958
# TIMESTEP 92110 / STATE explore / EPSILON 0.008083008999872656 / ACTION 0 / REWARD 0.1 / Q_MAX  9.404387366786453 / Loss  0.08576711267232895
# fps: 8.381533985316393
# TIMESTEP 92111 / STATE explore / EPSILON 0.008082009999872656 / ACTION 0 / REWARD 0.1 / Q_MAX  9.417942874828691 / Loss  0.29698047041893005
# fps: 8.683176064823057
# TIMESTEP 92112 / STATE explore / EPSILON 0.008081010999872656 / ACTION 0 / REWARD 0.1 / Q_MAX  3.414303130680368 / Loss  0.01567918434739113
# fps: 8.423227464880659
# TIMESTEP 92113 / STATE explore / EPSILON 0.008080011999872657 / ACTION 0 / REWARD 0.1 / Q_MAX  10.146826234070502 / Loss  0.030654437839984894
# fps: 8.158680078040659
# TIMESTEP 92114 / STATE explore / EPSILON 0.008079012999872657 / ACTION 0 / REWARD 0.1 / Q_MAX  10.124296766976888 / Loss  0.01859234645962715
# fps: 7.6341272080303595
# TIMESTEP 92115 / STATE explore / EPSILON 0.008078013999872657 / ACTION 0 / REWARD 0.1 / Q_MAX  3.491154866970942 / Loss  0.04397206008434296
# fps: 8.401512723543362
# TIMESTEP 92116 / STATE explore / EPSILON 0.008077014999872657 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7418733184398794 / Loss  0.03276167809963226
# fps: 8.181629145867836
# TIMESTEP 92117 / STATE explore / EPSILON 0.008076015999872658 / ACTION 0 / REWARD 0.1 / Q_MAX  3.5295608439209762 / Loss  0.08445682376623154
# fps: 8.574853825080753
# TIMESTEP 92118 / STATE explore / EPSILON 0.008075016999872658 / ACTION 0 / REWARD 0.1 / Q_MAX  3.084959870528617 / Loss  0.049356043338775635
# fps: 8.269869217771241
# TIMESTEP 92119 / STATE explore / EPSILON 0.008074017999872658 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8935759791573945 / Loss  0.9508268237113953
# fps: 8.445649919556686
# TIMESTEP 92120 / STATE explore / EPSILON 0.008073018999872658 / ACTION 0 / REWARD 0.1 / Q_MAX  1.760442190261997 / Loss  0.02911347523331642
# fps: 8.149849994559387
# TIMESTEP 92121 / STATE explore / EPSILON 0.008072019999872658 / ACTION 0 / REWARD 0.1 / Q_MAX  3.4263270240124197 / Loss  0.027644716203212738
# fps: 8.280693995846134
# TIMESTEP 92122 / STATE explore / EPSILON 0.008071020999872659 / ACTION 0 / REWARD 0.1 / Q_MAX  3.5147176739610506 / Loss  0.02883959375321865
# fps: 8.328542551121313
# TIMESTEP 92123 / STATE explore / EPSILON 0.008070021999872659 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7192049414034882 / Loss  1.6333452463150024
# fps: 8.569142698369243
# TIMESTEP 92124 / STATE explore / EPSILON 0.008069022999872659 / ACTION 0 / REWARD 0.1 / Q_MAX  3.284215651713849 / Loss  0.07551304996013641
# fps: 8.792444998794638
# TIMESTEP 92125 / STATE explore / EPSILON 0.00806802399987266 / ACTION 0 / REWARD 0.1 / Q_MAX  10.328362718550535 / Loss  0.06727681308984756
# fps: 8.431558358277064
# TIMESTEP 92126 / STATE explore / EPSILON 0.00806702499987266 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9609490673205374 / Loss  2.2628607749938965
# fps: 8.060745247791335
# TIMESTEP 92127 / STATE explore / EPSILON 0.00806602599987266 / ACTION 0 / REWARD 0.1 / Q_MAX  3.184416739979015 / Loss  0.02517092041671276
# fps: 8.627308367923714
# TIMESTEP 92128 / STATE explore / EPSILON 0.00806502699987266 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9919514028576923 / Loss  0.13639388978481293
# fps: 7.933345060365846
# TIMESTEP 92129 / STATE explore / EPSILON 0.00806402799987266 / ACTION 0 / REWARD 0.1 / Q_MAX  3.312444570871991 / Loss  0.03868080675601959
# fps: 8.354504910953487
# TIMESTEP 92130 / STATE explore / EPSILON 0.00806302899987266 / ACTION 0 / REWARD 0.1 / Q_MAX  3.41585929025367 / Loss  0.019858049228787422
# fps: 8.070361369745457
# TIMESTEP 92131 / STATE explore / EPSILON 0.00806202999987266 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.6197067350782324 / Loss  0.07235229015350342
# fps: 8.336107196874087
# TIMESTEP 92132 / STATE explore / EPSILON 0.00806103099987266 / ACTION 0 / REWARD 0.1 / Q_MAX  3.798871280917986 / Loss  0.07395234704017639
# fps: 8.18880124951191
# TIMESTEP 92133 / STATE explore / EPSILON 0.00806003199987266 / ACTION 0 / REWARD 0.1 / Q_MAX  10.039396562797954 / Loss  0.06835027784109116
# fps: 8.60998801175833
# TIMESTEP 92134 / STATE explore / EPSILON 0.008059032999872661 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9765699220660435 / Loss  0.06071789935231209
# fps: 8.277098923305232
# TIMESTEP 92135 / STATE explore / EPSILON 0.008058033999872661 / ACTION 0 / REWARD 0.1 / Q_MAX  3.4138356492830657 / Loss  0.06686697155237198
# fps: 8.44575195774611
# TIMESTEP 92136 / STATE explore / EPSILON 0.008057034999872661 / ACTION 0 / REWARD 0.1 / Q_MAX  2.810030299290519 / Loss  0.19707787036895752
# fps: 8.139933045461161
# TIMESTEP 92137 / STATE explore / EPSILON 0.008056035999872662 / ACTION 0 / REWARD 0.1 / Q_MAX  9.517679327259707 / Loss  0.03970592841506004
# fps: 8.145782231673804
# TIMESTEP 92138 / STATE explore / EPSILON 0.008055036999872662 / ACTION 0 / REWARD 0.1 / Q_MAX  3.7878147548623318 / Loss  0.06618683785200119
# fps: 8.437987100512197
# TIMESTEP 92139 / STATE explore / EPSILON 0.008054037999872662 / ACTION 0 / REWARD 0.1 / Q_MAX  9.334259137908274 / Loss  0.03233446180820465
# fps: 8.20419412447016
# TIMESTEP 92140 / STATE explore / EPSILON 0.008053038999872662 / ACTION 0 / REWARD 0.1 / Q_MAX  9.210321516202653 / Loss  0.045117806643247604
# fps: 8.678217473526527
# TIMESTEP 92141 / STATE explore / EPSILON 0.008052039999872663 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9240335844085577 / Loss  0.034544527530670166
# fps: 8.088710952717062
# TIMESTEP 92142 / STATE explore / EPSILON 0.008051040999872663 / ACTION 0 / REWARD 0.1 / Q_MAX  3.5710969954349414 / Loss  0.1640956997871399
# fps: 8.341047348021581
# TIMESTEP 92143 / STATE explore / EPSILON 0.008050041999872663 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2491402741600193 / Loss  0.04902555048465729
# fps: 7.859962633215211
# TIMESTEP 92144 / STATE explore / EPSILON 0.008049042999872663 / ACTION 0 / REWARD 0.1 / Q_MAX  0.9334391550182748 / Loss  0.13897180557250977
# fps: 8.000900369876524
# TIMESTEP 92145 / STATE explore / EPSILON 0.008048043999872663 / ACTION 0 / REWARD 0.1 / Q_MAX  9.53308799747766 / Loss  1.3558911085128784
# fps: 7.870109449263614
# TIMESTEP 92146 / STATE explore / EPSILON 0.008047044999872664 / ACTION 0 / REWARD 0.1 / Q_MAX  9.17967725498603 / Loss  0.11665679514408112
# fps: 7.5199351690159535
# TIMESTEP 92147 / STATE explore / EPSILON 0.008046045999872664 / ACTION 0 / REWARD 0.1 / Q_MAX  9.596478358034162 / Loss  0.2900025546550751
# fps: 8.255853869774034
# TIMESTEP 92148 / STATE explore / EPSILON 0.008045046999872664 / ACTION 0 / REWARD 0.1 / Q_MAX  9.273974466794522 / Loss  0.23937943577766418
# fps: 7.988952654505698
# TIMESTEP 92149 / STATE explore / EPSILON 0.008044047999872664 / ACTION 0 / REWARD 0.1 / Q_MAX  3.007662555229043 / Loss  0.03963036835193634
# fps: 7.533644787630918
# TIMESTEP 92150 / STATE explore / EPSILON 0.008043048999872664 / ACTION 0 / REWARD 0.1 / Q_MAX  2.276721084510948 / Loss  0.026094982400536537
# fps: 7.175048925018133
# TIMESTEP 92151 / STATE explore / EPSILON 0.008042049999872665 / ACTION 0 / REWARD 0.1 / Q_MAX  3.820210961168657 / Loss  0.04638352990150452
# fps: 8.613046772805772
# TIMESTEP 92152 / STATE explore / EPSILON 0.008041050999872665 / ACTION 0 / REWARD 0.1 / Q_MAX  3.6477962874206917 / Loss  0.1927565336227417
# fps: 7.746343193168051
# TIMESTEP 92153 / STATE explore / EPSILON 0.008040051999872665 / ACTION 0 / REWARD 0.1 / Q_MAX  3.6787396337397 / Loss  0.12201696634292603
# fps: 7.928770997243846
# TIMESTEP 92154 / STATE explore / EPSILON 0.008039052999872665 / ACTION 0 / REWARD 0.1 / Q_MAX  9.06845800425846 / Loss  0.03731609880924225
# fps: 8.73200273974314
# TIMESTEP 92155 / STATE explore / EPSILON 0.008038053999872665 / ACTION 0 / REWARD 0.1 / Q_MAX  2.66806188505052 / Loss  0.0194782093167305
# fps: 8.22077270446563
# TIMESTEP 92156 / STATE explore / EPSILON 0.008037054999872666 / ACTION 0 / REWARD 0.1 / Q_MAX  3.3326397472208615 / Loss  0.25976890325546265
# fps: 8.385320954185959
# TIMESTEP 92157 / STATE explore / EPSILON 0.008036055999872666 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.1387568132203842 / Loss  0.11099018156528473
# fps: 7.851693495397714
# TIMESTEP 92158 / STATE explore / EPSILON 0.008035056999872666 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2809020716658175 / Loss  0.027450893074274063
# fps: 7.8017161043352745
# TIMESTEP 92159 / STATE explore / EPSILON 0.008034057999872666 / ACTION 0 / REWARD 0.1 / Q_MAX  0.0004458154096986098 / Loss  0.06081077456474304
# fps: 8.184838266516797
# TIMESTEP 92160 / STATE explore / EPSILON 0.008033058999872666 / ACTION 0 / REWARD 0.1 / Q_MAX  3.3297856244076023 / Loss  0.07639174163341522
# fps: 7.994114440585964
# TIMESTEP 92161 / STATE explore / EPSILON 0.008032059999872667 / ACTION 0 / REWARD 0.1 / Q_MAX  2.519969576832167 / Loss  0.0578518807888031
# fps: 8.588180129857632
# TIMESTEP 92162 / STATE explore / EPSILON 0.008031060999872667 / ACTION 0 / REWARD 0.1 / Q_MAX  0.15477660276436525 / Loss  0.04126410186290741
# fps: 8.694263528611879
# TIMESTEP 92163 / STATE explore / EPSILON 0.008030061999872667 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.2611115805360307 / Loss  0.06939101219177246
# fps: 7.826435162292528
# TIMESTEP 92164 / STATE explore / EPSILON 0.008029062999872667 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1440798660768485 / Loss  0.45878326892852783
# fps: 7.958106282539731
# TIMESTEP 92165 / STATE explore / EPSILON 0.008028063999872668 / ACTION 0 / REWARD 0.1 / Q_MAX  3.194106623258981 / Loss  0.07535335421562195
# fps: 7.904072544855281
# TIMESTEP 92166 / STATE explore / EPSILON 0.008027064999872668 / ACTION 0 / REWARD 0.1 / Q_MAX  1.446293461739185 / Loss  0.11696984618902206
# fps: 8.005878950874495
# TIMESTEP 92167 / STATE explore / EPSILON 0.008026065999872668 / ACTION 0 / REWARD 0.1 / Q_MAX  8.156185278341239 / Loss  0.03185538947582245
# fps: 7.7646989129468915
# TIMESTEP 92168 / STATE explore / EPSILON 0.008025066999872668 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.1979219998728032 / Loss  0.1167958602309227
# fps: 8.121570753620944
# TIMESTEP 92169 / STATE explore / EPSILON 0.008024067999872668 / ACTION 0 / REWARD 0.1 / Q_MAX  7.342037285587497 / Loss  0.030383624136447906
# fps: 7.76577714168276
# TIMESTEP 92170 / STATE explore / EPSILON 0.008023068999872669 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8702676360764616 / Loss  0.12306379526853561
# fps: 7.74372598723504
# TIMESTEP 92171 / STATE explore / EPSILON 0.008022069999872669 / ACTION 0 / REWARD 0.1 / Q_MAX  8.856969184540871 / Loss  0.042133647948503494
# fps: 7.793873129252964
# TIMESTEP 92172 / STATE explore / EPSILON 0.008021070999872669 / ACTION 0 / REWARD 0.1 / Q_MAX  2.231969073409188 / Loss  0.37983399629592896
# fps: 8.348152851282684
# TIMESTEP 92173 / STATE explore / EPSILON 0.00802007199987267 / ACTION 0 / REWARD 0.1 / Q_MAX  3.06150359197859 / Loss  0.07902638614177704
# fps: 8.38074685944584
# TIMESTEP 92174 / STATE explore / EPSILON 0.00801907299987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.598928299939973 / Loss  0.05409066379070282
# fps: 8.399056426194186
# TIMESTEP 92175 / STATE explore / EPSILON 0.00801807399987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.409715277645119 / Loss  0.5547056794166565
# fps: 8.495377909567443
# TIMESTEP 92176 / STATE explore / EPSILON 0.00801707499987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.395422222310292 / Loss  0.07703260332345963
# fps: 7.616216972001445
# TIMESTEP 92177 / STATE explore / EPSILON 0.00801607599987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.740006072696343 / Loss  0.18379661440849304
# fps: 7.9346807818329035
# TIMESTEP 92178 / STATE explore / EPSILON 0.00801507699987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8845752436765157 / Loss  0.014131490141153336
# fps: 7.972052322067338
# TIMESTEP 92179 / STATE explore / EPSILON 0.00801407799987267 / ACTION 0 / REWARD 0.1 / Q_MAX  3.0803484302642437 / Loss  0.17666330933570862
# fps: 7.982642721743036
# TIMESTEP 92180 / STATE explore / EPSILON 0.00801307899987267 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2077101890304034 / Loss  0.19136440753936768
# fps: 8.390084654899262
# TIMESTEP 92181 / STATE explore / EPSILON 0.00801207999987267 / ACTION 0 / REWARD 0.1 / Q_MAX  2.22515623309326 / Loss  0.07544447481632233
# fps: 7.862320022344316
# TIMESTEP 92182 / STATE explore / EPSILON 0.008011080999872671 / ACTION 0 / REWARD 0.1 / Q_MAX  8.029573244434292 / Loss  0.09517248719930649
# fps: 7.984268666205996
# TIMESTEP 92183 / STATE explore / EPSILON 0.008010081999872671 / ACTION 0 / REWARD 0.1 / Q_MAX  2.284390091456499 / Loss  0.08143042027950287
# fps: 8.328344102077368
# TIMESTEP 92184 / STATE explore / EPSILON 0.008009082999872671 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7743487641050284 / Loss  0.2522164583206177
# fps: 8.016145801480032
# TIMESTEP 92185 / STATE explore / EPSILON 0.008008083999872672 / ACTION 0 / REWARD 0.1 / Q_MAX  3.0000505437344813 / Loss  0.02688719891011715
# fps: 8.000915632129532
# TIMESTEP 92186 / STATE explore / EPSILON 0.008007084999872672 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7744623825241495 / Loss  0.07106553763151169
# fps: 6.831303146829798
# TIMESTEP 92187 / STATE explore / EPSILON 0.008006085999872672 / ACTION 0 / REWARD 0.1 / Q_MAX  2.142233988917876 / Loss  0.04545805975794792
# fps: 7.763865288004827
# TIMESTEP 92188 / STATE explore / EPSILON 0.008005086999872672 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7618326577247885 / Loss  0.015598304569721222
# fps: 7.701906056043189
# TIMESTEP 92189 / STATE explore / EPSILON 0.008004087999872673 / ACTION 0 / REWARD 0.1 / Q_MAX  7.687612160694639 / Loss  0.008939806371927261
# fps: 8.166479750778816
# TIMESTEP 92190 / STATE explore / EPSILON 0.008003088999872673 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6576059403853889 / Loss  0.049914635717868805
# fps: 8.542335876432276
# TIMESTEP 92191 / STATE explore / EPSILON 0.008002089999872673 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.17372798639269627 / Loss  0.04098900780081749
# fps: 7.405158517875082
# TIMESTEP 92192 / STATE explore / EPSILON 0.008001090999872673 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8508143397433647 / Loss  0.06659902632236481
# fps: 8.090224345682536
# TIMESTEP 92193 / STATE explore / EPSILON 0.008000091999872673 / ACTION 0 / REWARD 0.1 / Q_MAX  2.797618414186019 / Loss  0.02639698050916195
# fps: 8.332496965434762
# TIMESTEP 92194 / STATE explore / EPSILON 0.007999092999872674 / ACTION 0 / REWARD 0.1 / Q_MAX  3.019722121286496 / Loss  0.021206513047218323
# fps: 7.856385051098391
# TIMESTEP 92195 / STATE explore / EPSILON 0.007998093999872674 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6799291717057323 / Loss  0.09036289155483246
# fps: 8.533663207195916
# TIMESTEP 92196 / STATE explore / EPSILON 0.007997094999872674 / ACTION 0 / REWARD 0.1 / Q_MAX  8.300607498685194 / Loss  0.021016065031290054
# fps: 7.941215785099088
# TIMESTEP 92197 / STATE explore / EPSILON 0.007996095999872674 / ACTION 0 / REWARD 0.1 / Q_MAX  7.308133366696746 / Loss  0.1137845441699028
# fps: 7.752485550628712
# TIMESTEP 92198 / STATE explore / EPSILON 0.007995096999872674 / ACTION 0 / REWARD 0.1 / Q_MAX  2.873571120642653 / Loss  0.04114331305027008
# fps: 8.302888974230049
# TIMESTEP 92199 / STATE explore / EPSILON 0.007994097999872675 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8415962474812915 / Loss  0.025666698813438416
# fps: 7.800134642064115
# TIMESTEP 92200 / STATE explore / EPSILON 0.007993098999872675 / ACTION 0 / REWARD 0.1 / Q_MAX  0.5703746313202289 / Loss  0.01823645830154419
# fps: 8.229305111648705
# TIMESTEP 92201 / STATE explore / EPSILON 0.007992099999872675 / ACTION 0 / REWARD 0.1 / Q_MAX  8.549089365010449 / Loss  0.025173861533403397
# fps: 8.318648168899555
# TIMESTEP 92202 / STATE explore / EPSILON 0.007991100999872675 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4206279522449643 / Loss  0.017975114285945892
# fps: 7.728643660539234
# TIMESTEP 92203 / STATE explore / EPSILON 0.007990101999872675 / ACTION 0 / REWARD 0.1 / Q_MAX  2.244947300318773 / Loss  0.026745492592453957
# fps: 7.846156148516185
# TIMESTEP 92204 / STATE explore / EPSILON 0.007989102999872676 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8602010319189279 / Loss  0.0756395012140274
# fps: 8.121696564116863
# TIMESTEP 92205 / STATE explore / EPSILON 0.007988103999872676 / ACTION 0 / REWARD 0.1 / Q_MAX  3.040595963105239 / Loss  0.15297454595565796
# fps: 8.05579104861742
# TIMESTEP 92206 / STATE explore / EPSILON 0.007987104999872676 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8998339152603005 / Loss  0.020861133933067322
# fps: 7.871660323251432
# TIMESTEP 92207 / STATE explore / EPSILON 0.007986105999872676 / ACTION 0 / REWARD 0.1 / Q_MAX  2.708216471832263 / Loss  0.41736289858818054
# fps: 8.084516978375389
# TIMESTEP 92208 / STATE explore / EPSILON 0.007985106999872676 / ACTION 0 / REWARD 0.1 / Q_MAX  7.1643002058744925 / Loss  0.6655529141426086
# fps: 8.040579554560408
# TIMESTEP 92209 / STATE explore / EPSILON 0.007984107999872677 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5181833193258867 / Loss  0.04042576998472214
# fps: 7.5636688889570145
# TIMESTEP 92210 / STATE explore / EPSILON 0.007983108999872677 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7994151005678267 / Loss  0.02983665093779564
# fps: 8.87722840591857
# TIMESTEP 92211 / STATE explore / EPSILON 0.007982109999872677 / ACTION 0 / REWARD 0.1 / Q_MAX  1.554295924787805 / Loss  0.018730880692601204
# fps: 8.425444041348777
# TIMESTEP 92212 / STATE explore / EPSILON 0.007981110999872677 / ACTION 0 / REWARD 0.1 / Q_MAX  8.175677293157957 / Loss  0.17056456208229065
# fps: 8.072256276523062
# TIMESTEP 92213 / STATE explore / EPSILON 0.007980111999872678 / ACTION 0 / REWARD 0.1 / Q_MAX  8.337058512024976 / Loss  0.05488002672791481
# fps: 7.551902512977204
# TIMESTEP 92214 / STATE explore / EPSILON 0.007979112999872678 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4882360187397494 / Loss  0.09235318005084991
# fps: 7.58340233958307
# TIMESTEP 92215 / STATE explore / EPSILON 0.007978113999872678 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1282457289781425 / Loss  0.16170573234558105
# fps: 7.242609844331437
# TIMESTEP 92216 / STATE explore / EPSILON 0.007977114999872678 / ACTION 0 / REWARD 0.1 / Q_MAX  2.30957467661925 / Loss  0.175869420170784
# fps: 8.277180594832366
# TIMESTEP 92217 / STATE explore / EPSILON 0.007976115999872678 / ACTION 0 / REWARD 0.1 / Q_MAX  2.041593736986898 / Loss  0.08602391183376312
# ----------Random Action----------
# fps: 6.430535624486391
# TIMESTEP 92218 / STATE explore / EPSILON 0.007975116999872679 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6558670394937323 / Loss  0.05477429926395416
# fps: 8.482612309615154
# TIMESTEP 92219 / STATE explore / EPSILON 0.007974117999872679 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5900107327279667 / Loss  0.029877644032239914
# fps: 7.86650787250204
# TIMESTEP 92220 / STATE explore / EPSILON 0.007973118999872679 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8982048531395246 / Loss  0.03369506448507309
# fps: 7.763017473852151
# TIMESTEP 92221 / STATE explore / EPSILON 0.00797211999987268 / ACTION 0 / REWARD 0.1 / Q_MAX  3.127867919008102 / Loss  0.03482196480035782
# fps: 7.718616638541335
# TIMESTEP 92222 / STATE explore / EPSILON 0.00797112099987268 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4483285674568216 / Loss  0.055447712540626526
# fps: 6.722955449623163
# TIMESTEP 92223 / STATE explore / EPSILON 0.00797012199987268 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8155501015635704 / Loss  0.029193513095378876
# fps: 7.846024052662198
# TIMESTEP 92224 / STATE explore / EPSILON 0.00796912299987268 / ACTION 0 / REWARD 0.1 / Q_MAX  8.07996119230344 / Loss  0.02203783020377159
# fps: 7.842033919854015
# TIMESTEP 92225 / STATE explore / EPSILON 0.00796812399987268 / ACTION 0 / REWARD 0.1 / Q_MAX  8.127764196393535 / Loss  0.0403723269701004
# fps: 8.139222230846853
# TIMESTEP 92226 / STATE explore / EPSILON 0.00796712499987268 / ACTION 0 / REWARD 0.1 / Q_MAX  0.977209257767994 / Loss  0.10006965696811676
# fps: 8.18860940391869
# TIMESTEP 92227 / STATE explore / EPSILON 0.00796612599987268 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6810049545093326 / Loss  0.32664409279823303
# fps: 7.9900484054398495
# TIMESTEP 92228 / STATE explore / EPSILON 0.00796512699987268 / ACTION 0 / REWARD 0.1 / Q_MAX  2.620874386648039 / Loss  0.013766668736934662
# fps: 8.04881905478327
# TIMESTEP 92229 / STATE explore / EPSILON 0.00796412799987268 / ACTION 0 / REWARD 0.1 / Q_MAX  8.296551835376402 / Loss  0.018411625176668167
# fps: 8.400351691664948
# TIMESTEP 92230 / STATE explore / EPSILON 0.007963128999872681 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8320888341533659 / Loss  0.08620116114616394
# fps: 8.11973122036871
# TIMESTEP 92231 / STATE explore / EPSILON 0.007962129999872681 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9928779969710722 / Loss  0.013880206272006035
# fps: 8.34028439223141
# TIMESTEP 92232 / STATE explore / EPSILON 0.007961130999872681 / ACTION 0 / REWARD 0.1 / Q_MAX  2.664133665776451 / Loss  0.01661400869488716
# fps: 8.12314366502692
# TIMESTEP 92233 / STATE explore / EPSILON 0.007960131999872682 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5736141453384853 / Loss  0.02457357570528984
# fps: 8.074991480866121
# TIMESTEP 92234 / STATE explore / EPSILON 0.007959132999872682 / ACTION 0 / REWARD 0.1 / Q_MAX  2.367449199206215 / Loss  0.10646937042474747
# fps: 8.023107322802414
# TIMESTEP 92235 / STATE explore / EPSILON 0.007958133999872682 / ACTION 0 / REWARD 0.1 / Q_MAX  2.411594555053719 / Loss  0.022698376327753067
# fps: 7.904444938619668
# TIMESTEP 92236 / STATE explore / EPSILON 0.007957134999872682 / ACTION 0 / REWARD 0.1 / Q_MAX  2.348946853107347 / Loss  0.16310802102088928
# fps: 7.994678225134712
# TIMESTEP 92237 / STATE explore / EPSILON 0.007956135999872683 / ACTION 0 / REWARD 0.1 / Q_MAX  8.352736675428297 / Loss  0.004009395372122526
# fps: 8.267261140972801
# TIMESTEP 92238 / STATE explore / EPSILON 0.007955136999872683 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3252134877696085 / Loss  0.08647470921278
# fps: 7.9754327318916225
# TIMESTEP 92239 / STATE explore / EPSILON 0.007954137999872683 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0790059356509567 / Loss  0.02988610416650772
# fps: 7.943877937544508
# TIMESTEP 92240 / STATE explore / EPSILON 0.007953138999872683 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5027545246692173 / Loss  0.020460747182369232
# fps: 8.054058517308057
# TIMESTEP 92241 / STATE explore / EPSILON 0.007952139999872683 / ACTION 0 / REWARD 0.1 / Q_MAX  2.687737419802883 / Loss  0.0203719399869442
# fps: 8.213190673593392
# TIMESTEP 92242 / STATE explore / EPSILON 0.007951140999872684 / ACTION 0 / REWARD 0.1 / Q_MAX  8.104473671295064 / Loss  0.015274026431143284
# fps: 8.01270018358719
# TIMESTEP 92243 / STATE explore / EPSILON 0.007950141999872684 / ACTION 0 / REWARD 0.1 / Q_MAX  2.478426753568189 / Loss  0.02012132853269577
# fps: 8.06803278530855
# TIMESTEP 92244 / STATE explore / EPSILON 0.007949142999872684 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9245412316326527 / Loss  0.01934274286031723
# fps: 8.083426322615956
# TIMESTEP 92245 / STATE explore / EPSILON 0.007948143999872684 / ACTION 0 / REWARD 0.1 / Q_MAX  2.253456849225045 / Loss  0.023129114881157875
# ----------Random Action----------
# fps: 7.361165907319916
# TIMESTEP 92246 / STATE explore / EPSILON 0.007947144999872684 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5339700248573123 / Loss  0.016821907833218575
# fps: 7.651228504141835
# TIMESTEP 92247 / STATE explore / EPSILON 0.007946145999872685 / ACTION 0 / REWARD 0.1 / Q_MAX  2.845448513194546 / Loss  0.3266594111919403
# fps: 7.303803309633391
# TIMESTEP 92248 / STATE explore / EPSILON 0.007945146999872685 / ACTION 0 / REWARD 0.1 / Q_MAX  8.879122239279699 / Loss  0.023485854268074036
# fps: 7.857871634090275
# TIMESTEP 92249 / STATE explore / EPSILON 0.007944147999872685 / ACTION 0 / REWARD 0.1 / Q_MAX  8.24298980795733 / Loss  0.07784652709960938
# fps: 8.832661209654153
# TIMESTEP 92250 / STATE explore / EPSILON 0.007943148999872685 / ACTION 0 / REWARD 0.1 / Q_MAX  7.574308388047223 / Loss  0.014819280244410038
# fps: 8.425393267003738
# TIMESTEP 92251 / STATE explore / EPSILON 0.007942149999872685 / ACTION 0 / REWARD 0.1 / Q_MAX  8.627556194321393 / Loss  0.08322195708751678
# fps: 7.517037562749452
# TIMESTEP 92252 / STATE explore / EPSILON 0.007941150999872686 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8900534938001363 / Loss  0.0107046440243721
# fps: 8.381450241493765
# TIMESTEP 92253 / STATE explore / EPSILON 0.007940151999872686 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.41582122098449725 / Loss  0.1300545632839203
# fps: 8.17039314001644
# TIMESTEP 92254 / STATE explore / EPSILON 0.007939152999872686 / ACTION 0 / REWARD 0.1 / Q_MAX  2.520681100256404 / Loss  0.029722154140472412
# fps: 7.655264301019533
# TIMESTEP 92255 / STATE explore / EPSILON 0.007938153999872686 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5330566516549502 / Loss  0.033116329461336136
# fps: 8.027406803471019
# TIMESTEP 92256 / STATE explore / EPSILON 0.007937154999872686 / ACTION 0 / REWARD 0.1 / Q_MAX  2.644692997016029 / Loss  0.027130769565701485
# fps: 8.16420661692714
# TIMESTEP 92257 / STATE explore / EPSILON 0.007936155999872687 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5461937922640763 / Loss  0.03134091570973396
# fps: 8.054630788966302
# TIMESTEP 92258 / STATE explore / EPSILON 0.007935156999872687 / ACTION 0 / REWARD 0.1 / Q_MAX  8.515922884582386 / Loss  0.0357457734644413
# fps: 7.207574794219236
# TIMESTEP 92259 / STATE explore / EPSILON 0.007934157999872687 / ACTION 0 / REWARD 0.1 / Q_MAX  8.948856625137742 / Loss  0.04691402614116669
# fps: 8.27280527180527
# TIMESTEP 92260 / STATE explore / EPSILON 0.007933158999872687 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6158651692326256 / Loss  0.030414417386054993
# fps: 8.43199906719981
# TIMESTEP 92261 / STATE explore / EPSILON 0.007932159999872688 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3616672197158795 / Loss  0.03975898027420044
# fps: 7.787549364916978
# TIMESTEP 92262 / STATE explore / EPSILON 0.007931160999872688 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8373459673172587 / Loss  0.00518269557505846
# fps: 8.055667271662202
# TIMESTEP 92263 / STATE explore / EPSILON 0.007930161999872688 / ACTION 0 / REWARD 0.1 / Q_MAX  2.891789234960137 / Loss  0.022059084847569466
# fps: 8.308415176714353
# TIMESTEP 92264 / STATE explore / EPSILON 0.007929162999872688 / ACTION 0 / REWARD 0.1 / Q_MAX  2.759430827791231 / Loss  0.026248641312122345
# fps: 8.122498697667032
# TIMESTEP 92265 / STATE explore / EPSILON 0.007928163999872688 / ACTION 0 / REWARD 0.1 / Q_MAX  2.659235152792024 / Loss  0.039492473006248474
# fps: 8.361916761696664
# TIMESTEP 92266 / STATE explore / EPSILON 0.007927164999872689 / ACTION 0 / REWARD 0.1 / Q_MAX  8.128569912488654 / Loss  0.03151752054691315
# fps: 8.495670438870649
# TIMESTEP 92267 / STATE explore / EPSILON 0.007926165999872689 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9012893490006268 / Loss  0.015569725073873997
# fps: 8.12314366502692
# TIMESTEP 92268 / STATE explore / EPSILON 0.007925166999872689 / ACTION 0 / REWARD 0.1 / Q_MAX  9.611649677821083 / Loss  0.2878640592098236
# fps: 8.24953730019334
# TIMESTEP 92269 / STATE explore / EPSILON 0.00792416799987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7578715147456494 / Loss  0.1340881735086441
# fps: 8.275400520874438
# TIMESTEP 92270 / STATE explore / EPSILON 0.00792316899987269 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.18459504872276836 / Loss  1.0077568292617798
# fps: 8.21578083436823
# TIMESTEP 92271 / STATE explore / EPSILON 0.00792216999987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4356918089457538 / Loss  0.08848574757575989
# fps: 8.232422480696231
# TIMESTEP 92272 / STATE explore / EPSILON 0.00792117099987269 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.6847517512843696 / Loss  0.11121555417776108
# fps: 8.261447795531184
# TIMESTEP 92273 / STATE explore / EPSILON 0.00792017199987269 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6951011432202638 / Loss  0.017313437536358833
# fps: 8.669858200008267
# TIMESTEP 92274 / STATE explore / EPSILON 0.00791917299987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6091240736639794 / Loss  0.005826259963214397
# fps: 8.042846048380138
# TIMESTEP 92275 / STATE explore / EPSILON 0.00791817399987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.573768856413524 / Loss  0.042272672057151794
# fps: 8.057756517395731
# TIMESTEP 92276 / STATE explore / EPSILON 0.00791717499987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4359856082611056 / Loss  0.01378234289586544
# fps: 8.095517870998375
# TIMESTEP 92277 / STATE explore / EPSILON 0.00791617599987269 / ACTION 0 / REWARD 0.1 / Q_MAX  2.681868569752305 / Loss  0.036865703761577606
# fps: 8.077028546779436
# TIMESTEP 92278 / STATE explore / EPSILON 0.007915176999872691 / ACTION 0 / REWARD 0.1 / Q_MAX  1.1664928676684507 / Loss  0.25642406940460205
# fps: 7.687056477625946
# TIMESTEP 92279 / STATE explore / EPSILON 0.007914177999872691 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0855721145578596 / Loss  0.014416087418794632
# fps: 9.209890802414511
# TIMESTEP 92280 / STATE explore / EPSILON 0.007913178999872691 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8673848598066618 / Loss  0.07001044601202011
# fps: 8.426595090668735
# TIMESTEP 92281 / STATE explore / EPSILON 0.007912179999872692 / ACTION 0 / REWARD 0.1 / Q_MAX  2.385729494128477 / Loss  0.05727517232298851
# fps: 7.809385851401547
# TIMESTEP 92282 / STATE explore / EPSILON 0.007911180999872692 / ACTION 0 / REWARD 0.1 / Q_MAX  2.964397149882546 / Loss  0.023347176611423492
# fps: 7.966086758337765
# TIMESTEP 92283 / STATE explore / EPSILON 0.007910181999872692 / ACTION 0 / REWARD 0.1 / Q_MAX  2.627416887228352 / Loss  0.02643292210996151
# fps: 8.07576886568124
# TIMESTEP 92284 / STATE explore / EPSILON 0.007909182999872692 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6469429875557884 / Loss  0.037089765071868896
# fps: 8.039423672220764
# TIMESTEP 92285 / STATE explore / EPSILON 0.007908183999872693 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.9448601816365638 / Loss  0.02296542003750801
# fps: 8.04549962307437
# TIMESTEP 92286 / STATE explore / EPSILON 0.007907184999872693 / ACTION 0 / REWARD 0.1 / Q_MAX  9.733345906959578 / Loss  0.011408800259232521
# fps: 8.54505078986077
# TIMESTEP 92287 / STATE explore / EPSILON 0.007906185999872693 / ACTION 0 / REWARD 0.1 / Q_MAX  9.299210231793067 / Loss  0.05191629007458687
# fps: 8.469628465904846
# TIMESTEP 92288 / STATE explore / EPSILON 0.007905186999872693 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1206570455000966 / Loss  0.02351287193596363
# fps: 8.700864629835538
# TIMESTEP 92289 / STATE explore / EPSILON 0.007904187999872693 / ACTION 0 / REWARD 0.1 / Q_MAX  3.11620729099282 / Loss  0.02352931536734104
# fps: 8.375057157519134
# TIMESTEP 92290 / STATE explore / EPSILON 0.007903188999872694 / ACTION 0 / REWARD 0.1 / Q_MAX  2.691971301735258 / Loss  0.0438123494386673
# ...
# fps: 9.407432993159134
# TIMESTEP 92761 / STATE explore / EPSILON 0.007432659999872792 / ACTION 1 / REWARD 0.1 / Q_MAX  2.810264817157408 / Loss  0.009740273468196392
# fps: 8.81749075008409
# TIMESTEP 92762 / STATE explore / EPSILON 0.007431660999872792 / ACTION 1 / REWARD 0.1 / Q_MAX  0.673811298647433 / Loss  0.008482052013278008
# fps: 8.125000484287767
# TIMESTEP 92763 / STATE explore / EPSILON 0.007430661999872792 / ACTION 1 / REWARD 0.1 / Q_MAX  7.693976636823377 / Loss  0.03307623788714409
# fps: 11.269376064655845
# TIMESTEP 92764 / STATE explore / EPSILON 0.007429662999872792 / ACTION 0 / REWARD 0.1 / Q_MAX  2.887544452832724 / Loss  0.03223771974444389
# fps: 11.007862939206568
# TIMESTEP 92765 / STATE explore / EPSILON 0.0074286639998727925 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6764945312324615 / Loss  0.23275797069072723
# fps: 9.555942868990092
# TIMESTEP 92766 / STATE explore / EPSILON 0.007427664999872793 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9075135858505528 / Loss  0.00621131993830204
# fps: 11.280438705721302
# TIMESTEP 92767 / STATE explore / EPSILON 0.007426665999872793 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8759238965933767 / Loss  0.031026417389512062
# fps: 11.293316855009598
# TIMESTEP 92768 / STATE explore / EPSILON 0.007425666999872793 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9388579098213388 / Loss  0.02364995889365673
# fps: 11.771105909823138
# TIMESTEP 92769 / STATE explore / EPSILON 0.007424667999872793 / ACTION 0 / REWARD 0.1 / Q_MAX  2.883845308373177 / Loss  0.01593397743999958
# fps: 9.712679291771451
# TIMESTEP 92770 / STATE explore / EPSILON 0.0074236689998727935 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1049184854053506 / Loss  0.09904100000858307
# fps: 9.243095176705738
# TIMESTEP 92771 / STATE explore / EPSILON 0.007422669999872794 / ACTION 1 / REWARD 0.1 / Q_MAX  6.877903349472112 / Loss  0.015619905665516853
# fps: 11.749803903991394
# TIMESTEP 92772 / STATE explore / EPSILON 0.007421670999872794 / ACTION 0 / REWARD 0.1 / Q_MAX  2.0080873661016745 / Loss  0.02938576228916645
# fps: 11.77649308314545
# TIMESTEP 92773 / STATE explore / EPSILON 0.007420671999872794 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8942662816691263 / Loss  0.05143972113728523
# fps: 11.48526520441414
# TIMESTEP 92774 / STATE explore / EPSILON 0.007419672999872794 / ACTION 0 / REWARD 0.1 / Q_MAX  7.84854902893225 / Loss  0.016357421875
# fps: 11.921359971122499
# TIMESTEP 92775 / STATE explore / EPSILON 0.0074186739998727946 / ACTION 0 / REWARD 0.1 / Q_MAX  6.963180813877567 / Loss  0.025654718279838562
# fps: 11.123084960525723
# TIMESTEP 92776 / STATE explore / EPSILON 0.007417674999872795 / ACTION 0 / REWARD -1 / Q_MAX  8.12462736875746 / Loss  0.012781829573214054
# fps: 11.413693262218352
# TIMESTEP 92777 / STATE explore / EPSILON 0.007416675999872795 / ACTION 0 / REWARD 0.1 / Q_MAX  2.246983455814849 / Loss  0.023019587621092796
# fps: 11.928072734925333
# TIMESTEP 92778 / STATE explore / EPSILON 0.007415676999872795 / ACTION 0 / REWARD 0.1 / Q_MAX  9.24036530025965 / Loss  0.03116656094789505
# fps: 10.067143025156433
# TIMESTEP 92779 / STATE explore / EPSILON 0.007414677999872795 / ACTION 1 / REWARD 0.1 / Q_MAX  10.412319062181565 / Loss  0.024673081934452057
# fps: 11.748125449906027
# TIMESTEP 92780 / STATE explore / EPSILON 0.007413678999872796 / ACTION 0 / REWARD 0.1 / Q_MAX  2.612612996284014 / Loss  0.037433892488479614
# fps: 9.179876647508657
# TIMESTEP 92781 / STATE explore / EPSILON 0.007412679999872796 / ACTION 1 / REWARD 0.1 / Q_MAX  2.903301612561074 / Loss  0.011557013727724552
# fps: 11.159337618662466
# TIMESTEP 92782 / STATE explore / EPSILON 0.007411680999872796 / ACTION 0 / REWARD 0.1 / Q_MAX  2.997933793651774 / Loss  0.10947245359420776
# fps: 9.380691132825342
# TIMESTEP 92783 / STATE explore / EPSILON 0.007410681999872796 / ACTION 1 / REWARD 0.1 / Q_MAX  9.746904321896315 / Loss  0.014337302185595036
# fps: 9.419115781152804
# TIMESTEP 92784 / STATE explore / EPSILON 0.0074096829998727964 / ACTION 1 / REWARD 0.1 / Q_MAX  8.043135704472176 / Loss  0.01529958751052618
# fps: 9.169180320701301
# TIMESTEP 92785 / STATE explore / EPSILON 0.007408683999872797 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1285434485505177 / Loss  0.05758919566869736
# fps: 10.942956732274425
# TIMESTEP 92786 / STATE explore / EPSILON 0.007407684999872797 / ACTION 0 / REWARD 0.1 / Q_MAX  3.023991764363031 / Loss  0.030690260231494904
# fps: 9.27617055062489
# TIMESTEP 92787 / STATE explore / EPSILON 0.007406685999872797 / ACTION 1 / REWARD 0.1 / Q_MAX  3.047801017895002 / Loss  0.029218116775155067
# fps: 9.592593609060387
# TIMESTEP 92788 / STATE explore / EPSILON 0.007405686999872797 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7918377551771725 / Loss  0.02631356380879879
# fps: 9.331832279480802
# TIMESTEP 92789 / STATE explore / EPSILON 0.0074046879998727975 / ACTION 1 / REWARD 0.1 / Q_MAX  2.859328941765804 / Loss  0.14229969680309296
# fps: 9.506969912643761
# TIMESTEP 92790 / STATE explore / EPSILON 0.007403688999872798 / ACTION 1 / REWARD 0.1 / Q_MAX  8.516230483376793 / Loss  0.02264873869717121
# fps: 9.511411051848627
# TIMESTEP 92791 / STATE explore / EPSILON 0.007402689999872798 / ACTION 1 / REWARD 0.1 / Q_MAX  10.597870128028553 / Loss  0.010477958247065544
# fps: 10.068182145514776
# TIMESTEP 92792 / STATE explore / EPSILON 0.007401690999872798 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.05279208898086645 / Loss  0.0244113989174366
# fps: 10.28413944615807
# TIMESTEP 92793 / STATE explore / EPSILON 0.007400691999872798 / ACTION 1 / REWARD 0.1 / Q_MAX  3.2270730473902027 / Loss  0.017865071073174477
# fps: 10.067046373701807
# TIMESTEP 92794 / STATE explore / EPSILON 0.0073996929998727985 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1085679655070044 / Loss  0.03178240731358528
# fps: 9.204130805928488
# TIMESTEP 92795 / STATE explore / EPSILON 0.007398693999872799 / ACTION 1 / REWARD 0.1 / Q_MAX  3.534914635817336 / Loss  0.044272832572460175
# fps: 11.739313213187158
# TIMESTEP 92796 / STATE explore / EPSILON 0.007397694999872799 / ACTION 0 / REWARD 0.1 / Q_MAX  1.1179224717792118 / Loss  0.011384163983166218
# fps: 9.869624044934831
# TIMESTEP 92797 / STATE explore / EPSILON 0.007396695999872799 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1024735043720946 / Loss  0.3274916708469391
# fps: 8.44111171486647
# TIMESTEP 92798 / STATE explore / EPSILON 0.007395696999872799 / ACTION 1 / REWARD 0.1 / Q_MAX  2.98821659766667 / Loss  0.07960815727710724
# fps: 10.841776847220606
# TIMESTEP 92799 / STATE explore / EPSILON 0.0073946979998727996 / ACTION 0 / REWARD 0.1 / Q_MAX  3.309169801228981 / Loss  0.016573064029216766
# fps: 9.721571563335134
# TIMESTEP 92800 / STATE explore / EPSILON 0.0073936989998728 / ACTION 1 / REWARD 0.1 / Q_MAX  2.739273363698744 / Loss  0.01810210756957531
# fps: 9.815278336812348
# TIMESTEP 92801 / STATE explore / EPSILON 0.0073926999998728 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1267592413751553 / Loss  0.04591801017522812
# fps: 11.508806589782216
# TIMESTEP 92802 / STATE explore / EPSILON 0.0073917009998728 / ACTION 0 / REWARD 0.1 / Q_MAX  9.747004489113111 / Loss  0.05662154406309128
# fps: 10.010224294872101
# TIMESTEP 92803 / STATE explore / EPSILON 0.0073907019998728 / ACTION 1 / REWARD 0.1 / Q_MAX  10.37058818921835 / Loss  0.06924010813236237
# fps: 11.588555956179977
# TIMESTEP 92804 / STATE explore / EPSILON 0.007389702999872801 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8701693097902394 / Loss  0.05000672489404678
# fps: 10.212523922454723
# TIMESTEP 92805 / STATE explore / EPSILON 0.007388703999872801 / ACTION 0 / REWARD 0.1 / Q_MAX  3.0658338430024084 / Loss  0.02623511478304863
# fps: 11.571164122611242
# TIMESTEP 92806 / STATE explore / EPSILON 0.007387704999872801 / ACTION 0 / REWARD 0.1 / Q_MAX  8.512290384738778 / Loss  0.0347333587706089
# fps: 11.578894480685298
# TIMESTEP 92807 / STATE explore / EPSILON 0.007386705999872801 / ACTION 0 / REWARD 0.1 / Q_MAX  10.297008394300702 / Loss  0.043081313371658325
# fps: 12.281391555910833
# TIMESTEP 92808 / STATE explore / EPSILON 0.0073857069998728014 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7078693618963006 / Loss  0.007247954607009888
# fps: 12.349518450798362
# TIMESTEP 92809 / STATE explore / EPSILON 0.007384707999872802 / ACTION 0 / REWARD 0.1 / Q_MAX  2.9769229612693358 / Loss  0.10955345630645752
# fps: 10.344582312884903
# TIMESTEP 92810 / STATE explore / EPSILON 0.007383708999872802 / ACTION 1 / REWARD 0.1 / Q_MAX  2.953054782628818 / Loss  0.10607382655143738
# fps: 9.89549379512103
# TIMESTEP 92811 / STATE explore / EPSILON 0.007382709999872802 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5685934728519406 / Loss  0.04232369363307953
# fps: 10.947640972635492
# TIMESTEP 92812 / STATE explore / EPSILON 0.007381710999872802 / ACTION 0 / REWARD 0.1 / Q_MAX  8.536538547545739 / Loss  0.042933303862810135
# fps: 12.302356754220012
# TIMESTEP 92813 / STATE explore / EPSILON 0.0073807119998728025 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1717172888554632 / Loss  0.041894592344760895
# fps: 11.892425862024968
# TIMESTEP 92814 / STATE explore / EPSILON 0.007379712999872803 / ACTION 0 / REWARD 0.1 / Q_MAX  10.275149281613269 / Loss  0.026080124080181122
# fps: 11.868734631046065
# TIMESTEP 92815 / STATE explore / EPSILON 0.007378713999872803 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8566518185249576 / Loss  0.05066942796111107
# fps: 10.226542708691444
# TIMESTEP 92816 / STATE explore / EPSILON 0.007377714999872803 / ACTION 1 / REWARD 0.1 / Q_MAX  2.845259542604266 / Loss  0.04316612333059311
# fps: 12.155218482475613
# TIMESTEP 92817 / STATE explore / EPSILON 0.007376715999872803 / ACTION 0 / REWARD 0.1 / Q_MAX  7.813032950930899 / Loss  0.032097671180963516
# fps: 12.093116591798958
# TIMESTEP 92818 / STATE explore / EPSILON 0.0073757169998728035 / ACTION 0 / REWARD 0.1 / Q_MAX  10.46974002111922 / Loss  0.05262758210301399
# fps: 12.129452421232234
# TIMESTEP 92819 / STATE explore / EPSILON 0.007374717999872804 / ACTION 0 / REWARD 0.1 / Q_MAX  2.479675392630473 / Loss  0.029869336634874344
# fps: 12.692742299114235
# TIMESTEP 92820 / STATE explore / EPSILON 0.007373718999872804 / ACTION 0 / REWARD 0.1 / Q_MAX  2.676242059502168 / Loss  0.06941987574100494
# fps: 10.534217400040184
# TIMESTEP 92821 / STATE explore / EPSILON 0.007372719999872804 / ACTION 1 / REWARD 0.1 / Q_MAX  3.143474607874392 / Loss  0.03328124061226845
# fps: 12.276898039468215
# TIMESTEP 92822 / STATE explore / EPSILON 0.007371720999872804 / ACTION 0 / REWARD 0.1 / Q_MAX  10.123429027383548 / Loss  0.041477568447589874
# fps: 12.651661126561736
# TIMESTEP 92823 / STATE explore / EPSILON 0.0073707219998728046 / ACTION 0 / REWARD 0.1 / Q_MAX  10.412100617931879 / Loss  0.04223497956991196
# fps: 12.183075640552701
# TIMESTEP 92824 / STATE explore / EPSILON 0.007369722999872805 / ACTION 0 / REWARD 0.1 / Q_MAX  8.679273233820963 / Loss  0.04439389333128929
# fps: 9.573938132281508
# TIMESTEP 92825 / STATE explore / EPSILON 0.007368723999872805 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9973224291618434 / Loss  0.028498739004135132
# fps: 9.301040026610488
# TIMESTEP 92826 / STATE explore / EPSILON 0.007367724999872805 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1527673767090394 / Loss  0.028254657983779907
# fps: 8.872158375797728
# TIMESTEP 92827 / STATE explore / EPSILON 0.007366725999872805 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9635850636107146 / Loss  0.041820548474788666
# fps: 8.870901153937261
# TIMESTEP 92828 / STATE explore / EPSILON 0.007365726999872806 / ACTION 1 / REWARD 0.1 / Q_MAX  3.4718323385607928 / Loss  0.1075800210237503
# fps: 11.455277403003173
# TIMESTEP 92829 / STATE explore / EPSILON 0.007364727999872806 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0785401128687728 / Loss  0.026163533329963684
# fps: 12.697468561360596
# TIMESTEP 92830 / STATE explore / EPSILON 0.007363728999872806 / ACTION 0 / REWARD 0.1 / Q_MAX  2.534768459035176 / Loss  0.0736733227968216
# fps: 12.008703818227628
# TIMESTEP 92831 / STATE explore / EPSILON 0.007362729999872806 / ACTION 0 / REWARD 0.1 / Q_MAX  10.49809340817769 / Loss  0.12308311462402344
# fps: 10.379011862989156
# TIMESTEP 92832 / STATE explore / EPSILON 0.0073617309998728064 / ACTION 1 / REWARD 0.1 / Q_MAX  9.766990689941563 / Loss  0.09659330546855927
# fps: 12.289236124336725
# TIMESTEP 92833 / STATE explore / EPSILON 0.007360731999872807 / ACTION 0 / REWARD 0.1 / Q_MAX  3.568964989874971 / Loss  0.04818316921591759
# fps: 11.906469734948377
# TIMESTEP 92834 / STATE explore / EPSILON 0.007359732999872807 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.5574318028230519 / Loss  0.03687950596213341
# fps: 9.166154558924443
# TIMESTEP 92835 / STATE explore / EPSILON 0.007358733999872807 / ACTION 1 / REWARD 0.1 / Q_MAX  2.8653933018458315 / Loss  0.05200512334704399
# fps: 10.070913879998175
# TIMESTEP 92836 / STATE explore / EPSILON 0.007357734999872807 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1471497429219393 / Loss  0.0704135000705719
# fps: 9.903835391957081
# TIMESTEP 92837 / STATE explore / EPSILON 0.0073567359998728075 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6649420679893785 / Loss  0.12750965356826782
# fps: 9.857539037161686
# TIMESTEP 92838 / STATE explore / EPSILON 0.007355736999872808 / ACTION 1 / REWARD -1 / Q_MAX  9.850600688395636 / Loss  0.018154475837945938
# fps: 12.27427534641441
# TIMESTEP 92839 / STATE explore / EPSILON 0.007354737999872808 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1902275848796378 / Loss  0.03811720758676529
# fps: 11.741745121258186
# TIMESTEP 92840 / STATE explore / EPSILON 0.007353738999872808 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2056652010735913 / Loss  0.010260076262056828
# fps: 11.913267247990456
# TIMESTEP 92841 / STATE explore / EPSILON 0.007352739999872808 / ACTION 0 / REWARD 0.1 / Q_MAX  0.24800445464381218 / Loss  0.019291622564196587
# fps: 12.563890270131022
# TIMESTEP 92842 / STATE explore / EPSILON 0.0073517409998728085 / ACTION 0 / REWARD 0.1 / Q_MAX  2.721261329395669 / Loss  0.04817090183496475
# fps: 12.575153130518471
# TIMESTEP 92843 / STATE explore / EPSILON 0.007350741999872809 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2180762855203167 / Loss  0.0063741160556674
# fps: 12.472913376928865
# TIMESTEP 92844 / STATE explore / EPSILON 0.007349742999872809 / ACTION 0 / REWARD 0.1 / Q_MAX  3.3263754907538265 / Loss  0.22347018122673035
# fps: 12.069557510409743
# TIMESTEP 92845 / STATE explore / EPSILON 0.007348743999872809 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5642216206262733 / Loss  0.021072397008538246
# fps: 12.380064640859517
# TIMESTEP 92846 / STATE explore / EPSILON 0.007347744999872809 / ACTION 0 / REWARD 0.1 / Q_MAX  9.084374193636462 / Loss  0.013004448264837265
# fps: 11.947541730758275
# TIMESTEP 92847 / STATE explore / EPSILON 0.0073467459998728096 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4175654733543044 / Loss  0.03451972454786301
# fps: 12.217641181593887
# TIMESTEP 92848 / STATE explore / EPSILON 0.00734574699987281 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2942815657763624 / Loss  0.13280445337295532
# fps: 11.98882953028575
# TIMESTEP 92849 / STATE explore / EPSILON 0.00734474799987281 / ACTION 0 / REWARD 0.1 / Q_MAX  3.88621727884796 / Loss  0.020903773605823517
# fps: 12.684911372345026
# TIMESTEP 92850 / STATE explore / EPSILON 0.00734374899987281 / ACTION 0 / REWARD 0.1 / Q_MAX  10.480052530133179 / Loss  0.01564442366361618
# fps: 12.613348008745103
# TIMESTEP 92851 / STATE explore / EPSILON 0.00734274999987281 / ACTION 0 / REWARD 0.1 / Q_MAX  10.483629676814076 / Loss  0.018427859991788864
# fps: 10.111020309769179
# TIMESTEP 92852 / STATE explore / EPSILON 0.007341750999872811 / ACTION 1 / REWARD 0.1 / Q_MAX  3.0418154702979514 / Loss  0.026789475232362747
# fps: 12.151556062879889
# TIMESTEP 92853 / STATE explore / EPSILON 0.007340751999872811 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1932923699630567 / Loss  0.2230411022901535
# fps: 10.018066562528363
# TIMESTEP 92854 / STATE explore / EPSILON 0.007339752999872811 / ACTION 1 / REWARD 0.1 / Q_MAX  3.417468554583904 / Loss  0.014436735771596432
# fps: 9.864192565938783
# TIMESTEP 92855 / STATE explore / EPSILON 0.007338753999872811 / ACTION 1 / REWARD 0.1 / Q_MAX  2.706638322680095 / Loss  0.04300268739461899
# fps: 12.615131044688134
# TIMESTEP 92856 / STATE explore / EPSILON 0.0073377549998728114 / ACTION 0 / REWARD 0.1 / Q_MAX  10.038844708744314 / Loss  0.01358473114669323
