# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

import numpy as np
import pandas as pd
from PIL import Image
import cv2  #opencv
from IPython.display import clear_output
from random import randint
import io
from io import BytesIO
import time
import os

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.callbacks import TensorBoard
from keras.optimizers import SGD , Adam
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D


from collections import deque
import random
import pickle
import _pickle as cPickle
import base64
import json

# %%
#path variables
game_url = "chrome://dino"
chromedriver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects_ddqn/loss_df.csv"
actions_file_path = "./objects_ddqn/actions_df.csv"
q_value_file_path = "./objects_ddqn/q_values.csv"
scores_file_path = "./objects_ddqn/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chromedriver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class Dino_Agent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_state:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        game_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            game_over = True
        return image, reward, game_over #return the Experience tuple

# %%
def save_object(obj, name):
    with open('objects_ddqn/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_object(name):
    with open('objects_ddqn/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = img_process(screen)#processing image as required
    return image

def img_process(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100 # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH_SIZE = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_object(INITIAL_EPSILON,"epsilon")
    t = 0
    save_object(t,"time")
    D = deque()
    save_object(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %%
def build_model():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model_ddqn.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate whether the model is to be trained(weight updates), else just play
'''
def train_Network(q_eval,q_target,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_object("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_object("epsilon") 
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)

    t = load_object("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0

        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = q_target.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        
        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH_SIZE)
            inputs = np.zeros((BATCH_SIZE, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    
                
                #q_next = q_target.predict(state_t1)
                #q_eval = q_eval.predict(state_t1)
                #q_pred = q_eval.predict(state_t)
                
                #targets[i] = q_pred
                Q_sa = q_target.predict(state_t1)      #predict q values for next step
                #old_q = q_eval.predict(state_t1)
                targets[i] = q_target.predict(state_t)  # predicted q values
                #max_Actions = np.argmax(old_q)
                q_eval = q_target
                #q_target  = targets[i]

                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    #targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += q_target.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 
            q_target.set_weights(q_eval.get_weights())

        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            q_target.save_weights("model_ddqn.h5", overwrite=True)
            save_object(D,"D") #saving episodes
            save_object(t,"time") #caching time steps
            save_object(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects_ddqn/loss_df.csv",index=False)
            scores_df.to_csv("./objects_ddqn/scores_df.csv",index=False)
            actions_df.to_csv("./objects_ddqn/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model_ddqn.json", "w") as outfile:
                json.dump(q_target.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX ", np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def play_Game(observe=False):
    game = Game()
    dino = Dino_Agent(game)
    game_state = Game_state(dino,game)    
    #model = build_model()
    q_eval = build_model()
    q_target = build_model()
    try:
        train_Network(q_eval,q_target,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
play_Game(observe=False);
# Out:
# TIMESTEP 5000 / STATE explore / EPSILON 0.09510489999999253 / ACTION 1 / REWARD 0.1 / Q_MAX  15.3829365 / Loss  0.6592115163803101
# fps: 1.544542496512695
# TIMESTEP 5001 / STATE explore / EPSILON 0.09510390099999252 / ACTION 1 / REWARD 0.1 / Q_MAX  20.949448 / Loss  1.1158332824707031
# fps: 9.55968902493225
# TIMESTEP 5002 / STATE explore / EPSILON 0.09510290199999252 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7700906 / Loss  3.4420976638793945
# fps: 9.754218033065193
# TIMESTEP 5003 / STATE explore / EPSILON 0.09510190299999252 / ACTION 1 / REWARD 0.1 / Q_MAX  17.169622 / Loss  1.0664479732513428
# fps: 9.639574087650795
# TIMESTEP 5004 / STATE explore / EPSILON 0.09510090399999252 / ACTION 1 / REWARD 0.1 / Q_MAX  19.741905 / Loss  1.9845260381698608
# fps: 9.357419020911
# TIMESTEP 5005 / STATE explore / EPSILON 0.09509990499999252 / ACTION 1 / REWARD 0.1 / Q_MAX  8.303769 / Loss  1.3243921995162964
# fps: 9.348680046004475
# TIMESTEP 5006 / STATE explore / EPSILON 0.09509890599999252 / ACTION 1 / REWARD 0.1 / Q_MAX  16.102242 / Loss  0.7548940181732178
# fps: 9.783797023086128
# TIMESTEP 5007 / STATE explore / EPSILON 0.09509790699999252 / ACTION 1 / REWARD 0.1 / Q_MAX  18.195976 / Loss  0.6360419988632202
# fps: 9.619367607969231
# TIMESTEP 5008 / STATE explore / EPSILON 0.09509690799999251 / ACTION 1 / REWARD 0.1 / Q_MAX  16.5206 / Loss  0.5427588224411011
# fps: 7.790283097016728
# TIMESTEP 5009 / STATE explore / EPSILON 0.09509590899999251 / ACTION 1 / REWARD 0.1 / Q_MAX  17.56065 / Loss  1.2038371562957764
# fps: 9.532725743766903
# TIMESTEP 5010 / STATE explore / EPSILON 0.09509490999999251 / ACTION 1 / REWARD 0.1 / Q_MAX  18.640423 / Loss  0.4046083092689514
# ----------Random Action----------
# fps: 10.497149407106711
# TIMESTEP 5011 / STATE explore / EPSILON 0.09509391099999251 / ACTION 0 / REWARD 0.1 / Q_MAX  24.186085 / Loss  1.2592079639434814
# fps: 9.534004196112573
# TIMESTEP 5012 / STATE explore / EPSILON 0.09509291199999251 / ACTION 1 / REWARD 0.1 / Q_MAX  23.012465 / Loss  0.24433937668800354
# fps: 9.576517541976994
# TIMESTEP 5013 / STATE explore / EPSILON 0.0950919129999925 / ACTION 1 / REWARD 0.1 / Q_MAX  19.989311 / Loss  1.81642484664917
# fps: 9.67530783887651
# TIMESTEP 5014 / STATE explore / EPSILON 0.0950909139999925 / ACTION 1 / REWARD 0.1 / Q_MAX  19.093134 / Loss  0.37896668910980225
# fps: 9.089991764552902
# TIMESTEP 5015 / STATE explore / EPSILON 0.0950899149999925 / ACTION 1 / REWARD 0.1 / Q_MAX  21.065966 / Loss  0.591036856174469
# fps: 7.862069482610603
# TIMESTEP 5016 / STATE explore / EPSILON 0.0950889159999925 / ACTION 1 / REWARD 0.1 / Q_MAX  18.607336 / Loss  1.2365820407867432
# fps: 8.736531635866758
# TIMESTEP 5017 / STATE explore / EPSILON 0.0950879169999925 / ACTION 1 / REWARD 0.1 / Q_MAX  18.693348 / Loss  0.3467899560928345
# fps: 9.040948605695341
# TIMESTEP 5018 / STATE explore / EPSILON 0.0950869179999925 / ACTION 1 / REWARD 0.1 / Q_MAX  24.691275 / Loss  1.6242525577545166
# fps: 11.662636665962252
# TIMESTEP 5019 / STATE explore / EPSILON 0.0950859189999925 / ACTION 0 / REWARD 0.1 / Q_MAX  20.156353 / Loss  1.7316548824310303
# fps: 10.824736627489845
# TIMESTEP 5020 / STATE explore / EPSILON 0.0950849199999925 / ACTION 0 / REWARD 0.1 / Q_MAX  22.502316 / Loss  2.6141858100891113
# fps: 10.997991451870886
# TIMESTEP 5021 / STATE explore / EPSILON 0.0950839209999925 / ACTION 0 / REWARD 0.1 / Q_MAX  17.564495 / Loss  0.22131302952766418
# fps: 9.704387018257455
# TIMESTEP 5022 / STATE explore / EPSILON 0.09508292199999249 / ACTION 1 / REWARD 0.1 / Q_MAX  25.41007 / Loss  1.2953712940216064
# fps: 9.417593052053466
# TIMESTEP 5023 / STATE explore / EPSILON 0.09508192299999249 / ACTION 1 / REWARD 0.1 / Q_MAX  22.127018 / Loss  0.15381518006324768
# fps: 9.052148596414366
# TIMESTEP 5024 / STATE explore / EPSILON 0.09508092399999249 / ACTION 1 / REWARD 0.1 / Q_MAX  19.31201 / Loss  0.28064870834350586
# fps: 9.647578389518623
# TIMESTEP 5025 / STATE explore / EPSILON 0.09507992499999249 / ACTION 1 / REWARD 0.1 / Q_MAX  17.816177 / Loss  1.3786954879760742
# fps: 9.792317066906982
# TIMESTEP 5026 / STATE explore / EPSILON 0.09507892599999249 / ACTION 1 / REWARD 0.1 / Q_MAX  17.93049 / Loss  2.6842405796051025
# fps: 9.312356517066975
# TIMESTEP 5027 / STATE explore / EPSILON 0.09507792699999248 / ACTION 1 / REWARD 0.1 / Q_MAX  18.416594 / Loss  1.9617220163345337
# fps: 9.664072256399622
# TIMESTEP 5028 / STATE explore / EPSILON 0.09507692799999248 / ACTION 1 / REWARD 0.1 / Q_MAX  18.580914 / Loss  0.49680095911026
# fps: 9.386863372177599
# TIMESTEP 5029 / STATE explore / EPSILON 0.09507592899999248 / ACTION 1 / REWARD 0.1 / Q_MAX  25.787735 / Loss  0.7722099423408508
# fps: 9.6478446887795
# TIMESTEP 5030 / STATE explore / EPSILON 0.09507492999999248 / ACTION 1 / REWARD 0.1 / Q_MAX  22.8763 / Loss  0.3833011984825134
# fps: 9.951725528810222
# TIMESTEP 5031 / STATE explore / EPSILON 0.09507393099999248 / ACTION 1 / REWARD 0.1 / Q_MAX  25.738258 / Loss  0.10993622988462448
# fps: 9.859369600834953
# TIMESTEP 5032 / STATE explore / EPSILON 0.09507293199999248 / ACTION 1 / REWARD 0.1 / Q_MAX  14.976102 / Loss  0.7415430545806885
# fps: 9.076870805714076
# TIMESTEP 5033 / STATE explore / EPSILON 0.09507193299999248 / ACTION 1 / REWARD 0.1 / Q_MAX  20.44863 / Loss  2.750763416290283
# fps: 8.800710048742411
# TIMESTEP 5034 / STATE explore / EPSILON 0.09507093399999247 / ACTION 1 / REWARD 0.1 / Q_MAX  18.427044 / Loss  1.2916159629821777
# fps: 9.065687971866847
# TIMESTEP 5035 / STATE explore / EPSILON 0.09506993499999247 / ACTION 1 / REWARD 0.1 / Q_MAX  18.899475 / Loss  2.924858808517456
# ----------Random Action----------
# fps: 11.035696337750975
# TIMESTEP 5036 / STATE explore / EPSILON 0.09506893599999247 / ACTION 0 / REWARD 0.1 / Q_MAX  16.41892 / Loss  0.6727074980735779
# fps: 8.165653010209247
# TIMESTEP 5037 / STATE explore / EPSILON 0.09506793699999247 / ACTION 1 / REWARD 0.1 / Q_MAX  24.664608 / Loss  1.4773004055023193
# fps: 9.52480265966627
# TIMESTEP 5038 / STATE explore / EPSILON 0.09506693799999247 / ACTION 1 / REWARD 0.1 / Q_MAX  17.09728 / Loss  1.2532380819320679
# ----------Random Action----------
# fps: 11.224380348856503
# TIMESTEP 5039 / STATE explore / EPSILON 0.09506593899999247 / ACTION 0 / REWARD 0.1 / Q_MAX  16.762306 / Loss  0.4213266968727112
# fps: 9.922297529068048
# TIMESTEP 5040 / STATE explore / EPSILON 0.09506493999999246 / ACTION 1 / REWARD 0.1 / Q_MAX  19.51623 / Loss  1.710374116897583
# fps: 9.463063111845118
# TIMESTEP 5041 / STATE explore / EPSILON 0.09506394099999246 / ACTION 1 / REWARD 0.1 / Q_MAX  15.993076 / Loss  0.1844073086977005
# fps: 9.237354616911018
# TIMESTEP 5042 / STATE explore / EPSILON 0.09506294199999246 / ACTION 1 / REWARD 0.1 / Q_MAX  17.021425 / Loss  1.3352923393249512
# fps: 9.496143178962383
# TIMESTEP 5043 / STATE explore / EPSILON 0.09506194299999246 / ACTION 1 / REWARD 0.1 / Q_MAX  15.438901 / Loss  1.4084012508392334
# fps: 9.52787507893888
# TIMESTEP 5044 / STATE explore / EPSILON 0.09506094399999246 / ACTION 1 / REWARD 0.1 / Q_MAX  22.855547 / Loss  0.33510321378707886
# fps: 9.652040842156616
# TIMESTEP 5045 / STATE explore / EPSILON 0.09505994499999246 / ACTION 1 / REWARD 0.1 / Q_MAX  14.718172 / Loss  0.6424205899238586
# fps: 9.969987615672236
# TIMESTEP 5046 / STATE explore / EPSILON 0.09505894599999246 / ACTION 1 / REWARD 0.1 / Q_MAX  20.771322 / Loss  0.5770077705383301
# fps: 9.635101018802477
# TIMESTEP 5047 / STATE explore / EPSILON 0.09505794699999245 / ACTION 1 / REWARD 0.1 / Q_MAX  18.462204 / Loss  0.7107881307601929
# fps: 9.360843977155303
# TIMESTEP 5048 / STATE explore / EPSILON 0.09505694799999245 / ACTION 1 / REWARD 0.1 / Q_MAX  15.64699 / Loss  1.0617918968200684
# fps: 10.031988098341756
# TIMESTEP 5049 / STATE explore / EPSILON 0.09505594899999245 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0356874 / Loss  0.07983886450529099
# fps: 9.423644578651622
# TIMESTEP 5050 / STATE explore / EPSILON 0.09505494999999245 / ACTION 1 / REWARD 0.1 / Q_MAX  14.348981 / Loss  0.6747912764549255
# fps: 9.510030836205333
# TIMESTEP 5051 / STATE explore / EPSILON 0.09505395099999245 / ACTION 1 / REWARD 0.1 / Q_MAX  14.167034 / Loss  1.4978482723236084
# fps: 9.413534847080422
# TIMESTEP 5052 / STATE explore / EPSILON 0.09505295199999245 / ACTION 1 / REWARD 0.1 / Q_MAX  15.658064 / Loss  0.5306466221809387
# fps: 9.77547405515261
# TIMESTEP 5053 / STATE explore / EPSILON 0.09505195299999245 / ACTION 1 / REWARD 0.1 / Q_MAX  16.873138 / Loss  1.0755541324615479
# fps: 9.619544102435903
# TIMESTEP 5054 / STATE explore / EPSILON 0.09505095399999244 / ACTION 1 / REWARD 0.1 / Q_MAX  15.645315 / Loss  0.578117847442627
# fps: 9.938378934248906
# TIMESTEP 5055 / STATE explore / EPSILON 0.09504995499999244 / ACTION 1 / REWARD 0.1 / Q_MAX  14.158823 / Loss  0.5756903290748596
# fps: 9.041435832877054
# TIMESTEP 5056 / STATE explore / EPSILON 0.09504895599999244 / ACTION 1 / REWARD 0.1 / Q_MAX  11.230022 / Loss  1.1104317903518677
# fps: 9.532790741544636
# TIMESTEP 5057 / STATE explore / EPSILON 0.09504795699999244 / ACTION 1 / REWARD 0.1 / Q_MAX  15.600064 / Loss  0.6819083094596863
# fps: 9.538687558987071
# TIMESTEP 5058 / STATE explore / EPSILON 0.09504695799999244 / ACTION 1 / REWARD 0.1 / Q_MAX  12.2021055 / Loss  0.7493263483047485
# fps: 9.437172203534745
# TIMESTEP 5059 / STATE explore / EPSILON 0.09504595899999244 / ACTION 1 / REWARD 0.1 / Q_MAX  13.889642 / Loss  0.8743078708648682
# fps: 9.803257231540174
# TIMESTEP 5060 / STATE explore / EPSILON 0.09504495999999243 / ACTION 1 / REWARD 0.1 / Q_MAX  16.577293 / Loss  0.4608480632305145
# fps: 9.634724761791
# TIMESTEP 5061 / STATE explore / EPSILON 0.09504396099999243 / ACTION 1 / REWARD 0.1 / Q_MAX  13.811701 / Loss  0.2644808292388916
# fps: 9.411485937647255
# TIMESTEP 5062 / STATE explore / EPSILON 0.09504296199999243 / ACTION 1 / REWARD 0.1 / Q_MAX  22.115334 / Loss  0.401003897190094
# fps: 9.552656511916041
# TIMESTEP 5063 / STATE explore / EPSILON 0.09504196299999243 / ACTION 1 / REWARD 0.1 / Q_MAX  12.608434 / Loss  0.6020963788032532
# fps: 9.402287410276758
# TIMESTEP 5064 / STATE explore / EPSILON 0.09504096399999243 / ACTION 1 / REWARD 0.1 / Q_MAX  21.87758 / Loss  0.6248706579208374
# fps: 9.640416020226398
# TIMESTEP 5065 / STATE explore / EPSILON 0.09503996499999243 / ACTION 1 / REWARD 0.1 / Q_MAX  14.213649 / Loss  0.33262360095977783
# fps: 9.176502505086749
# TIMESTEP 5066 / STATE explore / EPSILON 0.09503896599999243 / ACTION 1 / REWARD 0.1 / Q_MAX  13.578077 / Loss  0.18396472930908203
# fps: 9.818173306054804
# TIMESTEP 5067 / STATE explore / EPSILON 0.09503796699999242 / ACTION 1 / REWARD 0.1 / Q_MAX  13.88234 / Loss  0.5578066110610962
# fps: 9.685674830616891
# TIMESTEP 5068 / STATE explore / EPSILON 0.09503696799999242 / ACTION 1 / REWARD 0.1 / Q_MAX  16.520033 / Loss  0.2891199588775635
# fps: 9.713916481195415
# TIMESTEP 5069 / STATE explore / EPSILON 0.09503596899999242 / ACTION 1 / REWARD 0.1 / Q_MAX  7.130071 / Loss  0.6751208901405334
# fps: 9.405492194052142
# TIMESTEP 5070 / STATE explore / EPSILON 0.09503496999999242 / ACTION 1 / REWARD 0.1 / Q_MAX  13.348842 / Loss  1.751145839691162
# ----------Random Action----------
# fps: 9.664473077844752
# TIMESTEP 5071 / STATE explore / EPSILON 0.09503397099999242 / ACTION 1 / REWARD 0.1 / Q_MAX  14.357264 / Loss  0.5972525477409363
# ----------Random Action----------
# fps: 9.665118915667925
# TIMESTEP 5072 / STATE explore / EPSILON 0.09503297199999242 / ACTION 1 / REWARD 0.1 / Q_MAX  10.869466 / Loss  0.3239521384239197
# fps: 8.839306563036084
# TIMESTEP 5073 / STATE explore / EPSILON 0.09503197299999241 / ACTION 1 / REWARD 0.1 / Q_MAX  15.272934 / Loss  0.1728876531124115
# fps: 9.471012087423254
# TIMESTEP 5074 / STATE explore / EPSILON 0.09503097399999241 / ACTION 1 / REWARD 0.1 / Q_MAX  16.72677 / Loss  0.27738314867019653
# fps: 9.226524003941996
# TIMESTEP 5075 / STATE explore / EPSILON 0.09502997499999241 / ACTION 1 / REWARD 0.1 / Q_MAX  16.745808 / Loss  0.2039133906364441
# fps: 9.521818685385044
# TIMESTEP 5076 / STATE explore / EPSILON 0.09502897599999241 / ACTION 1 / REWARD 0.1 / Q_MAX  11.692302 / Loss  1.1325349807739258
# ----------Random Action----------
# fps: 9.93967429427266
# TIMESTEP 5077 / STATE explore / EPSILON 0.09502797699999241 / ACTION 1 / REWARD 0.1 / Q_MAX  18.127895 / Loss  0.728268027305603
# fps: 9.548915864530876
# TIMESTEP 5078 / STATE explore / EPSILON 0.0950269779999924 / ACTION 1 / REWARD 0.1 / Q_MAX  21.988367 / Loss  0.39031001925468445
# fps: 9.566622798114185
# TIMESTEP 5079 / STATE explore / EPSILON 0.0950259789999924 / ACTION 1 / REWARD 0.1 / Q_MAX  13.793606 / Loss  0.21057316660881042
# fps: 9.411676005107159
# TIMESTEP 5080 / STATE explore / EPSILON 0.0950249799999924 / ACTION 1 / REWARD 0.1 / Q_MAX  16.329155 / Loss  0.5875007510185242
# fps: 9.617338386999878
# TIMESTEP 5081 / STATE explore / EPSILON 0.0950239809999924 / ACTION 1 / REWARD 0.1 / Q_MAX  17.265427 / Loss  0.6503918170928955
# fps: 9.588931234011033
# TIMESTEP 5082 / STATE explore / EPSILON 0.0950229819999924 / ACTION 1 / REWARD 0.1 / Q_MAX  15.722652 / Loss  0.5388086438179016
# fps: 9.797578113320377
# TIMESTEP 5083 / STATE explore / EPSILON 0.0950219829999924 / ACTION 1 / REWARD 0.1 / Q_MAX  15.208322 / Loss  0.6082109212875366
# ----------Random Action----------
# fps: 9.536085122830153
# TIMESTEP 5084 / STATE explore / EPSILON 0.0950209839999924 / ACTION 1 / REWARD 0.1 / Q_MAX  18.056765 / Loss  0.16010552644729614
# fps: 9.739020595815822
# TIMESTEP 5085 / STATE explore / EPSILON 0.0950199849999924 / ACTION 1 / REWARD 0.1 / Q_MAX  4.195221 / Loss  0.5720986723899841
# ----------Random Action----------
# fps: 9.73567492537452
# TIMESTEP 5086 / STATE explore / EPSILON 0.0950189859999924 / ACTION 1 / REWARD 0.1 / Q_MAX  14.919491 / Loss  0.6006039381027222
# ----------Random Action----------
# fps: 11.529781736214195
# TIMESTEP 5087 / STATE explore / EPSILON 0.0950179869999924 / ACTION 0 / REWARD 0.1 / Q_MAX  19.142216 / Loss  0.8478788733482361
# fps: 9.344056461278667
# TIMESTEP 5088 / STATE explore / EPSILON 0.09501698799999239 / ACTION 1 / REWARD 0.1 / Q_MAX  18.134209 / Loss  2.080824851989746
# fps: 9.490814218444877
# TIMESTEP 5089 / STATE explore / EPSILON 0.09501598899999239 / ACTION 1 / REWARD 0.1 / Q_MAX  14.568984 / Loss  0.7478579878807068
# fps: 9.647556198577123
# TIMESTEP 5090 / STATE explore / EPSILON 0.09501498999999239 / ACTION 1 / REWARD 0.1 / Q_MAX  23.530727 / Loss  0.6484959125518799
# fps: 9.580082911732124
# TIMESTEP 5091 / STATE explore / EPSILON 0.09501399099999239 / ACTION 1 / REWARD 0.1 / Q_MAX  18.225323 / Loss  0.7217444181442261
# fps: 9.520543498739086
# TIMESTEP 5092 / STATE explore / EPSILON 0.09501299199999239 / ACTION 1 / REWARD 0.1 / Q_MAX  16.670057 / Loss  1.0943440198898315
# fps: 9.3493677262889
# TIMESTEP 5093 / STATE explore / EPSILON 0.09501199299999238 / ACTION 1 / REWARD 0.1 / Q_MAX  15.322853 / Loss  2.2809112071990967
# fps: 9.795564523662724
# TIMESTEP 5094 / STATE explore / EPSILON 0.09501099399999238 / ACTION 1 / REWARD 0.1 / Q_MAX  15.632843 / Loss  0.3637969493865967
# fps: 9.616302050136875
# TIMESTEP 5095 / STATE explore / EPSILON 0.09500999499999238 / ACTION 1 / REWARD 0.1 / Q_MAX  19.746286 / Loss  0.47310006618499756
# fps: 9.675397114661523
# TIMESTEP 5096 / STATE explore / EPSILON 0.09500899599999238 / ACTION 1 / REWARD 0.1 / Q_MAX  19.634245 / Loss  0.46817636489868164
# fps: 9.248292254841
# TIMESTEP 5097 / STATE explore / EPSILON 0.09500799699999238 / ACTION 1 / REWARD 0.1 / Q_MAX  19.219992 / Loss  0.6880224347114563
# fps: 8.797165982562152
# TIMESTEP 5098 / STATE explore / EPSILON 0.09500699799999238 / ACTION 1 / REWARD 0.1 / Q_MAX  16.376625 / Loss  0.34478938579559326
# ----------Random Action----------
# fps: 10.837770795435754
# TIMESTEP 5099 / STATE explore / EPSILON 0.09500599899999237 / ACTION 0 / REWARD 0.1 / Q_MAX  19.965302 / Loss  0.8138108253479004
# fps: 9.667903687551574
# TIMESTEP 5100 / STATE explore / EPSILON 0.09500499999999237 / ACTION 1 / REWARD 0.1 / Q_MAX  18.165382 / Loss  0.18124055862426758
# fps: 9.383923197909466
# TIMESTEP 5101 / STATE explore / EPSILON 0.09500400099999237 / ACTION 1 / REWARD 0.1 / Q_MAX  18.849043 / Loss  0.09850912541151047
# ----------Random Action----------
# fps: 11.036073821088582
# TIMESTEP 5102 / STATE explore / EPSILON 0.09500300199999237 / ACTION 0 / REWARD 0.1 / Q_MAX  10.966126 / Loss  0.5340287685394287
# fps: 9.661378708270083
# TIMESTEP 5103 / STATE explore / EPSILON 0.09500200299999237 / ACTION 1 / REWARD 0.1 / Q_MAX  15.5204935 / Loss  0.8242013454437256
# ----------Random Action----------
# fps: 11.202495673169377
# TIMESTEP 5104 / STATE explore / EPSILON 0.09500100399999237 / ACTION 0 / REWARD 0.1 / Q_MAX  19.23991 / Loss  0.6174578666687012
# fps: 9.255312482071062
# TIMESTEP 5105 / STATE explore / EPSILON 0.09500000499999237 / ACTION 1 / REWARD 0.1 / Q_MAX  19.71369 / Loss  0.23112940788269043
# fps: 9.237781859668134
# TIMESTEP 5106 / STATE explore / EPSILON 0.09499900599999236 / ACTION 1 / REWARD 0.1 / Q_MAX  19.698435 / Loss  0.47337865829467773
# fps: 9.104553683451925
# TIMESTEP 5107 / STATE explore / EPSILON 0.09499800699999236 / ACTION 1 / REWARD 0.1 / Q_MAX  17.000528 / Loss  0.5029772520065308
# fps: 9.493413488089956
# TIMESTEP 5108 / STATE explore / EPSILON 0.09499700799999236 / ACTION 1 / REWARD 0.1 / Q_MAX  21.878132 / Loss  0.39489030838012695
# fps: 8.437121448327884
# TIMESTEP 5109 / STATE explore / EPSILON 0.09499600899999236 / ACTION 1 / REWARD 0.1 / Q_MAX  18.623133 / Loss  0.4837310314178467
# fps: 9.472380999699634
# TIMESTEP 5110 / STATE explore / EPSILON 0.09499500999999236 / ACTION 1 / REWARD 0.1 / Q_MAX  17.978592 / Loss  0.4385390281677246
# fps: 4.684284883052136
# TIMESTEP 5111 / STATE explore / EPSILON 0.09499401099999236 / ACTION 1 / REWARD 0.1 / Q_MAX  18.192963 / Loss  0.11695893853902817
# fps: 4.062862279532562
# TIMESTEP 5112 / STATE explore / EPSILON 0.09499301199999236 / ACTION 1 / REWARD -1 / Q_MAX  16.224716 / Loss  0.7925278544425964
# fps: 4.943472413910965
# TIMESTEP 5113 / STATE explore / EPSILON 0.09499201299999235 / ACTION 1 / REWARD 0.1 / Q_MAX  16.196875 / Loss  1.5462827682495117
# fps: 4.407360199399155
# TIMESTEP 5114 / STATE explore / EPSILON 0.09499101399999235 / ACTION 1 / REWARD 0.1 / Q_MAX  20.90806 / Loss  0.688631534576416
# fps: 8.15569758827407
# TIMESTEP 5115 / STATE explore / EPSILON 0.09499001499999235 / ACTION 1 / REWARD 0.1 / Q_MAX  25.221712 / Loss  0.3341757655143738
# fps: 8.336239741941126
# TIMESTEP 5116 / STATE explore / EPSILON 0.09498901599999235 / ACTION 1 / REWARD 0.1 / Q_MAX  18.500778 / Loss  0.41629427671432495
# fps: 8.0684207893937
# TIMESTEP 5117 / STATE explore / EPSILON 0.09498801699999235 / ACTION 1 / REWARD 0.1 / Q_MAX  18.371809 / Loss  0.4123309850692749
# fps: 9.135429349305745
# TIMESTEP 5118 / STATE explore / EPSILON 0.09498701799999235 / ACTION 0 / REWARD 0.1 / Q_MAX  21.357811 / Loss  0.5609394311904907
# fps: 8.94949046651759
# TIMESTEP 5119 / STATE explore / EPSILON 0.09498601899999234 / ACTION 1 / REWARD 0.1 / Q_MAX  19.054827 / Loss  0.35167521238327026
# fps: 9.954914200270572
# TIMESTEP 5120 / STATE explore / EPSILON 0.09498501999999234 / ACTION 0 / REWARD 0.1 / Q_MAX  23.35865 / Loss  0.4750518798828125
# fps: 9.7584845432062
# TIMESTEP 5121 / STATE explore / EPSILON 0.09498402099999234 / ACTION 0 / REWARD 0.1 / Q_MAX  16.784496 / Loss  0.6132526993751526
# fps: 10.101425994475205
# TIMESTEP 5122 / STATE explore / EPSILON 0.09498302199999234 / ACTION 0 / REWARD 0.1 / Q_MAX  18.110928 / Loss  0.673662543296814
# fps: 9.755170865923802
# TIMESTEP 5123 / STATE explore / EPSILON 0.09498202299999234 / ACTION 0 / REWARD 0.1 / Q_MAX  21.883392 / Loss  0.9768471121788025
# ----------Random Action----------
# fps: 8.083488637874778
# TIMESTEP 5124 / STATE explore / EPSILON 0.09498102399999234 / ACTION 1 / REWARD 0.1 / Q_MAX  21.972237 / Loss  2.923067808151245
# fps: 9.784185013599824
# TIMESTEP 5125 / STATE explore / EPSILON 0.09498002499999234 / ACTION 0 / REWARD 0.1 / Q_MAX  21.20816 / Loss  0.6628084182739258
# fps: 9.983633169728504
# TIMESTEP 5126 / STATE explore / EPSILON 0.09497902599999233 / ACTION 0 / REWARD 0.1 / Q_MAX  15.151564 / Loss  0.3648131787776947
# ----------Random Action----------
# fps: 9.70771121536642
# TIMESTEP 5127 / STATE explore / EPSILON 0.09497802699999233 / ACTION 0 / REWARD 0.1 / Q_MAX  16.726545 / Loss  0.8732390999794006
# fps: 11.058799334516298
# TIMESTEP 5128 / STATE explore / EPSILON 0.09497702799999233 / ACTION 0 / REWARD 0.1 / Q_MAX  20.150263 / Loss  0.44932571053504944
# fps: 10.040970125850153
# TIMESTEP 5129 / STATE explore / EPSILON 0.09497602899999233 / ACTION 0 / REWARD 0.1 / Q_MAX  26.205067 / Loss  2.579596519470215
# fps: 8.510633462586567
# TIMESTEP 5130 / STATE explore / EPSILON 0.09497502999999233 / ACTION 1 / REWARD 0.1 / Q_MAX  26.147942 / Loss  0.22471684217453003
# ----------Random Action----------
# fps: 8.913771778077196
# TIMESTEP 5131 / STATE explore / EPSILON 0.09497403099999233 / ACTION 1 / REWARD 0.1 / Q_MAX  21.703346 / Loss  0.14819052815437317
# fps: 8.699222436310917
# TIMESTEP 5132 / STATE explore / EPSILON 0.09497303199999232 / ACTION 1 / REWARD 0.1 / Q_MAX  19.0188 / Loss  0.4662591218948364
# fps: 9.57636448736829
# TIMESTEP 5133 / STATE explore / EPSILON 0.09497203299999232 / ACTION 1 / REWARD 0.1 / Q_MAX  17.478157 / Loss  1.1546530723571777
# fps: 8.181517430791798
# TIMESTEP 5134 / STATE explore / EPSILON 0.09497103399999232 / ACTION 1 / REWARD 0.1 / Q_MAX  17.323473 / Loss  0.6980956196784973
# fps: 8.513034512433732
# TIMESTEP 5135 / STATE explore / EPSILON 0.09497003499999232 / ACTION 1 / REWARD 0.1 / Q_MAX  16.659016 / Loss  0.8821465969085693
# ----------Random Action----------
# fps: 8.663840897636105
# TIMESTEP 5136 / STATE explore / EPSILON 0.09496903599999232 / ACTION 0 / REWARD 0.1 / Q_MAX  17.180355 / Loss  0.8466298580169678
# fps: 10.427548212105918
# TIMESTEP 5137 / STATE explore / EPSILON 0.09496803699999232 / ACTION 0 / REWARD 0.1 / Q_MAX  15.444831 / Loss  0.4031514823436737
# fps: 8.38932948233548
# TIMESTEP 5138 / STATE explore / EPSILON 0.09496703799999232 / ACTION 1 / REWARD 0.1 / Q_MAX  16.903658 / Loss  0.6588698029518127
# fps: 7.8866391889046
# TIMESTEP 5139 / STATE explore / EPSILON 0.09496603899999231 / ACTION 0 / REWARD 0.1 / Q_MAX  16.834291 / Loss  0.4564284086227417
# fps: 7.073335424487414
# TIMESTEP 5140 / STATE explore / EPSILON 0.09496503999999231 / ACTION 1 / REWARD 0.1 / Q_MAX  16.654596 / Loss  0.5552498698234558
# fps: 7.991677368463171
# TIMESTEP 5141 / STATE explore / EPSILON 0.09496404099999231 / ACTION 0 / REWARD 0.1 / Q_MAX  20.351604 / Loss  11.49747371673584
# fps: 11.311682497559291
# TIMESTEP 5142 / STATE explore / EPSILON 0.09496304199999231 / ACTION 0 / REWARD 0.1 / Q_MAX  5.7567835 / Loss  0.7788904905319214
# fps: 8.448865307372179
# TIMESTEP 5143 / STATE explore / EPSILON 0.09496204299999231 / ACTION 1 / REWARD 0.1 / Q_MAX  13.736828 / Loss  0.8103934526443481
# fps: 9.882786489320342
# TIMESTEP 5144 / STATE explore / EPSILON 0.0949610439999923 / ACTION 0 / REWARD 0.1 / Q_MAX  17.91238 / Loss  0.6696776747703552
# ----------Random Action----------
# fps: 9.29117092610355
# TIMESTEP 5145 / STATE explore / EPSILON 0.0949600449999923 / ACTION 0 / REWARD 0.1 / Q_MAX  25.70277 / Loss  1.0725113153457642
# fps: 10.672339169531332
# TIMESTEP 5146 / STATE explore / EPSILON 0.0949590459999923 / ACTION 0 / REWARD 0.1 / Q_MAX  20.391596 / Loss  1.1187629699707031
# fps: 9.676133702756138
# TIMESTEP 5147 / STATE explore / EPSILON 0.0949580469999923 / ACTION 0 / REWARD 0.1 / Q_MAX  16.331272 / Loss  0.8832508325576782
# fps: 8.895698391085434
# TIMESTEP 5148 / STATE explore / EPSILON 0.0949570479999923 / ACTION 1 / REWARD 0.1 / Q_MAX  17.365402 / Loss  1.2427265644073486
# fps: 8.523033280906457
# TIMESTEP 5149 / STATE explore / EPSILON 0.0949560489999923 / ACTION 1 / REWARD 0.1 / Q_MAX  18.681099 / Loss  0.5356200933456421
# fps: 8.645286557904175
# TIMESTEP 5150 / STATE explore / EPSILON 0.0949550499999923 / ACTION 1 / REWARD 0.1 / Q_MAX  19.841476 / Loss  0.7811582684516907
# fps: 9.232840466583458
# TIMESTEP 5151 / STATE explore / EPSILON 0.0949540509999923 / ACTION 1 / REWARD 0.1 / Q_MAX  22.54708 / Loss  3.849625587463379
# fps: 10.738132970130492
# TIMESTEP 5152 / STATE explore / EPSILON 0.0949530519999923 / ACTION 0 / REWARD 0.1 / Q_MAX  19.656683 / Loss  0.4573804438114166
# fps: 9.945896725727511
# TIMESTEP 5153 / STATE explore / EPSILON 0.09495205299999229 / ACTION 0 / REWARD -1 / Q_MAX  17.671215 / Loss  0.8163896203041077
# fps: 9.748391655200624
# TIMESTEP 5154 / STATE explore / EPSILON 0.09495105399999229 / ACTION 0 / REWARD 0.1 / Q_MAX  18.794859 / Loss  2.576277017593384
# ----------Random Action----------
# fps: 9.148301230808826
# TIMESTEP 5155 / STATE explore / EPSILON 0.09495005499999229 / ACTION 1 / REWARD 0.1 / Q_MAX  17.612362 / Loss  0.32140618562698364
# fps: 8.144327054332356
# TIMESTEP 5156 / STATE explore / EPSILON 0.09494905599999229 / ACTION 1 / REWARD 0.1 / Q_MAX  9.906782 / Loss  0.7240327596664429
# fps: 10.703195414852733
# TIMESTEP 5157 / STATE explore / EPSILON 0.09494805699999229 / ACTION 0 / REWARD 0.1 / Q_MAX  20.429865 / Loss  1.384271502494812
# fps: 9.857168372862555
# TIMESTEP 5158 / STATE explore / EPSILON 0.09494705799999228 / ACTION 0 / REWARD 0.1 / Q_MAX  18.750427 / Loss  0.966515064239502
# fps: 10.824736627489845
# TIMESTEP 5159 / STATE explore / EPSILON 0.09494605899999228 / ACTION 0 / REWARD 0.1 / Q_MAX  21.97473 / Loss  1.2914879322052002
# fps: 10.160226347815977
# TIMESTEP 5160 / STATE explore / EPSILON 0.09494505999999228 / ACTION 0 / REWARD 0.1 / Q_MAX  19.538849 / Loss  22.153949737548828
# fps: 8.568827581698278
# TIMESTEP 5161 / STATE explore / EPSILON 0.09494406099999228 / ACTION 1 / REWARD 0.1 / Q_MAX  22.260763 / Loss  0.6382980346679688
# fps: 10.111117807439836
# TIMESTEP 5162 / STATE explore / EPSILON 0.09494306199999228 / ACTION 0 / REWARD 0.1 / Q_MAX  17.406122 / Loss  0.5955944657325745
# ----------Random Action----------
# fps: 9.352703368646855
# TIMESTEP 5163 / STATE explore / EPSILON 0.09494206299999228 / ACTION 1 / REWARD 0.1 / Q_MAX  20.229904 / Loss  0.9266664981842041
# fps: 10.480964958531471
# TIMESTEP 5164 / STATE explore / EPSILON 0.09494106399999228 / ACTION 0 / REWARD 0.1 / Q_MAX  10.207932 / Loss  1.9962358474731445
# fps: 9.142697706861975
# TIMESTEP 5165 / STATE explore / EPSILON 0.09494006499999227 / ACTION 1 / REWARD 0.1 / Q_MAX  21.923418 / Loss  0.6858478784561157
# fps: 8.698987887838062
# TIMESTEP 5166 / STATE explore / EPSILON 0.09493906599999227 / ACTION 1 / REWARD 0.1 / Q_MAX  19.736118 / Loss  0.4037139415740967
# fps: 9.352161164810417
# TIMESTEP 5167 / STATE explore / EPSILON 0.09493806699999227 / ACTION 0 / REWARD 0.1 / Q_MAX  15.288759 / Loss  0.8905593752861023
# fps: 10.49129415766817
# TIMESTEP 5168 / STATE explore / EPSILON 0.09493706799999227 / ACTION 0 / REWARD 0.1 / Q_MAX  16.91463 / Loss  0.791900098323822
# fps: 10.688112693571034
# TIMESTEP 5169 / STATE explore / EPSILON 0.09493606899999227 / ACTION 0 / REWARD 0.1 / Q_MAX  21.520266 / Loss  0.4258657395839691
# fps: 10.317481870689061
# TIMESTEP 5170 / STATE explore / EPSILON 0.09493506999999227 / ACTION 0 / REWARD 0.1 / Q_MAX  21.465406 / Loss  4.347949981689453
# fps: 10.842673711911859
# TIMESTEP 5171 / STATE explore / EPSILON 0.09493407099999226 / ACTION 0 / REWARD 0.1 / Q_MAX  19.373287 / Loss  0.9059151411056519
# fps: 9.570835938462661
# TIMESTEP 5172 / STATE explore / EPSILON 0.09493307199999226 / ACTION 0 / REWARD 0.1 / Q_MAX  14.712446 / Loss  3.200713634490967
# ----------Random Action----------
# fps: 10.670302888455844
# TIMESTEP 5173 / STATE explore / EPSILON 0.09493207299999226 / ACTION 0 / REWARD 0.1 / Q_MAX  20.878796 / Loss  14.541285514831543
# fps: 7.610053832601836
# TIMESTEP 5174 / STATE explore / EPSILON 0.09493107399999226 / ACTION 1 / REWARD 0.1 / Q_MAX  16.432316 / Loss  0.6063990592956543
# fps: 8.185317455670956
# TIMESTEP 5175 / STATE explore / EPSILON 0.09493007499999226 / ACTION 1 / REWARD 0.1 / Q_MAX  20.026447 / Loss  0.38368505239486694
# fps: 9.92349478545606
# TIMESTEP 5176 / STATE explore / EPSILON 0.09492907599999226 / ACTION 0 / REWARD 0.1 / Q_MAX  13.414268 / Loss  0.9336609244346619
# fps: 10.728354925758719
# TIMESTEP 5177 / STATE explore / EPSILON 0.09492807699999226 / ACTION 0 / REWARD 0.1 / Q_MAX  18.590265 / Loss  0.8141707181930542
# fps: 10.965500653594772
# TIMESTEP 5178 / STATE explore / EPSILON 0.09492707799999225 / ACTION 0 / REWARD 0.1 / Q_MAX  6.1620545 / Loss  1.693208932876587
# fps: 8.807621799488885
# TIMESTEP 5179 / STATE explore / EPSILON 0.09492607899999225 / ACTION 1 / REWARD 0.1 / Q_MAX  18.71026 / Loss  2.2951548099517822
# fps: 8.892133978676538
# TIMESTEP 5180 / STATE explore / EPSILON 0.09492507999999225 / ACTION 1 / REWARD 0.1 / Q_MAX  18.430075 / Loss  0.6652354598045349
# fps: 9.339063133191127
# TIMESTEP 5181 / STATE explore / EPSILON 0.09492408099999225 / ACTION 0 / REWARD 0.1 / Q_MAX  19.202272 / Loss  1.7011826038360596
# fps: 9.083141317717988
# TIMESTEP 5182 / STATE explore / EPSILON 0.09492308199999225 / ACTION 1 / REWARD 0.1 / Q_MAX  11.649595 / Loss  2.211177349090576
# fps: 9.966528767533427
# TIMESTEP 5183 / STATE explore / EPSILON 0.09492208299999225 / ACTION 0 / REWARD 0.1 / Q_MAX  14.611574 / Loss  1.6835029125213623
# fps: 10.107852658722031
# TIMESTEP 5184 / STATE explore / EPSILON 0.09492108399999225 / ACTION 0 / REWARD 0.1 / Q_MAX  17.152431 / Loss  0.6391170024871826
# fps: 9.618242607973803
# TIMESTEP 5185 / STATE explore / EPSILON 0.09492008499999224 / ACTION 0 / REWARD 0.1 / Q_MAX  15.64412 / Loss  2.770935297012329
# fps: 8.379156311680424
# TIMESTEP 5186 / STATE explore / EPSILON 0.09491908599999224 / ACTION 1 / REWARD 0.1 / Q_MAX  12.542109 / Loss  1.548316240310669
# fps: 9.368140802287144
# TIMESTEP 5187 / STATE explore / EPSILON 0.09491808699999224 / ACTION 0 / REWARD 0.1 / Q_MAX  12.5588 / Loss  0.6145998239517212
# fps: 11.015263727374911
# TIMESTEP 5188 / STATE explore / EPSILON 0.09491708799999224 / ACTION 0 / REWARD 0.1 / Q_MAX  17.564035 / Loss  0.3647328317165375
# fps: 9.559231488023338
# TIMESTEP 5189 / STATE explore / EPSILON 0.09491608899999224 / ACTION 0 / REWARD 0.1 / Q_MAX  12.056697 / Loss  1.3688675165176392
# fps: 10.0981427890426
# TIMESTEP 5190 / STATE explore / EPSILON 0.09491508999999224 / ACTION 0 / REWARD 0.1 / Q_MAX  14.95688 / Loss  1.3953214883804321
# fps: 9.37947443864761
# TIMESTEP 5191 / STATE explore / EPSILON 0.09491409099999223 / ACTION 0 / REWARD 0.1 / Q_MAX  11.625681 / Loss  0.8679467439651489
# fps: 9.475954869347937
# TIMESTEP 5192 / STATE explore / EPSILON 0.09491309199999223 / ACTION 0 / REWARD 0.1 / Q_MAX  11.976369 / Loss  0.9314018487930298
# fps: 9.818747907756343
# TIMESTEP 5193 / STATE explore / EPSILON 0.09491209299999223 / ACTION 0 / REWARD 0.1 / Q_MAX  16.833006 / Loss  0.8203049302101135
# fps: 9.931483884411021
# TIMESTEP 5194 / STATE explore / EPSILON 0.09491109399999223 / ACTION 0 / REWARD 0.1 / Q_MAX  16.131706 / Loss  0.898774266242981
# fps: 8.982533087762882
# TIMESTEP 5195 / STATE explore / EPSILON 0.09491009499999223 / ACTION 1 / REWARD 0.1 / Q_MAX  10.095372 / Loss  0.6167720556259155
# ----------Random Action----------
# fps: 10.610888907440998
# TIMESTEP 5196 / STATE explore / EPSILON 0.09490909599999223 / ACTION 0 / REWARD 0.1 / Q_MAX  11.281296 / Loss  0.5637237429618835
# ----------Random Action----------
# fps: 8.292071701254
# TIMESTEP 5197 / STATE explore / EPSILON 0.09490809699999223 / ACTION 1 / REWARD 0.1 / Q_MAX  9.630863 / Loss  0.38803642988204956
# fps: 9.33617360373776
# TIMESTEP 5198 / STATE explore / EPSILON 0.09490709799999222 / ACTION 0 / REWARD 0.1 / Q_MAX  11.668717 / Loss  0.7251461744308472
# fps: 10.035492538527611
# TIMESTEP 5199 / STATE explore / EPSILON 0.09490609899999222 / ACTION 0 / REWARD 0.1 / Q_MAX  12.23874 / Loss  0.5919032096862793
# fps: 9.592396164234437
# TIMESTEP 5200 / STATE explore / EPSILON 0.09490509999999222 / ACTION 0 / REWARD -1 / Q_MAX  16.358046 / Loss  0.6970752477645874
# fps: 10.848675310835732
# TIMESTEP 5201 / STATE explore / EPSILON 0.09490410099999222 / ACTION 0 / REWARD 0.1 / Q_MAX  9.373672 / Loss  2.7990572452545166
# fps: 9.342911685366728
# TIMESTEP 5202 / STATE explore / EPSILON 0.09490310199999222 / ACTION 0 / REWARD 0.1 / Q_MAX  5.634753 / Loss  0.3141263723373413
# ----------Random Action----------
# fps: 8.605995444939163
# TIMESTEP 5203 / STATE explore / EPSILON 0.09490210299999222 / ACTION 1 / REWARD 0.1 / Q_MAX  11.257303 / Loss  1.8289700746536255
# fps: 10.410052890354894
# TIMESTEP 5204 / STATE explore / EPSILON 0.09490110399999221 / ACTION 0 / REWARD 0.1 / Q_MAX  12.250091 / Loss  0.6166566610336304
# fps: 9.790854128247625
# TIMESTEP 5205 / STATE explore / EPSILON 0.09490010499999221 / ACTION 0 / REWARD 0.1 / Q_MAX  11.744965 / Loss  0.4674779772758484
# fps: 10.024579232412847
# TIMESTEP 5206 / STATE explore / EPSILON 0.09489910599999221 / ACTION 0 / REWARD 0.1 / Q_MAX  10.547326 / Loss  0.3579097390174866
# fps: 9.338189849406442
# TIMESTEP 5207 / STATE explore / EPSILON 0.09489810699999221 / ACTION 0 / REWARD 0.1 / Q_MAX  10.998437 / Loss  1.3627249002456665
# fps: 9.033432477078842
# TIMESTEP 5208 / STATE explore / EPSILON 0.09489710799999221 / ACTION 1 / REWARD 0.1 / Q_MAX  16.384426 / Loss  0.47252506017684937
# fps: 8.12888996559911
# TIMESTEP 5209 / STATE explore / EPSILON 0.09489610899999221 / ACTION 1 / REWARD 0.1 / Q_MAX  9.793615 / Loss  3.0306544303894043
# fps: 9.596280738361292
# TIMESTEP 5210 / STATE explore / EPSILON 0.0948951099999922 / ACTION 0 / REWARD 0.1 / Q_MAX  16.417374 / Loss  1.1645209789276123
# fps: 10.624166326822683
# TIMESTEP 5211 / STATE explore / EPSILON 0.0948941109999922 / ACTION 0 / REWARD 0.1 / Q_MAX  17.425222 / Loss  0.236151784658432
# fps: 8.8287010920358
# TIMESTEP 5212 / STATE explore / EPSILON 0.0948931119999922 / ACTION 1 / REWARD 0.1 / Q_MAX  12.303705 / Loss  0.479790598154068
# fps: 10.139741327208993
# TIMESTEP 5213 / STATE explore / EPSILON 0.0948921129999922 / ACTION 0 / REWARD 0.1 / Q_MAX  12.397442 / Loss  0.6266810894012451
# fps: 8.50404186426554
# TIMESTEP 5214 / STATE explore / EPSILON 0.0948911139999922 / ACTION 1 / REWARD 0.1 / Q_MAX  11.361159 / Loss  7.890805244445801
# fps: 9.142458563295058
# TIMESTEP 5215 / STATE explore / EPSILON 0.0948901149999922 / ACTION 0 / REWARD 0.1 / Q_MAX  13.079729 / Loss  0.5524846315383911
# fps: 9.323845663081004
# TIMESTEP 5216 / STATE explore / EPSILON 0.0948891159999922 / ACTION 1 / REWARD 0.1 / Q_MAX  15.908724 / Loss  0.24694836139678955
# ----------Random Action----------
# fps: 9.34089340038216
# TIMESTEP 5217 / STATE explore / EPSILON 0.0948881169999922 / ACTION 0 / REWARD 0.1 / Q_MAX  10.858404 / Loss  0.616966187953949
# fps: 10.928614792947203
# TIMESTEP 5218 / STATE explore / EPSILON 0.0948871179999922 / ACTION 0 / REWARD 0.1 / Q_MAX  13.496531 / Loss  0.4327746629714966
# fps: 9.788751919567217
# TIMESTEP 5219 / STATE explore / EPSILON 0.09488611899999219 / ACTION 0 / REWARD 0.1 / Q_MAX  12.777684 / Loss  0.4202527403831482
# ----------Random Action----------
# fps: 9.212925276159055
# TIMESTEP 5220 / STATE explore / EPSILON 0.09488511999999219 / ACTION 1 / REWARD 0.1 / Q_MAX  13.506532 / Loss  1.9939930438995361
# fps: 10.458854596550374
# TIMESTEP 5221 / STATE explore / EPSILON 0.09488412099999219 / ACTION 0 / REWARD 0.1 / Q_MAX  13.740938 / Loss  0.2829264998435974
# fps: 8.868837830865717
# TIMESTEP 5222 / STATE explore / EPSILON 0.09488312199999219 / ACTION 1 / REWARD 0.1 / Q_MAX  11.865364 / Loss  0.9370050430297852
# fps: 8.596100678169659
# TIMESTEP 5223 / STATE explore / EPSILON 0.09488212299999219 / ACTION 1 / REWARD 0.1 / Q_MAX  13.386377 / Loss  1.4982892274856567
# fps: 8.36715461556569
# TIMESTEP 5224 / STATE explore / EPSILON 0.09488112399999218 / ACTION 1 / REWARD 0.1 / Q_MAX  19.522387 / Loss  0.8000361919403076
# fps: 9.206999798048978
# TIMESTEP 5225 / STATE explore / EPSILON 0.09488012499999218 / ACTION 0 / REWARD 0.1 / Q_MAX  13.945492 / Loss  3.676027774810791
# fps: 9.704970833979282
# TIMESTEP 5226 / STATE explore / EPSILON 0.09487912599999218 / ACTION 0 / REWARD 0.1 / Q_MAX  15.029475 / Loss  1.7500057220458984
# fps: 8.641759708912895
# TIMESTEP 5227 / STATE explore / EPSILON 0.09487812699999218 / ACTION 1 / REWARD 0.1 / Q_MAX  17.877296 / Loss  0.6331561803817749
# fps: 7.57123284456631
# TIMESTEP 5228 / STATE explore / EPSILON 0.09487712799999218 / ACTION 1 / REWARD 0.1 / Q_MAX  14.965208 / Loss  0.4480603039264679
# fps: 8.563631500609455
# TIMESTEP 5229 / STATE explore / EPSILON 0.09487612899999218 / ACTION 1 / REWARD 0.1 / Q_MAX  13.513569 / Loss  0.404633104801178
# fps: 8.915514932511424
# TIMESTEP 5230 / STATE explore / EPSILON 0.09487512999999217 / ACTION 1 / REWARD 0.1 / Q_MAX  17.679657 / Loss  0.8716093897819519
# fps: 9.214888634036813
# TIMESTEP 5231 / STATE explore / EPSILON 0.09487413099999217 / ACTION 1 / REWARD 0.1 / Q_MAX  14.923305 / Loss  0.32737672328948975
# fps: 9.342474663102795
# TIMESTEP 5232 / STATE explore / EPSILON 0.09487313199999217 / ACTION 1 / REWARD 0.1 / Q_MAX  15.224078 / Loss  1.364579200744629
# fps: 9.84328855595295
# TIMESTEP 5233 / STATE explore / EPSILON 0.09487213299999217 / ACTION 1 / REWARD 0.1 / Q_MAX  13.774319 / Loss  0.28469932079315186
# ----------Random Action----------
# fps: 9.249067221776292
# TIMESTEP 5234 / STATE explore / EPSILON 0.09487113399999217 / ACTION 1 / REWARD 0.1 / Q_MAX  14.274138 / Loss  1.1716604232788086
# fps: 11.579981391650538
# TIMESTEP 5235 / STATE explore / EPSILON 0.09487013499999217 / ACTION 0 / REWARD 0.1 / Q_MAX  14.99476 / Loss  2.578390598297119
# fps: 11.219066215511361
# TIMESTEP 5236 / STATE explore / EPSILON 0.09486913599999217 / ACTION 0 / REWARD 0.1 / Q_MAX  13.1637745 / Loss  0.5661087036132812
# fps: 11.1327686839919
# TIMESTEP 5237 / STATE explore / EPSILON 0.09486813699999216 / ACTION 0 / REWARD 0.1 / Q_MAX  5.9436755 / Loss  1.3886440992355347
# fps: 11.445586919029843
# TIMESTEP 5238 / STATE explore / EPSILON 0.09486713799999216 / ACTION 0 / REWARD 0.1 / Q_MAX  17.652126 / Loss  1.240356206893921
# fps: 11.224981132479433
# TIMESTEP 5239 / STATE explore / EPSILON 0.09486613899999216 / ACTION 0 / REWARD 0.1 / Q_MAX  21.910427 / Loss  1.2529951333999634
# fps: 10.908491309470246
# TIMESTEP 5240 / STATE explore / EPSILON 0.09486513999999216 / ACTION 0 / REWARD 0.1 / Q_MAX  14.875399 / Loss  3.6049091815948486
# fps: 11.336201863824083
# TIMESTEP 5241 / STATE explore / EPSILON 0.09486414099999216 / ACTION 0 / REWARD 0.1 / Q_MAX  16.635595 / Loss  0.6998422145843506
# fps: 11.515694968769305
# TIMESTEP 5242 / STATE explore / EPSILON 0.09486314199999216 / ACTION 0 / REWARD 0.1 / Q_MAX  13.884613 / Loss  16.65589141845703
# fps: 10.947412380067444
# TIMESTEP 5243 / STATE explore / EPSILON 0.09486214299999216 / ACTION 0 / REWARD 0.1 / Q_MAX  15.447845 / Loss  3.610389232635498
# fps: 11.418913621117742
# TIMESTEP 5244 / STATE explore / EPSILON 0.09486114399999215 / ACTION 0 / REWARD 0.1 / Q_MAX  15.572885 / Loss  0.4449924826622009
# fps: 9.806695378514746
# TIMESTEP 5245 / STATE explore / EPSILON 0.09486014499999215 / ACTION 1 / REWARD 0.1 / Q_MAX  13.860699 / Loss  0.3844033479690552
# fps: 9.49880990395438
# TIMESTEP 5246 / STATE explore / EPSILON 0.09485914599999215 / ACTION 1 / REWARD 0.1 / Q_MAX  11.255422 / Loss  0.76591956615448
# fps: 9.336817876239365
# TIMESTEP 5247 / STATE explore / EPSILON 0.09485814699999215 / ACTION 1 / REWARD 0.1 / Q_MAX  14.776945 / Loss  1.1058621406555176
# fps: 8.990388655011875
# TIMESTEP 5248 / STATE explore / EPSILON 0.09485714799999215 / ACTION 1 / REWARD 0.1 / Q_MAX  14.44906 / Loss  0.38182350993156433
# fps: 9.555006788711603
# TIMESTEP 5249 / STATE explore / EPSILON 0.09485614899999215 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9015713 / Loss  1.2882009744644165
# fps: 9.839986299152377
# TIMESTEP 5250 / STATE explore / EPSILON 0.09485514999999214 / ACTION 1 / REWARD 0.1 / Q_MAX  13.973838 / Loss  0.3797924220561981
# ----------Random Action----------
# fps: 11.362212680653943
# TIMESTEP 5251 / STATE explore / EPSILON 0.09485415099999214 / ACTION 0 / REWARD 0.1 / Q_MAX  9.186794 / Loss  0.7922645211219788
# fps: 9.462166485062186
# TIMESTEP 5252 / STATE explore / EPSILON 0.09485315199999214 / ACTION 1 / REWARD 0.1 / Q_MAX  9.967261 / Loss  0.6876381635665894
# fps: 9.046018336593603
# TIMESTEP 5253 / STATE explore / EPSILON 0.09485215299999214 / ACTION 1 / REWARD 0.1 / Q_MAX  8.639913 / Loss  0.7768693566322327
# fps: 9.692725436591662
# TIMESTEP 5254 / STATE explore / EPSILON 0.09485115399999214 / ACTION 1 / REWARD 0.1 / Q_MAX  6.4536004 / Loss  1.1014115810394287
# fps: 9.739359812378819
# TIMESTEP 5255 / STATE explore / EPSILON 0.09485015499999214 / ACTION 1 / REWARD 0.1 / Q_MAX  8.6192 / Loss  0.7757482528686523
# fps: 9.465134542303423
# TIMESTEP 5256 / STATE explore / EPSILON 0.09484915599999214 / ACTION 1 / REWARD 0.1 / Q_MAX  11.450582 / Loss  1.0300740003585815
# fps: 9.774312247299674
# TIMESTEP 5257 / STATE explore / EPSILON 0.09484815699999213 / ACTION 1 / REWARD 0.1 / Q_MAX  13.062905 / Loss  0.6092571020126343
# fps: 9.720332423325253
# TIMESTEP 5258 / STATE explore / EPSILON 0.09484715799999213 / ACTION 1 / REWARD 0.1 / Q_MAX  16.902231 / Loss  0.3572646379470825
# fps: 11.534284095721569
# TIMESTEP 5259 / STATE explore / EPSILON 0.09484615899999213 / ACTION 0 / REWARD 0.1 / Q_MAX  9.761981 / Loss  2.2900912761688232
# fps: 11.16480333908303
# TIMESTEP 5260 / STATE explore / EPSILON 0.09484515999999213 / ACTION 0 / REWARD 0.1 / Q_MAX  4.9160843 / Loss  2.5371346473693848
# ----------Random Action----------
# fps: 11.385251820042454
# TIMESTEP 5261 / STATE explore / EPSILON 0.09484416099999213 / ACTION 0 / REWARD 0.1 / Q_MAX  9.620247 / Loss  0.4027344584465027
# fps: 11.38074151254667
# TIMESTEP 5262 / STATE explore / EPSILON 0.09484316199999213 / ACTION 0 / REWARD 0.1 / Q_MAX  10.799333 / Loss  0.8577355146408081
# fps: 11.26758989375277
# TIMESTEP 5263 / STATE explore / EPSILON 0.09484216299999212 / ACTION 0 / REWARD 0.1 / Q_MAX  10.348107 / Loss  0.776824414730072
# fps: 3.9623855724448056
# TIMESTEP 5264 / STATE explore / EPSILON 0.09484116399999212 / ACTION 0 / REWARD 0.1 / Q_MAX  8.511005 / Loss  0.9682493209838867
# fps: 6.730507174515147
# TIMESTEP 5265 / STATE explore / EPSILON 0.09484016499999212 / ACTION 0 / REWARD 0.1 / Q_MAX  5.7752066 / Loss  1.2552167177200317
# fps: 7.7642677052827995
# TIMESTEP 5266 / STATE explore / EPSILON 0.09483916599999212 / ACTION 0 / REWARD 0.1 / Q_MAX  13.568489 / Loss  0.7244219779968262
# fps: 6.794067527553341
# TIMESTEP 5267 / STATE explore / EPSILON 0.09483816699999212 / ACTION 0 / REWARD 0.1 / Q_MAX  12.348215 / Loss  0.8299702405929565
# fps: 9.37603583827175
# TIMESTEP 5268 / STATE explore / EPSILON 0.09483716799999212 / ACTION 0 / REWARD 0.1 / Q_MAX  13.737203 / Loss  0.5693252086639404
# fps: 10.574639847921782
# TIMESTEP 5269 / STATE explore / EPSILON 0.09483616899999212 / ACTION 0 / REWARD 0.1 / Q_MAX  11.097618 / Loss  0.4791666567325592
# ----------Random Action----------
# fps: 8.442946805641107
# TIMESTEP 5270 / STATE explore / EPSILON 0.09483516999999211 / ACTION 1 / REWARD 0.1 / Q_MAX  10.943458 / Loss  0.2727753818035126
# fps: 8.855187847695053
# TIMESTEP 5271 / STATE explore / EPSILON 0.09483417099999211 / ACTION 1 / REWARD 0.1 / Q_MAX  10.752157 / Loss  0.2034195065498352
# fps: 10.658724451029075
# TIMESTEP 5272 / STATE explore / EPSILON 0.09483317199999211 / ACTION 0 / REWARD 0.1 / Q_MAX  14.240758 / Loss  0.5321723818778992
# ----------Random Action----------
# fps: 9.163130793446893
# TIMESTEP 5273 / STATE explore / EPSILON 0.09483217299999211 / ACTION 1 / REWARD 0.1 / Q_MAX  9.46063 / Loss  0.735740065574646
# fps: 11.104208915551649
# TIMESTEP 5274 / STATE explore / EPSILON 0.09483117399999211 / ACTION 0 / REWARD 0.1 / Q_MAX  12.322068 / Loss  0.6488590240478516
# fps: 7.998520171248224
# TIMESTEP 5275 / STATE explore / EPSILON 0.0948301749999921 / ACTION 1 / REWARD 0.1 / Q_MAX  11.276707 / Loss  0.36793768405914307
# fps: 8.085389714911393
# TIMESTEP 5276 / STATE explore / EPSILON 0.0948291759999921 / ACTION 1 / REWARD 0.1 / Q_MAX  6.131629 / Loss  2.7559661865234375
# fps: 10.04488978723812
# TIMESTEP 5277 / STATE explore / EPSILON 0.0948281769999921 / ACTION 0 / REWARD 0.1 / Q_MAX  9.313911 / Loss  0.48765912652015686
# fps: 9.863682221495813
# TIMESTEP 5278 / STATE explore / EPSILON 0.0948271779999921 / ACTION 0 / REWARD 0.1 / Q_MAX  15.305933 / Loss  0.3697439432144165
# fps: 9.648044422872996
# TIMESTEP 5279 / STATE explore / EPSILON 0.0948261789999921 / ACTION 0 / REWARD 0.1 / Q_MAX  9.663422 / Loss  0.8675777912139893
# fps: 8.812210981899929
# TIMESTEP 5280 / STATE explore / EPSILON 0.0948251799999921 / ACTION 1 / REWARD 0.1 / Q_MAX  11.243356 / Loss  0.49955105781555176
# fps: 9.375134671178802
# TIMESTEP 5281 / STATE explore / EPSILON 0.0948241809999921 / ACTION 0 / REWARD -1 / Q_MAX  11.094385 / Loss  0.6102702617645264
# fps: 10.86342704108326
# TIMESTEP 5282 / STATE explore / EPSILON 0.0948231819999921 / ACTION 0 / REWARD 0.1 / Q_MAX  10.092292 / Loss  0.5415328741073608
# fps: 9.160529149294446
# TIMESTEP 5283 / STATE explore / EPSILON 0.0948221829999921 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.619688 / Loss  0.7576042413711548
# fps: 9.662780946764101
# TIMESTEP 5284 / STATE explore / EPSILON 0.09482118399999209 / ACTION 1 / REWARD 0.1 / Q_MAX  11.227815 / Loss  1.1803903579711914
# fps: 9.856010226573112
# TIMESTEP 5285 / STATE explore / EPSILON 0.09482018499999209 / ACTION 0 / REWARD 0.1 / Q_MAX  16.352423 / Loss  2.3590028285980225
# ----------Random Action----------
# fps: 10.352293061702007
# TIMESTEP 5286 / STATE explore / EPSILON 0.09481918599999209 / ACTION 0 / REWARD 0.1 / Q_MAX  4.831842 / Loss  0.7610405087471008
# fps: 10.28668689192404
# TIMESTEP 5287 / STATE explore / EPSILON 0.09481818699999209 / ACTION 0 / REWARD 0.1 / Q_MAX  10.9216795 / Loss  0.14436689019203186
# fps: 10.570935311270562
# TIMESTEP 5288 / STATE explore / EPSILON 0.09481718799999209 / ACTION 0 / REWARD 0.1 / Q_MAX  15.844765 / Loss  0.49126672744750977
# ----------Random Action----------
# fps: 9.225103483466839
# TIMESTEP 5289 / STATE explore / EPSILON 0.09481618899999208 / ACTION 0 / REWARD 0.1 / Q_MAX  15.48394 / Loss  0.4926472306251526
# ----------Random Action----------
# fps: 10.691981595013829
# TIMESTEP 5290 / STATE explore / EPSILON 0.09481518999999208 / ACTION 0 / REWARD 0.1 / Q_MAX  12.21992 / Loss  0.568775475025177
# fps: 10.344556799684309
# TIMESTEP 5291 / STATE explore / EPSILON 0.09481419099999208 / ACTION 0 / REWARD 0.1 / Q_MAX  11.3641615 / Loss  0.244381844997406
# ----------Random Action----------
# fps: 9.285905000166045
# TIMESTEP 5292 / STATE explore / EPSILON 0.09481319199999208 / ACTION 1 / REWARD 0.1 / Q_MAX  11.309693 / Loss  0.4770210385322571
# fps: 9.960280501445014
# TIMESTEP 5293 / STATE explore / EPSILON 0.09481219299999208 / ACTION 0 / REWARD 0.1 / Q_MAX  10.449555 / Loss  0.0997730940580368
# fps: 9.128351335528563
# TIMESTEP 5294 / STATE explore / EPSILON 0.09481119399999208 / ACTION 1 / REWARD 0.1 / Q_MAX  13.191567 / Loss  0.5501502156257629
# fps: 10.71259928996501
# TIMESTEP 5295 / STATE explore / EPSILON 0.09481019499999208 / ACTION 0 / REWARD 0.1 / Q_MAX  6.711629 / Loss  0.6080951690673828
# fps: 11.195468752919446
# TIMESTEP 5296 / STATE explore / EPSILON 0.09480919599999207 / ACTION 0 / REWARD 0.1 / Q_MAX  9.171674 / Loss  0.2998241186141968
# fps: 9.763732017319242
# TIMESTEP 5297 / STATE explore / EPSILON 0.09480819699999207 / ACTION 0 / REWARD 0.1 / Q_MAX  15.248997 / Loss  0.6053906679153442
# fps: 10.794482190652666
# TIMESTEP 5298 / STATE explore / EPSILON 0.09480719799999207 / ACTION 0 / REWARD 0.1 / Q_MAX  3.4337378 / Loss  0.509792685508728
# fps: 9.290306575616153
# TIMESTEP 5299 / STATE explore / EPSILON 0.09480619899999207 / ACTION 0 / REWARD 0.1 / Q_MAX  15.288282 / Loss  1.6140930652618408
# fps: 10.880420035746619
# TIMESTEP 5300 / STATE explore / EPSILON 0.09480519999999207 / ACTION 0 / REWARD 0.1 / Q_MAX  15.296277 / Loss  0.2571999430656433
# fps: 10.40506869229128
# TIMESTEP 5301 / STATE explore / EPSILON 0.09480420099999207 / ACTION 0 / REWARD 0.1 / Q_MAX  13.725256 / Loss  0.27026331424713135
# fps: 10.20782640651657
# TIMESTEP 5302 / STATE explore / EPSILON 0.09480320199999206 / ACTION 0 / REWARD 0.1 / Q_MAX  10.096346 / Loss  1.8642035722732544
# fps: 10.978042888214771
# TIMESTEP 5303 / STATE explore / EPSILON 0.09480220299999206 / ACTION 0 / REWARD 0.1 / Q_MAX  15.352985 / Loss  0.24442589282989502
# fps: 9.270245420468209
# TIMESTEP 5304 / STATE explore / EPSILON 0.09480120399999206 / ACTION 0 / REWARD 0.1 / Q_MAX  12.493366 / Loss  0.6570730209350586
# ----------Random Action----------
# fps: 8.60488313265618
# TIMESTEP 5305 / STATE explore / EPSILON 0.09480020499999206 / ACTION 1 / REWARD 0.1 / Q_MAX  9.836812 / Loss  0.657198429107666
# fps: 10.29431154111413
# ...
# fps: 10.215309676319443
# TIMESTEP 5345 / STATE explore / EPSILON 0.094760244999992 / ACTION 0 / REWARD 0.1 / Q_MAX  14.454699 / Loss  0.4240211546421051
# fps: 10.102131554228185
# TIMESTEP 5346 / STATE explore / EPSILON 0.094759245999992 / ACTION 0 / REWARD 0.1 / Q_MAX  11.425738 / Loss  0.8346118330955505
# fps: 8.15320856238677
# TIMESTEP 5347 / STATE explore / EPSILON 0.094758246999992 / ACTION 1 / REWARD 0.1 / Q_MAX  11.972891 / Loss  0.7205477356910706
# fps: 8.708994489271314
# TIMESTEP 5348 / STATE explore / EPSILON 0.094757247999992 / ACTION 1 / REWARD 0.1 / Q_MAX  14.486859 / Loss  0.3401857614517212
# fps: 9.146525706111198
# TIMESTEP 5349 / STATE explore / EPSILON 0.094756248999992 / ACTION 1 / REWARD 0.1 / Q_MAX  13.27234 / Loss  0.22773784399032593
# fps: 9.49188812423198
# TIMESTEP 5350 / STATE explore / EPSILON 0.09475524999999199 / ACTION 0 / REWARD 0.1 / Q_MAX  11.286662 / Loss  0.2868170142173767
# fps: 9.708272959998519
# TIMESTEP 5351 / STATE explore / EPSILON 0.09475425099999199 / ACTION 0 / REWARD 0.1 / Q_MAX  13.102466 / Loss  0.3480105698108673
# fps: 7.263845160038931
# TIMESTEP 5352 / STATE explore / EPSILON 0.09475325199999199 / ACTION 1 / REWARD 0.1 / Q_MAX  11.615057 / Loss  0.45834243297576904
# fps: 8.814525891055817
# TIMESTEP 5353 / STATE explore / EPSILON 0.09475225299999199 / ACTION 0 / REWARD 0.1 / Q_MAX  12.022126 / Loss  0.8847960233688354
# fps: 6.711401835660979
# TIMESTEP 5354 / STATE explore / EPSILON 0.09475125399999199 / ACTION 1 / REWARD 0.1 / Q_MAX  10.418204 / Loss  0.8958203792572021
# fps: 7.547866271725086
# TIMESTEP 5355 / STATE explore / EPSILON 0.09475025499999198 / ACTION 1 / REWARD 0.1 / Q_MAX  15.896191 / Loss  0.7087863683700562
# fps: 7.180969925661632
# TIMESTEP 5356 / STATE explore / EPSILON 0.09474925599999198 / ACTION 1 / REWARD 0.1 / Q_MAX  13.500878 / Loss  0.3929045498371124
# fps: 8.544302276074632
# TIMESTEP 5357 / STATE explore / EPSILON 0.09474825699999198 / ACTION 1 / REWARD 0.1 / Q_MAX  18.441467 / Loss  0.3536450266838074
# fps: 7.888419120412861
# TIMESTEP 5358 / STATE explore / EPSILON 0.09474725799999198 / ACTION 1 / REWARD 0.1 / Q_MAX  14.364401 / Loss  0.48708289861679077
# fps: 8.467901428980978
# TIMESTEP 5359 / STATE explore / EPSILON 0.09474625899999198 / ACTION 1 / REWARD 0.1 / Q_MAX  11.308947 / Loss  0.41969090700149536
# fps: 8.52507743965398
# TIMESTEP 5360 / STATE explore / EPSILON 0.09474525999999198 / ACTION 1 / REWARD 0.1 / Q_MAX  12.695745 / Loss  0.24070870876312256
# fps: 8.86619442911892
# TIMESTEP 5361 / STATE explore / EPSILON 0.09474426099999197 / ACTION 0 / REWARD 0.1 / Q_MAX  11.790841 / Loss  0.45262184739112854
# fps: 8.30351359270199
# TIMESTEP 5362 / STATE explore / EPSILON 0.09474326199999197 / ACTION 1 / REWARD 0.1 / Q_MAX  12.9457245 / Loss  0.5721144080162048
# fps: 7.654202571654859
# TIMESTEP 5363 / STATE explore / EPSILON 0.09474226299999197 / ACTION 1 / REWARD 0.1 / Q_MAX  12.631128 / Loss  1.6356010437011719
# fps: 9.144770808623456
# TIMESTEP 5364 / STATE explore / EPSILON 0.09474126399999197 / ACTION 0 / REWARD 0.1 / Q_MAX  12.64869 / Loss  0.8569431304931641
# fps: 9.545178145538625
# TIMESTEP 5365 / STATE explore / EPSILON 0.09474026499999197 / ACTION 0 / REWARD 0.1 / Q_MAX  15.123412 / Loss  1.4828529357910156
# ----------Random Action----------
# fps: 7.206423113863198
# TIMESTEP 5366 / STATE explore / EPSILON 0.09473926599999197 / ACTION 1 / REWARD 0.1 / Q_MAX  11.351097 / Loss  0.5024651288986206
# fps: 7.842649778331248
# TIMESTEP 5367 / STATE explore / EPSILON 0.09473826699999197 / ACTION 0 / REWARD 0.1 / Q_MAX  12.325619 / Loss  0.29295459389686584
# fps: 8.230257839174287
# TIMESTEP 5368 / STATE explore / EPSILON 0.09473726799999196 / ACTION 0 / REWARD 0.1 / Q_MAX  13.419257 / Loss  0.29364436864852905
# fps: 5.29821321425639
# TIMESTEP 5369 / STATE explore / EPSILON 0.09473626899999196 / ACTION 1 / REWARD 0.1 / Q_MAX  12.831749 / Loss  1.100830078125
# fps: 7.05861049357888
# TIMESTEP 5370 / STATE explore / EPSILON 0.09473526999999196 / ACTION 1 / REWARD 0.1 / Q_MAX  14.946585 / Loss  0.9229953289031982
# fps: 7.622223877966028
# TIMESTEP 5371 / STATE explore / EPSILON 0.09473427099999196 / ACTION 1 / REWARD 0.1 / Q_MAX  12.942493 / Loss  0.7659935355186462
# fps: 9.057719883212688
# TIMESTEP 5372 / STATE explore / EPSILON 0.09473327199999196 / ACTION 0 / REWARD 0.1 / Q_MAX  12.720516 / Loss  0.16150662302970886
# fps: 8.97472964356173
# TIMESTEP 5373 / STATE explore / EPSILON 0.09473227299999196 / ACTION 0 / REWARD 0.1 / Q_MAX  15.672985 / Loss  0.5950394868850708
# fps: 8.048680046899257
# TIMESTEP 5374 / STATE explore / EPSILON 0.09473127399999196 / ACTION 0 / REWARD 0.1 / Q_MAX  13.977783 / Loss  0.23378197848796844
# ----------Random Action----------
# fps: 8.260992192608583
# TIMESTEP 5375 / STATE explore / EPSILON 0.09473027499999195 / ACTION 0 / REWARD 0.1 / Q_MAX  15.852834 / Loss  0.3697285056114197
# fps: 6.678828025477707
# TIMESTEP 5376 / STATE explore / EPSILON 0.09472927599999195 / ACTION 1 / REWARD 0.1 / Q_MAX  13.77928 / Loss  0.2981075644493103
# fps: 9.470028426088783
# TIMESTEP 5377 / STATE explore / EPSILON 0.09472827699999195 / ACTION 0 / REWARD 0.1 / Q_MAX  15.993467 / Loss  0.4145321547985077
# fps: 8.267521874624252
# TIMESTEP 5378 / STATE explore / EPSILON 0.09472727799999195 / ACTION 1 / REWARD 0.1 / Q_MAX  8.192871 / Loss  1.1896963119506836
# fps: 8.825747261880965
# TIMESTEP 5379 / STATE explore / EPSILON 0.09472627899999195 / ACTION 0 / REWARD 0.1 / Q_MAX  12.072107 / Loss  0.851685643196106
# fps: 10.147763371503643
# TIMESTEP 5380 / STATE explore / EPSILON 0.09472527999999195 / ACTION 0 / REWARD 0.1 / Q_MAX  13.565308 / Loss  1.1421610116958618
# fps: 8.086231460756473
# TIMESTEP 5381 / STATE explore / EPSILON 0.09472428099999194 / ACTION 1 / REWARD 0.1 / Q_MAX  11.483474 / Loss  1.9683473110198975
# fps: 8.164667499815073
# TIMESTEP 5382 / STATE explore / EPSILON 0.09472328199999194 / ACTION 1 / REWARD 0.1 / Q_MAX  19.95339 / Loss  0.6246334910392761
# fps: 8.688788256692202
# TIMESTEP 5383 / STATE explore / EPSILON 0.09472228299999194 / ACTION 1 / REWARD 0.1 / Q_MAX  12.025213 / Loss  0.6885892152786255
# fps: 8.486302312218257
# TIMESTEP 5384 / STATE explore / EPSILON 0.09472128399999194 / ACTION 1 / REWARD 0.1 / Q_MAX  14.321669 / Loss  0.3217066526412964
# fps: 7.780037877171862
# TIMESTEP 5385 / STATE explore / EPSILON 0.09472028499999194 / ACTION 1 / REWARD 0.1 / Q_MAX  16.921154 / Loss  0.4614183008670807
# fps: 8.1663366490852
# TIMESTEP 5386 / STATE explore / EPSILON 0.09471928599999194 / ACTION 1 / REWARD 0.1 / Q_MAX  13.4866 / Loss  0.5433263778686523
# fps: 7.758063621129111
# TIMESTEP 5387 / STATE explore / EPSILON 0.09471828699999194 / ACTION 1 / REWARD 0.1 / Q_MAX  14.316674 / Loss  0.30527639389038086
# fps: 8.129630491076274
# TIMESTEP 5388 / STATE explore / EPSILON 0.09471728799999193 / ACTION 1 / REWARD 0.1 / Q_MAX  13.089366 / Loss  0.6552906036376953
# fps: 8.312432865223096
# TIMESTEP 5389 / STATE explore / EPSILON 0.09471628899999193 / ACTION 1 / REWARD 0.1 / Q_MAX  15.799255 / Loss  0.9193696975708008
# fps: 9.537819922456823
# TIMESTEP 5390 / STATE explore / EPSILON 0.09471528999999193 / ACTION 0 / REWARD 0.1 / Q_MAX  11.876172 / Loss  3.051198959350586
# ----------Random Action----------
# fps: 8.20587947583217
# TIMESTEP 5391 / STATE explore / EPSILON 0.09471429099999193 / ACTION 1 / REWARD 0.1 / Q_MAX  8.140938 / Loss  0.5454708933830261
# fps: 6.887289159791918
# TIMESTEP 5392 / STATE explore / EPSILON 0.09471329199999193 / ACTION 1 / REWARD -1 / Q_MAX  14.673337 / Loss  0.4245937466621399
# fps: 8.216585564619134
# TIMESTEP 5393 / STATE explore / EPSILON 0.09471229299999193 / ACTION 0 / REWARD 0.1 / Q_MAX  6.361726 / Loss  0.5094040036201477
# fps: 8.895453128346952
# TIMESTEP 5394 / STATE explore / EPSILON 0.09471129399999192 / ACTION 0 / REWARD 0.1 / Q_MAX  18.009708 / Loss  0.8291656970977783
# fps: 8.730366944405706
# TIMESTEP 5395 / STATE explore / EPSILON 0.09471029499999192 / ACTION 0 / REWARD 0.1 / Q_MAX  13.5661955 / Loss  1.356911540031433
# fps: 10.047945878221206
# TIMESTEP 5396 / STATE explore / EPSILON 0.09470929599999192 / ACTION 0 / REWARD 0.1 / Q_MAX  18.102009 / Loss  0.7563339471817017
# fps: 8.220160471615651
# TIMESTEP 5397 / STATE explore / EPSILON 0.09470829699999192 / ACTION 0 / REWARD 0.1 / Q_MAX  18.27293 / Loss  13.254734992980957
# fps: 9.757621862561038
# TIMESTEP 5398 / STATE explore / EPSILON 0.09470729799999192 / ACTION 0 / REWARD 0.1 / Q_MAX  20.349447 / Loss  1.2172943353652954
# fps: 8.433117996787042
# TIMESTEP 5399 / STATE explore / EPSILON 0.09470629899999192 / ACTION 0 / REWARD 0.1 / Q_MAX  13.853649 / Loss  0.43425267934799194
# fps: 9.185847723962725
# TIMESTEP 5400 / STATE explore / EPSILON 0.09470529999999192 / ACTION 0 / REWARD 0.1 / Q_MAX  15.772943 / Loss  0.4140221178531647
# fps: 10.5370755579673
# TIMESTEP 5401 / STATE explore / EPSILON 0.09470430099999191 / ACTION 0 / REWARD 0.1 / Q_MAX  15.79803 / Loss  0.48078060150146484
# fps: 9.33646455450217
# TIMESTEP 5402 / STATE explore / EPSILON 0.09470330199999191 / ACTION 0 / REWARD 0.1 / Q_MAX  14.551503 / Loss  0.2527349591255188
# ----------Random Action----------
# fps: 7.672067576614511
# TIMESTEP 5403 / STATE explore / EPSILON 0.09470230299999191 / ACTION 1 / REWARD 0.1 / Q_MAX  15.444984 / Loss  0.465517520904541
# fps: 9.617691233493005
# TIMESTEP 5404 / STATE explore / EPSILON 0.09470130399999191 / ACTION 0 / REWARD 0.1 / Q_MAX  15.684309 / Loss  0.2722839117050171
# fps: 8.073639187997829
# TIMESTEP 5405 / STATE explore / EPSILON 0.09470030499999191 / ACTION 0 / REWARD 0.1 / Q_MAX  15.201591 / Loss  0.2676544785499573
# fps: 8.776108285225863
# TIMESTEP 5406 / STATE explore / EPSILON 0.0946993059999919 / ACTION 1 / REWARD 0.1 / Q_MAX  15.604376 / Loss  2.4047698974609375
# fps: 8.608591958918195
# TIMESTEP 5407 / STATE explore / EPSILON 0.0946983069999919 / ACTION 0 / REWARD 0.1 / Q_MAX  18.858496 / Loss  1.5791950225830078
# fps: 8.018153282062164
# TIMESTEP 5408 / STATE explore / EPSILON 0.0946973079999919 / ACTION 1 / REWARD 0.1 / Q_MAX  6.9598093 / Loss  0.7662181258201599
# fps: 10.039768388750721
# TIMESTEP 5409 / STATE explore / EPSILON 0.0946963089999919 / ACTION 0 / REWARD 0.1 / Q_MAX  14.548926 / Loss  0.2694758176803589
# fps: 8.634448003557283
# TIMESTEP 5410 / STATE explore / EPSILON 0.0946953099999919 / ACTION 0 / REWARD 0.1 / Q_MAX  14.478768 / Loss  3.4006640911102295
# fps: 8.085000077104569
# TIMESTEP 5411 / STATE explore / EPSILON 0.0946943109999919 / ACTION 0 / REWARD 0.1 / Q_MAX  12.974367 / Loss  16.06093978881836
# ----------Random Action----------
# fps: 7.772843349826727
# TIMESTEP 5412 / STATE explore / EPSILON 0.0946933119999919 / ACTION 1 / REWARD 0.1 / Q_MAX  19.37529 / Loss  0.3834294378757477
# fps: 6.99325734789017
# TIMESTEP 5413 / STATE explore / EPSILON 0.0946923129999919 / ACTION 1 / REWARD 0.1 / Q_MAX  14.087022 / Loss  0.3566012382507324
# fps: 7.5417182867119665
# TIMESTEP 5414 / STATE explore / EPSILON 0.0946913139999919 / ACTION 1 / REWARD 0.1 / Q_MAX  13.7216 / Loss  0.23513948917388916
# fps: 7.874645629081132
# TIMESTEP 5415 / STATE explore / EPSILON 0.09469031499999189 / ACTION 1 / REWARD 0.1 / Q_MAX  15.025862 / Loss  0.44496941566467285
# ----------Random Action----------
# fps: 8.485495386321013
# TIMESTEP 5416 / STATE explore / EPSILON 0.09468931599999189 / ACTION 1 / REWARD 0.1 / Q_MAX  19.36291 / Loss  0.9709634780883789
# fps: 7.454406827556912
# TIMESTEP 5417 / STATE explore / EPSILON 0.09468831699999189 / ACTION 1 / REWARD 0.1 / Q_MAX  15.599045 / Loss  0.6820273399353027
# fps: 9.92142911210355
# TIMESTEP 5418 / STATE explore / EPSILON 0.09468731799999189 / ACTION 0 / REWARD 0.1 / Q_MAX  16.08979 / Loss  0.6310867071151733
# fps: 8.196498468886244
# TIMESTEP 5419 / STATE explore / EPSILON 0.09468631899999189 / ACTION 0 / REWARD 0.1 / Q_MAX  16.442404 / Loss  0.43788373470306396
# fps: 6.48613407107632
# TIMESTEP 5420 / STATE explore / EPSILON 0.09468531999999188 / ACTION 0 / REWARD 0.1 / Q_MAX  17.891535 / Loss  0.7213077545166016
# fps: 7.813109947487934
# TIMESTEP 5421 / STATE explore / EPSILON 0.09468432099999188 / ACTION 0 / REWARD 0.1 / Q_MAX  15.546312 / Loss  0.2738434076309204
# fps: 8.15933080439646
# TIMESTEP 5422 / STATE explore / EPSILON 0.09468332199999188 / ACTION 0 / REWARD 0.1 / Q_MAX  18.397945 / Loss  0.680828869342804
# fps: 8.5758181093266
# TIMESTEP 5423 / STATE explore / EPSILON 0.09468232299999188 / ACTION 0 / REWARD 0.1 / Q_MAX  20.004522 / Loss  0.5107135772705078
# fps: 6.606243502913845
# TIMESTEP 5424 / STATE explore / EPSILON 0.09468132399999188 / ACTION 0 / REWARD 0.1 / Q_MAX  15.098601 / Loss  0.34145939350128174
# fps: 9.179273940104874
# TIMESTEP 5425 / STATE explore / EPSILON 0.09468032499999188 / ACTION 0 / REWARD 0.1 / Q_MAX  18.15135 / Loss  0.5917985439300537
# fps: 9.649820200574714
# TIMESTEP 5426 / STATE explore / EPSILON 0.09467932599999188 / ACTION 0 / REWARD 0.1 / Q_MAX  20.62645 / Loss  0.7747777700424194
# fps: 9.21600225000055
# TIMESTEP 5427 / STATE explore / EPSILON 0.09467832699999187 / ACTION 0 / REWARD 0.1 / Q_MAX  14.11916 / Loss  0.476062148809433
# fps: 8.966364674143083
# TIMESTEP 5428 / STATE explore / EPSILON 0.09467732799999187 / ACTION 0 / REWARD 0.1 / Q_MAX  21.200039 / Loss  0.19662871956825256
# fps: 9.599421421590954
# TIMESTEP 5429 / STATE explore / EPSILON 0.09467632899999187 / ACTION 0 / REWARD 0.1 / Q_MAX  21.48426 / Loss  0.8994059562683105
# fps: 10.914906850077939
# TIMESTEP 5430 / STATE explore / EPSILON 0.09467532999999187 / ACTION 0 / REWARD 0.1 / Q_MAX  19.421114 / Loss  1.3221335411071777
# fps: 8.05359457295425
# TIMESTEP 5431 / STATE explore / EPSILON 0.09467433099999187 / ACTION 1 / REWARD 0.1 / Q_MAX  17.724892 / Loss  1.497760534286499
# fps: 9.036780088637622
# TIMESTEP 5432 / STATE explore / EPSILON 0.09467333199999187 / ACTION 0 / REWARD 0.1 / Q_MAX  18.588257 / Loss  0.8285179734230042
# fps: 8.33304326749236
# TIMESTEP 5433 / STATE explore / EPSILON 0.09467233299999187 / ACTION 0 / REWARD 0.1 / Q_MAX  17.810488 / Loss  0.6548838019371033
# fps: 10.838666997436533
# TIMESTEP 5434 / STATE explore / EPSILON 0.09467133399999186 / ACTION 0 / REWARD 0.1 / Q_MAX  19.079596 / Loss  1.0325666666030884
# fps: 9.49521877716604
# TIMESTEP 5435 / STATE explore / EPSILON 0.09467033499999186 / ACTION 0 / REWARD 0.1 / Q_MAX  17.826494 / Loss  0.45914071798324585
# fps: 8.146779011813333
# TIMESTEP 5436 / STATE explore / EPSILON 0.09466933599999186 / ACTION 1 / REWARD 0.1 / Q_MAX  22.83789 / Loss  0.4667969048023224
# fps: 10.129162822822533
# TIMESTEP 5437 / STATE explore / EPSILON 0.09466833699999186 / ACTION 0 / REWARD 0.1 / Q_MAX  19.468012 / Loss  0.2770977318286896
# fps: 8.230128642853218
# TIMESTEP 5438 / STATE explore / EPSILON 0.09466733799999186 / ACTION 1 / REWARD 0.1 / Q_MAX  16.3683 / Loss  0.3476264476776123
# ----------Random Action----------
# fps: 7.335571972240878
# TIMESTEP 5439 / STATE explore / EPSILON 0.09466633899999186 / ACTION 1 / REWARD 0.1 / Q_MAX  18.010166 / Loss  0.614051342010498
# fps: 8.38195272953275
# TIMESTEP 5440 / STATE explore / EPSILON 0.09466533999999185 / ACTION 0 / REWARD 0.1 / Q_MAX  20.63351 / Loss  0.4960453510284424
# fps: 6.822069764188844
# TIMESTEP 5441 / STATE explore / EPSILON 0.09466434099999185 / ACTION 1 / REWARD 0.1 / Q_MAX  23.487783 / Loss  0.8246889710426331
# fps: 7.175773170301912
# TIMESTEP 5442 / STATE explore / EPSILON 0.09466334199999185 / ACTION 1 / REWARD 0.1 / Q_MAX  18.61275 / Loss  0.8521420359611511
# fps: 6.6490133414498045
# TIMESTEP 5443 / STATE explore / EPSILON 0.09466234299999185 / ACTION 1 / REWARD 0.1 / Q_MAX  17.254444 / Loss  0.3935306668281555
# fps: 8.052048477727928
# TIMESTEP 5444 / STATE explore / EPSILON 0.09466134399999185 / ACTION 1 / REWARD 0.1 / Q_MAX  20.006254 / Loss  0.677669882774353
# fps: 7.728088293550259
# TIMESTEP 5445 / STATE explore / EPSILON 0.09466034499999185 / ACTION 1 / REWARD 0.1 / Q_MAX  20.518974 / Loss  0.12506964802742004
# fps: 9.505978768346523
# TIMESTEP 5446 / STATE explore / EPSILON 0.09465934599999185 / ACTION 0 / REWARD 0.1 / Q_MAX  27.848267 / Loss  1.24794340133667
# fps: 7.611572962545573
# TIMESTEP 5447 / STATE explore / EPSILON 0.09465834699999184 / ACTION 1 / REWARD 0.1 / Q_MAX  18.557398 / Loss  1.3328523635864258
# fps: 8.058685418948258
