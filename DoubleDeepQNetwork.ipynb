# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

import numpy as np
import pandas as pd
from PIL import Image
import cv2  #opencv
from IPython.display import clear_output
from random import randint
import io
from io import BytesIO
import time
import os

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.callbacks import TensorBoard
from keras.optimizers import SGD , Adam
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D


from collections import deque
import random
import pickle
import _pickle as cPickle
import base64
import json

# %%
#path variables
game_url = "chrome://dino"
chromedriver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects_ddqn/loss_df.csv"
actions_file_path = "./objects_ddqn/actions_df.csv"
q_value_file_path = "./objects_ddqn/q_values.csv"
scores_file_path = "./objects_ddqn/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chromedriver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class Dino_Agent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_state:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        game_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            game_over = True
        return image, reward, game_over #return the Experience tuple

# %%
def save_object(obj, name):
    with open('objects_ddqn/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_object(name):
    with open('objects_ddqn/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = img_process(screen)#processing image as required
    return image

def img_process(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100 # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH_SIZE = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_object(INITIAL_EPSILON,"epsilon")
    t = 0
    save_object(t,"time")
    D = deque()
    save_object(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %%
def build_model():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model_ddqn.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate whether the model is to be trained(weight updates), else just play
'''
def train_Network(q_eval,q_target,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_object("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_object("epsilon") 
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)

    t = load_object("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0

        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = q_target.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        
        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH_SIZE)
            inputs = np.zeros((BATCH_SIZE, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    
                
                #q_next = q_target.predict(state_t1)
                #q_eval = q_eval.predict(state_t1)
                #q_pred = q_eval.predict(state_t)
                
                #targets[i] = q_pred
                Q_sa = q_target.predict(state_t1)      #predict q values for next step
                #old_q = q_eval.predict(state_t1)
                targets[i] = q_target.predict(state_t)  # predicted q values
                #max_Actions = np.argmax(old_q)
                q_eval = q_target
                #q_target  = targets[i]

                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    #targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += q_target.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 
            q_target.set_weights(q_eval.get_weights())

        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            q_target.save_weights("model_ddqn.h5", overwrite=True)
            save_object(D,"D") #saving episodes
            save_object(t,"time") #caching time steps
            save_object(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects_ddqn/loss_df.csv",index=False)
            scores_df.to_csv("./objects_ddqn/scores_df.csv",index=False)
            actions_df.to_csv("./objects_ddqn/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model_ddqn.json", "w") as outfile:
                json.dump(q_target.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX ", np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def play_Game(observe=False):
    game = Game()
    dino = Dino_Agent(game)
    game_state = Game_state(dino,game)    
    #model = build_model()
    q_eval = build_model()
    q_target = build_model()
    try:
        train_Network(q_eval,q_target,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
play_Game(observe=False);
# Out:
# TIMESTEP 260000 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.490399 / Loss  0.018630996346473694
# fps: 0.18478584348733726
# TIMESTEP 260001 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.686392 / Loss  0.03000415861606598
# fps: 8.280187228430925
# TIMESTEP 260002 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.112508 / Loss  0.022375309839844704
# fps: 7.155232033463724
# TIMESTEP 260003 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.83216 / Loss  0.007487312890589237
# fps: 7.19832222943032
# TIMESTEP 260004 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.533012 / Loss  0.04205619543790817
# fps: 7.041262433373904
# TIMESTEP 260005 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.766775 / Loss  0.007928796112537384
# fps: 7.640399006127907
# TIMESTEP 260006 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.696276 / Loss  0.06255471706390381
# fps: 8.607178695801174
# TIMESTEP 260007 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.585823 / Loss  0.020926877856254578
# fps: 8.962915792307923
# TIMESTEP 260008 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.753661 / Loss  0.042920611798763275
# fps: 8.169008707913859
# TIMESTEP 260009 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.173439 / Loss  0.020721381530165672
# fps: 8.994630204669836
# TIMESTEP 260010 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.630689 / Loss  0.007198752835392952
# fps: 8.709591276919594
# TIMESTEP 260011 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.989881 / Loss  0.030273541808128357
# fps: 8.066279472287397
# TIMESTEP 260012 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.526656 / Loss  0.015339819714426994
# fps: 8.838598738999966
# TIMESTEP 260013 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.922983 / Loss  0.022688785567879677
# fps: 8.929674859060174
# TIMESTEP 260014 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.851372 / Loss  0.147363543510437
# fps: 8.234652928842364
# TIMESTEP 260015 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.591733 / Loss  0.04342055320739746
# fps: 9.223419718743472
# TIMESTEP 260016 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.768241 / Loss  0.01619860529899597
# fps: 7.776734527385323
# TIMESTEP 260017 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.726687 / Loss  0.046237267553806305
# fps: 7.203935255159526
# TIMESTEP 260018 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.422272 / Loss  0.02161077968776226
# fps: 7.38089447704856
# TIMESTEP 260019 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.784227 / Loss  0.02233283966779709
# fps: 7.370842120061859
# TIMESTEP 260020 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.014163 / Loss  0.01568804681301117
# fps: 6.173804887167689
# TIMESTEP 260021 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.400119 / Loss  0.02946113608777523
# fps: 7.079340592197761
# TIMESTEP 260022 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.708705 / Loss  0.025475289672613144
# fps: 7.027494713843865
# TIMESTEP 260023 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.899663 / Loss  0.014720072969794273
# fps: 7.128805493235434
# TIMESTEP 260024 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.62402 / Loss  0.0073502580635249615
# fps: 8.7385338494681
# TIMESTEP 260025 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.683535 / Loss  0.012966628186404705
# fps: 7.103138770436556
# TIMESTEP 260026 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  11.541252 / Loss  0.022465042769908905
# fps: 8.339587902310221
# TIMESTEP 260027 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.557812 / Loss  0.009892359375953674
# fps: 8.57618634779906
# TIMESTEP 260028 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.5999565 / Loss  0.014427460730075836
# fps: 8.439600063584175
# TIMESTEP 260029 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.508799 / Loss  0.010229755192995071
# fps: 8.363217272361112
# TIMESTEP 260030 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.322428 / Loss  0.05742413178086281
# fps: 6.178907205256257
# TIMESTEP 260031 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.303426 / Loss  0.019531110301613808
# fps: 8.49942348337626
# TIMESTEP 260032 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.636919 / Loss  0.0356350801885128
# fps: 8.451742516598994
# TIMESTEP 260033 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.334439 / Loss  0.010969233699142933
# fps: 8.646783666720955
# TIMESTEP 260034 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.86125 / Loss  0.016490675508975983
# fps: 8.661228838934296
# TIMESTEP 260035 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.558379 / Loss  0.013049780391156673
# fps: 8.375709407512431
# TIMESTEP 260036 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.667191 / Loss  0.018500277772545815
# fps: 8.676045383557252
# TIMESTEP 260037 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.260223 / Loss  0.004582617431879044
# fps: 8.59696401998844
# TIMESTEP 260038 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.761116 / Loss  0.1649337112903595
# fps: 8.355603366701528
# TIMESTEP 260039 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.399732 / Loss  0.021082405000925064
# fps: 8.630219628725808
# TIMESTEP 260040 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.709681 / Loss  0.02066943235695362
# fps: 8.637132860940708
# TIMESTEP 260041 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.594196 / Loss  0.0371568500995636
# fps: 7.972370534399027
# TIMESTEP 260042 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.607465 / Loss  0.06432416290044785
# fps: 8.663178788523462
# TIMESTEP 260043 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.602029 / Loss  0.011498219333589077
# fps: 8.883922198240713
# TIMESTEP 260044 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.417744 / Loss  0.019598405808210373
# fps: 8.540735582189967
# TIMESTEP 260045 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.539327 / Loss  0.01373974047601223
# fps: 9.022395171195821
# TIMESTEP 260046 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.441315 / Loss  0.011629585176706314
# fps: 8.624860169770349
# TIMESTEP 260047 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.921282 / Loss  0.0053969621658325195
# fps: 8.515990181129332
# TIMESTEP 260048 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.515016 / Loss  0.007834997959434986
# fps: 8.925133473634036
# TIMESTEP 260049 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.619988 / Loss  0.005505772307515144
# fps: 8.851338261642127
# TIMESTEP 260050 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.485142 / Loss  0.019975654780864716
# fps: 8.253481992813654
# TIMESTEP 260051 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.111002 / Loss  0.015034309588372707
# fps: 8.68824830763367
# TIMESTEP 260052 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.527177 / Loss  0.02380475401878357
# fps: 8.491129902442086
# TIMESTEP 260053 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.290929 / Loss  0.017030945047736168
# fps: 7.814813158640016
# TIMESTEP 260054 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.394065 / Loss  0.014399321749806404
# fps: 8.252994789617013
# TIMESTEP 260055 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.5383 / Loss  0.08786793053150177
# fps: 8.33541140441701
# TIMESTEP 260056 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.611298 / Loss  0.023135725408792496
# fps: 7.782954079445695
# TIMESTEP 260057 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.322127 / Loss  0.015992190688848495
# fps: 8.721580500342059
# TIMESTEP 260058 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.583774 / Loss  0.017231790348887444
# fps: 8.186052321360261
# TIMESTEP 260059 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.250692 / Loss  0.013352401554584503
# fps: 7.4015910326182865
# TIMESTEP 260060 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.413726 / Loss  0.011324891820549965
# fps: 8.827772001532225
# TIMESTEP 260061 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.6324617 / Loss  3.73258638381958
# fps: 8.848238602442477
# TIMESTEP 260062 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.54243 / Loss  0.01844879984855652
# fps: 7.665995894950204
# TIMESTEP 260063 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.459646 / Loss  0.015836438164114952
# fps: 7.50446227286065
# TIMESTEP 260064 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.620057 / Loss  0.02407626062631607
# fps: 7.419318547659564
# TIMESTEP 260065 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.523406 / Loss  0.016240034252405167
# fps: 6.849543070280298
# TIMESTEP 260066 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.507832 / Loss  0.0458708219230175
# fps: 5.255967358723221
# TIMESTEP 260067 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.151594 / Loss  0.012148914858698845
# fps: 8.870919915823313
# TIMESTEP 260068 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.411277 / Loss  0.024572113528847694
# fps: 7.312347452544666
# TIMESTEP 260069 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.346846 / Loss  0.04576551169157028
# fps: 7.677614803506479
# TIMESTEP 260070 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.354394 / Loss  0.6582013368606567
# fps: 7.3750672570044
# TIMESTEP 260071 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.695617 / Loss  0.06052529066801071
# fps: 7.396500583706306
# TIMESTEP 260072 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.286533 / Loss  0.022450225427746773
# fps: 7.554065103613225
# TIMESTEP 260073 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.40419 / Loss  0.06631738692522049
# fps: 8.669499793303018
# TIMESTEP 260074 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.6487465 / Loss  0.006447712890803814
# fps: 8.573311421259618
# TIMESTEP 260075 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.503094 / Loss  0.01953347958624363
# fps: 8.75564462257849
# TIMESTEP 260076 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.346819 / Loss  0.024805579334497452
# fps: 9.06715782282925
# TIMESTEP 260077 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.180846 / Loss  0.022504225373268127
# fps: 8.49942348337626
# TIMESTEP 260078 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.4651375 / Loss  0.013058525510132313
# fps: 7.8331733444889755
# TIMESTEP 260079 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.497188 / Loss  0.01180961262434721
# fps: 7.362251274345976
# TIMESTEP 260080 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.246872 / Loss  0.010879579000175
# fps: 7.901883579063975
# TIMESTEP 260081 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.518488 / Loss  0.029736243188381195
# fps: 7.008893330169478
# TIMESTEP 260082 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.443345 / Loss  0.008966583758592606
# fps: 8.171189003007964
# TIMESTEP 260083 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.629211 / Loss  0.008030232973396778
# fps: 7.950126711361564
# TIMESTEP 260084 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.740176 / Loss  0.0211342740803957
# fps: 8.937019249208426
# TIMESTEP 260085 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.458045 / Loss  0.01313723810017109
# fps: 8.664216734318677
# TIMESTEP 260086 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.749294 / Loss  0.019088171422481537
# fps: 7.512742435857938
# TIMESTEP 260087 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.378134 / Loss  0.008045964874327183
# fps: 7.511518079884238
# TIMESTEP 260088 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.27153 / Loss  0.014782199636101723
# fps: 8.730712227939584
# TIMESTEP 260089 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.823024 / Loss  0.023250378668308258
# fps: 6.966495478916003
# TIMESTEP 260090 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.38255 / Loss  0.02990998700261116
# fps: 9.027638412679964
# TIMESTEP 260091 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.20161 / Loss  0.02132239192724228
# fps: 8.502042247668392
# TIMESTEP 260092 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.752032 / Loss  0.02909553423523903
# fps: 7.5704265772383845
# TIMESTEP 260093 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.507492 / Loss  0.014759925194084644
# fps: 7.8003667431644805
# TIMESTEP 260094 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.367344 / Loss  0.013656163588166237
# fps: 8.841244345512877
# TIMESTEP 260095 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.350997 / Loss  0.016841743141412735
# fps: 8.204852131659358
# TIMESTEP 260096 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.341207 / Loss  0.017367033287882805
# fps: 8.693020180687308
# TIMESTEP 260097 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.04719 / Loss  0.09610000252723694
# fps: 8.52733061443564
# TIMESTEP 260098 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.350027 / Loss  0.04003516212105751
# fps: 8.213753613084654
# TIMESTEP 260099 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.483624 / Loss  0.010360239073634148
# fps: 8.497064531682394
# TIMESTEP 260100 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.448242 / Loss  0.029179608449339867
# fps: 8.879107665666764
# TIMESTEP 260101 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.975581 / Loss  0.028653249144554138
# fps: 7.661850803851473
# TIMESTEP 260102 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.375897 / Loss  0.2590532898902893
# fps: 5.401077561784673
# TIMESTEP 260103 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  11.204436 / Loss  0.03210756555199623
# fps: 8.635941360566628
# TIMESTEP 260104 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.1462345 / Loss  0.015715181827545166
# fps: 8.665129616315872
# TIMESTEP 260105 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.04751 / Loss  0.02792978286743164
# fps: 8.740810206459061
# TIMESTEP 260106 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.386707 / Loss  0.019373269751667976
# fps: 8.649939986883732
# TIMESTEP 260107 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.247467 / Loss  0.009646839462220669
# fps: 8.57648446877294
# TIMESTEP 260108 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.222846 / Loss  0.04597104340791702
# fps: 8.700413416002705
# TIMESTEP 260109 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.268209 / Loss  0.048111025243997574
# fps: 8.601424443583134
# TIMESTEP 260110 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.018909 / Loss  0.007376215420663357
# fps: 8.423515046352083
# TIMESTEP 260111 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.992581 / Loss  0.014662024565041065
# fps: 8.661389810698127
# TIMESTEP 260112 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.249576 / Loss  0.08064232021570206
# fps: 8.716958388581071
# TIMESTEP 260113 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.227744 / Loss  0.007042553275823593
# fps: 8.544302276074632
# TIMESTEP 260114 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.186212 / Loss  0.033996954560279846
# fps: 8.921640322721307
# TIMESTEP 260115 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.090263 / Loss  0.013193199411034584
# fps: 8.666866413057628
# TIMESTEP 260116 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.243838 / Loss  0.024246226996183395
# fps: 8.610889501594151
# TIMESTEP 260117 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.292614 / Loss  0.013300718739628792
# fps: 8.998219365579263
# TIMESTEP 260118 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.223028 / Loss  0.043070532381534576
# fps: 8.742030822074842
# TIMESTEP 260119 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.060661 / Loss  0.01996440440416336
# fps: 8.563631500609455
# TIMESTEP 260120 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.140709 / Loss  0.010242423973977566
# fps: 9.176442275085162
# TIMESTEP 260121 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.254063 / Loss  0.46925824880599976
# fps: 8.899341190948537
# TIMESTEP 260122 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.930828 / Loss  0.019757449626922607
# fps: 8.792205396521943
# TIMESTEP 260123 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.909745 / Loss  0.02424856275320053
# fps: 8.754109583322897
# TIMESTEP 260124 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.297636 / Loss  0.01928265392780304
# fps: 8.789202260635232
# TIMESTEP 260125 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.759695 / Loss  0.015083380974829197
# fps: 8.617364559599118
# TIMESTEP 260126 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.225495 / Loss  0.024962972849607468
# fps: 9.084459422873245
# TIMESTEP 260127 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.388841 / Loss  0.01634632796049118
# fps: 8.702381051181396
# TIMESTEP 260128 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.442437 / Loss  0.44020503759384155
# fps: 8.95015886767571
# TIMESTEP 260129 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.170671 / Loss  0.01687445677816868
# fps: 8.866962915357718
# TIMESTEP 260130 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.060462 / Loss  0.023062502965331078
# fps: 8.717719340544226
# TIMESTEP 260131 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.226135 / Loss  0.010294603183865547
# fps: 8.581099217650332
# TIMESTEP 260132 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.009399 / Loss  0.01979159191250801
# fps: 9.072453235044732
# TIMESTEP 260133 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.890987 / Loss  0.010065126232802868
# fps: 8.81245167579924
# TIMESTEP 260134 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.063185 / Loss  0.04348619654774666
# fps: 8.716433046893671
# TIMESTEP 260135 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.253731 / Loss  0.016629917547106743
# fps: 9.001463651230369
# TIMESTEP 260136 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.796267 / Loss  0.06232558190822601
# fps: 8.989174766124798
# TIMESTEP 260137 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.484309 / Loss  0.04312105476856232
# fps: 8.811674096732311
# TIMESTEP 260138 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.572908 / Loss  0.02165452390909195
# fps: 6.191987906273621
# TIMESTEP 260139 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.803144 / Loss  0.027941733598709106
# fps: 8.61906454788125
# TIMESTEP 260140 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.832617 / Loss  0.01943664252758026
# fps: 8.32541807679711
# TIMESTEP 260141 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.027137 / Loss  0.040397223085165024
# fps: 7.43316396966695
# TIMESTEP 260142 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.020172 / Loss  0.027109021320939064
# fps: 7.348076306536581
# TIMESTEP 260143 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.234454 / Loss  0.010082770138978958
# fps: 7.566807323792222
# TIMESTEP 260144 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.083489 / Loss  0.026974007487297058
# fps: 7.7245159175374685
# TIMESTEP 260145 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.421583 / Loss  3.6127493381500244
# fps: 7.433664580641617
# TIMESTEP 260146 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.740525 / Loss  4.23028564453125
# fps: 8.076950777306838
# TIMESTEP 260147 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.26671 / Loss  0.09161461889743805
# fps: 9.154051476349382
# TIMESTEP 260148 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.012442 / Loss  0.02247615158557892
# fps: 8.790031142202086
# TIMESTEP 260149 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.219382 / Loss  0.02801966853439808
# fps: 8.729440265735372
# TIMESTEP 260150 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.7934 / Loss  0.042108431458473206
# fps: 8.846036550000527
# TIMESTEP 260151 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.529188 / Loss  0.03223242238163948
# fps: 8.867675289859362
# TIMESTEP 260152 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.653375 / Loss  0.010734936222434044
# fps: 8.736822809911846
# TIMESTEP 260153 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.81271 / Loss  0.10908517241477966
# fps: 8.015824085098414
# TIMESTEP 260154 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.680396 / Loss  0.01598830707371235
# fps: 8.801264067047594
# TIMESTEP 260155 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.377136 / Loss  0.012864555232226849
# fps: 8.737132203601671
# TIMESTEP 260156 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.614819 / Loss  0.0614926852285862
# fps: 7.733959282567769
# TIMESTEP 260157 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.625065 / Loss  0.03822369500994682
# fps: 8.799159168483083
# TIMESTEP 260158 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.432605 / Loss  0.04631566256284714
# fps: 8.46891020657878
# TIMESTEP 260159 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.771302 / Loss  0.03945165500044823
# fps: 9.15648952450395
# TIMESTEP 260160 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.312177 / Loss  0.03564884886145592
# fps: 8.84674556587437
# TIMESTEP 260161 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.355097 / Loss  0.4808555245399475
# fps: 7.606769062244396
# TIMESTEP 260162 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.391947 / Loss  0.05552899092435837
# fps: 7.638896173907976
# TIMESTEP 260163 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.207925 / Loss  0.012940808199346066
# fps: 7.639717092309289
# TIMESTEP 260164 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.149354 / Loss  0.012552336789667606
# fps: 7.172509084690693
# TIMESTEP 260165 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.102465 / Loss  0.054823845624923706
# fps: 9.054591299241835
# TIMESTEP 260166 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.486873 / Loss  0.021077526733279228
# fps: 7.554582132564842
# TIMESTEP 260167 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.770925 / Loss  0.025547489523887634
# fps: 8.094549216078308
# TIMESTEP 260168 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.738318 / Loss  0.059317074716091156
# fps: 7.609018409805017
# TIMESTEP 260169 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.209102 / Loss  0.06440482288599014
# fps: 7.74372598723504
# TIMESTEP 260170 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.524886 / Loss  0.04572825878858566
# fps: 6.854479520580742
# TIMESTEP 260171 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.687991 / Loss  0.0740836039185524
# fps: 9.07661545120104
# TIMESTEP 260172 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.827491 / Loss  0.060045890510082245
# fps: 7.630502332283018
# TIMESTEP 260173 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.648458 / Loss  0.5985593199729919
# fps: 7.030321722019035
# TIMESTEP 260174 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.073595 / Loss  0.039168134331703186
# fps: 5.2741225836549255
# TIMESTEP 260175 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.131863 / Loss  0.03893878683447838
# fps: 8.433694530962526
# TIMESTEP 260176 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.429216 / Loss  0.04054615646600723
# fps: 8.684632379280142
# TIMESTEP 260177 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.268898 / Loss  0.03677326440811157
# fps: 9.023462744878685
# TIMESTEP 260178 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.101252 / Loss  0.023526541888713837
# fps: 8.818250816270323
# TIMESTEP 260179 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.732561 / Loss  0.046194158494472504
# fps: 8.534739815114389
# TIMESTEP 260180 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.646929 / Loss  0.046327266842126846
# fps: 8.774015400481552
# TIMESTEP 260181 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.387206 / Loss  0.05438225716352463
# fps: 8.598074285749428
# TIMESTEP 260182 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.300121 / Loss  0.02993481419980526
# fps: 8.771299810742704
# TIMESTEP 260183 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.515064 / Loss  0.04659992828965187
# fps: 8.014169951524856
# TIMESTEP 260184 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.3929 / Loss  0.02540443278849125
# fps: 8.853075767042096
# TIMESTEP 260185 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.6338415 / Loss  0.05395763739943504
# fps: 8.644306588899651
# TIMESTEP 260186 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.087766 / Loss  0.15579411387443542
# fps: 9.199871026893526
# TIMESTEP 260187 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.760912 / Loss  0.14920493960380554
# fps: 8.833461101048819
# TIMESTEP 260188 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.456961 / Loss  0.27905866503715515
# fps: 8.70745768552869
# TIMESTEP 260189 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.8816595 / Loss  0.17713521420955658
# fps: 8.956714486446318
# TIMESTEP 260190 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.735846 / Loss  0.255471408367157
# fps: 9.021192027341222
# TIMESTEP 260191 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.294134 / Loss  0.885103166103363
# fps: 7.135366498871251
# TIMESTEP 260192 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.937307 / Loss  0.10164342820644379
# fps: 9.06658942394366
# TIMESTEP 260193 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.236509 / Loss  0.12735940515995026
# fps: 8.609705230314475
# TIMESTEP 260194 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.826294 / Loss  2.7198283672332764
# fps: 8.918472274789812
# TIMESTEP 260195 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.763235 / Loss  0.03946436941623688
# fps: 9.077519077856701
# TIMESTEP 260196 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.899565 / Loss  0.5622940063476562
# fps: 9.054200378202417
# TIMESTEP 260197 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.405318 / Loss  0.09408502280712128
# fps: 8.8124331604171
# TIMESTEP 260198 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.944088 / Loss  0.021756542846560478
# fps: 9.059774191667081
# TIMESTEP 260199 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.888426 / Loss  0.05699503794312477
# fps: 8.816397226210169
# TIMESTEP 260200 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.647784 / Loss  0.062387410551309586
# fps: 8.764096970608762
# TIMESTEP 260201 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.614175 / Loss  0.050863638520240784
# fps: 8.737441619205146
# TIMESTEP 260202 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.568508 / Loss  0.40691205859184265
# fps: 7.838692375116104
# TIMESTEP 260203 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.536782 / Loss  0.050230931490659714
# fps: 7.6203820452538675
# TIMESTEP 260204 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  13.033376 / Loss  0.026460446417331696
# fps: 9.293147188439578
# TIMESTEP 260205 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.592748 / Loss  0.07611514627933502
# fps: 7.754520831600063
# TIMESTEP 260206 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.689779 / Loss  0.11790096759796143
# fps: 7.908140986240002
# TIMESTEP 260207 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.627293 / Loss  0.05540970340371132
# fps: 7.711421784566507
# TIMESTEP 260208 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.357612 / Loss  0.02106073684990406
# fps: 7.653155101094975
# TIMESTEP 260209 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8340166 / Loss  0.016630586236715317
# fps: 7.0069262304667275
# TIMESTEP 260210 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.4675865 / Loss  0.07650645822286606
# fps: 6.1448791257733655
# TIMESTEP 260211 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.797744 / Loss  0.02518630400300026
# fps: 8.971984367546616
# TIMESTEP 260212 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.681562 / Loss  0.08276847749948502
# fps: 8.721580500342059
# TIMESTEP 260213 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.396459 / Loss  0.027761995792388916
# fps: 9.119281294435337
# TIMESTEP 260214 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.163151 / Loss  0.03916584327816963
# fps: 8.746223590154226
# TIMESTEP 260215 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.754097 / Loss  2.208235740661621
# fps: 8.495962988320416
# TIMESTEP 260216 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.040781 / Loss  0.035423025488853455
# fps: 7.787795177635757
# TIMESTEP 260217 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.971547 / Loss  0.021130673587322235
# fps: 8.795616351027444
# TIMESTEP 260218 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.886158 / Loss  0.06828934699296951
# fps: 8.417429277847349
# TIMESTEP 260219 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.1538315 / Loss  0.045963309705257416
# fps: 8.837276529397512
# TIMESTEP 260220 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.66953 / Loss  0.0755937248468399
# fps: 8.839306563036084
# TIMESTEP 260221 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.724928 / Loss  0.055037785321474075
# fps: 8.651938397052696
# TIMESTEP 260222 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.627106 / Loss  0.07026762515306473
# fps: 8.971427838072545
# TIMESTEP 260223 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.636902 / Loss  0.2087140679359436
# fps: 8.353107294000498
# TIMESTEP 260224 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.834471 / Loss  0.08820800483226776
# fps: 8.325715544774772
# TIMESTEP 260225 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.099321 / Loss  3.303806781768799
# fps: 7.595212139869258
# TIMESTEP 260226 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.851863 / Loss  0.04234326258301735
# fps: 8.724864268924344
# TIMESTEP 260227 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.317142 / Loss  0.37469482421875
# fps: 8.691272887017497
# TIMESTEP 260228 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.492998 / Loss  0.039141684770584106
# fps: 8.631835871178055
# TIMESTEP 260229 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.285316 / Loss  0.02668885327875614
# fps: 8.656205950761851
# TIMESTEP 260230 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.055995 / Loss  0.09674072265625
# fps: 8.551008758338362
# TIMESTEP 260231 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.269234 / Loss  0.053462591022253036
# fps: 9.061927324030083
# TIMESTEP 260232 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.719169 / Loss  0.03427303209900856
# fps: 8.630059813461012
# TIMESTEP 260233 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.75381 / Loss  0.05756895989179611
# fps: 8.54247506079504
# TIMESTEP 260234 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.940686 / Loss  0.04962558671832085
# fps: 8.840461677247474
# TIMESTEP 260235 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.822634 / Loss  0.037597302347421646
# fps: 8.928876456638267
# TIMESTEP 260236 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.603858 / Loss  0.027533158659934998
# fps: 8.639890577557688
# TIMESTEP 260237 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.852283 / Loss  0.030755246058106422
# fps: 8.834075069452197
# TIMESTEP 260238 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.796922 / Loss  0.022286275401711464
# fps: 8.540666017780564
# TIMESTEP 260239 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.9707 / Loss  0.03839808702468872
# fps: 8.53255215485236
# TIMESTEP 260240 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.702047 / Loss  0.013769900426268578
# fps: 8.510270831811578
# TIMESTEP 260241 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.637395 / Loss  0.05345246195793152
# fps: 7.813648489545299
# TIMESTEP 260242 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.21878 / Loss  0.02207339182496071
# fps: 6.906125325399165
# TIMESTEP 260243 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.174195 / Loss  0.04121626541018486
# fps: 7.931094861802085
# TIMESTEP 260244 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.477512 / Loss  0.030994411557912827
# fps: 7.53643333686709
# TIMESTEP 260245 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.4293585 / Loss  0.033580876886844635
# fps: 8.135701580663495
# TIMESTEP 260246 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.312809 / Loss  0.1757655143737793
# fps: 6.030596517058133
# TIMESTEP 260247 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.633998 / Loss  0.054286982864141464
# fps: 8.946302612241938
# TIMESTEP 260248 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.477487 / Loss  0.022571071982383728
# fps: 7.529384731930966
# TIMESTEP 260249 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.368334 / Loss  0.08431252837181091
# fps: 7.959752457115529
# TIMESTEP 260250 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.133892 / Loss  0.4824537932872772
# fps: 7.434784612493929
# TIMESTEP 260251 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.886746 / Loss  0.05272693186998367
# fps: 8.036774103305492
# TIMESTEP 260252 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.407554 / Loss  0.027277911081910133
# fps: 8.106219729503032
# TIMESTEP 260253 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.748211 / Loss  0.01959931291639805
# fps: 8.281920302661119
# TIMESTEP 260254 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.958709 / Loss  0.021705294027924538
# fps: 8.577414037800056
# TIMESTEP 260255 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.6806 / Loss  0.05803796276450157
# fps: 9.118190928992398
# TIMESTEP 260256 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.887782 / Loss  0.04237116873264313
# fps: 8.82714033167775
# TIMESTEP 260257 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.770394 / Loss  0.12608647346496582
# fps: 8.701406148216071
# TIMESTEP 260258 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.665486 / Loss  0.019228022545576096
# fps: 7.8050552399312965
# TIMESTEP 260259 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.360815 / Loss  0.026268552988767624
# fps: 8.865463553622233
# TIMESTEP 260260 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.294202 / Loss  0.025334378704428673
# fps: 8.624540942009615
# TIMESTEP 260261 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.169627 / Loss  0.03778048977255821
# fps: 9.204635780482935
# TIMESTEP 260262 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.555274 / Loss  0.020702185109257698
# fps: 8.80213216931439
# TIMESTEP 260263 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.356438 / Loss  0.015110206790268421
# fps: 8.74543941918144
# TIMESTEP 260264 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.405147 / Loss  0.02927841618657112
# fps: 7.792598868167107
# TIMESTEP 260265 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.144125 / Loss  0.0750921443104744
# fps: 8.895698391085434
# TIMESTEP 260266 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.34664 / Loss  2.9771885871887207
# fps: 7.4064792283975684
# TIMESTEP 260267 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.317819 / Loss  0.012212244793772697
# fps: 9.053535889897642
# TIMESTEP 260268 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.04961 / Loss  0.019212692975997925
# fps: 8.51848075763084
# TIMESTEP 260269 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.855808 / Loss  0.013098908588290215
# fps: 8.477468828257798
# TIMESTEP 260270 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.553077 / Loss  0.026833590120077133
# fps: 7.6442701289991
# TIMESTEP 260271 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.937511 / Loss  0.014134892262518406
# fps: 8.895528592364482
# TIMESTEP 260272 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.651276 / Loss  0.04696786031126976
# fps: 7.961157529904375
# TIMESTEP 260273 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.744939 / Loss  0.01628369465470314
# fps: 8.81095218188655
# TIMESTEP 260274 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.942276 / Loss  0.3158706724643707
# fps: 8.623211080660449
# TIMESTEP 260275 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.520018 / Loss  0.022125739604234695
# fps: 7.795379611560264
# TIMESTEP 260276 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.65793 / Loss  0.06503885239362717
# fps: 8.737441619205146
# TIMESTEP 260277 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.512648 / Loss  0.02475684881210327
# fps: 8.93321235820565
# TIMESTEP 260278 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.690183 / Loss  3.1958892345428467
# fps: 7.87977914170363
# TIMESTEP 260279 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.424203 / Loss  0.03376588225364685
# fps: 9.105146618271494
# TIMESTEP 260280 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.383336 / Loss  0.023206591606140137
# fps: 7.647545541898912
# TIMESTEP 260281 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.223206 / Loss  0.046299710869789124
# fps: 7.958680100946851
# TIMESTEP 260282 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.002978 / Loss  0.018532579764723778
# fps: 5.20548509643846
# TIMESTEP 260283 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.078741 / Loss  0.0625089779496193
# fps: 8.819660066069059
# TIMESTEP 260284 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.730772 / Loss  0.04796802997589111
# fps: 8.573977391197694
# TIMESTEP 260285 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.255866 / Loss  0.019645828753709793
# fps: 9.100425046269075
# TIMESTEP 260286 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.251906 / Loss  0.031921062618494034
# fps: 8.87003819296116
# TIMESTEP 260287 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.677777 / Loss  1.7350585460662842
# fps: 8.8932275156956
# TIMESTEP 260288 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.061725 / Loss  0.10118377208709717
# fps: 7.794727696782167
# TIMESTEP 260289 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.263657 / Loss  0.03167836368083954
# fps: 9.019329727869945
# TIMESTEP 260290 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.355099 / Loss  0.04444717615842819
# fps: 8.590853882092215
# TIMESTEP 260291 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.353058 / Loss  0.026096787303686142
# fps: 9.130318558411084
# TIMESTEP 260292 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.24767 / Loss  0.028131552040576935
# fps: 8.939038217266395
# TIMESTEP 260293 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.924223 / Loss  0.03593560308218002
# fps: 8.956637980738432
# TIMESTEP 260294 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.701983 / Loss  0.03624185919761658
# fps: 8.96282002790795
# TIMESTEP 260295 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.54466 / Loss  0.01800413429737091
# fps: 8.831898657412866
# TIMESTEP 260296 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.364744 / Loss  0.020969586446881294
# fps: 8.62642117906445
# TIMESTEP 260297 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.324608 / Loss  0.01436060294508934
# fps: 9.063043440681774
# TIMESTEP 260298 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.141174 / Loss  0.01721661165356636
# fps: 8.663321938675397
# TIMESTEP 260299 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.477605 / Loss  0.05118212848901749
# fps: 8.68968832094407
# TIMESTEP 260300 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.649092 / Loss  0.02415144257247448
# fps: 7.520447536398192
# TIMESTEP 260301 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.623023 / Loss  0.026135284453630447
# fps: 8.843835593331127
# TIMESTEP 260302 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.67849 / Loss  1.5849778652191162
# fps: 8.599502191750489
# TIMESTEP 260303 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.391702 / Loss  0.025371812283992767
# fps: 7.672474568706109
# TIMESTEP 260304 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.324965 / Loss  0.0190291590988636
# fps: 8.628728249733586
# TIMESTEP 260305 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.595033 / Loss  0.05031987279653549
# fps: 8.66162233603172
# TIMESTEP 260306 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.527554 / Loss  0.07292507588863373
# fps: 8.546670117146508
# ...
# fps: 8.31366859131786
# TIMESTEP 260773 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.202886 / Loss  0.04783635586500168
# fps: 7.330405345180441
# TIMESTEP 260774 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.442094 / Loss  0.022145526483654976
# fps: 8.013159428153305
# TIMESTEP 260775 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.596783 / Loss  0.04283953085541725
# fps: 8.34843532919591
# TIMESTEP 260776 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.612584 / Loss  0.025629382580518723
# fps: 8.117609717200963
# TIMESTEP 260777 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.149639 / Loss  0.026684369891881943
# fps: 8.559245110523394
# TIMESTEP 260778 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.677536 / Loss  0.012250801548361778
# fps: 8.4287287488445
# TIMESTEP 260779 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.603076 / Loss  0.016793500632047653
# fps: 7.665071263183095
# TIMESTEP 260780 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.65614 / Loss  0.07215636223554611
# fps: 8.575888247549997
# TIMESTEP 260781 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.612742 / Loss  0.01642823964357376
# fps: 8.82723321863392
# TIMESTEP 260782 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.684734 / Loss  0.03456805646419525
# fps: 8.418848503825743
# TIMESTEP 260783 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.263666 / Loss  4.230529308319092
# fps: 8.923462495026923
# TIMESTEP 260784 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.618704 / Loss  0.015558384358882904
# fps: 8.56391126356518
# TIMESTEP 260785 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.499565 / Loss  0.007515073753893375
# fps: 8.526377202843546
# TIMESTEP 260786 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.230462 / Loss  0.02516062930226326
# fps: 5.932352882937165
# TIMESTEP 260787 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.492329 / Loss  0.023934077471494675
# fps: 8.77267574407563
# TIMESTEP 260788 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.295616 / Loss  0.3192474842071533
# fps: 8.364084504233587
# TIMESTEP 260789 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.545104 / Loss  0.012484634295105934
# fps: 8.968051760339025
# TIMESTEP 260790 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.777885 / Loss  0.4768519103527069
# fps: 8.820605999427984
# TIMESTEP 260791 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.872337 / Loss  0.019025903195142746
# fps: 8.721507958786896
# TIMESTEP 260792 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.756424 / Loss  0.028207845985889435
# fps: 8.816471354850915
# TIMESTEP 260793 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.919046 / Loss  0.032599933445453644
# fps: 8.796852322586599
# TIMESTEP 260794 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.844589 / Loss  0.014540590345859528
# fps: 8.145908793409168
# TIMESTEP 260795 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.1810255 / Loss  0.012467880733311176
# fps: 8.534531418188182
# TIMESTEP 260796 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.872421 / Loss  0.03513457626104355
# fps: 8.92063465055936
# TIMESTEP 260797 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.767943 / Loss  0.020392989739775658
# fps: 8.755571513263916
# TIMESTEP 260798 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.276628 / Loss  0.021366849541664124
# fps: 8.67574030100196
# TIMESTEP 260799 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.2711 / Loss  0.17834514379501343
# fps: 8.880198000935804
# TIMESTEP 260800 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.631588 / Loss  0.01927429810166359
# fps: 8.496961249858192
# TIMESTEP 260801 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.089584 / Loss  0.161875918507576
# fps: 8.861324200816771
# TIMESTEP 260802 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.163144 / Loss  0.021035078912973404
# fps: 8.627521320404645
# TIMESTEP 260803 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.766948 / Loss  0.01442425325512886
# fps: 8.694137375655277
# TIMESTEP 260804 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.225314 / Loss  0.02851148694753647
# fps: 8.566254996109315
# TIMESTEP 260805 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.3671255 / Loss  0.022220056504011154
# fps: 7.223600205979963
# TIMESTEP 260806 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.05191 / Loss  0.05330941826105118
# fps: 8.244024301795116
# TIMESTEP 260807 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.566579 / Loss  0.02965041995048523
# fps: 8.78688222367007
# TIMESTEP 260808 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.114293 / Loss  0.024147111922502518
# fps: 8.357717874734979
# TIMESTEP 260809 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.022078 / Loss  0.03782379627227783
# fps: 8.186307957748129
# TIMESTEP 260810 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.41194 / Loss  0.02369675412774086
# fps: 8.13920643637655
# TIMESTEP 260811 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.273085 / Loss  0.01801154762506485
# fps: 7.7646989129468915
# TIMESTEP 260812 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.010412 / Loss  0.03368386998772621
# fps: 8.292694693178696
# TIMESTEP 260813 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.66177 / Loss  2.589096784591675
# fps: 9.163631279057574
# TIMESTEP 260814 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.090863 / Loss  0.08192434906959534
# fps: 8.964831510146155
# TIMESTEP 260815 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.872404 / Loss  0.033669374883174896
# fps: 8.613435903965302
# TIMESTEP 260816 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.012077 / Loss  0.007449738681316376
# fps: 8.705722653371717
# TIMESTEP 260817 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.850074 / Loss  0.017625072970986366
# fps: 9.26191385763655
# TIMESTEP 260818 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.537767 / Loss  0.10874054580926895
# fps: 8.119401135936878
# TIMESTEP 260819 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.224546 / Loss  0.04079608619213104
# fps: 8.578220996915828
# TIMESTEP 260820 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.185064 / Loss  0.027927540242671967
# fps: 8.288433986835111
# TIMESTEP 260821 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.894302 / Loss  0.07473232597112656
# fps: 7.580702239524876
# TIMESTEP 260822 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.292791 / Loss  0.02964359149336815
# fps: 5.255993704292209
# TIMESTEP 260823 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.115137 / Loss  0.04959314316511154
# fps: 9.07300274290263
# TIMESTEP 260824 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.214897 / Loss  0.21478989720344543
# fps: 8.659744603536735
# TIMESTEP 260825 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.941889 / Loss  1.7924913167953491
# fps: 8.870919915823313
# TIMESTEP 260826 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.220428 / Loss  0.023934461176395416
# fps: 8.686898728540628
# TIMESTEP 260827 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.24163 / Loss  0.03594371676445007
# fps: 8.632670870860983
# TIMESTEP 260828 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.34703 / Loss  0.01461887639015913
# fps: 8.931747569714329
# TIMESTEP 260829 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.101248 / Loss  0.04470844566822052
# fps: 8.724573891410433
# TIMESTEP 260830 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.796467 / Loss  0.11865317076444626
# fps: 8.462400129125978
# TIMESTEP 260831 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.900523 / Loss  0.024204691872000694
# fps: 8.864058362444815
# TIMESTEP 260832 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.032866 / Loss  0.01922934502363205
# fps: 8.59131140119991
# TIMESTEP 260833 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.2241125 / Loss  0.012735049240291119
# fps: 8.900379840848807
# TIMESTEP 260834 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.802113 / Loss  0.012661338783800602
# fps: 8.71400642803571
# TIMESTEP 260835 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.564002 / Loss  0.05566316470503807
# fps: 9.028687792350926
# TIMESTEP 260836 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.930253 / Loss  0.06780518591403961
# fps: 8.534236206629933
# TIMESTEP 260837 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.715748 / Loss  0.23425325751304626
# fps: 9.282123801367211
# TIMESTEP 260838 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.073564 / Loss  0.029091257601976395
# fps: 8.828868349096021
# TIMESTEP 260839 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.910382 / Loss  0.013429337181150913
# fps: 8.691489008985114
# TIMESTEP 260840 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.177921 / Loss  0.0386355035007
# fps: 9.172970348565105
# TIMESTEP 260841 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.099643 / Loss  0.013742130249738693
# fps: 9.163451097939575
# TIMESTEP 260842 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.744613 / Loss  0.03198959305882454
# fps: 8.195777741302631
# TIMESTEP 260843 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.09602 / Loss  0.016185693442821503
# fps: 9.222202922131462
# TIMESTEP 260844 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.99857 / Loss  0.02054246887564659
# fps: 8.883056702155372
# TIMESTEP 260845 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.866179 / Loss  0.03015957772731781
# fps: 8.71915101497781
# TIMESTEP 260846 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.320278 / Loss  0.02273239567875862
# fps: 8.73329363311165
# TIMESTEP 260847 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.453127 / Loss  0.03758695721626282
# fps: 8.816415758253493
# TIMESTEP 260848 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.734406 / Loss  0.046652328222990036
# fps: 8.555473964197713
# TIMESTEP 260849 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.1457615 / Loss  0.17029468715190887
# fps: 9.292653044042742
# TIMESTEP 260850 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.072299 / Loss  0.05034113675355911
# fps: 8.777173469494523
# TIMESTEP 260851 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.908305 / Loss  0.03683806210756302
# fps: 8.980129104086155
# TIMESTEP 260852 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.047459 / Loss  0.06843148171901703
# fps: 9.071629098050412
# TIMESTEP 260853 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.448871 / Loss  0.04081983119249344
# fps: 9.273442820125052
# TIMESTEP 260854 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.467557 / Loss  0.014206564985215664
# fps: 8.757655607291253
# TIMESTEP 260855 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.389836 / Loss  0.053883589804172516
# fps: 9.406821133087677
# TIMESTEP 260856 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.121535 / Loss  0.007372512482106686
# fps: 8.906219675076072
# TIMESTEP 260857 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.913591 / Loss  0.033597130328416824
# fps: 8.668227688784821
# TIMESTEP 260858 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.856685 / Loss  0.017047274857759476
# fps: 6.270928116809624
# TIMESTEP 260859 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.994624 / Loss  0.030977191403508186
# fps: 9.069549798901527
# TIMESTEP 260860 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.77815 / Loss  0.09864912182092667
# fps: 8.554845762863973
# TIMESTEP 260861 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.029499 / Loss  0.015937820076942444
# fps: 9.277729974363115
# TIMESTEP 260862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-72cb52f7ef17> in <module>
# ----> 1 play_Game(observe=False);
#
# <ipython-input-51-5ba40716cf16> in play_Game(observe)
#       8     q_target = build_model()
#       9     try:
# ---> 10         train_Network(q_eval,q_target,game_state,observe=observe)
#      11     except StopIteration:
#      12         game.end()
#
# <ipython-input-50-53c72357d4c6> in train_Network(q_eval, q_target, game_state, observe)
#     150             state = "train"
#     151
# --> 152         print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX ", np.max(Q_sa), "/ Loss ", loss)
#     153
#     154     print("Episode finished!")
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     393                                  copy_threshold=self.copy_threshold)
#     394             data.group = group
# --> 395         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     396
#     397     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# KeyboardInterrupt:
