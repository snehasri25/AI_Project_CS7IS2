# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

import numpy as np
import pandas as pd
from PIL import Image
import cv2  #opencv
from IPython.display import clear_output
from random import randint
import io
from io import BytesIO
import time
import os

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.callbacks import TensorBoard
from keras.optimizers import SGD , Adam
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D


from collections import deque
import random
import pickle
import _pickle as cPickle
import base64
import json

# %%
#path variables
game_url = "chrome://dino"
chromedriver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects_ddqn/loss_df.csv"
actions_file_path = "./objects_ddqn/actions_df.csv"
q_value_file_path = "./objects_ddqn/q_values.csv"
scores_file_path = "./objects_ddqn/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chromedriver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class Dino_Agent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_state:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        game_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            game_over = True
        return image, reward, game_over #return the Experience tuple

# %%
def save_object(obj, name):
    with open('objects_ddqn/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_object(name):
    with open('objects_ddqn/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = img_process(screen)#processing image as required
    return image

def img_process(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100 # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH_SIZE = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_object(INITIAL_EPSILON,"epsilon")
    t = 0
    save_object(t,"time")
    D = deque()
    save_object(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %%
def build_model():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model_ddqn.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate whether the model is to be trained(weight updates), else just play
'''
def train_Network(q_eval,q_target,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_object("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_object("epsilon") 
        q_eval.load_weights("model_ddqn.h5")
        adam = Adam(lr=LEARNING_RATE)
        q_eval.compile(loss='mse',optimizer=adam)

    t = load_object("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0

        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = q_target.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        
        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH_SIZE)
            inputs = np.zeros((BATCH_SIZE, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    
                
                #q_next = q_target.predict(state_t1)
                #q_eval = q_eval.predict(state_t1)
                #q_pred = q_eval.predict(state_t)
                
                #targets[i] = q_pred
                Q_sa = q_target.predict(state_t1)      #predict q values for next step
                #old_q = q_eval.predict(state_t1)
                targets[i] = q_target.predict(state_t)  # predicted q values
                #max_Actions = np.argmax(old_q)
                q_eval = q_target
                #q_target  = targets[i]

                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    #targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += q_target.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 
            q_target.set_weights(q_eval.get_weights())

        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            q_target.save_weights("model_ddqn.h5", overwrite=True)
            save_object(D,"D") #saving episodes
            save_object(t,"time") #caching time steps
            save_object(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects_ddqn/loss_df.csv",index=False)
            scores_df.to_csv("./objects_ddqn/scores_df.csv",index=False)
            actions_df.to_csv("./objects_ddqn/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model_ddqn.json", "w") as outfile:
                json.dump(q_target.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX ", np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def play_Game(observe=False):
    game = Game()
    dino = Dino_Agent(game)
    game_state = Game_state(dino,game)    
    #model = build_model()
    q_eval = build_model()
    q_target = build_model()
    try:
        train_Network(q_eval,q_target,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
play_Game(observe=False);
# Out:
# TIMESTEP 213000 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.996299 / Loss  0.023960581049323082
# fps: 0.17466138489610003
# TIMESTEP 213001 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.763978 / Loss  0.5595617294311523
# fps: 8.119919852094203
# TIMESTEP 213002 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.618349 / Loss  0.07007310539484024
# fps: 7.720762080073631
# TIMESTEP 213003 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.033579 / Loss  0.048007577657699585
# fps: 7.872458153616301
# TIMESTEP 213004 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.463142 / Loss  0.23840101063251495
# fps: 7.395352937650092
# TIMESTEP 213005 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.454078 / Loss  0.03008529543876648
# fps: 7.235151247516008
# TIMESTEP 213006 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.712619 / Loss  0.06453657150268555
# fps: 7.283902249267148
# TIMESTEP 213007 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.577487 / Loss  0.08104445040225983
# fps: 7.634530184606088
# TIMESTEP 213008 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.418588 / Loss  0.020449373871088028
# fps: 6.351224195289775
# TIMESTEP 213009 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.753962 / Loss  0.11515188217163086
# fps: 7.231134726584993
# TIMESTEP 213010 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.712767 / Loss  0.07830370962619781
# fps: 6.39426295986877
# TIMESTEP 213011 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.694828 / Loss  0.2547374665737152
# fps: 5.527854731020958
# TIMESTEP 213012 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.409883 / Loss  0.12519009411334991
# fps: 7.168255509107502
# TIMESTEP 213013 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.529029 / Loss  0.05826135724782944
# fps: 6.086614047537161
# TIMESTEP 213014 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.3429165 / Loss  0.04345615953207016
# fps: 5.953234867474189
# TIMESTEP 213015 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.981268 / Loss  0.07613689452409744
# fps: 5.831439944275829
# TIMESTEP 213016 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.827664 / Loss  0.22232475876808167
# fps: 6.428800902480596
# TIMESTEP 213017 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.632556 / Loss  0.10998551547527313
# fps: 5.658542376631401
# TIMESTEP 213018 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.454458 / Loss  0.013770610094070435
# fps: 7.092544743712883
# TIMESTEP 213019 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.49155 / Loss  1.0680756568908691
# fps: 6.738270732255888
# TIMESTEP 213020 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.245007 / Loss  0.07669823616743088
# fps: 7.2348392460719255
# TIMESTEP 213021 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.952878 / Loss  0.18670041859149933
# fps: 6.938376332488569
# TIMESTEP 213022 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.551809 / Loss  0.09493817389011383
# fps: 6.717399590643088
# TIMESTEP 213023 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.506207 / Loss  0.07687608897686005
# fps: 6.5614635039179765
# TIMESTEP 213024 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.930588 / Loss  0.09403599798679352
# fps: 5.51176454355148
# TIMESTEP 213025 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.7078085 / Loss  0.0767962709069252
# fps: 6.357192549558712
# TIMESTEP 213026 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.429542 / Loss  0.0364111103117466
# fps: 6.565767187319
# TIMESTEP 213027 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.337859 / Loss  0.04789876192808151
# fps: 5.117794700281739
# TIMESTEP 213028 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.1632595 / Loss  0.13354621827602386
# fps: 5.598160242062173
# TIMESTEP 213029 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.265979 / Loss  0.22456754744052887
# fps: 7.3584538893118925
# TIMESTEP 213030 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.898687 / Loss  0.04511649161577225
# fps: 7.306895230131354
# TIMESTEP 213031 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.456064 / Loss  0.10380081832408905
# fps: 7.0894397990625855
# TIMESTEP 213032 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.621884 / Loss  1.2720681428909302
# fps: 7.197815756822757
# TIMESTEP 213033 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.924377 / Loss  0.0867699608206749
# fps: 6.803269355228519
# TIMESTEP 213034 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.130177 / Loss  0.07574474811553955
# fps: 7.107062491527722
# TIMESTEP 213035 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.350385 / Loss  0.028895795345306396
# fps: 6.144060000585943
# TIMESTEP 213036 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.673758 / Loss  0.06586755067110062
# fps: 7.129459838927361
# TIMESTEP 213037 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.460976 / Loss  0.03420444577932358
# fps: 7.111255789980536
# TIMESTEP 213038 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.142138 / Loss  0.10869161784648895
# fps: 5.508391348486222
# TIMESTEP 213039 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.053788 / Loss  0.05076398327946663
# fps: 6.702778718861665
# TIMESTEP 213040 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.26409 / Loss  0.0963834598660469
# fps: 6.671147707336935
# TIMESTEP 213041 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.947781 / Loss  0.07218705862760544
# fps: 6.729384131099566
# TIMESTEP 213042 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.661698 / Loss  0.0724809467792511
# fps: 6.3570480214856895
# TIMESTEP 213043 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.166324 / Loss  0.2577020525932312
# fps: 6.933375651299955
# TIMESTEP 213044 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.033789 / Loss  0.027006912976503372
# fps: 7.382206545997282
# TIMESTEP 213045 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.84468 / Loss  0.15411633253097534
# fps: 6.145869568721344
# TIMESTEP 213046 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.807491 / Loss  0.07155726850032806
# fps: 7.176080098000972
# TIMESTEP 213047 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.069163 / Loss  0.08285368233919144
# fps: 7.00657507884749
# TIMESTEP 213048 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.821517 / Loss  0.1715882569551468
# fps: 6.719304344482768
# TIMESTEP 213049 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.1390955 / Loss  0.051462411880493164
# fps: 7.321282196295288
# TIMESTEP 213050 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.439082 / Loss  0.024128859862685204
# fps: 7.3297648319116995
# TIMESTEP 213051 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.904503 / Loss  0.13406455516815186
# fps: 7.638131069861799
# TIMESTEP 213052 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.826013 / Loss  0.07942214608192444
# fps: 6.818398914077169
# TIMESTEP 213053 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.066492 / Loss  0.029794488102197647
# fps: 7.230187378255848
# TIMESTEP 213054 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.095705 / Loss  0.2567805349826813
# fps: 6.417469429722022
# TIMESTEP 213055 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.43144 / Loss  0.13186787068843842
# fps: 7.870537724802594
# TIMESTEP 213056 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.889511 / Loss  0.05819772928953171
# fps: 6.910654059014751
# TIMESTEP 213057 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.903764 / Loss  0.13216005265712738
# fps: 7.1643006601815715
# TIMESTEP 213058 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.547363 / Loss  1.2578473091125488
# fps: 7.75390440132513
# TIMESTEP 213059 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.907036 / Loss  0.10152314603328705
# fps: 7.10055341027017
# TIMESTEP 213060 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.011607 / Loss  0.09153337776660919
# fps: 7.803733762005232
# TIMESTEP 213061 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.159075 / Loss  0.07726117223501205
# fps: 7.961988720384365
# TIMESTEP 213062 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.0330925 / Loss  0.14231353998184204
# fps: 6.315039515069025
# TIMESTEP 213063 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.278325 / Loss  0.09019312262535095
# fps: 4.7485177524406
# TIMESTEP 213064 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.815002 / Loss  0.03442515432834625
# fps: 7.347548542158628
# TIMESTEP 213065 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.317313 / Loss  0.19050033390522003
# fps: 7.05083834006314
# TIMESTEP 213066 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  11.259158 / Loss  0.05425041913986206
# fps: 8.421756031740932
# TIMESTEP 213067 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.76848 / Loss  0.08350808173418045
# fps: 8.19835692910323
# TIMESTEP 213068 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.369232 / Loss  0.15674346685409546
# fps: 8.098659782468077
# TIMESTEP 213069 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.340278 / Loss  0.04253888875246048
# fps: 7.963122441695335
# TIMESTEP 213070 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -3.332007 / Loss  0.6853179335594177
# fps: 8.60098348419166
# TIMESTEP 213071 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.494028 / Loss  0.04092377796769142
# fps: 8.70702386265738
# TIMESTEP 213072 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.709634 / Loss  0.08278656005859375
# fps: 8.980379058434607
# TIMESTEP 213073 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.379985 / Loss  0.3075334429740906
# fps: 8.662803041881638
# TIMESTEP 213074 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.327925 / Loss  0.6370158195495605
# fps: 8.972003559449654
# TIMESTEP 213075 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.325373 / Loss  0.04516972601413727
# fps: 8.72560844953806
# TIMESTEP 213076 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.800862 / Loss  5.295778274536133
# fps: 8.565222896117952
# TIMESTEP 213077 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.434151 / Loss  0.03404237702488899
# fps: 8.620765207025189
# TIMESTEP 213078 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.073511 / Loss  0.7463295459747314
# fps: 9.749343350053694
# TIMESTEP 213079 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.031001 / Loss  0.12126191705465317
# fps: 9.19819645958701
# TIMESTEP 213080 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.780748 / Loss  0.052501000463962555
# fps: 8.910268584551131
# TIMESTEP 213081 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.675714 / Loss  0.9794774651527405
# fps: 8.861380365246639
# TIMESTEP 213082 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.576311 / Loss  0.07711785286664963
# fps: 8.944299435317399
# TIMESTEP 213083 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.312241 / Loss  0.036485254764556885
# fps: 8.885239581148728
# TIMESTEP 213084 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.188065 / Loss  0.05370054766535759
# fps: 9.17945474401595
# TIMESTEP 213085 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.601469 / Loss  0.06912293285131454
# fps: 8.961364660939273
# TIMESTEP 213086 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.235081 / Loss  0.160264253616333
# fps: 8.74363453672936
# TIMESTEP 213087 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.10056 / Loss  0.04581348970532417
# fps: 8.850983371317634
# TIMESTEP 213088 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.764417 / Loss  0.15145236253738403
# fps: 8.831861463110595
# TIMESTEP 213089 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.366917 / Loss  0.0610114187002182
# fps: 8.710423299212714
# TIMESTEP 213090 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.648204 / Loss  0.05895484238862991
# fps: 8.911536990608932
# TIMESTEP 213091 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.86214 / Loss  0.03617885336279869
# fps: 8.766863074199408
# TIMESTEP 213092 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.922166 / Loss  0.04120825231075287
# fps: 9.158768874671091
# TIMESTEP 213093 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.939024 / Loss  0.046127885580062866
# fps: 8.62737935091595
# TIMESTEP 213094 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.768468 / Loss  0.10801199078559875
# fps: 9.028940457226504
# TIMESTEP 213095 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.726158 / Loss  0.016624629497528076
# fps: 7.31662064309725
# TIMESTEP 213096 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.713291 / Loss  0.07957463711500168
# fps: 8.402303755120847
# TIMESTEP 213097 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.922604 / Loss  0.048687808215618134
# fps: 8.051847528949228
# TIMESTEP 213098 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.854936 / Loss  0.026473069563508034
# fps: 7.768740218005353
# TIMESTEP 213099 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.00295 / Loss  0.031236832961440086
# fps: 5.417240662265854
# TIMESTEP 213100 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.412268 / Loss  0.06523081660270691
# fps: 8.225173796660359
# TIMESTEP 213101 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.746233 / Loss  0.06368102133274078
# fps: 8.212885110182535
# TIMESTEP 213102 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.596818 / Loss  0.03765951842069626
# fps: 8.404644060868137
# TIMESTEP 213103 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.878822 / Loss  0.04208490252494812
# fps: 8.487040698015585
# TIMESTEP 213104 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.509787 / Loss  0.41735756397247314
# fps: 7.144482164788125
# TIMESTEP 213105 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.310616 / Loss  0.03906213492155075
# fps: 8.208898787738821
# TIMESTEP 213106 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.301807 / Loss  0.1366686224937439
# fps: 7.695970642201835
# TIMESTEP 213107 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.519895 / Loss  0.029320545494556427
# fps: 7.370673733378086
# TIMESTEP 213108 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.262346 / Loss  0.19311784207820892
# fps: 7.810840153821801
# TIMESTEP 213109 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.901324 / Loss  0.02574940212070942
# fps: 8.378302687694136
# TIMESTEP 213110 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.05607 / Loss  0.5540786385536194
# fps: 8.450584587363725
# TIMESTEP 213111 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.462288 / Loss  0.05561742186546326
# fps: 8.402286923110825
# TIMESTEP 213112 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.5529785 / Loss  0.044204264879226685
# fps: 8.545329340097386
# TIMESTEP 213113 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.531838 / Loss  0.05284072458744049
# fps: 7.374691204990655
# TIMESTEP 213114 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.865895 / Loss  1.8018510341644287
# fps: 9.025016030399662
# TIMESTEP 213115 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.882122 / Loss  0.30215585231781006
# fps: 9.067491055311146
# TIMESTEP 213116 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.414606 / Loss  0.01852809265255928
# fps: 7.549442202535017
# TIMESTEP 213117 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.319879 / Loss  0.07150093466043472
# fps: 8.179953740000078
# TIMESTEP 213118 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.560339 / Loss  0.24264849722385406
# fps: 8.556294254805682
# TIMESTEP 213119 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.410381 / Loss  0.07666436582803726
# fps: 8.414659786699621
# TIMESTEP 213120 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.265338 / Loss  0.04382568597793579
# fps: 8.90410208617714
# TIMESTEP 213121 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.201879 / Loss  1.38283109664917
# fps: 7.633696487006913
# TIMESTEP 213122 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.857186 / Loss  0.011234637349843979
# fps: 8.818269356106955
# TIMESTEP 213123 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.45826 / Loss  0.03353675454854965
# fps: 7.459630389121183
# TIMESTEP 213124 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.773547 / Loss  0.051942989230155945
# fps: 8.74042769560343
# TIMESTEP 213125 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.513206 / Loss  0.02420395240187645
# fps: 7.479210763291399
# TIMESTEP 213126 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.807889 / Loss  0.06035545468330383
# fps: 8.847678654676548
# TIMESTEP 213127 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.093322 / Loss  0.07295266538858414
# fps: 8.8588910925385
# TIMESTEP 213128 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.212874 / Loss  0.05815436318516731
# fps: 8.626119576417068
# TIMESTEP 213129 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.532205 / Loss  0.21638189256191254
# fps: 8.74363453672936
# TIMESTEP 213130 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.705399 / Loss  0.06113704293966293
# fps: 7.483681261820648
# TIMESTEP 213131 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.89884 / Loss  0.032494738698005676
# fps: 8.665362342494593
# TIMESTEP 213132 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.707826 / Loss  4.613466739654541
# fps: 8.985939331095224
# TIMESTEP 213133 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.731507 / Loss  0.03674984350800514
# fps: 7.576142480401719
# TIMESTEP 213134 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.331624 / Loss  0.05331612750887871
# fps: 7.456898375566472
# TIMESTEP 213135 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.918617 / Loss  1.0121850967407227
# fps: 5.930566219149222
# TIMESTEP 213136 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.720854 / Loss  0.05044108256697655
# fps: 8.011368671974084
# TIMESTEP 213137 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.467219 / Loss  0.04662208631634712
# fps: 8.95271881236726
# TIMESTEP 213138 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.798315 / Loss  0.04975850135087967
# fps: 9.126504110328261
# TIMESTEP 213139 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.0925865 / Loss  0.09049999713897705
# fps: 7.70827559590539
# TIMESTEP 213140 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.723439 / Loss  0.03365960344672203
# fps: 7.586488564116014
# TIMESTEP 213141 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.301594 / Loss  0.018482433632016182
# fps: 8.562075652724193
# TIMESTEP 213142 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.575517 / Loss  0.034747228026390076
# fps: 8.97941777170725
# TIMESTEP 213143 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.340885 / Loss  0.05865054577589035
# fps: 7.590181615502103
# TIMESTEP 213144 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.723986 / Loss  0.07476362586021423
# fps: 7.580359724712278
# TIMESTEP 213145 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.256171 / Loss  0.04072018712759018
# fps: 7.247390420107372
# TIMESTEP 213146 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.800494 / Loss  0.04587257280945778
# fps: 7.7460570736283785
# TIMESTEP 213147 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.253355 / Loss  0.06082683429121971
# fps: 8.600507298828537
# TIMESTEP 213148 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.23065 / Loss  0.050426118075847626
# fps: 9.093578586326364
# TIMESTEP 213149 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.9687805 / Loss  0.02778395637869835
# fps: 8.618232178154756
# TIMESTEP 213150 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.540601 / Loss  0.029059788212180138
# fps: 9.012449773308408
# TIMESTEP 213151 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.125347 / Loss  0.06492888182401657
# fps: 8.783661981269582
# TIMESTEP 213152 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.937401 / Loss  0.057886600494384766
# fps: 8.923101797681097
# TIMESTEP 213153 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.556329 / Loss  0.021764229983091354
# fps: 8.926406115656045
# TIMESTEP 213154 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.085261 / Loss  0.10496062785387039
# fps: 9.152133924811308
# TIMESTEP 213155 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.730103 / Loss  0.08397190272808075
# fps: 8.795229028442975
# TIMESTEP 213156 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.139427 / Loss  0.048969969153404236
# fps: 9.112129289874625
# TIMESTEP 213157 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.147464 / Loss  0.02140839770436287
# fps: 8.780260290518886
# TIMESTEP 213158 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.471948 / Loss  0.056559592485427856
# fps: 9.002932072928338
# TIMESTEP 213159 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.006139 / Loss  0.03801488131284714
# fps: 7.7219418705481
# TIMESTEP 213160 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.9346485 / Loss  0.03896293416619301
# fps: 8.912673183170421
# TIMESTEP 213161 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.908636 / Loss  0.045756153762340546
# fps: 8.743616309394016
# TIMESTEP 213162 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.979217 / Loss  0.05225309729576111
# fps: 8.056332617522886
# TIMESTEP 213163 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.389107 / Loss  0.05703892186284065
# fps: 8.897283491792777
# TIMESTEP 213164 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.9111805 / Loss  0.028392549604177475
# fps: 8.946798775610329
# TIMESTEP 213165 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.12481 / Loss  0.057487815618515015
# fps: 8.843611828580466
# TIMESTEP 213166 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  8.447752 / Loss  0.05961509793996811
# fps: 9.162950632009892
# TIMESTEP 213167 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.536264 / Loss  0.5819889903068542
# fps: 8.82868250830918
# TIMESTEP 213168 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.326401 / Loss  0.031549207866191864
# fps: 8.997563068474344
# TIMESTEP 213169 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.419012 / Loss  0.17263193428516388
# fps: 8.983764425671913
# TIMESTEP 213170 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.62629 / Loss  0.15409383177757263
# fps: 8.853692465196787
# TIMESTEP 213171 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.661186 / Loss  0.0918152928352356
# fps: 6.192755857148763
# TIMESTEP 213172 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.610207 / Loss  0.1037435382604599
# fps: 8.769465904220286
# TIMESTEP 213173 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  10.455529 / Loss  0.048434171825647354
# fps: 8.841039347572684
# TIMESTEP 213174 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.679834 / Loss  0.09419067949056625
# fps: 8.812821999781482
# TIMESTEP 213175 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.0117445 / Loss  0.0665053203701973
# fps: 8.862035669538063
# TIMESTEP 213176 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.630316 / Loss  0.05812535807490349
# fps: 9.000092268936053
# TIMESTEP 213177 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.039778 / Loss  0.07757119834423065
# fps: 9.05568605775874
# TIMESTEP 213178 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.18488 / Loss  0.09963715076446533
# fps: 9.206838117147097
# TIMESTEP 213179 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.709437 / Loss  0.11405934393405914
# fps: 8.873040520243197
# TIMESTEP 213180 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.1315 / Loss  0.4742668867111206
# fps: 9.237619095862534
# TIMESTEP 213181 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.296435 / Loss  0.11483129113912582
# fps: 9.211589861396924
# TIMESTEP 213182 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.430087 / Loss  0.03813452646136284
# fps: 8.839474222176326
# TIMESTEP 213183 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.498147 / Loss  0.052026066929101944
# fps: 8.637079503146518
# TIMESTEP 213184 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.190567 / Loss  0.06056950241327286
# fps: 9.10566055758902
# TIMESTEP 213185 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.793763 / Loss  0.06855183839797974
# fps: 8.657331571994716
# TIMESTEP 213186 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.539345 / Loss  0.10721923410892487
# fps: 9.154231288003457
# TIMESTEP 213187 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.256416 / Loss  0.40903329849243164
# fps: 8.850889983856844
# TIMESTEP 213188 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.256685 / Loss  0.06594888865947723
# fps: 9.000575102359637
# TIMESTEP 213189 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.892282 / Loss  0.11710536479949951
# fps: 8.866325624656492
# TIMESTEP 213190 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.803846 / Loss  0.08197284489870071
# fps: 8.80715944548734
# TIMESTEP 213191 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.718466 / Loss  0.08026660978794098
# fps: 8.470398164678132
# TIMESTEP 213192 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.8830185 / Loss  0.07541164755821228
# fps: 8.955834749707472
# TIMESTEP 213193 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.9329 / Loss  0.04924246668815613
# fps: 8.825190157070265
# TIMESTEP 213194 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.709589 / Loss  0.07028898596763611
# fps: 8.702832469130422
# TIMESTEP 213195 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.880799 / Loss  0.09665338695049286
# fps: 8.982302249481746
# TIMESTEP 213196 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.412582 / Loss  0.15143005549907684
# fps: 9.35840030701539
# TIMESTEP 213197 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.916737 / Loss  0.05358382686972618
# fps: 8.112208821049212
# TIMESTEP 213198 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.736169 / Loss  0.1552359163761139
# fps: 8.116604354859934
# TIMESTEP 213199 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.532032 / Loss  0.0775744616985321
# fps: 8.872402355648818
# TIMESTEP 213200 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.187099 / Loss  0.14013998210430145
# fps: 8.976496723409538
# TIMESTEP 213201 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.9905205 / Loss  0.06741424649953842
# fps: 8.52028041351039
# TIMESTEP 213202 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.689004 / Loss  0.08130207657814026
# fps: 8.51478001019101
# TIMESTEP 213203 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.190016 / Loss  0.10055258870124817
# fps: 8.656974200206399
# TIMESTEP 213204 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.207709 / Loss  0.1637052297592163
# fps: 8.859508601169354
# TIMESTEP 213205 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.809044 / Loss  0.09719599783420563
# fps: 7.74125342369678
# TIMESTEP 213206 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.182745 / Loss  0.4804959297180176
# fps: 8.873284548614416
# TIMESTEP 213207 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.654757 / Loss  0.13363945484161377
# fps: 5.944872883337846
# TIMESTEP 213208 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.925291 / Loss  0.04615205526351929
# fps: 7.837842787334037
# TIMESTEP 213209 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.439817 / Loss  0.08138087391853333
# fps: 7.597977642478928
# TIMESTEP 213210 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.411328 / Loss  0.20354095101356506
# fps: 8.909303323434825
# TIMESTEP 213211 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.464188 / Loss  0.11289010941982269
# fps: 7.5344297044109325
# TIMESTEP 213212 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.686798 / Loss  0.07022031396627426
# fps: 7.64544059263364
# TIMESTEP 213213 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.320384 / Loss  0.12640073895454407
# fps: 7.462298021940484
# TIMESTEP 213214 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.176734 / Loss  0.07517426460981369
# fps: 8.702525499829862
# TIMESTEP 213215 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.61238 / Loss  0.08791345357894897
# fps: 7.339718227045794
# TIMESTEP 213216 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.383017 / Loss  0.10335556417703629
# fps: 9.162890579771883
# TIMESTEP 213217 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.899153 / Loss  0.07478725910186768
# fps: 8.828143614267132
# TIMESTEP 213218 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.28129 / Loss  0.07074613124132156
# fps: 8.786863815577222
# TIMESTEP 213219 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.828796 / Loss  0.04132827743887901
# fps: 8.616231606582701
# TIMESTEP 213220 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.918503 / Loss  0.06932799518108368
# fps: 9.07761730898671
# TIMESTEP 213221 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.900771 / Loss  0.0685422420501709
# fps: 8.714205577185977
# TIMESTEP 213222 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.594953 / Loss  0.15904207527637482
# fps: 8.871220116793817
# TIMESTEP 213223 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.324723 / Loss  0.07196758687496185
# fps: 7.517280067388947
# TIMESTEP 213224 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.780795 / Loss  1.1562254428863525
# fps: 8.975305788802437
# TIMESTEP 213225 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.420036 / Loss  0.07144047319889069
# fps: 8.934791824214216
# TIMESTEP 213226 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.840733 / Loss  0.07819410413503647
# fps: 8.881702351130038
# TIMESTEP 213227 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.640965 / Loss  0.1350730061531067
# fps: 8.764408299046517
# TIMESTEP 213228 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.34816 / Loss  0.14167794585227966
# fps: 9.115277958882078
# TIMESTEP 213229 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.615042 / Loss  0.21982461214065552
# fps: 7.817434933983434
# TIMESTEP 213230 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.437798 / Loss  0.29671382904052734
# fps: 8.279794934964695
# TIMESTEP 213231 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.068043 / Loss  0.2053881585597992
# fps: 6.471363130715455
# TIMESTEP 213232 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.284214 / Loss  0.1350928395986557
# fps: 9.026181345522314
# TIMESTEP 213233 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.989225 / Loss  0.087236687541008
# fps: 7.633057442146565
# TIMESTEP 213234 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.529442 / Loss  0.15698586404323578
# fps: 9.09752341455585
# TIMESTEP 213235 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.524015 / Loss  7.161555767059326
# fps: 8.842344042180448
# TIMESTEP 213236 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  13.584548 / Loss  0.12106131762266159
# fps: 8.67385644298397
# TIMESTEP 213237 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.800238 / Loss  0.0466710589826107
# fps: 7.559715440780213
# TIMESTEP 213238 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.240482 / Loss  0.23382428288459778
# fps: 7.991753504474791
# TIMESTEP 213239 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.207691 / Loss  0.06806690245866776
# fps: 7.486713563820768
# TIMESTEP 213240 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.60378 / Loss  5.946992874145508
# fps: 9.27498081673179
# TIMESTEP 213241 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.057476 / Loss  0.1493711769580841
# fps: 7.626367791931982
# TIMESTEP 213242 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.990282 / Loss  0.15895630419254303
# fps: 8.892115126948323
# TIMESTEP 213243 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.606513 / Loss  0.1300511658191681
# fps: 5.828935775175592
# TIMESTEP 213244 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.178874 / Loss  5.002492904663086
# fps: 9.132167328196408
# TIMESTEP 213245 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.295985 / Loss  0.22905924916267395
# fps: 8.779175981044718
# TIMESTEP 213246 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.688115 / Loss  0.0729229599237442
# fps: 7.977025397586146
# TIMESTEP 213247 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.692781 / Loss  0.043473195284605026
# fps: 7.693443804695338
# TIMESTEP 213248 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.36749 / Loss  0.048482127487659454
# fps: 7.794771154375089
# TIMESTEP 213249 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.979433 / Loss  0.3097665309906006
# fps: 7.586859079875117
# TIMESTEP 213250 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.272235 / Loss  0.11381692439317703
# fps: 7.875207474333266
# TIMESTEP 213251 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.297436 / Loss  0.35160955786705017
# fps: 8.59601259181532
# TIMESTEP 213252 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.86256 / Loss  0.08836998790502548
# fps: 9.018437648495638
# TIMESTEP 213253 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.205636 / Loss  0.19128046929836273
# fps: 9.03522275142875
# TIMESTEP 213254 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.438765 / Loss  0.0954592153429985
# fps: 8.95455370314625
# TIMESTEP 213255 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.019436 / Loss  0.11523068696260452
# fps: 7.089583597440903
# TIMESTEP 213256 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.220786 / Loss  0.12757857143878937
# fps: 9.111020842610595
# TIMESTEP 213257 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.066495 / Loss  0.1612187772989273
# fps: 8.452066112371687
# TIMESTEP 213258 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.057616 / Loss  0.08157132565975189
# fps: 8.813525701101506
# TIMESTEP 213259 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.449295 / Loss  0.04031818360090256
# fps: 7.592613577737189
# TIMESTEP 213260 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.496322 / Loss  0.07526643574237823
# fps: 8.859733171106773
# TIMESTEP 213261 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.7809 / Loss  0.10168416798114777
# fps: 7.776590340224344
# TIMESTEP 213262 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.523202 / Loss  0.03284261375665665
# fps: 9.26725497907617
# TIMESTEP 213263 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.785742 / Loss  0.06967321038246155
# fps: 8.689310271246766
# TIMESTEP 213264 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.305601 / Loss  0.11325013637542725
# fps: 9.091804529532133
# TIMESTEP 213265 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.688272 / Loss  1.070878267288208
# fps: 9.101511166662327
# TIMESTEP 213266 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.547692 / Loss  0.09298425912857056
# fps: 8.754493292674018
# TIMESTEP 213267 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.133355 / Loss  0.10823021084070206
# fps: 8.669499793303018
# TIMESTEP 213268 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.057234 / Loss  0.1112605631351471
# fps: 9.069059537066067
# TIMESTEP 213269 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.09713 / Loss  0.05088894069194794
# fps: 7.694728190677469
# TIMESTEP 213270 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.992706 / Loss  0.10638122260570526
# fps: 8.70702386265738
# TIMESTEP 213271 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.947156 / Loss  0.068512462079525
# fps: 7.580113133211646
# TIMESTEP 213272 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.380722 / Loss  1.8270350694656372
# fps: 7.657668250183486
# TIMESTEP 213273 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.974721 / Loss  0.08021855354309082
# fps: 7.167483787178414
# TIMESTEP 213274 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  12.33726 / Loss  0.09393441677093506
# fps: 8.540666017780564
# TIMESTEP 213275 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  12.021444 / Loss  0.05216473340988159
# fps: 8.320248835566982
# TIMESTEP 213276 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.163788 / Loss  0.1909317672252655
# fps: 8.837835161246142
# TIMESTEP 213277 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.292932 / Loss  0.05790136009454727
# fps: 9.137081138545057
# TIMESTEP 213278 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.950816 / Loss  0.09977453947067261
# fps: 8.789662731094374
# TIMESTEP 213279 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.20071 / Loss  0.1755296289920807
# fps: 5.833459432996573
# TIMESTEP 213280 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.628064 / Loss  0.10016139596700668
# fps: 8.944642773363359
# TIMESTEP 213281 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.85768 / Loss  0.40814658999443054
# fps: 8.526897219099354
# TIMESTEP 213282 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.888386 / Loss  0.09340270608663559
# fps: 8.792739911827411
# TIMESTEP 213283 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.920801 / Loss  0.11831211298704147
# fps: 8.639000799162938
# TIMESTEP 213284 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.957192 / Loss  0.029912570491433144
# fps: 8.501800978224075
# TIMESTEP 213285 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.944308 / Loss  0.0970669686794281
# fps: 7.686112673836676
# TIMESTEP 213286 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.825809 / Loss  0.036524783819913864
# fps: 9.190316028423496
# TIMESTEP 213287 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.19436 / Loss  0.05543423816561699
# fps: 7.56086015225178
# TIMESTEP 213288 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.872785 / Loss  0.10018138587474823
# fps: 8.891003016447375
# TIMESTEP 213289 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.951052 / Loss  2.012200355529785
# fps: 8.739407830308586
# TIMESTEP 213290 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.533297 / Loss  0.06153895705938339
# fps: 8.806771105637898
# TIMESTEP 213291 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.104627 / Loss  0.03510450944304466
# fps: 8.781197790832541
# TIMESTEP 213292 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.238363 / Loss  0.04044266790151596
# fps: 8.8671503712348
# TIMESTEP 213293 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.710921 / Loss  0.06345757842063904
# fps: 8.42453019675898
# TIMESTEP 213294 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.936194 / Loss  0.20548036694526672
# fps: 7.681326791676052
# TIMESTEP 213295 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.18363 / Loss  0.041086263954639435
# fps: 7.560914670969021
# TIMESTEP 213296 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.795221 / Loss  1.4839837551116943
# fps: 8.71187067319975
# TIMESTEP 213297 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.562943 / Loss  0.04790734872221947
# fps: 7.806289991773653
# TIMESTEP 213298 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.550709 / Loss  0.14322812855243683
# fps: 8.726606940000083
# TIMESTEP 213299 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.444383 / Loss  0.15037661790847778
# fps: 8.704205067331298
# TIMESTEP 213300 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.530456 / Loss  0.08058875799179077
# fps: 8.770382761613014
# TIMESTEP 213301 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.043382 / Loss  0.17433702945709229
# fps: 8.510426241216777
# TIMESTEP 213302 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.351138 / Loss  0.1280117928981781
# fps: 8.780554386714146
# TIMESTEP 213303 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.621069 / Loss  0.07975348830223083
# fps: 8.381115282937055
# TIMESTEP 213304 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.586333 / Loss  0.21264410018920898
# fps: 7.6753106774974516
# TIMESTEP 213305 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.420767 / Loss  0.08632977306842804
# fps: 8.381584232413237
# TIMESTEP 213306 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.645479 / Loss  0.27344292402267456
# fps: 8.974979297417473
# TIMESTEP 213307 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.621956 / Loss  0.06875500082969666
# fps: 6.612179780240568
# ...
# fps: 8.080420752499663
# TIMESTEP 213729 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.926776 / Loss  0.044309116899967194
# fps: 9.264061844284926
# TIMESTEP 213730 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.682181 / Loss  0.061541587114334106
# fps: 8.552054872727568
# TIMESTEP 213731 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.122228 / Loss  0.14044281840324402
# fps: 8.720818874193528
# TIMESTEP 213732 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.450448 / Loss  0.09656599164009094
# fps: 7.627865698188286
# TIMESTEP 213733 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  11.363713 / Loss  0.06880413740873337
# fps: 8.488019686569098
# TIMESTEP 213734 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.130942 / Loss  0.13715527951717377
# fps: 8.705487754254877
# TIMESTEP 213735 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.496058 / Loss  0.039620012044906616
# fps: 8.967495718619782
# TIMESTEP 213736 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.140343 / Loss  0.29673463106155396
# fps: 8.637951096347157
# TIMESTEP 213737 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.607187 / Loss  0.054923780262470245
# fps: 8.329882329576487
# TIMESTEP 213738 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.179376 / Loss  0.046894997358322144
# fps: 8.625073001406562
# TIMESTEP 213739 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.398314 / Loss  0.04958288371562958
# fps: 8.929218611622044
# TIMESTEP 213740 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.968023 / Loss  0.7922925353050232
# fps: 8.469919224555735
# TIMESTEP 213741 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.091024 / Loss  0.03815315663814545
# fps: 5.448811000759973
# TIMESTEP 213742 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  11.334745 / Loss  0.25494611263275146
# fps: 9.051738351641237
# TIMESTEP 213743 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.984934 / Loss  0.05232834443449974
# fps: 8.714766864677417
# TIMESTEP 213744 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.272041 / Loss  2.416160821914673
# fps: 9.288043562505951
# TIMESTEP 213745 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.21059 / Loss  0.029175352305173874
# fps: 8.411352296610033
# TIMESTEP 213746 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.147005 / Loss  0.03910175710916519
# fps: 8.88691510369435
# TIMESTEP 213747 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.869393 / Loss  0.03019048273563385
# fps: 8.299011867874428
# TIMESTEP 213748 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.957762 / Loss  0.24086861312389374
# fps: 8.827604786008187
# TIMESTEP 213749 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.283406 / Loss  0.0481739342212677
# fps: 8.604071149731578
# TIMESTEP 213750 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.578484 / Loss  0.024919185787439346
# fps: 9.362870893716572
# TIMESTEP 213751 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.528524 / Loss  0.08888091892004013
# fps: 8.914813799318578
# TIMESTEP 213752 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.2802105 / Loss  0.10369575023651123
# fps: 8.996115692730061
# TIMESTEP 213753 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.092092 / Loss  0.028657959774136543
# fps: 9.048691982758248
# TIMESTEP 213754 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.294504 / Loss  0.2633022665977478
# fps: 9.276273128181991
# TIMESTEP 213755 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.131659 / Loss  0.04921083524823189
# fps: 8.747372745796081
# TIMESTEP 213756 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.648447 / Loss  0.07802121341228485
# fps: 8.882718075677644
# TIMESTEP 213757 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.907568 / Loss  0.12156589329242706
# fps: 8.711092649899271
# TIMESTEP 213758 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.789276 / Loss  0.07082928717136383
# fps: 9.281774606869874
# TIMESTEP 213759 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.828341 / Loss  3.1533286571502686
# fps: 8.995343949386092
# TIMESTEP 213760 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.704217 / Loss  0.20125705003738403
# fps: 8.292268425433315
# TIMESTEP 213761 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.851571 / Loss  0.1510854959487915
# fps: 7.679132910407455
# TIMESTEP 213762 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.496984 / Loss  0.2884066104888916
# fps: 9.352265429896539
# TIMESTEP 213763 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.579181 / Loss  0.0486239455640316
# fps: 8.396450284565784
# TIMESTEP 213764 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.462692 / Loss  0.12211652845144272
# fps: 8.797701101206084
# TIMESTEP 213765 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.389619 / Loss  0.09752582758665085
# fps: 8.829072782998216
# TIMESTEP 213766 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.31081 / Loss  0.06321953237056732
# fps: 9.301019401220975
# TIMESTEP 213767 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.872198 / Loss  0.03179473429918289
# fps: 8.841244345512877
# TIMESTEP 213768 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.385453 / Loss  0.12579211592674255
# fps: 9.139271177429336
# TIMESTEP 213769 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.854886 / Loss  0.07415251433849335
# fps: 8.653884165200042
# TIMESTEP 213770 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.173693 / Loss  0.03448757156729698
# fps: 9.02064877722505
# TIMESTEP 213771 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.006501 / Loss  0.03874579071998596
# fps: 8.92243743152834
# TIMESTEP 213772 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.156318 / Loss  0.037943266332149506
# fps: 9.040539375441863
# TIMESTEP 213773 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.138237 / Loss  0.08290265500545502
# fps: 8.010052899948437
# TIMESTEP 213774 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.461878 / Loss  0.048492178320884705
# fps: 7.976464099955309
# TIMESTEP 213775 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.399028 / Loss  0.02902105450630188
# fps: 7.85829857871406
# TIMESTEP 213776 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.8935375 / Loss  0.05922970175743103
# fps: 8.99874061090026
# TIMESTEP 213777 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.363139 / Loss  0.1107233464717865
# fps: 6.489807223062058
# TIMESTEP 213778 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.713023 / Loss  0.03373271971940994
# fps: 9.074985449486459
# TIMESTEP 213779 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.058754 / Loss  0.0413980707526207
# fps: 8.706318992680911
# TIMESTEP 213780 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.526668 / Loss  0.42467474937438965
# fps: 7.625549739742888
# TIMESTEP 213781 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.536145 / Loss  0.07473728060722351
# fps: 8.747007901767
# TIMESTEP 213782 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.671796 / Loss  0.026796452701091766
# fps: 7.880341719758985
# TIMESTEP 213783 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.692504 / Loss  0.05145683139562607
# fps: 7.591747785448214
# TIMESTEP 213784 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.170231 / Loss  0.03277745842933655
# fps: 9.332268306629791
# TIMESTEP 213785 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.977555 / Loss  0.08298393338918686
# fps: 8.604388863929627
# TIMESTEP 213786 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.204448 / Loss  0.06526419520378113
# fps: 9.493886235541773
# TIMESTEP 213787 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.372607 / Loss  0.036701131612062454
# fps: 9.162870562534135
# TIMESTEP 213788 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.897315 / Loss  0.09333692491054535
# fps: 9.050664077250904
# TIMESTEP 213789 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.450406 / Loss  0.03917420282959938
# fps: 8.032510734134355
# TIMESTEP 213790 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.541126 / Loss  0.8494778275489807
# fps: 9.295680503534939
# TIMESTEP 213791 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.68872 / Loss  0.06809158623218536
# fps: 8.06880883080007
# TIMESTEP 213792 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.7321 / Loss  0.047516193240880966
# fps: 8.411622198334644
# TIMESTEP 213793 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.87912 / Loss  0.8214772343635559
# fps: 7.85713563160685
# TIMESTEP 213794 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.7200165 / Loss  0.07114758342504501
# fps: 9.526252075341423
# TIMESTEP 213795 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.338785 / Loss  0.025051798671483994
# fps: 9.284959411685273
# TIMESTEP 213796 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  11.08686 / Loss  0.032882072031497955
# fps: 8.16099777213515
# TIMESTEP 213797 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.630652 / Loss  0.09373019635677338
# fps: 9.119340776414058
# TIMESTEP 213798 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.998615 / Loss  0.0838007926940918
# fps: 8.293809754505997
# TIMESTEP 213799 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.948949 / Loss  0.03707084059715271
# fps: 7.82503344147788
# TIMESTEP 213800 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.911287 / Loss  0.046355005353689194
# fps: 9.261647985726524
# TIMESTEP 213801 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.659804 / Loss  1.8153083324432373
# fps: 9.281589749831266
# TIMESTEP 213802 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.312856 / Loss  0.1560078114271164
# fps: 9.369019697193071
# TIMESTEP 213803 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.758141 / Loss  0.09427402168512344
# fps: 8.580063537782069
# TIMESTEP 213804 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.669505 / Loss  0.04428117722272873
# fps: 9.230564731410915
# TIMESTEP 213805 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.958964 / Loss  0.021044809371232986
# fps: 7.5568143327640005
# TIMESTEP 213806 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.577686 / Loss  0.0630590170621872
# fps: 8.940715034830877
# TIMESTEP 213807 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.256652 / Loss  0.05242178589105606
# fps: 8.863983431427455
# TIMESTEP 213808 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.484333 / Loss  0.027601853013038635
# fps: 9.2560069205374
# TIMESTEP 213809 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.59741 / Loss  0.02706860564649105
# fps: 8.403296963091483
# TIMESTEP 213810 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.571126 / Loss  0.07147988677024841
# fps: 9.776385470276722
# TIMESTEP 213811 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.58994 / Loss  0.523173987865448
# fps: 9.418058278151644
# TIMESTEP 213812 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.644227 / Loss  0.08063370734453201
# fps: 9.315417519888774
# TIMESTEP 213813 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.771072 / Loss  0.10197456181049347
# fps: 6.433474959736176
# TIMESTEP 213814 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.599968 / Loss  0.3016898036003113
# fps: 9.603817435366688
# TIMESTEP 213815 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.955848 / Loss  3.926994800567627
# fps: 7.775754160116276
# TIMESTEP 213816 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.802944 / Loss  0.021042052656412125
# fps: 9.520197744280692
# TIMESTEP 213817 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  8.609769 / Loss  2.1853551864624023
# fps: 7.731435944700461
# TIMESTEP 213818 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.267745 / Loss  0.0642857700586319
# fps: 7.827603646644956
# TIMESTEP 213819 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.20057 / Loss  0.1605832576751709
# fps: 7.562973327755579
# TIMESTEP 213820 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.987315 / Loss  0.04844101890921593
# fps: 9.001792072386847
# TIMESTEP 213821 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.304548 / Loss  0.07239417731761932
# fps: 8.59821529239808
# TIMESTEP 213822 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.32953 / Loss  0.06722047179937363
# fps: 7.983022556018904
# TIMESTEP 213823 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.30518 / Loss  0.10345594584941864
# fps: 8.787894787567938
# TIMESTEP 213824 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.712046 / Loss  0.0476970300078392
# fps: 9.197268648665244
# TIMESTEP 213825 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.521898 / Loss  0.05037650093436241
# fps: 8.003068192876373
# TIMESTEP 213826 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  9.7921295 / Loss  0.02297816425561905
# fps: 8.196130081173717
# TIMESTEP 213827 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  10.046681 / Loss  0.04662906378507614
# fps: 8.676332539680898
# TIMESTEP 213828 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.263233 / Loss  0.03859042748808861
# fps: 9.33916710642628
# TIMESTEP 213829 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  9.805861 / Loss  0.03302415460348129
# fps: 9.195836960024906
# TIMESTEP 213830 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  10.104047 / Loss  0.0752815306186676
# fps: 7.860522385122688
