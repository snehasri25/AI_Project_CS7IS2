# %%
from keras import backend as K
# !pip install selenium
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
# Out:
# Using TensorFlow backend.
# Error processing line 3 of /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages/googleapis_common_protos-1.6.0-py3.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/divyanshumarwah/anaconda3/lib/python3.7/site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 580, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Requirement already satisfied: selenium in /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/divyanshumarwah/anaconda3/lib/python3.7/site-packages (from selenium) (1.24.2)

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# []

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('./objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('./objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 61000 / STATE explore / EPSILON 0.03916189899990705 / ACTION 0 / REWARD 0.1 / Q_MAX  13.195868 / Loss  0.5679876804351807
# fps: 0.22087801018608808
# TIMESTEP 61001 / STATE explore / EPSILON 0.039160899999907045 / ACTION 0 / REWARD 0.1 / Q_MAX  13.060308 / Loss  7.464420795440674
# fps: 11.635233839043728
# TIMESTEP 61002 / STATE explore / EPSILON 0.039159900999907044 / ACTION 0 / REWARD 0.1 / Q_MAX  13.725747 / Loss  2.547964096069336
# fps: 10.323525792175955
# TIMESTEP 61003 / STATE explore / EPSILON 0.03915890199990704 / ACTION 1 / REWARD 0.1 / Q_MAX  14.773779 / Loss  0.26131218671798706
# fps: 9.275821803899367
# TIMESTEP 61004 / STATE explore / EPSILON 0.03915790299990704 / ACTION 1 / REWARD 0.1 / Q_MAX  13.812936 / Loss  0.39574766159057617
# fps: 10.513252154383714
# TIMESTEP 61005 / STATE explore / EPSILON 0.03915690399990704 / ACTION 1 / REWARD 0.1 / Q_MAX  14.209175 / Loss  0.7589638233184814
# fps: 12.84197312382696
# TIMESTEP 61006 / STATE explore / EPSILON 0.03915590499990704 / ACTION 0 / REWARD 0.1 / Q_MAX  11.744997 / Loss  0.2567901611328125
# fps: 11.893741067580137
# TIMESTEP 61007 / STATE explore / EPSILON 0.039154905999907036 / ACTION 0 / REWARD 0.1 / Q_MAX  15.732113 / Loss  0.9374951124191284
# fps: 12.572929094299127
# TIMESTEP 61008 / STATE explore / EPSILON 0.039153906999907034 / ACTION 0 / REWARD 0.1 / Q_MAX  12.681686 / Loss  0.1752777397632599
# fps: 11.890032260076312
# TIMESTEP 61009 / STATE explore / EPSILON 0.03915290799990703 / ACTION 0 / REWARD 0.1 / Q_MAX  8.675702 / Loss  0.7890406250953674
# fps: 12.326073604307053
# TIMESTEP 61010 / STATE explore / EPSILON 0.03915190899990703 / ACTION 0 / REWARD 0.1 / Q_MAX  12.775686 / Loss  1.0799404382705688
# fps: 12.154478777569455
# TIMESTEP 61011 / STATE explore / EPSILON 0.03915090999990703 / ACTION 0 / REWARD 0.1 / Q_MAX  12.90595 / Loss  0.9337789416313171
# fps: 9.94610899139916
# TIMESTEP 61012 / STATE explore / EPSILON 0.03914991099990703 / ACTION 1 / REWARD 0.1 / Q_MAX  14.618415 / Loss  0.23960019648075104
# fps: 10.139128542938296
# TIMESTEP 61013 / STATE explore / EPSILON 0.03914891199990703 / ACTION 1 / REWARD 0.1 / Q_MAX  13.63406 / Loss  0.6721649765968323
# ----------Random Action----------
# fps: 10.316390656398577
# TIMESTEP 61014 / STATE explore / EPSILON 0.039147912999907025 / ACTION 1 / REWARD 0.1 / Q_MAX  13.530742 / Loss  0.34773874282836914
# fps: 10.00881494579548
# TIMESTEP 61015 / STATE explore / EPSILON 0.039146913999907024 / ACTION 1 / REWARD 0.1 / Q_MAX  13.825749 / Loss  0.2720601260662079
# fps: 10.533423742434517
# TIMESTEP 61016 / STATE explore / EPSILON 0.03914591499990702 / ACTION 1 / REWARD 0.1 / Q_MAX  13.763048 / Loss  0.6522184610366821
# fps: 9.557031565084046
# TIMESTEP 61017 / STATE explore / EPSILON 0.03914491599990702 / ACTION 1 / REWARD 0.1 / Q_MAX  14.184178 / Loss  0.25439804792404175
# fps: 12.052701603749458
# TIMESTEP 61018 / STATE explore / EPSILON 0.03914391699990702 / ACTION 0 / REWARD 0.1 / Q_MAX  12.545512 / Loss  0.5989017486572266
# fps: 12.388657844990549
# TIMESTEP 61019 / STATE explore / EPSILON 0.03914291799990702 / ACTION 0 / REWARD 0.1 / Q_MAX  13.92298 / Loss  0.3380088806152344
# fps: 12.339744985319298
# TIMESTEP 61020 / STATE explore / EPSILON 0.039141918999907016 / ACTION 0 / REWARD 0.1 / Q_MAX  13.343897 / Loss  0.49173641204833984
# fps: 12.076403485030836
# TIMESTEP 61021 / STATE explore / EPSILON 0.039140919999907015 / ACTION 0 / REWARD 0.1 / Q_MAX  13.510832 / Loss  0.3630934953689575
# fps: 10.150317386180209
# TIMESTEP 61022 / STATE explore / EPSILON 0.03913992099990701 / ACTION 1 / REWARD 0.1 / Q_MAX  11.685058 / Loss  0.3312147557735443
# fps: 11.948256461532765
# TIMESTEP 61023 / STATE explore / EPSILON 0.03913892199990701 / ACTION 0 / REWARD 0.1 / Q_MAX  13.579544 / Loss  0.5774897336959839
# fps: 9.906478660336806
# TIMESTEP 61024 / STATE explore / EPSILON 0.03913792299990701 / ACTION 1 / REWARD 0.1 / Q_MAX  14.043408 / Loss  0.24493485689163208
# fps: 10.128526857727936
# TIMESTEP 61025 / STATE explore / EPSILON 0.03913692399990701 / ACTION 1 / REWARD 0.1 / Q_MAX  13.853733 / Loss  0.4186852276325226
# fps: 10.483060611892437
# TIMESTEP 61026 / STATE explore / EPSILON 0.03913592499990701 / ACTION 1 / REWARD 0.1 / Q_MAX  13.429213 / Loss  0.19999012351036072
# fps: 9.757894271549448
# TIMESTEP 61027 / STATE explore / EPSILON 0.039134925999907005 / ACTION 1 / REWARD 0.1 / Q_MAX  14.704864 / Loss  0.6215147376060486
# fps: 10.074784359034101
# TIMESTEP 61028 / STATE explore / EPSILON 0.039133926999907004 / ACTION 1 / REWARD -1 / Q_MAX  12.591816 / Loss  0.12626957893371582
# fps: 8.819437522998475
# TIMESTEP 61029 / STATE explore / EPSILON 0.039132927999907 / ACTION 1 / REWARD 0.1 / Q_MAX  13.602533 / Loss  0.38288503885269165
# fps: 8.80288958987888
# TIMESTEP 61030 / STATE explore / EPSILON 0.039131928999907 / ACTION 1 / REWARD 0.1 / Q_MAX  14.2574415 / Loss  1.4712642431259155
# fps: 10.934797457596188
# TIMESTEP 61031 / STATE explore / EPSILON 0.039130929999907 / ACTION 0 / REWARD 0.1 / Q_MAX  14.435963 / Loss  0.1449505090713501
# fps: 11.155093497589089
# TIMESTEP 61032 / STATE explore / EPSILON 0.039129930999907 / ACTION 0 / REWARD 0.1 / Q_MAX  12.708149 / Loss  0.32039082050323486
# fps: 10.094570169506211
# TIMESTEP 61033 / STATE explore / EPSILON 0.039128931999906996 / ACTION 1 / REWARD 0.1 / Q_MAX  13.099697 / Loss  0.3276500999927521
# fps: 8.11657294129941
# TIMESTEP 61034 / STATE explore / EPSILON 0.039127932999906995 / ACTION 1 / REWARD 0.1 / Q_MAX  15.73502 / Loss  0.20350411534309387
# fps: 8.171189003007964
# TIMESTEP 61035 / STATE explore / EPSILON 0.03912693399990699 / ACTION 1 / REWARD 0.1 / Q_MAX  13.701027 / Loss  0.281026691198349
# fps: 9.81064075635166
# TIMESTEP 61036 / STATE explore / EPSILON 0.03912593499990699 / ACTION 1 / REWARD 0.1 / Q_MAX  14.766069 / Loss  0.3110671937465668
# fps: 12.328501052285047
# TIMESTEP 61037 / STATE explore / EPSILON 0.03912493599990699 / ACTION 0 / REWARD 0.1 / Q_MAX  14.819104 / Loss  0.3937043845653534
# fps: 12.1654426693583
# TIMESTEP 61038 / STATE explore / EPSILON 0.03912393699990699 / ACTION 0 / REWARD 0.1 / Q_MAX  14.390868 / Loss  0.7622663974761963
# fps: 10.072848747709518
# TIMESTEP 61039 / STATE explore / EPSILON 0.03912293799990699 / ACTION 1 / REWARD 0.1 / Q_MAX  14.539273 / Loss  0.2883259654045105
# fps: 12.421090038972268
# TIMESTEP 61040 / STATE explore / EPSILON 0.039121938999906986 / ACTION 0 / REWARD 0.1 / Q_MAX  15.490126 / Loss  0.2879740297794342
# fps: 9.756101191860736
# TIMESTEP 61041 / STATE explore / EPSILON 0.039120939999906984 / ACTION 1 / REWARD 0.1 / Q_MAX  14.782794 / Loss  0.18808062374591827
# fps: 10.179336522336369
# TIMESTEP 61042 / STATE explore / EPSILON 0.03911994099990698 / ACTION 1 / REWARD 0.1 / Q_MAX  14.548062 / Loss  0.5563406944274902
# fps: 10.419906192861118
# TIMESTEP 61043 / STATE explore / EPSILON 0.03911894199990698 / ACTION 0 / REWARD 0.1 / Q_MAX  13.344819 / Loss  0.20684625208377838
# fps: 12.277796479683388
# TIMESTEP 61044 / STATE explore / EPSILON 0.03911794299990698 / ACTION 0 / REWARD 0.1 / Q_MAX  13.606892 / Loss  0.24330413341522217
# fps: 10.561565637362166
# TIMESTEP 61045 / STATE explore / EPSILON 0.03911694399990698 / ACTION 0 / REWARD 0.1 / Q_MAX  13.744207 / Loss  1.449424386024475
# fps: 11.2170559635432
# TIMESTEP 61046 / STATE explore / EPSILON 0.039115944999906976 / ACTION 0 / REWARD 0.1 / Q_MAX  15.620889 / Loss  0.9736785292625427
# fps: 8.994186582606924
# TIMESTEP 61047 / STATE explore / EPSILON 0.039114945999906975 / ACTION 1 / REWARD 0.1 / Q_MAX  14.56802 / Loss  0.32380643486976624
# fps: 9.951725528810222
# TIMESTEP 61048 / STATE explore / EPSILON 0.03911394699990697 / ACTION 1 / REWARD 0.1 / Q_MAX  14.727836 / Loss  3.592374086380005
# ----------Random Action----------
# fps: 12.82512735523089
# TIMESTEP 61049 / STATE explore / EPSILON 0.03911294799990697 / ACTION 0 / REWARD 0.1 / Q_MAX  14.439698 / Loss  0.37390485405921936
# fps: 12.267669691926564
# TIMESTEP 61050 / STATE explore / EPSILON 0.03911194899990697 / ACTION 0 / REWARD 0.1 / Q_MAX  16.80672 / Loss  3.2832705974578857
# fps: 11.938156067126625
# TIMESTEP 61051 / STATE explore / EPSILON 0.03911094999990697 / ACTION 0 / REWARD 0.1 / Q_MAX  14.947927 / Loss  0.09197377413511276
# fps: 12.367835343378646
# TIMESTEP 61052 / STATE explore / EPSILON 0.03910995099990697 / ACTION 0 / REWARD 0.1 / Q_MAX  14.083005 / Loss  0.26837557554244995
# fps: 11.98009745619898
# TIMESTEP 61053 / STATE explore / EPSILON 0.039108951999906966 / ACTION 0 / REWARD 0.1 / Q_MAX  15.067017 / Loss  1.3857753276824951
# fps: 11.616318165452682
# TIMESTEP 61054 / STATE explore / EPSILON 0.039107952999906964 / ACTION 0 / REWARD 0.1 / Q_MAX  13.818192 / Loss  0.4277401566505432
# fps: 11.0337802821644
# TIMESTEP 61055 / STATE explore / EPSILON 0.03910695399990696 / ACTION 0 / REWARD 0.1 / Q_MAX  13.828024 / Loss  0.793002188205719
# fps: 11.35280186005722
# TIMESTEP 61056 / STATE explore / EPSILON 0.03910595499990696 / ACTION 0 / REWARD 0.1 / Q_MAX  14.752588 / Loss  0.4109044671058655
# fps: 12.289668226448708
# TIMESTEP 61057 / STATE explore / EPSILON 0.03910495599990696 / ACTION 0 / REWARD 0.1 / Q_MAX  15.777639 / Loss  0.3768644332885742
# fps: 11.63914064191008
# TIMESTEP 61058 / STATE explore / EPSILON 0.03910395699990696 / ACTION 0 / REWARD 0.1 / Q_MAX  12.376769 / Loss  0.15786316990852356
# fps: 12.464647425229423
# TIMESTEP 61059 / STATE explore / EPSILON 0.03910295799990696 / ACTION 0 / REWARD 0.1 / Q_MAX  12.857099 / Loss  1.3498868942260742
# fps: 11.071146891909727
# TIMESTEP 61060 / STATE explore / EPSILON 0.039101958999906955 / ACTION 0 / REWARD 0.1 / Q_MAX  14.415288 / Loss  0.4753931164741516
# fps: 12.298893648964464
# TIMESTEP 61061 / STATE explore / EPSILON 0.039100959999906953 / ACTION 0 / REWARD 0.1 / Q_MAX  13.449382 / Loss  0.3887108862400055
# fps: 12.439472443256806
# TIMESTEP 61062 / STATE explore / EPSILON 0.03909996099990695 / ACTION 0 / REWARD 0.1 / Q_MAX  14.822001 / Loss  0.19504602253437042
# fps: 11.15458916641845
# TIMESTEP 61063 / STATE explore / EPSILON 0.03909896199990695 / ACTION 0 / REWARD 0.1 / Q_MAX  14.939597 / Loss  0.17685022950172424
# fps: 11.855784858823496
# TIMESTEP 61064 / STATE explore / EPSILON 0.03909796299990695 / ACTION 0 / REWARD 0.1 / Q_MAX  13.911488 / Loss  0.5072804689407349
# fps: 12.147368116193869
# TIMESTEP 61065 / STATE explore / EPSILON 0.03909696399990695 / ACTION 0 / REWARD 0.1 / Q_MAX  14.133392 / Loss  0.544357180595398
# fps: 11.937476519541434
# TIMESTEP 61066 / STATE explore / EPSILON 0.039095964999906946 / ACTION 0 / REWARD 0.1 / Q_MAX  14.305052 / Loss  0.3886651396751404
# fps: 12.230751958848865
# TIMESTEP 61067 / STATE explore / EPSILON 0.039094965999906944 / ACTION 0 / REWARD 0.1 / Q_MAX  14.802664 / Loss  0.25904345512390137
# fps: 12.404485875171533
# TIMESTEP 61068 / STATE explore / EPSILON 0.03909396699990694 / ACTION 0 / REWARD 0.1 / Q_MAX  14.957995 / Loss  0.09798771888017654
# fps: 12.449441537278833
# TIMESTEP 61069 / STATE explore / EPSILON 0.03909296799990694 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3417153 / Loss  0.5884682536125183
# fps: 12.391585913495627
# TIMESTEP 61070 / STATE explore / EPSILON 0.03909196899990694 / ACTION 0 / REWARD 0.1 / Q_MAX  13.169305 / Loss  0.194842129945755
# fps: 9.669775955956602
# TIMESTEP 61071 / STATE explore / EPSILON 0.03909096999990694 / ACTION 1 / REWARD 0.1 / Q_MAX  14.146174 / Loss  3.406552791595459
# fps: 9.795495893149488
# TIMESTEP 61072 / STATE explore / EPSILON 0.03908997099990694 / ACTION 1 / REWARD 0.1 / Q_MAX  12.229827 / Loss  3.5081000328063965
# fps: 11.7262179677147
# TIMESTEP 61073 / STATE explore / EPSILON 0.039088971999906935 / ACTION 0 / REWARD 0.1 / Q_MAX  14.150511 / Loss  0.3909037411212921
# ----------Random Action----------
# fps: 12.992943304813299
# TIMESTEP 61074 / STATE explore / EPSILON 0.039087972999906934 / ACTION 0 / REWARD 0.1 / Q_MAX  13.802886 / Loss  0.2963881492614746
# fps: 11.680890290023783
# TIMESTEP 61075 / STATE explore / EPSILON 0.03908697399990693 / ACTION 0 / REWARD 0.1 / Q_MAX  14.746243 / Loss  0.496681809425354
# fps: 12.46898290321334
# TIMESTEP 61076 / STATE explore / EPSILON 0.03908597499990693 / ACTION 0 / REWARD 0.1 / Q_MAX  14.37109 / Loss  1.9627562761306763
# fps: 11.503787691784467
# TIMESTEP 61077 / STATE explore / EPSILON 0.03908497599990693 / ACTION 0 / REWARD 0.1 / Q_MAX  14.322408 / Loss  0.20642569661140442
# fps: 11.069919660483727
# TIMESTEP 61078 / STATE explore / EPSILON 0.03908397699990693 / ACTION 0 / REWARD 0.1 / Q_MAX  15.618908 / Loss  0.21029362082481384
# fps: 9.16245022074356
# TIMESTEP 61079 / STATE explore / EPSILON 0.039082977999906926 / ACTION 1 / REWARD 0.1 / Q_MAX  15.285429 / Loss  0.48098862171173096
# fps: 9.914229457357012
# TIMESTEP 61080 / STATE explore / EPSILON 0.039081978999906924 / ACTION 1 / REWARD 0.1 / Q_MAX  15.442906 / Loss  0.1473645120859146
# fps: 10.036837357109869
# TIMESTEP 61081 / STATE explore / EPSILON 0.03908097999990692 / ACTION 1 / REWARD 0.1 / Q_MAX  15.388529 / Loss  0.22623172402381897
# fps: 9.536974128796665
# TIMESTEP 61082 / STATE explore / EPSILON 0.03907998099990692 / ACTION 1 / REWARD 0.1 / Q_MAX  15.294832 / Loss  0.1292911320924759
# fps: 11.648352991165778
# TIMESTEP 61083 / STATE explore / EPSILON 0.03907898199990692 / ACTION 0 / REWARD 0.1 / Q_MAX  11.014949 / Loss  0.8036673069000244
# fps: 11.264140251746298
# TIMESTEP 61084 / STATE explore / EPSILON 0.03907798299990692 / ACTION 0 / REWARD 0.1 / Q_MAX  14.922378 / Loss  0.5049466490745544
# fps: 12.640337051223709
# TIMESTEP 61085 / STATE explore / EPSILON 0.03907698399990692 / ACTION 0 / REWARD 0.1 / Q_MAX  14.835489 / Loss  0.11630101501941681
# fps: 12.363059709191448
# TIMESTEP 61086 / STATE explore / EPSILON 0.039075984999906915 / ACTION 0 / REWARD 0.1 / Q_MAX  15.615442 / Loss  0.9795364141464233
# fps: 12.244713026215916
# TIMESTEP 61087 / STATE explore / EPSILON 0.039074985999906914 / ACTION 0 / REWARD 0.1 / Q_MAX  14.770913 / Loss  0.4473705589771271
# fps: 10.421226554560882
# TIMESTEP 61088 / STATE explore / EPSILON 0.03907398699990691 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2542708 / Loss  0.5176771879196167
# fps: 10.651226808469575
# TIMESTEP 61089 / STATE explore / EPSILON 0.03907298799990691 / ACTION 1 / REWARD 0.1 / Q_MAX  15.128135 / Loss  0.5403239130973816
# fps: 9.920232354075067
# TIMESTEP 61090 / STATE explore / EPSILON 0.03907198899990691 / ACTION 1 / REWARD 0.1 / Q_MAX  14.886656 / Loss  0.3698437511920929
# fps: 10.198221154547532
# TIMESTEP 61091 / STATE explore / EPSILON 0.03907098999990691 / ACTION 1 / REWARD 0.1 / Q_MAX  16.024788 / Loss  0.1426457166671753
# fps: 9.742889065944404
# TIMESTEP 61092 / STATE explore / EPSILON 0.039069990999906906 / ACTION 1 / REWARD 0.1 / Q_MAX  16.27355 / Loss  0.9058972597122192
# fps: 12.141671515456785
# TIMESTEP 61093 / STATE explore / EPSILON 0.039068991999906905 / ACTION 0 / REWARD 0.1 / Q_MAX  16.309559 / Loss  0.38710927963256836
# fps: 11.610369406651811
# TIMESTEP 61094 / STATE explore / EPSILON 0.0390679929999069 / ACTION 0 / REWARD 0.1 / Q_MAX  16.309023 / Loss  0.46772506833076477
# fps: 11.393509375738528
# TIMESTEP 61095 / STATE explore / EPSILON 0.0390669939999069 / ACTION 0 / REWARD 0.1 / Q_MAX  14.266506 / Loss  8.147237777709961
# fps: 10.693889830832578
# TIMESTEP 61096 / STATE explore / EPSILON 0.0390659949999069 / ACTION 0 / REWARD 0.1 / Q_MAX  15.583919 / Loss  0.5623712539672852
# fps: 10.608849172524213
# TIMESTEP 61097 / STATE explore / EPSILON 0.0390649959999069 / ACTION 0 / REWARD 0.1 / Q_MAX  16.765682 / Loss  4.007964611053467
# fps: 10.982354620031265
# TIMESTEP 61098 / STATE explore / EPSILON 0.0390639969999069 / ACTION 0 / REWARD 0.1 / Q_MAX  15.699111 / Loss  0.13582059741020203
# fps: 10.922752000666671
# TIMESTEP 61099 / STATE explore / EPSILON 0.039062997999906895 / ACTION 0 / REWARD 0.1 / Q_MAX  15.701319 / Loss  0.14183790981769562
# fps: 9.035709361643457
# TIMESTEP 61100 / STATE explore / EPSILON 0.039061998999906894 / ACTION 1 / REWARD 0.1 / Q_MAX  15.267157 / Loss  0.2255607694387436
# fps: 9.049629108609254
# TIMESTEP 61101 / STATE explore / EPSILON 0.03906099999990689 / ACTION 1 / REWARD 0.1 / Q_MAX  15.867945 / Loss  0.2293568253517151
# fps: 9.624819863233741
# TIMESTEP 61102 / STATE explore / EPSILON 0.03906000099990689 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7918205 / Loss  0.7478763461112976
# fps: 10.18796576081148
# TIMESTEP 61103 / STATE explore / EPSILON 0.03905900199990689 / ACTION 1 / REWARD 0.1 / Q_MAX  15.893053 / Loss  0.2789526581764221
# fps: 12.141495779442586
# TIMESTEP 61104 / STATE explore / EPSILON 0.03905800299990689 / ACTION 0 / REWARD 0.1 / Q_MAX  16.977863 / Loss  3.1069869995117188
# fps: 11.051951474013723
# TIMESTEP 61105 / STATE explore / EPSILON 0.039057003999906886 / ACTION 0 / REWARD 0.1 / Q_MAX  16.085258 / Loss  0.35041654109954834
# fps: 11.014540555729168
# TIMESTEP 61106 / STATE explore / EPSILON 0.039056004999906885 / ACTION 0 / REWARD 0.1 / Q_MAX  15.843095 / Loss  0.48794397711753845
# fps: 10.825323329539325
# TIMESTEP 61107 / STATE explore / EPSILON 0.03905500599990688 / ACTION 0 / REWARD 0.1 / Q_MAX  16.263512 / Loss  0.14813151955604553
# fps: 11.722481833426496
# TIMESTEP 61108 / STATE explore / EPSILON 0.03905400699990688 / ACTION 0 / REWARD 0.1 / Q_MAX  15.400832 / Loss  0.37962454557418823
# fps: 9.57048652151492
# TIMESTEP 61109 / STATE explore / EPSILON 0.03905300799990688 / ACTION 1 / REWARD 0.1 / Q_MAX  15.171478 / Loss  0.9460801482200623
# fps: 9.510224904825284
# TIMESTEP 61110 / STATE explore / EPSILON 0.03905200899990688 / ACTION 1 / REWARD 0.1 / Q_MAX  14.522303 / Loss  0.6517191529273987
# fps: 8.795155256580161
# TIMESTEP 61111 / STATE explore / EPSILON 0.03905100999990688 / ACTION 1 / REWARD 0.1 / Q_MAX  14.183432 / Loss  0.2054416388273239
# fps: 7.692258598144382
# TIMESTEP 61112 / STATE explore / EPSILON 0.039050010999906876 / ACTION 1 / REWARD 0.1 / Q_MAX  16.868277 / Loss  0.3021465241909027
# ----------Random Action----------
# fps: 12.326472074952685
# TIMESTEP 61113 / STATE explore / EPSILON 0.039049011999906874 / ACTION 0 / REWARD 0.1 / Q_MAX  14.972032 / Loss  0.3431452512741089
# ----------Random Action----------
# fps: 12.325566497106905
# TIMESTEP 61114 / STATE explore / EPSILON 0.03904801299990687 / ACTION 0 / REWARD 0.1 / Q_MAX  14.807717 / Loss  0.49336591362953186
# fps: 11.327721197291698
# TIMESTEP 61115 / STATE explore / EPSILON 0.03904701399990687 / ACTION 0 / REWARD 0.1 / Q_MAX  2.224756 / Loss  0.6805630922317505
# fps: 12.986506653786373
# TIMESTEP 61116 / STATE explore / EPSILON 0.03904601499990687 / ACTION 0 / REWARD 0.1 / Q_MAX  13.670158 / Loss  0.7474132180213928
# fps: 9.633905951043827
# TIMESTEP 61117 / STATE explore / EPSILON 0.03904501599990687 / ACTION 1 / REWARD 0.1 / Q_MAX  14.978329 / Loss  0.31014907360076904
# fps: 10.135012553069643
# TIMESTEP 61118 / STATE explore / EPSILON 0.039044016999906866 / ACTION 1 / REWARD 0.1 / Q_MAX  15.315163 / Loss  4.191049575805664
# fps: 9.440910799538118
# TIMESTEP 61119 / STATE explore / EPSILON 0.039043017999906865 / ACTION 1 / REWARD 0.1 / Q_MAX  15.367628 / Loss  0.7596398591995239
# fps: 9.522272647812692
# TIMESTEP 61120 / STATE explore / EPSILON 0.03904201899990686 / ACTION 1 / REWARD 0.1 / Q_MAX  14.865583 / Loss  0.9640750288963318
# fps: 10.406591852482242
# TIMESTEP 61121 / STATE explore / EPSILON 0.03904101999990686 / ACTION 0 / REWARD 0.1 / Q_MAX  14.925927 / Loss  0.1587473750114441
# fps: 12.701967541769001
# TIMESTEP 61122 / STATE explore / EPSILON 0.03904002099990686 / ACTION 0 / REWARD 0.1 / Q_MAX  15.757894 / Loss  0.22225582599639893
# fps: 8.777485727679094
# TIMESTEP 61123 / STATE explore / EPSILON 0.03903902199990686 / ACTION 1 / REWARD 0.1 / Q_MAX  15.263187 / Loss  2.386251449584961
# fps: 9.265596730546198
# TIMESTEP 61124 / STATE explore / EPSILON 0.03903802299990686 / ACTION 1 / REWARD 0.1 / Q_MAX  15.290499 / Loss  0.8299973011016846
# fps: 9.730186678915514
# TIMESTEP 61125 / STATE explore / EPSILON 0.039037023999906856 / ACTION 0 / REWARD 0.1 / Q_MAX  10.977538 / Loss  1.0534173250198364
# fps: 9.346950873009682
# TIMESTEP 61126 / STATE explore / EPSILON 0.039036024999906854 / ACTION 1 / REWARD 0.1 / Q_MAX  15.169547 / Loss  0.40063297748565674
# fps: 11.789005033995632
# TIMESTEP 61127 / STATE explore / EPSILON 0.03903502599990685 / ACTION 0 / REWARD 0.1 / Q_MAX  15.394578 / Loss  0.3151521682739258
# fps: 12.54153746789342
# TIMESTEP 61128 / STATE explore / EPSILON 0.03903402699990685 / ACTION 0 / REWARD 0.1 / Q_MAX  14.978897 / Loss  0.7765288352966309
# fps: 12.039658527903919
# TIMESTEP 61129 / STATE explore / EPSILON 0.03903302799990685 / ACTION 0 / REWARD 0.1 / Q_MAX  15.214548 / Loss  0.3056469261646271
# fps: 10.87632897343609
# TIMESTEP 61130 / STATE explore / EPSILON 0.03903202899990685 / ACTION 0 / REWARD 0.1 / Q_MAX  14.052409 / Loss  0.2057090848684311
# fps: 11.126921005647949
# TIMESTEP 61131 / STATE explore / EPSILON 0.03903102999990685 / ACTION 0 / REWARD 0.1 / Q_MAX  14.5759325 / Loss  0.7219109535217285
# fps: 10.173361501686948
# TIMESTEP 61132 / STATE explore / EPSILON 0.039030030999906845 / ACTION 1 / REWARD 0.1 / Q_MAX  14.678181 / Loss  0.29400426149368286
# fps: 10.365929850923326
# TIMESTEP 61133 / STATE explore / EPSILON 0.039029031999906844 / ACTION 1 / REWARD 0.1 / Q_MAX  15.740242 / Loss  1.8846806287765503
# fps: 12.428414380831878
# TIMESTEP 61134 / STATE explore / EPSILON 0.03902803299990684 / ACTION 0 / REWARD 0.1 / Q_MAX  15.053568 / Loss  1.1652379035949707
# fps: 10.120217735397445
# TIMESTEP 61135 / STATE explore / EPSILON 0.03902703399990684 / ACTION 1 / REWARD 0.1 / Q_MAX  16.761272 / Loss  2.4862663745880127
# fps: 12.627398324296497
# TIMESTEP 61136 / STATE explore / EPSILON 0.03902603499990684 / ACTION 0 / REWARD 0.1 / Q_MAX  15.037324 / Loss  0.3481980562210083
# fps: 12.127979366001902
# TIMESTEP 61137 / STATE explore / EPSILON 0.03902503599990684 / ACTION 0 / REWARD 0.1 / Q_MAX  16.462421 / Loss  4.64960241317749
# fps: 11.51980664387042
# TIMESTEP 61138 / STATE explore / EPSILON 0.039024036999906836 / ACTION 0 / REWARD 0.1 / Q_MAX  16.148937 / Loss  3.1241567134857178
# fps: 11.421774413158325
# TIMESTEP 61139 / STATE explore / EPSILON 0.039023037999906834 / ACTION 0 / REWARD 0.1 / Q_MAX  16.56394 / Loss  0.28278493881225586
# fps: 9.752562361651073
# TIMESTEP 61140 / STATE explore / EPSILON 0.03902203899990683 / ACTION 0 / REWARD 0.1 / Q_MAX  15.134931 / Loss  0.2670775353908539
# fps: 10.271471427346974
# TIMESTEP 61141 / STATE explore / EPSILON 0.03902103999990683 / ACTION 0 / REWARD 0.1 / Q_MAX  16.559391 / Loss  0.2847185432910919
# fps: 10.931463078362537
# TIMESTEP 61142 / STATE explore / EPSILON 0.03902004099990683 / ACTION 0 / REWARD 0.1 / Q_MAX  17.08475 / Loss  0.27621734142303467
# fps: 10.734230602880169
# TIMESTEP 61143 / STATE explore / EPSILON 0.03901904199990683 / ACTION 0 / REWARD 0.1 / Q_MAX  15.207035 / Loss  0.39996805787086487
# fps: 10.800903357719871
# TIMESTEP 61144 / STATE explore / EPSILON 0.03901804299990683 / ACTION 0 / REWARD 0.1 / Q_MAX  14.076505 / Loss  0.7743080854415894
# fps: 10.178224933630359
# TIMESTEP 61145 / STATE explore / EPSILON 0.039017043999906825 / ACTION 0 / REWARD 0.1 / Q_MAX  4.5422544 / Loss  0.7279391288757324
# ----------Random Action----------
# fps: 7.939336808670929
# TIMESTEP 61146 / STATE explore / EPSILON 0.039016044999906824 / ACTION 1 / REWARD 0.1 / Q_MAX  15.926629 / Loss  0.30247896909713745
# fps: 8.76992430895329
# TIMESTEP 61147 / STATE explore / EPSILON 0.03901504599990682 / ACTION 0 / REWARD 0.1 / Q_MAX  16.616673 / Loss  0.2978321313858032
# fps: 7.825223228444882
# TIMESTEP 61148 / STATE explore / EPSILON 0.03901404699990682 / ACTION 1 / REWARD 0.1 / Q_MAX  17.000523 / Loss  1.1483910083770752
# fps: 8.653294987064324
# TIMESTEP 61149 / STATE explore / EPSILON 0.03901304799990682 / ACTION 0 / REWARD 0.1 / Q_MAX  17.79038 / Loss  0.6541105508804321
# fps: 7.972961567559964
# TIMESTEP 61150 / STATE explore / EPSILON 0.03901204899990682 / ACTION 1 / REWARD 0.1 / Q_MAX  16.525894 / Loss  0.4688040018081665
# fps: 9.452165682606932
# TIMESTEP 61151 / STATE explore / EPSILON 0.039011049999906816 / ACTION 0 / REWARD 0.1 / Q_MAX  15.863772 / Loss  0.3431733250617981
# fps: 10.526312619366108
# TIMESTEP 61152 / STATE explore / EPSILON 0.039010050999906815 / ACTION 0 / REWARD 0.1 / Q_MAX  15.874124 / Loss  0.3842954635620117
# fps: 8.728077860298448
# TIMESTEP 61153 / STATE explore / EPSILON 0.03900905199990681 / ACTION 1 / REWARD 0.1 / Q_MAX  15.740165 / Loss  1.7233314514160156
# fps: 9.191705711418015
# TIMESTEP 61154 / STATE explore / EPSILON 0.03900805299990681 / ACTION 1 / REWARD 0.1 / Q_MAX  16.650612 / Loss  0.3165275454521179
# fps: 10.565689440618277
# TIMESTEP 61155 / STATE explore / EPSILON 0.03900705399990681 / ACTION 0 / REWARD 0.1 / Q_MAX  16.532116 / Loss  0.44961583614349365
# fps: 9.974468732758785
# TIMESTEP 61156 / STATE explore / EPSILON 0.03900605499990681 / ACTION 0 / REWARD 0.1 / Q_MAX  15.543686 / Loss  0.6275156736373901
# ----------Random Action----------
# fps: 8.763932158625286
# TIMESTEP 61157 / STATE explore / EPSILON 0.03900505599990681 / ACTION 1 / REWARD 0.1 / Q_MAX  15.979233 / Loss  1.74233877658844
# fps: 8.136632756787796
# TIMESTEP 61158 / STATE explore / EPSILON 0.039004056999906805 / ACTION 1 / REWARD -1 / Q_MAX  14.576668 / Loss  10.402539253234863
# fps: 8.497546546729067
# TIMESTEP 61159 / STATE explore / EPSILON 0.039003057999906804 / ACTION 1 / REWARD 0.1 / Q_MAX  14.3067465 / Loss  0.5482383966445923
# fps: 8.60341814422501
# TIMESTEP 61160 / STATE explore / EPSILON 0.0390020589999068 / ACTION 1 / REWARD 0.1 / Q_MAX  15.551577 / Loss  0.8975653052330017
# fps: 11.138415453497698
# TIMESTEP 61161 / STATE explore / EPSILON 0.0390010599999068 / ACTION 0 / REWARD 0.1 / Q_MAX  15.203401 / Loss  0.32716429233551025
# fps: 9.610749327479619
# TIMESTEP 61162 / STATE explore / EPSILON 0.0390000609999068 / ACTION 0 / REWARD 0.1 / Q_MAX  15.819857 / Loss  0.28261899948120117
# ----------Random Action----------
# fps: 8.464756953554174
# TIMESTEP 61163 / STATE explore / EPSILON 0.0389990619999068 / ACTION 1 / REWARD 0.1 / Q_MAX  17.474953 / Loss  0.23394477367401123
# fps: 10.296611251313374
# TIMESTEP 61164 / STATE explore / EPSILON 0.038998062999906796 / ACTION 0 / REWARD 0.1 / Q_MAX  15.4347 / Loss  0.3543434739112854
# fps: 9.68093543279462
# TIMESTEP 61165 / STATE explore / EPSILON 0.038997063999906795 / ACTION 0 / REWARD 0.1 / Q_MAX  15.636896 / Loss  0.22971850633621216
# fps: 9.816610729615743
# TIMESTEP 61166 / STATE explore / EPSILON 0.03899606499990679 / ACTION 0 / REWARD 0.1 / Q_MAX  13.879841 / Loss  0.09131823480129242
# fps: 9.72790737588192
# TIMESTEP 61167 / STATE explore / EPSILON 0.03899506599990679 / ACTION 0 / REWARD 0.1 / Q_MAX  16.146763 / Loss  0.17002537846565247
# fps: 10.313853841103409
# TIMESTEP 61168 / STATE explore / EPSILON 0.03899406699990679 / ACTION 0 / REWARD 0.1 / Q_MAX  14.142582 / Loss  0.3151981234550476
# fps: 9.808438293633163
# TIMESTEP 61169 / STATE explore / EPSILON 0.03899306799990679 / ACTION 0 / REWARD 0.1 / Q_MAX  15.36011 / Loss  2.542630195617676
# fps: 10.095396264925975
# TIMESTEP 61170 / STATE explore / EPSILON 0.03899206899990679 / ACTION 0 / REWARD 0.1 / Q_MAX  13.975636 / Loss  0.2199903130531311
# fps: 10.148033446887581
# TIMESTEP 61171 / STATE explore / EPSILON 0.038991069999906786 / ACTION 0 / REWARD 0.1 / Q_MAX  13.676334 / Loss  0.2214384824037552
# fps: 10.012231510701378
# TIMESTEP 61172 / STATE explore / EPSILON 0.038990070999906784 / ACTION 0 / REWARD 0.1 / Q_MAX  13.538632 / Loss  0.3510236144065857
# fps: 9.691224924559952
# TIMESTEP 61173 / STATE explore / EPSILON 0.03898907199990678 / ACTION 0 / REWARD 0.1 / Q_MAX  1.3669538 / Loss  4.331584453582764
# fps: 10.017133454179833
# TIMESTEP 61174 / STATE explore / EPSILON 0.03898807299990678 / ACTION 0 / REWARD 0.1 / Q_MAX  13.820048 / Loss  0.3524949550628662
# fps: 10.094472990698065
# TIMESTEP 61175 / STATE explore / EPSILON 0.03898707399990678 / ACTION 0 / REWARD 0.1 / Q_MAX  11.698732 / Loss  0.19918304681777954
# fps: 9.797097522406258
# TIMESTEP 61176 / STATE explore / EPSILON 0.03898607499990678 / ACTION 0 / REWARD 0.1 / Q_MAX  14.139677 / Loss  0.33275306224823
# fps: 9.18932940722824
# TIMESTEP 61177 / STATE explore / EPSILON 0.038985075999906776 / ACTION 0 / REWARD 0.1 / Q_MAX  12.889439 / Loss  0.26259249448776245
# fps: 10.032372027162461
# TIMESTEP 61178 / STATE explore / EPSILON 0.038984076999906775 / ACTION 0 / REWARD 0.1 / Q_MAX  15.570117 / Loss  0.2824360430240631
# fps: 7.981883161616661
# TIMESTEP 61179 / STATE explore / EPSILON 0.03898307799990677 / ACTION 0 / REWARD 0.1 / Q_MAX  13.338085 / Loss  0.13128352165222168
# fps: 9.35865088113099
# TIMESTEP 61180 / STATE explore / EPSILON 0.03898207899990677 / ACTION 0 / REWARD 0.1 / Q_MAX  0.120481804 / Loss  0.5950663089752197
# fps: 9.964634525882651
# TIMESTEP 61181 / STATE explore / EPSILON 0.03898107999990677 / ACTION 0 / REWARD 0.1 / Q_MAX  13.310272 / Loss  0.18813595175743103
# fps: 9.382118003905576
# TIMESTEP 61182 / STATE explore / EPSILON 0.03898008099990677 / ACTION 0 / REWARD 0.1 / Q_MAX  13.08119 / Loss  0.14066609740257263
# fps: 9.585162129241766
# TIMESTEP 61183 / STATE explore / EPSILON 0.03897908199990677 / ACTION 0 / REWARD 0.1 / Q_MAX  13.542323 / Loss  3.8111140727996826
# fps: 9.68504860646085
# TIMESTEP 61184 / STATE explore / EPSILON 0.038978082999906766 / ACTION 0 / REWARD 0.1 / Q_MAX  13.267959 / Loss  0.3738800585269928
# fps: 9.529606892446392
# TIMESTEP 61185 / STATE explore / EPSILON 0.038977083999906764 / ACTION 0 / REWARD 0.1 / Q_MAX  12.250443 / Loss  0.2090151309967041
# fps: 9.102577791667208
# TIMESTEP 61186 / STATE explore / EPSILON 0.03897608499990676 / ACTION 0 / REWARD 0.1 / Q_MAX  0.87911654 / Loss  0.6029326915740967
# fps: 8.707692690967825
# TIMESTEP 61187 / STATE explore / EPSILON 0.03897508599990676 / ACTION 0 / REWARD 0.1 / Q_MAX  13.168545 / Loss  0.843416690826416
# fps: 9.967310352038707
# TIMESTEP 61188 / STATE explore / EPSILON 0.03897408699990676 / ACTION 0 / REWARD 0.1 / Q_MAX  12.10204 / Loss  0.5321982502937317
# fps: 10.520556741422254
# TIMESTEP 61189 / STATE explore / EPSILON 0.03897308799990676 / ACTION 0 / REWARD 0.1 / Q_MAX  11.806221 / Loss  1.635038137435913
# fps: 8.554967905898094
# TIMESTEP 61190 / STATE explore / EPSILON 0.03897208899990676 / ACTION 1 / REWARD 0.1 / Q_MAX  13.61897 / Loss  0.05093841999769211
# fps: 8.163189680171739
# TIMESTEP 61191 / STATE explore / EPSILON 0.038971089999906755 / ACTION 1 / REWARD 0.1 / Q_MAX  12.761215 / Loss  0.21044988930225372
# fps: 8.196114065067817
# TIMESTEP 61192 / STATE explore / EPSILON 0.038970090999906754 / ACTION 1 / REWARD 0.1 / Q_MAX  13.608385 / Loss  0.5421291589736938
# fps: 8.626722802802968
# TIMESTEP 61193 / STATE explore / EPSILON 0.03896909199990675 / ACTION 1 / REWARD 0.1 / Q_MAX  13.09005 / Loss  0.3402327597141266
# fps: 8.201146200156815
# TIMESTEP 61194 / STATE explore / EPSILON 0.03896809299990675 / ACTION 1 / REWARD 0.1 / Q_MAX  13.630548 / Loss  4.186323642730713
# fps: 10.157126182369437
# TIMESTEP 61195 / STATE explore / EPSILON 0.03896709399990675 / ACTION 0 / REWARD 0.1 / Q_MAX  13.216369 / Loss  0.5985955595970154
# fps: 10.129358520457696
# TIMESTEP 61196 / STATE explore / EPSILON 0.03896609499990675 / ACTION 0 / REWARD 0.1 / Q_MAX  11.830983 / Loss  0.15774956345558167
# fps: 10.018234061915555
# TIMESTEP 61197 / STATE explore / EPSILON 0.038965095999906746 / ACTION 0 / REWARD 0.1 / Q_MAX  12.703394 / Loss  0.5469105839729309
# fps: 9.845044503699253
# TIMESTEP 61198 / STATE explore / EPSILON 0.038964096999906744 / ACTION 0 / REWARD 0.1 / Q_MAX  13.621911 / Loss  0.5628817677497864
# fps: 10.112531734990826
# TIMESTEP 61199 / STATE explore / EPSILON 0.03896309799990674 / ACTION 0 / REWARD 0.1 / Q_MAX  12.961169 / Loss  0.4897392690181732
# fps: 10.16837945622265
# TIMESTEP 61200 / STATE explore / EPSILON 0.03896209899990674 / ACTION 0 / REWARD 0.1 / Q_MAX  13.57874 / Loss  0.4005153477191925
# fps: 9.709486550303255
# TIMESTEP 61201 / STATE explore / EPSILON 0.03896109999990674 / ACTION 0 / REWARD 0.1 / Q_MAX  14.318331 / Loss  0.08751542866230011
# fps: 10.707348578839074
# TIMESTEP 61202 / STATE explore / EPSILON 0.03896010099990674 / ACTION 0 / REWARD 0.1 / Q_MAX  14.139961 / Loss  1.3343818187713623
# fps: 8.56772485583611
# TIMESTEP 61203 / STATE explore / EPSILON 0.03895910199990674 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2683716 / Loss  3.0381569862365723
# fps: 10.075389390139614
# TIMESTEP 61204 / STATE explore / EPSILON 0.038958102999906735 / ACTION 0 / REWARD 0.1 / Q_MAX  13.295085 / Loss  0.08233299106359482
# fps: 10.365699287996778
# TIMESTEP 61205 / STATE explore / EPSILON 0.038957103999906734 / ACTION 0 / REWARD 0.1 / Q_MAX  12.960988 / Loss  1.7249293327331543
# ----------Random Action----------
# fps: 8.362100142548123
# TIMESTEP 61206 / STATE explore / EPSILON 0.03895610499990673 / ACTION 1 / REWARD 0.1 / Q_MAX  14.044465 / Loss  0.790831446647644
# ----------Random Action----------
# fps: 10.399960327299777
# TIMESTEP 61207 / STATE explore / EPSILON 0.03895510599990673 / ACTION 0 / REWARD 0.1 / Q_MAX  13.363553 / Loss  0.7635802030563354
# fps: 10.116531877790347
# TIMESTEP 61208 / STATE explore / EPSILON 0.03895410699990673 / ACTION 0 / REWARD 0.1 / Q_MAX  13.582548 / Loss  0.6427596807479858
# fps: 10.030188823630693
# TIMESTEP 61209 / STATE explore / EPSILON 0.03895310799990673 / ACTION 0 / REWARD 0.1 / Q_MAX  13.204153 / Loss  3.2136037349700928
# fps: 9.9905056582561
# TIMESTEP 61210 / STATE explore / EPSILON 0.038952108999906726 / ACTION 0 / REWARD 0.1 / Q_MAX  13.169438 / Loss  1.1637184619903564
# fps: 10.257755734413328
# TIMESTEP 61211 / STATE explore / EPSILON 0.038951109999906725 / ACTION 0 / REWARD 0.1 / Q_MAX  15.052313 / Loss  0.6434314250946045
# fps: 10.535672749651473
# TIMESTEP 61212 / STATE explore / EPSILON 0.03895011099990672 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.8933723 / Loss  0.644611120223999
# fps: 9.541248006697042
# TIMESTEP 61213 / STATE explore / EPSILON 0.03894911199990672 / ACTION 0 / REWARD -1 / Q_MAX  13.078199 / Loss  0.3656231760978699
# fps: 10.694844204191952
# TIMESTEP 61214 / STATE explore / EPSILON 0.03894811299990672 / ACTION 0 / REWARD 0.1 / Q_MAX  13.345494 / Loss  0.3487647771835327
# fps: 10.429700360561979
# TIMESTEP 61215 / STATE explore / EPSILON 0.03894711399990672 / ACTION 0 / REWARD 0.1 / Q_MAX  13.721729 / Loss  0.9080548286437988
# fps: 10.160817070098258
# TIMESTEP 61216 / STATE explore / EPSILON 0.03894611499990672 / ACTION 0 / REWARD 0.1 / Q_MAX  14.150438 / Loss  0.5488827228546143
# fps: 10.471309592761989
# TIMESTEP 61217 / STATE explore / EPSILON 0.038945115999906715 / ACTION 0 / REWARD 0.1 / Q_MAX  13.820036 / Loss  0.6277844309806824
# fps: 10.090830135569162
# TIMESTEP 61218 / STATE explore / EPSILON 0.038944116999906714 / ACTION 0 / REWARD 0.1 / Q_MAX  22.765617 / Loss  0.5384193062782288
# ----------Random Action----------
# fps: 10.567472984855394
# TIMESTEP 61219 / STATE explore / EPSILON 0.03894311799990671 / ACTION 0 / REWARD 0.1 / Q_MAX  15.03929 / Loss  0.5120997428894043
# fps: 10.41341281447146
# TIMESTEP 61220 / STATE explore / EPSILON 0.03894211899990671 / ACTION 0 / REWARD 0.1 / Q_MAX  15.088897 / Loss  7.126296043395996
# fps: 10.574159977411158
# TIMESTEP 61221 / STATE explore / EPSILON 0.03894111999990671 / ACTION 0 / REWARD 0.1 / Q_MAX  14.567172 / Loss  0.2599475681781769
# fps: 10.255774262170819
# TIMESTEP 61222 / STATE explore / EPSILON 0.03894012099990671 / ACTION 0 / REWARD 0.1 / Q_MAX  14.828096 / Loss  0.5340534448623657
# fps: 8.418645727957351
# TIMESTEP 61223 / STATE explore / EPSILON 0.038939121999906706 / ACTION 0 / REWARD 0.1 / Q_MAX  13.274171 / Loss  2.745079278945923
# fps: 8.746843731883
# TIMESTEP 61224 / STATE explore / EPSILON 0.038938122999906705 / ACTION 1 / REWARD 0.1 / Q_MAX  13.037536 / Loss  0.10292267054319382
# fps: 8.457519871916375
# TIMESTEP 61225 / STATE explore / EPSILON 0.0389371239999067 / ACTION 1 / REWARD 0.1 / Q_MAX  23.239332 / Loss  1.8563599586486816
# fps: 8.423481212218585
# TIMESTEP 61226 / STATE explore / EPSILON 0.0389361249999067 / ACTION 1 / REWARD 0.1 / Q_MAX  14.03407 / Loss  0.693156361579895
# fps: 8.34885077262078
# TIMESTEP 61227 / STATE explore / EPSILON 0.0389351259999067 / ACTION 1 / REWARD 0.1 / Q_MAX  14.268223 / Loss  0.22745481133460999
# fps: 8.601054034656004
# TIMESTEP 61228 / STATE explore / EPSILON 0.0389341269999067 / ACTION 1 / REWARD 0.1 / Q_MAX  14.126305 / Loss  9.88372802734375
# fps: 7.830307103519089
# TIMESTEP 61229 / STATE explore / EPSILON 0.0389331279999067 / ACTION 1 / REWARD 0.1 / Q_MAX  13.787302 / Loss  0.4182867705821991
# fps: 10.300556003064893
# TIMESTEP 61230 / STATE explore / EPSILON 0.038932128999906696 / ACTION 0 / REWARD 0.1 / Q_MAX  13.074087 / Loss  0.23755624890327454
# fps: 7.874527356085325
# TIMESTEP 61231 / STATE explore / EPSILON 0.038931129999906694 / ACTION 1 / REWARD 0.1 / Q_MAX  14.22827 / Loss  0.2657582461833954
# fps: 8.422686188317934
# TIMESTEP 61232 / STATE explore / EPSILON 0.03893013099990669 / ACTION 1 / REWARD 0.1 / Q_MAX  12.46859 / Loss  0.2386326640844345
# fps: 9.286604037188006
# TIMESTEP 61233 / STATE explore / EPSILON 0.03892913199990669 / ACTION 0 / REWARD 0.1 / Q_MAX  13.242534 / Loss  0.15017035603523254
# fps: 10.070212674007097
# TIMESTEP 61234 / STATE explore / EPSILON 0.03892813299990669 / ACTION 0 / REWARD 0.1 / Q_MAX  13.45569 / Loss  0.21013383567333221
# fps: 10.037221657194136
# TIMESTEP 61235 / STATE explore / EPSILON 0.03892713399990669 / ACTION 0 / REWARD 0.1 / Q_MAX  14.086282 / Loss  0.2888093888759613
# fps: 10.40669513372155
# TIMESTEP 61236 / STATE explore / EPSILON 0.038926134999906686 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.4104301 / Loss  0.2507544159889221
# fps: 10.168601324683133
# TIMESTEP 61237 / STATE explore / EPSILON 0.038925135999906685 / ACTION 0 / REWARD 0.1 / Q_MAX  13.766273 / Loss  0.22674965858459473
# fps: 9.488838866579945
# TIMESTEP 61238 / STATE explore / EPSILON 0.03892413699990668 / ACTION 0 / REWARD 0.1 / Q_MAX  13.847084 / Loss  1.4842772483825684
# fps: 9.964823917645298
# TIMESTEP 61239 / STATE explore / EPSILON 0.03892313799990668 / ACTION 0 / REWARD 0.1 / Q_MAX  15.860726 / Loss  0.1548054814338684
# fps: 9.737483110382646
# TIMESTEP 61240 / STATE explore / EPSILON 0.03892213899990668 / ACTION 0 / REWARD 0.1 / Q_MAX  13.3265 / Loss  0.21913820505142212
# fps: 8.274110854002316
# TIMESTEP 61241 / STATE explore / EPSILON 0.03892113999990668 / ACTION 0 / REWARD 0.1 / Q_MAX  4.8264236 / Loss  0.7940493822097778
# fps: 10.429596622189509
# TIMESTEP 61242 / STATE explore / EPSILON 0.03892014099990668 / ACTION 0 / REWARD 0.1 / Q_MAX  15.230591 / Loss  1.2649827003479004
# fps: 10.782826880559412
# TIMESTEP 61243 / STATE explore / EPSILON 0.038919141999906676 / ACTION 0 / REWARD 0.1 / Q_MAX  12.474622 / Loss  4.990074634552002
# fps: 10.688439534676299
# TIMESTEP 61244 / STATE explore / EPSILON 0.038918142999906674 / ACTION 0 / REWARD 0.1 / Q_MAX  14.535484 / Loss  0.6703921556472778
# fps: 9.295392089073276
# TIMESTEP 61245 / STATE explore / EPSILON 0.03891714399990667 / ACTION 0 / REWARD 0.1 / Q_MAX  12.647918 / Loss  0.1567021608352661
# fps: 9.341579935544653
# TIMESTEP 61246 / STATE explore / EPSILON 0.03891614499990667 / ACTION 0 / REWARD 0.1 / Q_MAX  14.069963 / Loss  0.15372136235237122
# fps: 9.394432287268712
# TIMESTEP 61247 / STATE explore / EPSILON 0.03891514599990667 / ACTION 0 / REWARD 0.1 / Q_MAX  13.626799 / Loss  0.2990836501121521
# fps: 9.565902787914172
# TIMESTEP 61248 / STATE explore / EPSILON 0.03891414699990667 / ACTION 0 / REWARD 0.1 / Q_MAX  13.174945 / Loss  0.1946028470993042
# fps: 8.69134492647912
# TIMESTEP 61249 / STATE explore / EPSILON 0.038913147999906667 / ACTION 0 / REWARD 0.1 / Q_MAX  14.450354 / Loss  0.39108791947364807
# fps: 9.659509689900165
# TIMESTEP 61250 / STATE explore / EPSILON 0.038912148999906665 / ACTION 0 / REWARD 0.1 / Q_MAX  13.615443 / Loss  0.215495765209198
# fps: 8.953101019264635
# TIMESTEP 61251 / STATE explore / EPSILON 0.03891114999990666 / ACTION 0 / REWARD 0.1 / Q_MAX  12.689035 / Loss  0.9721429347991943
# fps: 9.201243416015672
# TIMESTEP 61252 / STATE explore / EPSILON 0.03891015099990666 / ACTION 0 / REWARD 0.1 / Q_MAX  12.758443 / Loss  0.7203059196472168
# fps: 9.335404749716218
# TIMESTEP 61253 / STATE explore / EPSILON 0.03890915199990666 / ACTION 0 / REWARD 0.1 / Q_MAX  13.020238 / Loss  2.1095023155212402
# fps: 9.697072824501252
# TIMESTEP 61254 / STATE explore / EPSILON 0.03890815299990666 / ACTION 0 / REWARD 0.1 / Q_MAX  13.584483 / Loss  0.13061563670635223
# fps: 8.64452038137008
# TIMESTEP 61255 / STATE explore / EPSILON 0.03890715399990666 / ACTION 0 / REWARD 0.1 / Q_MAX  12.662648 / Loss  0.5030391812324524
# fps: 9.722991330149751
# TIMESTEP 61256 / STATE explore / EPSILON 0.038906154999906656 / ACTION 0 / REWARD 0.1 / Q_MAX  13.93539 / Loss  0.35291117429733276
# fps: 7.851884577799909
# TIMESTEP 61257 / STATE explore / EPSILON 0.038905155999906654 / ACTION 1 / REWARD 0.1 / Q_MAX  10.786996 / Loss  0.13568156957626343
# fps: 9.568477869080589
# TIMESTEP 61258 / STATE explore / EPSILON 0.03890415699990665 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7792577 / Loss  0.1816645860671997
# fps: 6.789052838764397
# TIMESTEP 61259 / STATE explore / EPSILON 0.03890315799990665 / ACTION 1 / REWARD 0.1 / Q_MAX  13.697599 / Loss  0.834088921546936
# fps: 10.120437507087894
# TIMESTEP 61260 / STATE explore / EPSILON 0.03890215899990665 / ACTION 0 / REWARD 0.1 / Q_MAX  13.855227 / Loss  0.26167428493499756
# fps: 9.209547021496169
# TIMESTEP 61261 / STATE explore / EPSILON 0.03890115999990665 / ACTION 0 / REWARD 0.1 / Q_MAX  13.9731455 / Loss  0.18232408165931702
# fps: 9.872644118623203
# TIMESTEP 61262 / STATE explore / EPSILON 0.03890016099990665 / ACTION 0 / REWARD 0.1 / Q_MAX  12.503021 / Loss  0.2414032518863678
# fps: 8.274225112051006
# TIMESTEP 61263 / STATE explore / EPSILON 0.038899161999906645 / ACTION 0 / REWARD 0.1 / Q_MAX  12.968625 / Loss  0.9777564406394958
# fps: 9.779690775253627
# TIMESTEP 61264 / STATE explore / EPSILON 0.038898162999906644 / ACTION 0 / REWARD 0.1 / Q_MAX  13.447951 / Loss  0.5190734267234802
# fps: 9.618441118263394
# TIMESTEP 61265 / STATE explore / EPSILON 0.03889716399990664 / ACTION 0 / REWARD 0.1 / Q_MAX  12.820188 / Loss  1.858305811882019
# fps: 9.926524429928882
# TIMESTEP 61266 / STATE explore / EPSILON 0.03889616499990664 / ACTION 0 / REWARD 0.1 / Q_MAX  12.365533 / Loss  0.15672869980335236
# ----------Random Action----------
# fps: 9.07903207302528
# TIMESTEP 61267 / STATE explore / EPSILON 0.03889516599990664 / ACTION 0 / REWARD 0.1 / Q_MAX  11.9260645 / Loss  2.3123791217803955
# fps: 10.39449632229029
# TIMESTEP 61268 / STATE explore / EPSILON 0.03889416699990664 / ACTION 0 / REWARD 0.1 / Q_MAX  11.267002 / Loss  0.3769051730632782
# fps: 10.42459369648587
# TIMESTEP 61269 / STATE explore / EPSILON 0.038893167999906636 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.18703742 / Loss  2.2307393550872803
# fps: 10.491871515157579
# TIMESTEP 61270 / STATE explore / EPSILON 0.038892168999906634 / ACTION 0 / REWARD 0.1 / Q_MAX  12.91728 / Loss  0.19701451063156128
# fps: 10.386491111204661
# TIMESTEP 61271 / STATE explore / EPSILON 0.03889116999990663 / ACTION 0 / REWARD 0.1 / Q_MAX  12.298773 / Loss  0.2122543752193451
# fps: 8.517010449537223
# TIMESTEP 61272 / STATE explore / EPSILON 0.03889017099990663 / ACTION 1 / REWARD 0.1 / Q_MAX  12.344099 / Loss  0.2948438227176666
# fps: 8.386813221970499
# TIMESTEP 61273 / STATE explore / EPSILON 0.03888917199990663 / ACTION 1 / REWARD 0.1 / Q_MAX  12.409611 / Loss  0.21868950128555298
# fps: 11.166348969703424
# TIMESTEP 61274 / STATE explore / EPSILON 0.03888817299990663 / ACTION 0 / REWARD 0.1 / Q_MAX  13.587865 / Loss  0.692499577999115
# fps: 9.318439130164316
# TIMESTEP 61275 / STATE explore / EPSILON 0.03888717399990663 / ACTION 1 / REWARD 0.1 / Q_MAX  12.721356 / Loss  0.44172215461730957
# fps: 11.116304586932266
# TIMESTEP 61276 / STATE explore / EPSILON 0.038886174999906625 / ACTION 0 / REWARD 0.1 / Q_MAX  12.731524 / Loss  0.2965609133243561
# fps: 11.040082544562482
# TIMESTEP 61277 / STATE explore / EPSILON 0.038885175999906624 / ACTION 0 / REWARD 0.1 / Q_MAX  12.732859 / Loss  0.6555584073066711
# fps: 9.7744944734064
# TIMESTEP 61278 / STATE explore / EPSILON 0.03888417699990662 / ACTION 0 / REWARD 0.1 / Q_MAX  12.727697 / Loss  0.13389693200588226
# fps: 10.727202510505196
# TIMESTEP 61279 / STATE explore / EPSILON 0.03888317799990662 / ACTION 0 / REWARD 0.1 / Q_MAX  12.013605 / Loss  0.3057098388671875
# fps: 11.055680320522958
# TIMESTEP 61280 / STATE explore / EPSILON 0.03888217899990662 / ACTION 0 / REWARD 0.1 / Q_MAX  12.241289 / Loss  0.4141346514225006
# fps: 10.4093811656967
# TIMESTEP 61281 / STATE explore / EPSILON 0.03888117999990662 / ACTION 0 / REWARD 0.1 / Q_MAX  11.509568 / Loss  0.2141313999891281
# fps: 10.66005184771006
# TIMESTEP 61282 / STATE explore / EPSILON 0.038880180999906616 / ACTION 0 / REWARD 0.1 / Q_MAX  12.935879 / Loss  0.3869684040546417
# fps: 9.931954232022429
# TIMESTEP 61283 / STATE explore / EPSILON 0.038879181999906615 / ACTION 0 / REWARD 0.1 / Q_MAX  11.703712 / Loss  0.39972516894340515
# fps: 8.518238554319636
# TIMESTEP 61284 / STATE explore / EPSILON 0.03887818299990661 / ACTION 1 / REWARD 0.1 / Q_MAX  13.843349 / Loss  0.6877042651176453
# fps: 8.525805258215199
# TIMESTEP 61285 / STATE explore / EPSILON 0.03887718399990661 / ACTION 1 / REWARD 0.1 / Q_MAX  12.062819 / Loss  0.2608712911605835
# fps: 8.94374633501434
# TIMESTEP 61286 / STATE explore / EPSILON 0.03887618499990661 / ACTION 1 / REWARD 0.1 / Q_MAX  12.822062 / Loss  1.638796091079712
# ----------Random Action----------
# fps: 10.80861327863276
# TIMESTEP 61287 / STATE explore / EPSILON 0.03887518599990661 / ACTION 0 / REWARD 0.1 / Q_MAX  12.202831 / Loss  0.17712342739105225
# fps: 8.379206530273034
# TIMESTEP 61288 / STATE explore / EPSILON 0.03887418699990661 / ACTION 1 / REWARD 0.1 / Q_MAX  13.743649 / Loss  0.23296254873275757
# fps: 10.100185421532979
# TIMESTEP 61289 / STATE explore / EPSILON 0.038873187999906605 / ACTION 0 / REWARD 0.1 / Q_MAX  11.640807 / Loss  0.3278128206729889
# fps: 10.499645781546095
# TIMESTEP 61290 / STATE explore / EPSILON 0.038872188999906604 / ACTION 0 / REWARD 0.1 / Q_MAX  12.221766 / Loss  0.20033405721187592
# fps: 9.754104612980344
# TIMESTEP 61291 / STATE explore / EPSILON 0.0388711899999066 / ACTION 0 / REWARD 0.1 / Q_MAX  13.166729 / Loss  0.19336768984794617
# fps: 9.072276621654652
# TIMESTEP 61292 / STATE explore / EPSILON 0.0388701909999066 / ACTION 1 / REWARD 0.1 / Q_MAX  12.565602 / Loss  0.12039916962385178
# fps: 9.42152777621787
# TIMESTEP 61293 / STATE explore / EPSILON 0.0388691919999066 / ACTION 1 / REWARD 0.1 / Q_MAX  11.426362 / Loss  0.2554095387458801
# fps: 8.416010530286613
# TIMESTEP 61294 / STATE explore / EPSILON 0.0388681929999066 / ACTION 1 / REWARD 0.1 / Q_MAX  14.035387 / Loss  0.27116113901138306
# fps: 7.856811834190951
# TIMESTEP 61295 / STATE explore / EPSILON 0.038867193999906596 / ACTION 1 / REWARD 0.1 / Q_MAX  12.526886 / Loss  0.2949947118759155
# fps: 8.223738490737691
# TIMESTEP 61296 / STATE explore / EPSILON 0.038866194999906595 / ACTION 1 / REWARD 0.1 / Q_MAX  13.082515 / Loss  0.3955186605453491
# fps: 10.916696598214518
# TIMESTEP 61297 / STATE explore / EPSILON 0.03886519599990659 / ACTION 0 / REWARD 0.1 / Q_MAX  3.7986724 / Loss  8.741826057434082
# fps: 10.936108967272272
# TIMESTEP 61298 / STATE explore / EPSILON 0.03886419699990659 / ACTION 0 / REWARD 0.1 / Q_MAX  13.897583 / Loss  0.23543649911880493
# fps: 10.92704886855666
# TIMESTEP 61299 / STATE explore / EPSILON 0.03886319799990659 / ACTION 0 / REWARD 0.1 / Q_MAX  13.220085 / Loss  0.290321409702301
# fps: 10.259963845666494
# TIMESTEP 61300 / STATE explore / EPSILON 0.03886219899990659 / ACTION 0 / REWARD 0.1 / Q_MAX  12.12576 / Loss  0.4058343470096588
# fps: 10.605817858154307
# TIMESTEP 61301 / STATE explore / EPSILON 0.03886119999990659 / ACTION 0 / REWARD 0.1 / Q_MAX  14.33615 / Loss  0.4449174404144287
# ----------Random Action----------
# fps: 9.279987963882798
# TIMESTEP 61302 / STATE explore / EPSILON 0.038860200999906586 / ACTION 1 / REWARD 0.1 / Q_MAX  11.984918 / Loss  0.1984533816576004
# fps: 9.331313252663593
# TIMESTEP 61303 / STATE explore / EPSILON 0.038859201999906584 / ACTION 1 / REWARD 0.1 / Q_MAX  13.834935 / Loss  0.18538260459899902
# fps: 11.122318068877004
# TIMESTEP 61304 / STATE explore / EPSILON 0.03885820299990658 / ACTION 0 / REWARD 0.1 / Q_MAX  12.554744 / Loss  0.13977986574172974
# fps: 8.889288272669857
# TIMESTEP 61305 / STATE explore / EPSILON 0.03885720399990658 / ACTION 1 / REWARD 0.1 / Q_MAX  11.085313 / Loss  0.175820991396904
# fps: 9.290491780039073
# TIMESTEP 61306 / STATE explore / EPSILON 0.03885620499990658 / ACTION 1 / REWARD 0.1 / Q_MAX  14.0866165 / Loss  0.9507728815078735
# fps: 11.052038840067983
# ...
# fps: 11.998020498708462
# TIMESTEP 61712 / STATE explore / EPSILON 0.03845061099990596 / ACTION 0 / REWARD 0.1 / Q_MAX  16.832647 / Loss  0.4980018138885498
# fps: 12.010423169216143
# TIMESTEP 61713 / STATE explore / EPSILON 0.03844961199990596 / ACTION 0 / REWARD 0.1 / Q_MAX  16.151382 / Loss  2.0589277744293213
# fps: 11.104061928323896
# TIMESTEP 61714 / STATE explore / EPSILON 0.03844861299990596 / ACTION 0 / REWARD 0.1 / Q_MAX  14.745321 / Loss  0.49819377064704895
# fps: 12.165054541552223
# TIMESTEP 61715 / STATE explore / EPSILON 0.038447613999905955 / ACTION 0 / REWARD 0.1 / Q_MAX  15.601771 / Loss  0.583112359046936
# fps: 11.74457265902606
# TIMESTEP 61716 / STATE explore / EPSILON 0.038446614999905954 / ACTION 0 / REWARD 0.1 / Q_MAX  16.118284 / Loss  0.6031887531280518
# fps: 11.649032372742019
# TIMESTEP 61717 / STATE explore / EPSILON 0.03844561599990595 / ACTION 0 / REWARD 0.1 / Q_MAX  16.102655 / Loss  0.4502527415752411
# fps: 11.914959377308108
# TIMESTEP 61718 / STATE explore / EPSILON 0.03844461699990595 / ACTION 0 / REWARD 0.1 / Q_MAX  16.632677 / Loss  0.729961633682251
# fps: 11.090761013274102
# TIMESTEP 61719 / STATE explore / EPSILON 0.03844361799990595 / ACTION 0 / REWARD 0.1 / Q_MAX  17.279322 / Loss  0.6111224889755249
# fps: 10.025441838007868
# TIMESTEP 61720 / STATE explore / EPSILON 0.03844261899990595 / ACTION 1 / REWARD 0.1 / Q_MAX  17.327555 / Loss  0.3137926757335663
# fps: 11.918108016719376
# TIMESTEP 61721 / STATE explore / EPSILON 0.038441619999905946 / ACTION 0 / REWARD 0.1 / Q_MAX  15.92339 / Loss  0.35937923192977905
# fps: 9.858813408330729
# TIMESTEP 61722 / STATE explore / EPSILON 0.038440620999905944 / ACTION 1 / REWARD 0.1 / Q_MAX  17.149302 / Loss  0.26871243119239807
# fps: 9.893253073432149
# TIMESTEP 61723 / STATE explore / EPSILON 0.03843962199990594 / ACTION 1 / REWARD 0.1 / Q_MAX  16.5773 / Loss  0.4464458227157593
# fps: 9.53797174745536
# TIMESTEP 61724 / STATE explore / EPSILON 0.03843862299990594 / ACTION 1 / REWARD 0.1 / Q_MAX  16.128843 / Loss  0.5222429633140564
# fps: 9.969774329572951
# TIMESTEP 61725 / STATE explore / EPSILON 0.03843762399990594 / ACTION 1 / REWARD 0.1 / Q_MAX  16.871944 / Loss  0.9944783449172974
# fps: 9.315748559650673
# TIMESTEP 61726 / STATE explore / EPSILON 0.03843662499990594 / ACTION 1 / REWARD 0.1 / Q_MAX  15.964469 / Loss  0.4951097071170807
# fps: 8.958397942750716
# TIMESTEP 61727 / STATE explore / EPSILON 0.03843562599990594 / ACTION 1 / REWARD 0.1 / Q_MAX  19.056623 / Loss  1.1672050952911377
# fps: 9.531057770748545
# TIMESTEP 61728 / STATE explore / EPSILON 0.038434626999905935 / ACTION 1 / REWARD 0.1 / Q_MAX  16.989815 / Loss  0.4250999987125397
# ----------Random Action----------
# fps: 9.787038830307287
# TIMESTEP 61729 / STATE explore / EPSILON 0.038433627999905934 / ACTION 1 / REWARD 0.1 / Q_MAX  14.002831 / Loss  0.32671231031417847
# fps: 1.1492855984181891
# TIMESTEP 61730 / STATE explore / EPSILON 0.03843262899990593 / ACTION 0 / REWARD -1 / Q_MAX  29.006508 / Loss  0.540987491607666
# fps: 9.920912828130396
# TIMESTEP 61731 / STATE explore / EPSILON 0.03843162999990593 / ACTION 0 / REWARD 0.1 / Q_MAX  18.491745 / Loss  4.840635299682617
# fps: 9.257968250604792
# TIMESTEP 61732 / STATE explore / EPSILON 0.03843063099990593 / ACTION 1 / REWARD 0.1 / Q_MAX  17.918533 / Loss  0.4861180782318115
# fps: 9.149538520604603
# TIMESTEP 61733 / STATE explore / EPSILON 0.03842963199990593 / ACTION 1 / REWARD 0.1 / Q_MAX  21.09943 / Loss  6.250026702880859
# fps: 9.218777336726934
# TIMESTEP 61734 / STATE explore / EPSILON 0.038428632999905926 / ACTION 1 / REWARD 0.1 / Q_MAX  18.595438 / Loss  2.577888250350952
# fps: 9.279782646692464
# TIMESTEP 61735 / STATE explore / EPSILON 0.038427633999905925 / ACTION 1 / REWARD 0.1 / Q_MAX  17.19054 / Loss  0.919745683670044
# fps: 9.962953989405925
# TIMESTEP 61736 / STATE explore / EPSILON 0.03842663499990592 / ACTION 1 / REWARD 0.1 / Q_MAX  17.007872 / Loss  0.4995843768119812
# fps: 12.347955110163802
# TIMESTEP 61737 / STATE explore / EPSILON 0.03842563599990592 / ACTION 0 / REWARD 0.1 / Q_MAX  19.404055 / Loss  2.2972447872161865
# fps: 12.142409662272094
# TIMESTEP 61738 / STATE explore / EPSILON 0.03842463699990592 / ACTION 0 / REWARD 0.1 / Q_MAX  18.139782 / Loss  0.4995498061180115
# fps: 11.60979093372602
# TIMESTEP 61739 / STATE explore / EPSILON 0.03842363799990592 / ACTION 0 / REWARD 0.1 / Q_MAX  19.002361 / Loss  2.4875762462615967
# fps: 11.720581906789844
# TIMESTEP 61740 / STATE explore / EPSILON 0.03842263899990592 / ACTION 0 / REWARD 0.1 / Q_MAX  18.740866 / Loss  1.4222404956817627
# fps: 11.316596201633422
# TIMESTEP 61741 / STATE explore / EPSILON 0.038421639999905915 / ACTION 0 / REWARD 0.1 / Q_MAX  18.229137 / Loss  0.5362575650215149
# fps: 11.594738791735546
# TIMESTEP 61742 / STATE explore / EPSILON 0.038420640999905914 / ACTION 0 / REWARD 0.1 / Q_MAX  17.781294 / Loss  0.5382963418960571
# fps: 11.74796092139464
# TIMESTEP 61743 / STATE explore / EPSILON 0.03841964199990591 / ACTION 0 / REWARD 0.1 / Q_MAX  15.17489 / Loss  0.6299930810928345
# fps: 11.026325613186467
# TIMESTEP 61744 / STATE explore / EPSILON 0.03841864299990591 / ACTION 0 / REWARD 0.1 / Q_MAX  16.62149 / Loss  1.7827743291854858
# fps: 12.033544588883693
# TIMESTEP 61745 / STATE explore / EPSILON 0.03841764399990591 / ACTION 0 / REWARD 0.1 / Q_MAX  18.28191 / Loss  1.0812170505523682
# fps: 11.776063250339723
# TIMESTEP 61746 / STATE explore / EPSILON 0.03841664499990591 / ACTION 0 / REWARD 0.1 / Q_MAX  17.66747 / Loss  2.239469051361084
# ----------Random Action----------
# fps: 10.104686991820952
# TIMESTEP 61747 / STATE explore / EPSILON 0.038415645999905906 / ACTION 1 / REWARD 0.1 / Q_MAX  18.74931 / Loss  0.4223059415817261
# fps: 11.529496493846707
# TIMESTEP 61748 / STATE explore / EPSILON 0.038414646999905905 / ACTION 0 / REWARD 0.1 / Q_MAX  20.274729 / Loss  0.19590914249420166
# fps: 9.167837517650197
# TIMESTEP 61749 / STATE explore / EPSILON 0.0384136479999059 / ACTION 1 / REWARD 0.1 / Q_MAX  18.597599 / Loss  0.9552655220031738
# ----------Random Action----------
# fps: 12.206298855124004
# TIMESTEP 61750 / STATE explore / EPSILON 0.0384126489999059 / ACTION 0 / REWARD 0.1 / Q_MAX  17.709232 / Loss  0.30250084400177
# fps: 9.453955316731882
# TIMESTEP 61751 / STATE explore / EPSILON 0.0384116499999059 / ACTION 1 / REWARD 0.1 / Q_MAX  18.131687 / Loss  0.8944913148880005
# fps: 10.121756337705275
# TIMESTEP 61752 / STATE explore / EPSILON 0.0384106509999059 / ACTION 1 / REWARD 0.1 / Q_MAX  17.600368 / Loss  1.5800204277038574
# fps: 9.988721231519586
# TIMESTEP 61753 / STATE explore / EPSILON 0.0384096519999059 / ACTION 1 / REWARD 0.1 / Q_MAX  18.243013 / Loss  0.41809916496276855
# fps: 9.962173087931063
# TIMESTEP 61754 / STATE explore / EPSILON 0.038408652999905896 / ACTION 1 / REWARD 0.1 / Q_MAX  17.314432 / Loss  4.207869529724121
# fps: 9.793643232742115
# TIMESTEP 61755 / STATE explore / EPSILON 0.038407653999905894 / ACTION 1 / REWARD 0.1 / Q_MAX  15.843442 / Loss  1.302189826965332
# fps: 9.472102907368011
# TIMESTEP 61756 / STATE explore / EPSILON 0.03840665499990589 / ACTION 1 / REWARD 0.1 / Q_MAX  19.361374 / Loss  0.6841272115707397
# fps: 9.969489962302182
# TIMESTEP 61757 / STATE explore / EPSILON 0.03840565599990589 / ACTION 1 / REWARD 0.1 / Q_MAX  17.680664 / Loss  0.44157272577285767
# fps: 9.342224954450488
# TIMESTEP 61758 / STATE explore / EPSILON 0.03840465699990589 / ACTION 1 / REWARD 0.1 / Q_MAX  16.088799 / Loss  9.546510696411133
# fps: 11.575411347165417
# TIMESTEP 61759 / STATE explore / EPSILON 0.03840365799990589 / ACTION 0 / REWARD 0.1 / Q_MAX  17.79095 / Loss  0.37559598684310913
# fps: 11.182693410047698
# TIMESTEP 61760 / STATE explore / EPSILON 0.038402658999905886 / ACTION 0 / REWARD 0.1 / Q_MAX  17.215538 / Loss  1.106113076210022
# fps: 10.364649075552173
# TIMESTEP 61761 / STATE explore / EPSILON 0.038401659999905885 / ACTION 0 / REWARD 0.1 / Q_MAX  16.522484 / Loss  0.4435219168663025
# fps: 12.197531007808298
# TIMESTEP 61762 / STATE explore / EPSILON 0.03840066099990588 / ACTION 0 / REWARD 0.1 / Q_MAX  18.004608 / Loss  0.7786685228347778
# fps: 11.003906444715543
# TIMESTEP 61763 / STATE explore / EPSILON 0.03839966199990588 / ACTION 0 / REWARD 0.1 / Q_MAX  16.311846 / Loss  0.9074591398239136
# fps: 11.616672067446041
# TIMESTEP 61764 / STATE explore / EPSILON 0.03839866299990588 / ACTION 0 / REWARD 0.1 / Q_MAX  16.702099 / Loss  0.7262262105941772
# fps: 8.616957370313303
# TIMESTEP 61765 / STATE explore / EPSILON 0.03839766399990588 / ACTION 1 / REWARD 0.1 / Q_MAX  16.025816 / Loss  3.265516996383667
# fps: 9.147463256862826
# TIMESTEP 61766 / STATE explore / EPSILON 0.03839666499990588 / ACTION 0 / REWARD 0.1 / Q_MAX  16.651814 / Loss  0.4863775968551636
# fps: 10.648847093232861
# TIMESTEP 61767 / STATE explore / EPSILON 0.038395665999905876 / ACTION 0 / REWARD 0.1 / Q_MAX  17.408728 / Loss  2.3070571422576904
# fps: 11.661696300724286
# TIMESTEP 61768 / STATE explore / EPSILON 0.038394666999905874 / ACTION 0 / REWARD 0.1 / Q_MAX  17.557297 / Loss  0.6448148488998413
# fps: 12.166960133902283
# TIMESTEP 61769 / STATE explore / EPSILON 0.03839366799990587 / ACTION 0 / REWARD 0.1 / Q_MAX  16.770548 / Loss  1.575505256652832
# fps: 11.450180039256475
# TIMESTEP 61770 / STATE explore / EPSILON 0.03839266899990587 / ACTION 0 / REWARD 0.1 / Q_MAX  18.50761 / Loss  0.36539214849472046
# fps: 12.185199280677953
# TIMESTEP 61771 / STATE explore / EPSILON 0.03839166999990587 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.4240674 / Loss  0.46176058053970337
# fps: 11.80084631313586
# TIMESTEP 61772 / STATE explore / EPSILON 0.03839067099990587 / ACTION 0 / REWARD 0.1 / Q_MAX  15.700387 / Loss  0.4327283501625061
# fps: 11.784400988986288
# TIMESTEP 61773 / STATE explore / EPSILON 0.03838967199990587 / ACTION 0 / REWARD 0.1 / Q_MAX  16.125475 / Loss  1.6264443397521973
# fps: 12.032232801379275
# TIMESTEP 61774 / STATE explore / EPSILON 0.038388672999905865 / ACTION 0 / REWARD 0.1 / Q_MAX  13.486531 / Loss  0.9028093814849854
# fps: 11.447148791231585
# TIMESTEP 61775 / STATE explore / EPSILON 0.038387673999905864 / ACTION 0 / REWARD 0.1 / Q_MAX  16.310955 / Loss  4.803335666656494
# fps: 11.958442150880995
# TIMESTEP 61776 / STATE explore / EPSILON 0.03838667499990586 / ACTION 0 / REWARD 0.1 / Q_MAX  15.878784 / Loss  0.8070778846740723
# fps: 11.861954280769133
# TIMESTEP 61777 / STATE explore / EPSILON 0.03838567599990586 / ACTION 0 / REWARD 0.1 / Q_MAX  15.150202 / Loss  0.5487878322601318
# fps: 11.52670820084809
# TIMESTEP 61778 / STATE explore / EPSILON 0.03838467699990586 / ACTION 0 / REWARD 0.1 / Q_MAX  19.067183 / Loss  1.132226586341858
# fps: 11.640238893452633
# TIMESTEP 61779 / STATE explore / EPSILON 0.03838367799990586 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.052158713 / Loss  0.21848106384277344
# fps: 9.273360807966464
# TIMESTEP 61780 / STATE explore / EPSILON 0.038382678999905856 / ACTION 1 / REWARD 0.1 / Q_MAX  17.42124 / Loss  4.404155254364014
# fps: 9.920232354075067
# TIMESTEP 61781 / STATE explore / EPSILON 0.038381679999905854 / ACTION 1 / REWARD 0.1 / Q_MAX  15.402031 / Loss  0.8307643532752991
# fps: 9.372683535082446
# TIMESTEP 61782 / STATE explore / EPSILON 0.03838068099990585 / ACTION 1 / REWARD 0.1 / Q_MAX  16.784142 / Loss  0.5192098021507263
# fps: 9.689747262394308
# TIMESTEP 61783 / STATE explore / EPSILON 0.03837968199990585 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0403578 / Loss  8.575303077697754
# fps: 9.696019233436589
# TIMESTEP 61784 / STATE explore / EPSILON 0.03837868299990585 / ACTION 1 / REWARD 0.1 / Q_MAX  17.73222 / Loss  0.7606258392333984
# fps: 10.191827689436646
# TIMESTEP 61785 / STATE explore / EPSILON 0.03837768399990585 / ACTION 1 / REWARD 0.1 / Q_MAX  14.959973 / Loss  0.4881567358970642
# fps: 11.832072352645802
# TIMESTEP 61786 / STATE explore / EPSILON 0.03837668499990585 / ACTION 0 / REWARD 0.1 / Q_MAX  16.13758 / Loss  1.7360116243362427
# fps: 12.10816303553953
# TIMESTEP 61787 / STATE explore / EPSILON 0.038375685999905845 / ACTION 0 / REWARD 0.1 / Q_MAX  19.191381 / Loss  0.7886894345283508
# fps: 11.821567582954952
# TIMESTEP 61788 / STATE explore / EPSILON 0.038374686999905844 / ACTION 0 / REWARD 0.1 / Q_MAX  16.688757 / Loss  6.5709404945373535
# fps: 11.279922977210505
# TIMESTEP 61789 / STATE explore / EPSILON 0.03837368799990584 / ACTION 0 / REWARD 0.1 / Q_MAX  14.902342 / Loss  0.9349187612533569
# fps: 9.914815357630829
# TIMESTEP 61790 / STATE explore / EPSILON 0.03837268899990584 / ACTION 1 / REWARD 0.1 / Q_MAX  14.75822 / Loss  0.9317846298217773
# fps: 9.300689407428925
# TIMESTEP 61791 / STATE explore / EPSILON 0.03837168999990584 / ACTION 1 / REWARD 0.1 / Q_MAX  18.512205 / Loss  0.8273338079452515
# fps: 9.964019052370261
# TIMESTEP 61792 / STATE explore / EPSILON 0.03837069099990584 / ACTION 1 / REWARD 0.1 / Q_MAX  15.738587 / Loss  1.3362329006195068
# fps: 8.765855350880493
# TIMESTEP 61793 / STATE explore / EPSILON 0.038369691999905836 / ACTION 1 / REWARD 0.1 / Q_MAX  17.663568 / Loss  0.8176740407943726
# fps: 10.28968995785311
# TIMESTEP 61794 / STATE explore / EPSILON 0.038368692999905835 / ACTION 1 / REWARD 0.1 / Q_MAX  18.03297 / Loss  0.6251150369644165
# fps: 9.633728929180917
# TIMESTEP 61795 / STATE explore / EPSILON 0.03836769399990583 / ACTION 1 / REWARD 0.1 / Q_MAX  16.287863 / Loss  0.8025540709495544
# fps: 11.944819730022214
# TIMESTEP 61796 / STATE explore / EPSILON 0.03836669499990583 / ACTION 0 / REWARD 0.1 / Q_MAX  18.316847 / Loss  0.3249359726905823
# ----------Random Action----------
# fps: 11.623722425451724
# TIMESTEP 61797 / STATE explore / EPSILON 0.03836569599990583 / ACTION 0 / REWARD 0.1 / Q_MAX  0.0558825 / Loss  0.5140242576599121
# fps: 12.202996121741812
# TIMESTEP 61798 / STATE explore / EPSILON 0.03836469699990583 / ACTION 0 / REWARD 0.1 / Q_MAX  18.759233 / Loss  0.7274113893508911
# fps: 11.853941983766306
# TIMESTEP 61799 / STATE explore / EPSILON 0.03836369799990583 / ACTION 0 / REWARD 0.1 / Q_MAX  19.690905 / Loss  0.6125977635383606
# fps: 11.6927760385159
# TIMESTEP 61800 / STATE explore / EPSILON 0.038362698999905825 / ACTION 0 / REWARD 0.1 / Q_MAX  22.053349 / Loss  0.89913409948349
# fps: 11.807058386373042
# TIMESTEP 61801 / STATE explore / EPSILON 0.038361699999905824 / ACTION 0 / REWARD 0.1 / Q_MAX  20.709978 / Loss  0.5017796158790588
# fps: 11.557740424359327
# TIMESTEP 61802 / STATE explore / EPSILON 0.03836070099990582 / ACTION 0 / REWARD 0.1 / Q_MAX  22.303955 / Loss  8.227645874023438
# fps: 9.533527444977077
# TIMESTEP 61803 / STATE explore / EPSILON 0.03835970199990582 / ACTION 1 / REWARD 0.1 / Q_MAX  18.835052 / Loss  0.7796193957328796
# fps: 9.823301130042742
# TIMESTEP 61804 / STATE explore / EPSILON 0.03835870299990582 / ACTION 1 / REWARD 0.1 / Q_MAX  19.718369 / Loss  1.8489524126052856
# fps: 9.904326512106772
# TIMESTEP 61805 / STATE explore / EPSILON 0.03835770399990582 / ACTION 1 / REWARD 0.1 / Q_MAX  22.388762 / Loss  0.39046913385391235
# fps: 12.133452518362304
# TIMESTEP 61806 / STATE explore / EPSILON 0.038356704999905816 / ACTION 0 / REWARD 0.1 / Q_MAX  20.645 / Loss  0.3606942296028137
# fps: 9.733302701410693
# TIMESTEP 61807 / STATE explore / EPSILON 0.038355705999905815 / ACTION 1 / REWARD 0.1 / Q_MAX  20.072851 / Loss  8.42579174041748
# fps: 10.35280411317653
# TIMESTEP 61808 / STATE explore / EPSILON 0.03835470699990581 / ACTION 1 / REWARD 0.1 / Q_MAX  19.241983 / Loss  0.6686559915542603
# fps: 12.292693792258568
# TIMESTEP 61809 / STATE explore / EPSILON 0.03835370799990581 / ACTION 0 / REWARD 0.1 / Q_MAX  19.000463 / Loss  0.8801663517951965
# fps: 11.470408545573383
# TIMESTEP 61810 / STATE explore / EPSILON 0.03835270899990581 / ACTION 0 / REWARD 0.1 / Q_MAX  19.737207 / Loss  1.3599772453308105
# fps: 12.526480206668957
# TIMESTEP 61811 / STATE explore / EPSILON 0.03835170999990581 / ACTION 0 / REWARD 0.1 / Q_MAX  29.055788 / Loss  0.7968419194221497
# fps: 11.47342074093121
# TIMESTEP 61812 / STATE explore / EPSILON 0.03835071099990581 / ACTION 0 / REWARD 0.1 / Q_MAX  18.411074 / Loss  4.1322431564331055
# fps: 11.900692879963229
# TIMESTEP 61813 / STATE explore / EPSILON 0.038349711999905806 / ACTION 0 / REWARD 0.1 / Q_MAX  20.251999 / Loss  1.3877969980239868
# fps: 12.606561910143428
