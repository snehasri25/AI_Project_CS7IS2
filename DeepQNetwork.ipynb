# %%
pip install selenium
pip install keras
# Out:
# Requirement already satisfied: selenium in c:\users\nic\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\nic\anaconda3\lib\site-packages (from selenium) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

import numpy as np
import pandas as pd
from PIL import Image
import cv2  #opencv
from IPython.display import clear_output
from random import randint
import io
from io import BytesIO
import time
import os

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.callbacks import TensorBoard
from keras.optimizers import SGD , Adam
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D


from collections import deque
import random
import pickle
import _pickle as cPickle
import base64
import json
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chromedriver_path = "./chrome_driver/chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chromedriver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class Dino_Agent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_state:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        game_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            game_over = True
        return image, reward, game_over #return the Experience tuple

# %%
def save_object(obj, name):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_object(name):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = img_process(screen)#processing image as required
    return image

def img_process(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100 # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH_SIZE = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_object(INITIAL_EPSILON,"epsilon")
    t = 0
    save_object(t,"time")
    D = deque()
    save_object(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def build_model():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate whether the model is to be trained(weight updates), else just play
'''
def train_Network(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_object("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_object("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_object("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH_SIZE)
            inputs = np.zeros((BATCH_SIZE, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_object(D,"D") #saving episodes
            save_object(t,"time") #caching time steps
            save_object(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX ", np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def play_Game(observe=False):
    game = Game()
    dino = Dino_Agent(game)
    game_state = Game_state(dino,game)    
    model = build_model()
    try:
        train_Network(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
play_Game(observe=False);
# Out:
# TIMESTEP 141000 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.779759 / Loss  0.05708666518330574
# fps: 0.15050824968721743
# TIMESTEP 141001 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.773938 / Loss  0.057238951325416565
# fps: 4.770238778980171
# TIMESTEP 141002 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1 / Q_MAX  8.844951 / Loss  0.21962100267410278
# fps: 5.4101412803588955
# TIMESTEP 141003 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.573895 / Loss  0.02473675273358822
# fps: 5.6268944450183325
# TIMESTEP 141004 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.900728 / Loss  0.03013724647462368
# fps: 5.433127759923418
# TIMESTEP 141005 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.862457 / Loss  0.030947571620345116
# fps: 5.171430227124492
# TIMESTEP 141006 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.386878 / Loss  0.049615226686000824
# fps: 5.374350037799674
# TIMESTEP 141007 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.783678 / Loss  0.11535754799842834
# fps: 5.9813954151663165
# TIMESTEP 141008 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.572689 / Loss  0.043682657182216644
# fps: 5.656276001947322
# TIMESTEP 141009 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.6738205 / Loss  0.28367137908935547
# fps: 5.482306009186184
# TIMESTEP 141010 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.324013 / Loss  0.29823386669158936
# fps: 6.137074814503751
# TIMESTEP 141011 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.709504 / Loss  0.1410524845123291
# fps: 5.752185713286531
# TIMESTEP 141012 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.866325 / Loss  1.7575408220291138
# fps: 5.547081975538533
# TIMESTEP 141013 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.326962 / Loss  0.02159884013235569
# fps: 6.359698747409073
# TIMESTEP 141014 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.562645 / Loss  0.018214000388979912
# fps: 6.372908138923583
# TIMESTEP 141015 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.715563 / Loss  0.02159440517425537
# fps: 5.760797278309849
# TIMESTEP 141016 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.563032 / Loss  0.016853179782629013
# fps: 6.466673758832444
# TIMESTEP 141017 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.726257 / Loss  0.022582625970244408
# fps: 6.132417874834053
# TIMESTEP 141018 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.895385 / Loss  0.012461531907320023
# fps: 5.464335872054697
# TIMESTEP 141019 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.744011 / Loss  0.03637353703379631
# fps: 6.330279604816338
# TIMESTEP 141020 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.566479 / Loss  0.017625506967306137
# fps: 6.311143612499191
# TIMESTEP 141021 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.30277 / Loss  0.13374336063861847
# fps: 5.748913761578548
# TIMESTEP 141022 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.628569 / Loss  0.037916235625743866
# fps: 6.320587588193986
# TIMESTEP 141023 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.409958 / Loss  0.027243008837103844
# fps: 5.73068289103884
# TIMESTEP 141024 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.669401 / Loss  0.03513728827238083
# fps: 5.542163771358049
# TIMESTEP 141025 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.688061 / Loss  0.028303461149334908
# fps: 6.370526980886766
# TIMESTEP 141026 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.554114 / Loss  0.07285220921039581
# fps: 5.420615196525061
# TIMESTEP 141027 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.502675 / Loss  0.07617319375276566
# fps: 5.614894858874746
# TIMESTEP 141028 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.750159 / Loss  0.019046630710363388
# fps: 5.451608458868945
# TIMESTEP 141029 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.68427 / Loss  0.07905171066522598
# fps: 6.188808423488028
# TIMESTEP 141030 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.915344 / Loss  0.06860668212175369
# fps: 5.51824744533134
# TIMESTEP 141031 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.669798 / Loss  2.369924783706665
# fps: 6.276248649522207
# TIMESTEP 141032 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.833321 / Loss  2.8951544761657715
# fps: 5.6677792401888585
# TIMESTEP 141033 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.407398 / Loss  0.275691419839859
# fps: 3.5729105440073328
# TIMESTEP 141034 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.572879 / Loss  0.032134875655174255
# fps: 5.788017161317209
# TIMESTEP 141035 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.179147 / Loss  0.03482919558882713
# fps: 6.395998597069094
# TIMESTEP 141036 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.016119 / Loss  1.0090744495391846
# fps: 6.053863063286718
# TIMESTEP 141037 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.449887 / Loss  0.031530797481536865
# fps: 6.284448839543908
# TIMESTEP 141038 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.513618 / Loss  0.07607422024011612
# fps: 6.355497167205344
# TIMESTEP 141039 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.367781 / Loss  0.04403219372034073
# fps: 5.275794362076404
# TIMESTEP 141040 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.5003605 / Loss  3.5989043712615967
# fps: 6.283620325454159
# TIMESTEP 141041 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.432088 / Loss  0.0351206474006176
# fps: 6.628009765887344
# TIMESTEP 141042 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.5822167 / Loss  0.07062889635562897
# fps: 5.3927235651624965
# TIMESTEP 141043 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.291732 / Loss  0.020991530269384384
# fps: 6.578082801928427
# TIMESTEP 141044 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.459404 / Loss  0.02285267971456051
# fps: 6.6388259278487585
# TIMESTEP 141045 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.284734 / Loss  0.019480161368846893
# fps: 6.050509582164263
# TIMESTEP 141046 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.280654 / Loss  0.05704078823328018
# fps: 6.2143821256861775
# TIMESTEP 141047 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.643559 / Loss  0.22940121591091156
# fps: 5.703168469230413
# TIMESTEP 141048 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.1539955 / Loss  0.048565078526735306
# fps: 5.293131668780485
# TIMESTEP 141049 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.108139 / Loss  0.0187828429043293
# fps: 6.245557398677122
# TIMESTEP 141050 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.240479 / Loss  0.020487848669290543
# fps: 6.308988679540443
# TIMESTEP 141051 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.4195385 / Loss  0.034818731248378754
# fps: 5.988457991027959
# TIMESTEP 141052 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.248351 / Loss  0.013105610385537148
# fps: 5.74058907259389
# TIMESTEP 141053 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.268637 / Loss  0.07017039507627487
# fps: 6.2732166226695885
# TIMESTEP 141054 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.22485 / Loss  0.03275015950202942
# fps: 6.04309970968137
# TIMESTEP 141055 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.2606735 / Loss  0.029417406767606735
# fps: 6.570601431203238
# TIMESTEP 141056 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.398842 / Loss  2.642868995666504
# fps: 6.370672122507317
# TIMESTEP 141057 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.352949 / Loss  0.05949528515338898
# fps: 6.096699967876179
# TIMESTEP 141058 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.111229 / Loss  0.04740791767835617
# fps: 6.0263334846752
# TIMESTEP 141059 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.27669 / Loss  0.050774917006492615
# fps: 5.729344301259163
# TIMESTEP 141060 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.056616 / Loss  0.05846628174185753
# fps: 6.138008847809194
# TIMESTEP 141061 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.931604 / Loss  0.007998354732990265
# fps: 6.545234372317881
# TIMESTEP 141062 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.424967 / Loss  0.07304805517196655
# fps: 5.589871258362876
# TIMESTEP 141063 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.392857 / Loss  0.09460248053073883
# fps: 5.789343356057459
# TIMESTEP 141064 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.192879 / Loss  0.05779505521059036
# fps: 6.3041336126951295
# TIMESTEP 141065 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.17035 / Loss  0.022223226726055145
# fps: 5.228514655982687
# TIMESTEP 141066 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.428163 / Loss  0.03427970036864281
# fps: 5.6024598813337
# TIMESTEP 141067 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.593038 / Loss  0.24380208551883698
# fps: 6.718981428825449
# TIMESTEP 141068 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.094978 / Loss  0.0457388274371624
# fps: 6.015797135747223
# TIMESTEP 141069 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.28745 / Loss  0.05599997937679291
# fps: 3.573994386321302
# TIMESTEP 141070 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.0524435 / Loss  0.014035427011549473
# fps: 5.7445438321849185
# TIMESTEP 141071 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.282188 / Loss  0.014278562739491463
# fps: 5.771268486259487
# TIMESTEP 141072 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  7.953849 / Loss  0.012557552196085453
# fps: 5.438707460499614
# TIMESTEP 141073 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.262944 / Loss  0.12103287875652313
# fps: 6.527459564276188
# TIMESTEP 141074 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.160328 / Loss  0.028329793363809586
# fps: 6.394516421159833
# TIMESTEP 141075 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.661886 / Loss  0.04278678447008133
# fps: 6.0874974419559855
# TIMESTEP 141076 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.160511 / Loss  0.024026211351156235
# fps: 6.212531993553891
# TIMESTEP 141077 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.385087 / Loss  0.09931567311286926
# fps: 6.580632002397348
# TIMESTEP 141078 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.966305 / Loss  0.09430593252182007
# fps: 5.9491142220898405
# TIMESTEP 141079 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.508322 / Loss  0.30526599287986755
# fps: 6.514239742058531
# TIMESTEP 141080 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.501675 / Loss  0.042760856449604034
# fps: 6.543988516865853
# TIMESTEP 141081 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.631492 / Loss  0.01950347051024437
# fps: 5.417415586663326
# TIMESTEP 141082 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.586787 / Loss  0.037810228765010834
# fps: 6.755657493339862
# TIMESTEP 141083 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.708183 / Loss  0.015431633219122887
# fps: 6.2729820678102985
# TIMESTEP 141084 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.845927 / Loss  0.3254460096359253
# fps: 6.004025296958696
# TIMESTEP 141085 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.109621 / Loss  0.006421058904379606
# fps: 6.5029985425904675
# TIMESTEP 141086 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.73238 / Loss  0.01754559949040413
# fps: 6.445714847736018
# TIMESTEP 141087 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.492311 / Loss  0.08011563122272491
# fps: 5.941167721711737
# TIMESTEP 141088 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.642392 / Loss  0.054871816188097
# fps: 6.473330699328328
# TIMESTEP 141089 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.729431 / Loss  0.14072908461093903
# fps: 6.4372368851188435
# TIMESTEP 141090 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.916018 / Loss  0.019325627014040947
# fps: 5.523276010782381
# TIMESTEP 141091 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.777288 / Loss  0.056826282292604446
# fps: 6.541947156627257
# TIMESTEP 141092 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.78513 / Loss  0.03419274464249611
# fps: 6.425747701207536
# TIMESTEP 141093 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.036607 / Loss  0.5480638146400452
# fps: 6.285635501525587
# TIMESTEP 141094 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.211543 / Loss  0.014381536282598972
# fps: 6.5995805148684346
# TIMESTEP 141095 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.185016 / Loss  1.7600266933441162
# fps: 6.571805956188002
# TIMESTEP 141096 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.454433 / Loss  0.021875640377402306
# fps: 5.521414664520044
# TIMESTEP 141097 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.880127 / Loss  0.08781234174966812
# fps: 6.832093199025268
# TIMESTEP 141098 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.008921 / Loss  0.046724021434783936
# fps: 6.956558660403895
# TIMESTEP 141099 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.872358 / Loss  0.035011813044548035
# fps: 5.332085795356311
# TIMESTEP 141100 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.779857 / Loss  0.1167445033788681
# fps: 6.695951749218543
# TIMESTEP 141101 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.151074 / Loss  0.27747464179992676
# fps: 6.343731519587158
# TIMESTEP 141102 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.831643 / Loss  0.09246204793453217
# fps: 5.654080038392115
# TIMESTEP 141103 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.006934 / Loss  0.8612564206123352
# fps: 6.098641354922762
# TIMESTEP 141104 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.245378 / Loss  0.02985863760113716
# fps: 5.86540473113949
# TIMESTEP 141105 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.91457 / Loss  0.02243470773100853
# fps: 3.6037843007025754
# TIMESTEP 141106 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.110713 / Loss  0.0394652858376503
# fps: 5.638862038044099
# TIMESTEP 141107 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.02276 / Loss  0.07803230732679367
# fps: 5.722949629686229
# TIMESTEP 141108 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.029782 / Loss  0.996039092540741
# fps: 6.031515765072664
# TIMESTEP 141109 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.18749 / Loss  0.05689806118607521
# fps: 6.560088337371181
# TIMESTEP 141110 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.456681 / Loss  0.14079682528972626
# fps: 6.767309519852724
# TIMESTEP 141111 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.163726 / Loss  0.028468605130910873
# fps: 5.956853577687704
# TIMESTEP 141112 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.890834 / Loss  0.015185270458459854
# fps: 6.276323783358323
# TIMESTEP 141113 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.009891 / Loss  0.028906380757689476
# fps: 6.251459164267019
# TIMESTEP 141114 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.71022 / Loss  0.03355143591761589
# fps: 5.4901566557761585
# TIMESTEP 141115 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.980081 / Loss  0.04199264571070671
# fps: 6.27919900354508
# TIMESTEP 141116 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.218639 / Loss  0.0832759290933609
# fps: 6.46102561732674
# TIMESTEP 141117 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.53931 / Loss  0.03173830732703209
# fps: 6.067323020306845
# TIMESTEP 141118 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.210064 / Loss  0.43268561363220215
# fps: 6.470853955049801
# TIMESTEP 141119 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -2.0124 / Loss  3.4516208171844482
# fps: 6.483747748861871
# TIMESTEP 141120 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.39341 / Loss  0.019722262397408485
# fps: 6.015986964871994
# TIMESTEP 141121 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.351583 / Loss  0.013972032815217972
# fps: 6.710016781825075
# TIMESTEP 141122 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.215552 / Loss  1.1773922443389893
# fps: 5.600013885532476
# TIMESTEP 141123 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.551004 / Loss  0.044063009321689606
# fps: 6.127195090418515
# TIMESTEP 141124 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.716653 / Loss  0.044426947832107544
# fps: 6.4201314852940055
# TIMESTEP 141125 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.575623 / Loss  0.0677604228258133
# fps: 6.405375605137368
# TIMESTEP 141126 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.380922 / Loss  0.0695524588227272
# fps: 6.077397891466758
# TIMESTEP 141127 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.158792 / Loss  0.060831956565380096
# fps: 6.579032070848875
# TIMESTEP 141128 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.406269 / Loss  3.2983555793762207
# fps: 6.2474179508643575
# TIMESTEP 141129 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.140856 / Loss  0.08055587112903595
# fps: 6.211483154387264
# TIMESTEP 141130 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.349899 / Loss  2.8565561771392822
# fps: 5.835114996577649
# TIMESTEP 141131 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.805781 / Loss  0.07813112437725067
# fps: 5.899360878566927
# TIMESTEP 141132 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.308293 / Loss  0.15326187014579773
# fps: 5.883117629979563
# TIMESTEP 141133 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.773943 / Loss  0.04879329353570938
# fps: 6.467212192139685
# TIMESTEP 141134 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.703985 / Loss  0.2690114378929138
# fps: 6.499239950848605
# TIMESTEP 141135 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.487089 / Loss  0.05074862018227577
# fps: 5.885742912431714
# TIMESTEP 141136 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.527948 / Loss  0.03367122262716293
# fps: 5.947604185425881
# TIMESTEP 141137 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.651158 / Loss  0.08190834522247314
# fps: 5.667878807534462
# TIMESTEP 141138 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.62425 / Loss  0.05684814602136612
# fps: 5.643915468509261
# TIMESTEP 141139 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.979629 / Loss  0.038958922028541565
# fps: 6.718938375749498
# TIMESTEP 141140 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.631306 / Loss  0.03914273530244827
# fps: 4.983033489878427
# TIMESTEP 141141 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.138365 / Loss  0.05638522654771805
# fps: 3.6326523542107654
# TIMESTEP 141142 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.596384 / Loss  0.07395296543836594
# fps: 6.563404084851747
# TIMESTEP 141143 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.155663 / Loss  0.052136264741420746
# fps: 5.64991392385966
# TIMESTEP 141144 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.745105 / Loss  0.021691003814339638
# fps: 5.938492774224788
# TIMESTEP 141145 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.426496 / Loss  0.6176362633705139
# fps: 6.597774159804315
# TIMESTEP 141146 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.879214 / Loss  0.08932766318321228
# fps: 6.366108167425313
# TIMESTEP 141147 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.847831 / Loss  0.11563853919506073
# fps: 5.635869156266461
# TIMESTEP 141148 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  7.386753 / Loss  0.1397094577550888
# fps: 6.507458055227155
# TIMESTEP 141149 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.837507 / Loss  0.052100908011198044
# fps: 6.618753353321761
# TIMESTEP 141150 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.255842 / Loss  0.9027044177055359
# fps: 5.888411872558957
# TIMESTEP 141151 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.195065 / Loss  0.08263593912124634
# fps: 6.206556513452483
# TIMESTEP 141152 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.267143 / Loss  0.052812568843364716
# fps: 6.462279907063311
# TIMESTEP 141153 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.093024 / Loss  0.08009917289018631
# fps: 6.159687955261055
# TIMESTEP 141154 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.525334 / Loss  0.025825724005699158
# fps: 5.767641667571949
# TIMESTEP 141155 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.93681 / Loss  0.03670298308134079
# fps: 6.440924084300272
# TIMESTEP 141156 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.001217 / Loss  0.07207909226417542
# fps: 5.983682308615221
# TIMESTEP 141157 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.435913 / Loss  0.3897125720977783
# fps: 6.701011789027689
# TIMESTEP 141158 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.159275 / Loss  0.04439537599682808
# fps: 6.238850016659526
# TIMESTEP 141159 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.17977 / Loss  0.046315327286720276
# fps: 6.082394961578117
# TIMESTEP 141160 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.72526 / Loss  0.15130482614040375
# fps: 5.4152193560048545
# TIMESTEP 141161 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.278583 / Loss  0.042135871946811676
# fps: 6.370246392505707
# TIMESTEP 141162 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.30837 / Loss  0.2516959309577942
# fps: 5.915135104642635
# TIMESTEP 141163 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.235816 / Loss  0.14996561408042908
# fps: 6.728239876288924
# TIMESTEP 141164 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.449623 / Loss  1.1073863506317139
# fps: 5.700409084113674
# TIMESTEP 141165 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.161977 / Loss  0.05060965567827225
# fps: 5.949055155970537
# TIMESTEP 141166 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.245707 / Loss  0.12267879396677017
# fps: 6.439025588435771
# TIMESTEP 141167 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.389601 / Loss  0.021277818828821182
# fps: 6.146013659748872
# TIMESTEP 141168 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.421281 / Loss  0.06454955786466599
# fps: 5.686921976584162
# TIMESTEP 141169 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.126275 / Loss  0.02204343117773533
# fps: 6.514199272835707
# TIMESTEP 141170 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.31596 / Loss  0.09006281197071075
# fps: 5.839038535696437
# TIMESTEP 141171 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.599268 / Loss  0.07238361239433289
# fps: 5.760298843628973
# TIMESTEP 141172 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.202824 / Loss  1.5422463417053223
# fps: 6.6753840375347755
# TIMESTEP 141173 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.593826 / Loss  0.08157992362976074
# fps: 6.2793588152424356
# TIMESTEP 141174 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.045538 / Loss  0.2106626182794571
# fps: 5.911250292440518
# TIMESTEP 141175 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.62207 / Loss  0.012889988720417023
# fps: 5.848841960238008
# TIMESTEP 141176 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.792635 / Loss  0.0499141626060009
# fps: 5.383607500051342
# TIMESTEP 141177 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.872484 / Loss  0.39052459597587585
# fps: 3.4454238903195864
# TIMESTEP 141178 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.092984 / Loss  0.12608596682548523
# fps: 6.339388113526373
# TIMESTEP 141179 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.321842 / Loss  0.03174234926700592
# fps: 5.655116808663539
# TIMESTEP 141180 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.510789 / Loss  0.048072557896375656
# fps: 6.075232403526102
# TIMESTEP 141181 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.859528 / Loss  0.09328559041023254
# fps: 6.285079786556539
# TIMESTEP 141182 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.519946 / Loss  0.19677193462848663
# fps: 5.829681128157515
# TIMESTEP 141183 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.221181 / Loss  0.030440373346209526
# fps: 6.06751611521948
# TIMESTEP 141184 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.012716 / Loss  0.2196367084980011
# fps: 5.583627870321188
# TIMESTEP 141185 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.006199 / Loss  0.045978546142578125
# fps: 5.7793161224894725
# TIMESTEP 141186 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.81487 / Loss  0.017056114971637726
# fps: 5.446037626094419
# TIMESTEP 141187 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.744278 / Loss  0.082277312874794
# fps: 6.579764846146002
# TIMESTEP 141188 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.922646 / Loss  0.03176388889551163
# fps: 6.295636302504863
# TIMESTEP 141189 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.194093 / Loss  0.08550849556922913
# fps: 5.981685446618681
# TIMESTEP 141190 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.101274 / Loss  0.04490617662668228
# fps: 5.745905277520535
# TIMESTEP 141191 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.159378 / Loss  0.049737103283405304
# fps: 6.541457419664748
# TIMESTEP 141192 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.3011465 / Loss  0.2072640061378479
# fps: 5.332112909541172
# TIMESTEP 141193 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.266274 / Loss  0.04131586477160454
# fps: 6.463036698265554
# TIMESTEP 141194 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.100936 / Loss  2.481484889984131
# fps: 5.706326434267041
# TIMESTEP 141195 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1 / Q_MAX  9.330393 / Loss  0.05137837678194046
# fps: 5.973711308637896
# TIMESTEP 141196 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.889141 / Loss  0.02477443590760231
# fps: 6.73241937011337
# TIMESTEP 141197 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.112544 / Loss  0.06116010993719101
# fps: 6.262529376808521
# TIMESTEP 141198 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.540976 / Loss  0.05620978772640228
# fps: 5.897030187400616
# TIMESTEP 141199 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.907833 / Loss  0.16597598791122437
# fps: 6.532868350593663
# TIMESTEP 141200 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.146883 / Loss  0.0439310148358345
# fps: 6.418775623887623
# TIMESTEP 141201 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.582279 / Loss  0.02645700052380562
# fps: 6.0845037731633935
# TIMESTEP 141202 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.008266 / Loss  0.01787564903497696
# fps: 6.439905481199879
# TIMESTEP 141203 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.402884 / Loss  0.03485264256596565
# fps: 6.371688299061786
# TIMESTEP 141204 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.324828 / Loss  0.017608629539608955
# fps: 6.000666692418735
# TIMESTEP 141205 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.2114 / Loss  0.06312469393014908
# fps: 6.87091833307942
# TIMESTEP 141206 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.23271 / Loss  0.09844970703125
# fps: 6.168656553979922
# TIMESTEP 141207 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.155329 / Loss  0.04465804249048233
# fps: 5.965240839453639
# TIMESTEP 141208 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.380943 / Loss  0.01413467712700367
# fps: 6.402168703387683
# TIMESTEP 141209 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.289786 / Loss  0.03289779648184776
# fps: 6.934418776132382
# TIMESTEP 141210 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.437515 / Loss  0.0834336206316948
# fps: 5.998761432790566
# TIMESTEP 141211 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.386475 / Loss  0.06985879689455032
# fps: 6.599310536890682
# TIMESTEP 141212 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.658046 / Loss  0.019204506650567055
# fps: 5.639074312342278
# TIMESTEP 141213 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.402953 / Loss  1.1629782915115356
# fps: 3.6180374647624896
# TIMESTEP 141214 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.386319 / Loss  0.021198630332946777
# fps: 6.2793588152424356
# TIMESTEP 141215 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.319531 / Loss  0.02676745504140854
# fps: 6.363519678600309
# TIMESTEP 141216 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.070593 / Loss  0.022641386836767197
# fps: 6.056756678700361
# TIMESTEP 141217 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.287167 / Loss  0.05888248607516289
# fps: 6.338784534728551
# TIMESTEP 141218 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.56293 / Loss  0.23808759450912476
# fps: 6.543304519295421
# TIMESTEP 141219 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.071019 / Loss  0.1779755800962448
# fps: 5.961044258327305
# TIMESTEP 141220 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.011337 / Loss  0.02767462097108364
# fps: 6.409388753056235
# TIMESTEP 141221 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.237213 / Loss  0.03194185346364975
# fps: 6.516263844503447
# TIMESTEP 141222 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.10591 / Loss  0.04934478551149368
# fps: 5.406863408603689
# TIMESTEP 141223 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  2.294743 / Loss  0.02481716498732567
# fps: 6.46350480258768
# TIMESTEP 141224 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.859486 / Loss  0.02538975700736046
# fps: 6.319997106934918
# TIMESTEP 141225 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.798179 / Loss  0.031948961317539215
# fps: 6.042481588622403
# TIMESTEP 141226 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.19224 / Loss  0.036497414112091064
# fps: 6.184674502379172
# TIMESTEP 141227 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.194439 / Loss  0.055306363850831985
# fps: 6.5812721929236835
# TIMESTEP 141228 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.778094 / Loss  0.02245749905705452
# fps: 5.923714750167007
# TIMESTEP 141229 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  6.818025 / Loss  0.24136874079704285
# fps: 6.4124264244981575
# TIMESTEP 141230 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.233141 / Loss  0.0497187003493309
# fps: 6.424468189393196
# TIMESTEP 141231 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.92632 / Loss  0.04131501913070679
# fps: 5.41676492505027
# TIMESTEP 141232 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.119412 / Loss  0.03449637442827225
# fps: 6.666842571237377
# TIMESTEP 141233 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.310377 / Loss  0.04205205291509628
# fps: 5.747298869396139
# TIMESTEP 141234 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.760164 / Loss  0.7760359644889832
# fps: 6.059985754141918
# TIMESTEP 141235 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.495243 / Loss  0.02021806314587593
# fps: 6.753601579268558
# TIMESTEP 141236 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.318567 / Loss  0.19646182656288147
# fps: 6.2582870784840345
# TIMESTEP 141237 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.140667 / Loss  0.30391043424606323
# fps: 5.3712047965966905
# TIMESTEP 141238 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.251907 / Loss  0.030167900025844574
# fps: 6.865160281853819
# TIMESTEP 141239 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.768877 / Loss  0.1255999207496643
# fps: 6.181693844104088
# TIMESTEP 141240 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.133933 / Loss  0.11344214528799057
# fps: 5.98795357887779
# TIMESTEP 141241 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.307672 / Loss  0.03873759135603905
# fps: 6.445992217420438
# TIMESTEP 141242 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.360479 / Loss  0.049944259226322174
# fps: 6.137227473588716
# TIMESTEP 141243 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.1322365 / Loss  0.031708795577287674
# fps: 5.3759412662666834
# TIMESTEP 141244 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.785387 / Loss  0.19978193938732147
# fps: 6.645568436946936
# TIMESTEP 141245 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.491267 / Loss  0.06281489133834839
# fps: 5.795182637266375
# TIMESTEP 141246 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.229006 / Loss  0.03296099230647087
# fps: 5.699928790028429
# TIMESTEP 141247 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.446586 / Loss  0.21941237151622772
# fps: 6.5327869490794175
# TIMESTEP 141248 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.991646 / Loss  0.04854821413755417
# fps: 5.66175045288021
# TIMESTEP 141249 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.462894 / Loss  0.17464007437229156
# fps: 3.7160913521640633
# TIMESTEP 141250 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.379724 / Loss  0.06094498932361603
# fps: 5.70095919773718
# TIMESTEP 141251 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.51482 / Loss  0.049032099545001984
# fps: 6.437740783830992
# TIMESTEP 141252 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.5319805 / Loss  0.15542063117027283
# fps: 6.06623489697983
# TIMESTEP 141253 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.656577 / Loss  0.032271821051836014
# fps: 6.738054234674206
# TIMESTEP 141254 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.45691 / Loss  0.05240858718752861
# fps: 6.125915388457708
# TIMESTEP 141255 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.585663 / Loss  0.030075479298830032
# fps: 5.886337641341157
# TIMESTEP 141256 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  10.165976 / Loss  0.07404514402151108
# fps: 6.437533286572254
# TIMESTEP 141257 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.3745575 / Loss  0.05319477617740631
# fps: 6.336457521316389
# TIMESTEP 141258 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.425264 / Loss  0.1251356601715088
# fps: 5.567403977870045
# TIMESTEP 141259 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  10.162487 / Loss  0.04080970585346222
# fps: 5.750734557161093
# TIMESTEP 141260 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.722958 / Loss  0.1709648221731186
# fps: 6.536105704575098
# TIMESTEP 141261 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.881991 / Loss  0.1292220652103424
# fps: 5.955390345129187
# TIMESTEP 141262 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.84217 / Loss  0.03772801160812378
# fps: 6.60467269557878
# TIMESTEP 141263 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  10.175549 / Loss  0.04930572956800461
# fps: 5.647677268198099
# TIMESTEP 141264 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.883896 / Loss  0.13325272500514984
# fps: 5.4373819490447675
# TIMESTEP 141265 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.795172 / Loss  0.24659550189971924
# fps: 5.7473618725669
# TIMESTEP 141266 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.889849 / Loss  0.022943824529647827
# fps: 6.3743803134983
# TIMESTEP 141267 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.877652 / Loss  0.04171959310770035
# fps: 6.198787230300621
# TIMESTEP 141268 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.968964 / Loss  0.4555128514766693
# fps: 6.304654794812941
# TIMESTEP 141269 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  10.044371 / Loss  0.06144781783223152
# fps: 6.293850810233294
# TIMESTEP 141270 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.872808 / Loss  2.8614702224731445
# fps: 5.406605532023502
# TIMESTEP 141271 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.5653305 / Loss  0.07053844630718231
# fps: 6.33360614892107
# TIMESTEP 141272 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.229691 / Loss  0.046207256615161896
# fps: 6.578805046835689
# TIMESTEP 141273 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.454968 / Loss  0.06389028578996658
# fps: 5.996788790792436
# TIMESTEP 141274 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.8493 / Loss  0.14199602603912354
# fps: 6.431482231136299
# TIMESTEP 141275 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.93349 / Loss  0.027941495180130005
# fps: 6.476049309518515
# TIMESTEP 141276 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.75747 / Loss  1.9995735883712769
# fps: 5.976682084647852
# TIMESTEP 141277 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.137741 / Loss  3.5271081924438477
# fps: 6.552995895690866
# TIMESTEP 141278 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.882888 / Loss  0.05858390033245087
# fps: 5.863076200487575
# TIMESTEP 141279 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.407421 / Loss  0.04349382221698761
# fps: 5.8645518151667515
# TIMESTEP 141280 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.662667 / Loss  4.093082427978516
# fps: 6.656061750572881
# TIMESTEP 141281 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.330599 / Loss  0.019212104380130768
# fps: 6.287529437866053
# TIMESTEP 141282 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  10.014706 / Loss  0.02529299445450306
# fps: 5.571686089993345
# TIMESTEP 141283 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.32348 / Loss  0.16636256873607635
# fps: 6.280496533548957
# TIMESTEP 141284 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.654274 / Loss  0.1551520675420761
# fps: 5.420405040585475
# TIMESTEP 141285 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.342353 / Loss  0.018793033435940742
# fps: 3.526566303301397
# TIMESTEP 141286 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.316238 / Loss  0.33255502581596375
# fps: 6.436367598291739
# TIMESTEP 141287 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  4.8007994 / Loss  3.1579291820526123
# fps: 6.368408666117025
# TIMESTEP 141288 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.468815 / Loss  0.011536849662661552
# fps: 5.9371814162987455
# TIMESTEP 141289 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  6.9945517 / Loss  0.10055698454380035
# fps: 5.6205681266934855
# TIMESTEP 141290 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1 / Q_MAX  9.686122 / Loss  0.07541153579950333
# fps: 6.369578885024829
# TIMESTEP 141291 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.218407 / Loss  0.02997932955622673
# fps: 6.0846891361209074
# TIMESTEP 141292 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.561063 / Loss  0.1508442759513855
# fps: 6.5270735650893785
# TIMESTEP 141293 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.044733 / Loss  0.6430925726890564
# fps: 6.445714847736018
# TIMESTEP 141294 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.592925 / Loss  0.050610654056072235
# fps: 5.924375753911867
# TIMESTEP 141295 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.127393 / Loss  0.03093000128865242
# fps: 6.550375986818987
# TIMESTEP 141296 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.321989 / Loss  0.09549366682767868
# fps: 6.439974696449519
# TIMESTEP 141297 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.325134 / Loss  0.05343504250049591
# fps: 5.807813255089084
# TIMESTEP 141298 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.379698 / Loss  2.7405288219451904
# fps: 6.503008625087018
# TIMESTEP 141299 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.2179575 / Loss  0.6620033979415894
# fps: 6.360402765983259
# TIMESTEP 141300 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.1502075 / Loss  0.027362637221813202
# fps: 6.050492125842268
# TIMESTEP 141301 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.177542 / Loss  0.0282999649643898
# fps: 6.580539081866391
# TIMESTEP 141302 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.352546 / Loss  0.08125808835029602
# fps: 6.2209539291212685
# TIMESTEP 141303 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.39557 / Loss  0.09616786241531372
# fps: 5.866996410676768
# TIMESTEP 141304 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.987831 / Loss  0.03953917324542999
# fps: 6.453698759976428
# TIMESTEP 141305 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.18977 / Loss  0.02195790782570839
# fps: 6.415653426863946
# TIMESTEP 141306 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.07448 / Loss  0.01740589179098606
# fps: 6.065796247982553
# TIMESTEP 141307 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.252453 / Loss  0.06428245455026627
# fps: 6.71568946110258
# TIMESTEP 141308 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.449352 / Loss  0.6433559060096741
# fps: 6.084168383184891
# TIMESTEP 141309 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.186369 / Loss  0.031152470037341118
# fps: 5.920094398477881
# TIMESTEP 141310 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.209251 / Loss  0.07838644087314606
# fps: 6.662807580499118
# TIMESTEP 141311 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.186873 / Loss  0.10028364509344101
# fps: 6.172614650140838
# TIMESTEP 141312 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.451767 / Loss  0.05555557459592819
# fps: 5.9715765584912965
# TIMESTEP 141313 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.413985 / Loss  0.04190417379140854
# fps: 6.439233181908202
# TIMESTEP 141314 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.102554 / Loss  0.08816462755203247
# fps: 6.417862214170298
# TIMESTEP 141315 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.248124 / Loss  0.04340025782585144
# fps: 5.837990117614309
# TIMESTEP 141316 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.331051 / Loss  0.1624217927455902
# fps: 6.47944077549917
# TIMESTEP 141317 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.375068 / Loss  0.04427789896726608
# fps: 6.283695635889676
# TIMESTEP 141318 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.11438 / Loss  0.020550526678562164
# fps: 5.423432859172941
# TIMESTEP 141319 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  9.141363 / Loss  0.024917691946029663
# fps: 6.640465590505804
# TIMESTEP 141320 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.142928 / Loss  0.012549886479973793
# fps: 5.529961013568122
# TIMESTEP 141321 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.232156 / Loss  0.07906705141067505
# fps: 3.648277283769996
# TIMESTEP 141322 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.934914 / Loss  0.22953687608242035
# fps: 6.43645649184836
# TIMESTEP 141323 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.282076 / Loss  0.1243789941072464
# fps: 6.319473385253522
# TIMESTEP 141324 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.325886 / Loss  0.5486822128295898
# fps: 6.0320882686256345
# TIMESTEP 141325 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.882227 / Loss  0.5008670091629028
# fps: 6.373072756252953
# TIMESTEP 141326 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.313549 / Loss  0.05852971225976944
# fps: 6.503684223583993
# TIMESTEP 141327 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.753895 / Loss  0.028245141729712486
# fps: 5.953158820298317
# TIMESTEP 141328 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.323157 / Loss  0.03662436082959175
# fps: 5.616112817573919
# TIMESTEP 141329 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.939779 / Loss  0.07354116439819336
# fps: 5.914743057308494
# TIMESTEP 141330 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  10.046223 / Loss  0.10609970986843109
# fps: 5.406542809007158
# TIMESTEP 141331 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.823655 / Loss  0.30400654673576355
# fps: 6.2947670474669675
# TIMESTEP 141332 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.671683 / Loss  0.18097226321697235
# fps: 6.396652142814658
# TIMESTEP 141333 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.25359 / Loss  0.09041079133749008
# fps: 6.024645535492415
# TIMESTEP 141334 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.615445 / Loss  0.054412614554166794
# fps: 6.51414868701427
# TIMESTEP 141335 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.846603 / Loss  0.07054831087589264
# fps: 6.251133066156756
# TIMESTEP 141336 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.183532 / Loss  3.141942262649536
# fps: 6.0111328315342325
# TIMESTEP 141337 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.144124 / Loss  0.02842332422733307
# fps: 5.748779809182852
# TIMESTEP 141338 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.956347 / Loss  0.04133113473653793
# fps: 5.70881181205569
# TIMESTEP 141339 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.1766595 / Loss  0.37891891598701477
# fps: 5.98960392080701
# TIMESTEP 141340 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  9.390961 / Loss  0.01687794178724289
# fps: 6.303574622211201
# TIMESTEP 141341 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.517419 / Loss  0.020778095349669456
# fps: 6.265111207372996
# ...
# fps: 3.392129761799817
# TIMESTEP 141601 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8015347 / Loss  0.02805117517709732
# fps: 4.570068763980792
# TIMESTEP 141602 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  7.8709106 / Loss  0.01369530986994505
# fps: 5.1672444592280495
# TIMESTEP 141603 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.554301 / Loss  0.012433631345629692
# fps: 5.4910910428651105
# TIMESTEP 141604 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.057396 / Loss  0.03900546580553055
# fps: 6.602967499193187
# TIMESTEP 141605 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.60799 / Loss  0.06127031147480011
# fps: 4.821853807482413
# TIMESTEP 141606 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1 / Q_MAX  7.5381246 / Loss  0.013092104345560074
# fps: 5.287539883743065
# TIMESTEP 141607 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.545508 / Loss  0.17958593368530273
# fps: 6.536828948229698
# TIMESTEP 141608 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7521257 / Loss  0.023592974990606308
# fps: 5.276232383957089
# TIMESTEP 141609 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.4479723 / Loss  0.11172913014888763
# fps: 3.3119742010066284
# TIMESTEP 141610 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.6163435 / Loss  0.012992363423109055
# fps: 6.438561022972361
# TIMESTEP 141611 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  2.328387 / Loss  0.6555535197257996
# fps: 6.0589527756630925
# TIMESTEP 141612 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9010696 / Loss  0.07001570612192154
# fps: 5.783826867334641
# TIMESTEP 141613 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.425536 / Loss  0.08180239051580429
# fps: 6.382149535981059
# TIMESTEP 141614 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7810307 / Loss  1.6015368700027466
# fps: 5.930356587393604
# TIMESTEP 141615 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7315617 / Loss  0.021858621388673782
# fps: 5.904302057628231
# TIMESTEP 141616 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.966015 / Loss  0.7849485278129578
# fps: 6.0127270199019165
# TIMESTEP 141617 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.6184826 / Loss  0.1559237539768219
# fps: 6.138242400560802
# TIMESTEP 141618 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.764757 / Loss  0.005711618810892105
# fps: 5.802678944470423
# TIMESTEP 141619 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.902155 / Loss  0.012179632671177387
# fps: 6.5455203732892215
# TIMESTEP 141620 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.77592 / Loss  0.027253123000264168
# fps: 6.229713311371002
# TIMESTEP 141621 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.999464 / Loss  0.055305901914834976
# fps: 5.677853239350059
# TIMESTEP 141622 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.6970577 / Loss  0.04705914482474327
# fps: 6.392274960679843
# TIMESTEP 141623 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.666159 / Loss  0.03650077432394028
# fps: 6.0757428266815
# TIMESTEP 141624 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.61329 / Loss  0.03440965712070465
# fps: 5.730330569931198
# TIMESTEP 141625 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.4876776 / Loss  0.03488609939813614
# fps: 6.093511331162841
# TIMESTEP 141626 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7102966 / Loss  0.012137827463448048
# fps: 6.105645930228326
# TIMESTEP 141627 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8805356 / Loss  0.028571639209985733
# fps: 5.81307750624022
# TIMESTEP 141628 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.854283 / Loss  0.03742976114153862
# fps: 6.627957397048133
# TIMESTEP 141629 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  3.2527914 / Loss  0.6040189266204834
# fps: 6.159525131214516
# TIMESTEP 141630 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.932501 / Loss  0.01994708552956581
# fps: 5.614534083668432
# TIMESTEP 141631 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8339853 / Loss  0.009813977405428886
# fps: 6.068332515889517
# TIMESTEP 141632 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.029371 / Loss  0.050776004791259766
# fps: 5.440929846409299
# TIMESTEP 141633 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  7.817646 / Loss  0.036822035908699036
# fps: 5.7584087405046
# TIMESTEP 141634 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9031506 / Loss  0.04930359497666359
# fps: 6.611710738916256
# TIMESTEP 141635 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.000446 / Loss  0.00951734371483326
# fps: 4.865849640598245
# TIMESTEP 141636 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.122133 / Loss  0.007788093760609627
# fps: 4.514421638377337
# TIMESTEP 141637 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8747134 / Loss  0.01990937441587448
# fps: 4.106828551845687
# TIMESTEP 141638 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  7.955212 / Loss  0.030581535771489143
# fps: 5.101002005470349
# TIMESTEP 141639 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.060915 / Loss  0.011991182342171669
# fps: 5.339219542622189
# TIMESTEP 141640 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.130169 / Loss  0.007598563097417355
# fps: 5.3366041096761885
# TIMESTEP 141641 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD 0.1 / Q_MAX  8.219519 / Loss  0.024018727242946625
# fps: 4.961993928682126
# TIMESTEP 141642 / STATE train / EPSILON 0.0001 / ACTION 1 / REWARD -1 / Q_MAX  8.035843 / Loss  0.02076546847820282
# fps: 5.558586890690373
# TIMESTEP 141643 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.281604 / Loss  0.005144160706549883
# fps: 6.135046068018893
# TIMESTEP 141644 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.207061 / Loss  0.020147070288658142
# fps: 5.695602048312695
# TIMESTEP 141645 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.013847 / Loss  0.015203173272311687
# fps: 3.2275967997242043
# TIMESTEP 141646 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.438256 / Loss  0.15835195779800415
# fps: 5.903421174490173
# TIMESTEP 141647 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.13767 / Loss  0.015411674045026302
# fps: 6.229870614044859
# TIMESTEP 141648 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.214272 / Loss  0.023182164877653122
# fps: 5.870716430236057
# TIMESTEP 141649 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.229101 / Loss  0.015420456416904926
# fps: 6.227733827477253
# TIMESTEP 141650 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.1530075 / Loss  0.016826201230287552
# fps: 6.108776104968956
# TIMESTEP 141651 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.114611 / Loss  0.012093264609575272
# fps: 5.881558429903187
# TIMESTEP 141652 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.687232 / Loss  0.04392020404338837
# fps: 6.311181598084814
# TIMESTEP 141653 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.590376 / Loss  0.013556900434195995
# fps: 6.140012589480464
# TIMESTEP 141654 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.282647 / Loss  0.09622517228126526
# fps: 5.795623060320408
# TIMESTEP 141655 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.35904 / Loss  0.014043964445590973
# fps: 6.11400317193768
# TIMESTEP 141656 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.363358 / Loss  0.020607538521289825
# fps: 5.807636335943395
# TIMESTEP 141657 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.319724 / Loss  0.023299532011151314
# fps: 5.686043090955184
# TIMESTEP 141658 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.427517 / Loss  0.017255835235118866
# fps: 6.2348806925953895
# TIMESTEP 141659 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.373536 / Loss  0.02285659685730934
# fps: 6.3413529355735605
# TIMESTEP 141660 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.559012 / Loss  0.6969663500785828
# fps: 5.698914241225681
# TIMESTEP 141661 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.261205 / Loss  0.03426756337285042
# fps: 6.569654593412652
# TIMESTEP 141662 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.4495945 / Loss  0.9316498637199402
# fps: 6.355179383680161
# TIMESTEP 141663 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.271695 / Loss  0.0433770976960659
# fps: 4.814359847889193
# TIMESTEP 141664 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.58481 / Loss  0.015308205038309097
# fps: 5.438502951152972
# TIMESTEP 141665 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.063918 / Loss  0.02420017309486866
# fps: 5.2353541783685955
# TIMESTEP 141666 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.448562 / Loss  0.016011357307434082
# fps: 5.765683336540841
# TIMESTEP 141667 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.35736 / Loss  0.012860137969255447
# fps: 6.417174872935683
# TIMESTEP 141668 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.446988 / Loss  0.01763497292995453
# fps: 5.726262444229645
# TIMESTEP 141669 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.243887 / Loss  0.002997657749801874
# fps: 5.4727063011153385
# TIMESTEP 141670 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.321333 / Loss  0.02048279345035553
# fps: 5.91289196150273
# TIMESTEP 141671 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.667281 / Loss  0.032018885016441345
# fps: 5.4495897512521845
# TIMESTEP 141672 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.505144 / Loss  0.0149386553093791
# fps: 5.067861406332313
# TIMESTEP 141673 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.272626 / Loss  0.021853318437933922
# fps: 5.762625610362631
# TIMESTEP 141674 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.354644 / Loss  0.02314113825559616
# fps: 6.3324682304948
# TIMESTEP 141675 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7305264 / Loss  0.055375758558511734
# fps: 5.803088391758939
# TIMESTEP 141676 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.6099415 / Loss  0.017499588429927826
# fps: 6.214115123176939
# TIMESTEP 141677 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  6.6075945 / Loss  0.25225502252578735
# fps: 6.057631426920855
# TIMESTEP 141678 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.736232 / Loss  2.1404740810394287
# fps: 5.548806510974437
# TIMESTEP 141679 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.73526 / Loss  0.04699649661779404
# fps: 5.869886613318107
# TIMESTEP 141680 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.515219 / Loss  0.021290253847837448
# fps: 5.9474270805269205
# TIMESTEP 141681 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.47772 / Loss  0.030823372304439545
# fps: 3.3302108583683148
# TIMESTEP 141682 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.545285 / Loss  0.010290711186826229
# fps: 5.946035908958811
# TIMESTEP 141683 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.745501 / Loss  1.1501761674880981
# fps: 5.86527349715008
# TIMESTEP 141684 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.370429 / Loss  0.1473328322172165
# fps: 5.769601329360658
# TIMESTEP 141685 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.276542 / Loss  0.07067415118217468
# fps: 6.219256649555312
# TIMESTEP 141686 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.300643 / Loss  0.018172811716794968
# fps: 6.113780371727054
# TIMESTEP 141687 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.27041 / Loss  0.015632271766662598
# fps: 5.70284278480875
# TIMESTEP 141688 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.213423 / Loss  0.013201114721596241
# fps: 6.361164824731824
# TIMESTEP 141689 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.448755 / Loss  0.2850019037723541
# fps: 6.077036869611078
# TIMESTEP 141690 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.747656 / Loss  1.5679491758346558
# fps: 5.8138107501961365
# TIMESTEP 141691 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.282889 / Loss  0.13688628375530243
# fps: 6.224166535583803
# TIMESTEP 141692 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.617676 / Loss  0.549597978591919
# fps: 6.3869991198335905
# TIMESTEP 141693 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9135637 / Loss  0.03197987750172615
# fps: 5.876062454906521
# TIMESTEP 141694 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.1602125 / Loss  0.07136763632297516
# fps: 6.325305874386781
# TIMESTEP 141695 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.401446 / Loss  0.023290066048502922
# fps: 6.251943715716671
# TIMESTEP 141696 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.550465 / Loss  0.8476322889328003
# fps: 5.5101860111325545
# TIMESTEP 141697 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.455444 / Loss  0.07906923443078995
# fps: 5.6207262995814915
# TIMESTEP 141698 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.408301 / Loss  0.03615621477365494
# fps: 6.049270433557316
# TIMESTEP 141699 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.400517 / Loss  0.00790809839963913
# fps: 5.514380525156058
# TIMESTEP 141700 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.211463 / Loss  0.008219362236559391
# fps: 6.024463812746692
# TIMESTEP 141701 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.607653 / Loss  0.02598584070801735
# fps: 6.056415595367192
# TIMESTEP 141702 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.263635 / Loss  0.011322623118758202
# fps: 5.7177537427170035
# TIMESTEP 141703 / STATE train / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  8.590141 / Loss  0.08725704252719879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-72cb52f7ef17> in <module>
# ----> 1 play_Game(observe=False);
#
# <ipython-input-13-e511e924bf20> in play_Game(observe)
#       6     model = build_model()
#       7     try:
# ----> 8         train_Network(model,game_state,observe=observe)
#       9     except StopIteration:
#      10         game.end()
#
# <ipython-input-12-2bc1be09397c> in train_Network(model, game_state, observe)
#      67
#      68         #run the selected action and observed next state and reward
# ---> 69         x_t1, r_t, terminal = game_state.get_state(a_t)
#      70         print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
#      71         last_time = time.time()
#
# <ipython-input-5-999ca9103e92> in get_state(self, actions)
#      13             self._agent.jump()
#      14         image = grab_screen(self._game._driver)
# ---> 15         self._display.send(image) #display the image on screen
#      16         if self._agent.is_crashed():
#      17             scores_df.loc[len(loss_df)] = score # log the score when game is over
#
# <ipython-input-6-26eea7f0507e> in show_img(graphs)
#      29         imS = cv2.resize(screen, (800, 400))
#      30         cv2.imshow(window_title, screen)
# ---> 31         if (cv2.waitKey(1) & 0xFF == ord('q')):
#      32             cv2.destroyAllWindows()
#      33             break
#
# KeyboardInterrupt:
